# %% [markdown]
# ### MACHINE LEARNING MODELS FOR THE BANK MARKETING DATASET (K=2)

# %% [markdown]
# First of all, we will perform data curation and preparation. Next, we will apply the following Machine Learning models:
#
# - Linear Regression
# - k-Nearest Neighbors(k-NN)
# - Support Vector Machines (SVM)
# - Classification Trees
# - Random Forest
# - Ada Boosting
# - Gradient Boosting
# - Neural Networks(NN)

# %% [markdown]
# **Import the necessary libraries:**

# %% [markdown]
# We try to eliminate the warnings that come up when some cells are executed:

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.warn("ignore")
warnings.simplefilter('ignore')

# %% [markdown]
# Now we import the libraries needed for executing the models and visualize the plots:

# %%
from imblearn.over_sampling import SMOTE

# %%
# %matplotlib inline
import pandas as pd
import pandas_profiling as pp
import numpy as np

from sklearn.metrics import accuracy_score, classification_report, make_scorer, roc_curve, roc_auc_score, confusion_matrix, precision_score, recall_score, f1_score

from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

import matplotlib.pyplot as plt
import shap
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Load the dataset**

# %%
file_name = "bank_k_5-anonymized.csv"
df = pd.read_csv(file_name, sep=";")

# %% [markdown]
# **We check that we have loaded the dataset correctly by showing the first 5 rows of the dataset**

# %%
df.head()
# Out:
#         age          job marital          education  default  housing  \
# 0  [40, 60[       admin.  single  University Degree  unknown       no
# 1  [20, 40[       admin.  single  University Degree       no       no
# 2  [40, 60[       admin.  single        HIgh School       no      yes
# 3  [40, 60[  blue-collar  single              Basic       no  unknown
# 4  [20, 40[       admin.  single            Unknown       no      yes
#
#       loan    contact month day_of_week  emp.var.rate  cons.price.idx  \
# 0       no   cellular   aug         tue           1.4          93.444
# 1       no   cellular   jul         mon           1.4          93.918
# 2      yes   cellular   may         mon          -1.8          92.893
# 3  unknown  telephone   jul         fri           1.4          93.918
# 4       no  telephone   nov         mon          -3.4          92.649
#
#    cons.conf.idx  euribor3m   y
# 0          -36.1      4.966  no
# 1          -42.7      4.960  no
# 2          -46.2      1.244  no
# 3          -42.7      4.962  no
# 4          -30.1      0.714  no

# %% [markdown]
# **We explore the original dataset**

# %%
print(df.head())
print(df.info())
print(df.describe())
print(df.shape)
# Out:
#         age          job marital          education  default  housing  \
# 0  [40, 60[       admin.  single  University Degree  unknown       no
# 1  [20, 40[       admin.  single  University Degree       no       no
# 2  [40, 60[       admin.  single        HIgh School       no      yes
# 3  [40, 60[  blue-collar  single              Basic       no  unknown
# 4  [20, 40[       admin.  single            Unknown       no      yes
#
#       loan    contact month day_of_week  emp.var.rate  cons.price.idx  \
# 0       no   cellular   aug         tue           1.4          93.444
# 1       no   cellular   jul         mon           1.4          93.918
# 2      yes   cellular   may         mon          -1.8          92.893
# 3  unknown  telephone   jul         fri           1.4          93.918
# 4       no  telephone   nov         mon          -3.4          92.649
#
#    cons.conf.idx  euribor3m   y
# 0          -36.1      4.966  no
# 1          -42.7      4.960  no
# 2          -46.2      1.244  no
# 3          -42.7      4.962  no
# 4          -30.1      0.714  no
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  object
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  emp.var.rate    41188 non-null  float64
#  11  cons.price.idx  41188 non-null  float64
#  12  cons.conf.idx   41188 non-null  float64
#  13  euribor3m       41188 non-null  float64
#  14  y               41188 non-null  object
# dtypes: float64(4), object(11)
# memory usage: 4.7+ MB
# None
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m
# count  41188.000000    41188.000000   41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291
# std        1.570960        0.578840       4.628198      1.734447
# min       -3.400000       92.201000     -50.800000      0.634000
# 25%       -1.800000       93.075000     -42.700000      1.344000
# 50%        1.100000       93.749000     -41.800000      4.857000
# 75%        1.400000       93.994000     -36.400000      4.961000
# max        1.400000       94.767000     -26.900000      5.045000
# (41188, 15)

# %% [markdown]
# **We check if there is any null value to remove it if exists:**

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# y                 0
# dtype: int64

# %% [markdown]
# **Delete anonymized records**:

# %%
q_i=["age","job","marital","education","default","housing","loan"]
a_s = ["y"]

def delete_rows(file_name, quasi_ident, fillna=True):
    """Delete the rows of the given file in which all QIs are set to *."""
    df = pd.read_csv(file_name, sep = ";")
    df_qi = df[quasi_ident]
    tmp = df_qi[df_qi == ["*"] * len(quasi_ident)]
    tmp.dropna(inplace=True)
    df_new=df.drop(tmp.index.values, axis = 0).reset_index()
    print(df_new)
    return df_new

# %%
df = delete_rows(file_name,q_i)
# Out:
#        index       age            job   marital          education  default  \
# 0          0  [40, 60[         admin.    single  University Degree  unknown
# 1          1  [20, 40[         admin.    single  University Degree       no
# 2          2  [40, 60[         admin.    single        HIgh School       no
# 3          3  [40, 60[    blue-collar    single              Basic       no
# 4          4  [20, 40[         admin.    single            Unknown       no
# ...      ...       ...            ...       ...                ...      ...
# 38505  41182  [40, 60[    blue-collar   married              Basic       no
# 38506  41183  [40, 60[         admin.  divorced        HIgh School  unknown
# 38507  41184  [20, 40[  self-employed    single  University Degree       no
# 38508  41186  [20, 40[         admin.    single  University Degree       no
# 38509  41187  [20, 40[     technician   married              Basic       no
#
#        housing     loan    contact month day_of_week  emp.var.rate  \
# 0           no       no   cellular   aug         tue           1.4
# 1           no       no   cellular   jul         mon           1.4
# 2          yes      yes   cellular   may         mon          -1.8
# 3      unknown  unknown  telephone   jul         fri           1.4
# 4          yes       no  telephone   nov         mon          -3.4
# ...        ...      ...        ...   ...         ...           ...
# 38505      yes       no   cellular   may         thu          -1.8
# 38506       no       no   cellular   aug         wed           1.4
# 38507      yes       no  telephone   may         tue           1.1
# 38508       no       no   cellular   may         fri          -1.8
# 38509      yes       no   cellular   apr         mon          -1.8
#
#        cons.price.idx  cons.conf.idx  euribor3m    y
# 0              93.444          -36.1      4.966   no
# 1              93.918          -42.7      4.960   no
# 2              92.893          -46.2      1.244   no
# 3              93.918          -42.7      4.962   no
# 4              92.649          -30.1      0.714   no
# ...               ...            ...        ...  ...
# 38505          92.893          -46.2      1.270   no
# 38506          93.444          -36.1      4.967   no
# 38507          93.994          -36.4      4.857   no
# 38508          92.893          -46.2      1.313   no
# 38509          93.075          -47.1      1.405  yes
#
# [38510 rows x 16 columns]

# %% [markdown]
# **Convert categorical to factors and store in a dictionary all the mapping:**
#
# We discretise the variables in order to better manage the data in the dataset.

# %%
df["job"] = df["job"].astype("category").cat.codes
df["marital"] = df["marital"].astype("category").cat.codes
df["education"] = df["education"].astype("category").cat.codes
df["default"] = df["default"].astype("category").cat.codes
df["housing"] = df["housing"].astype("category").cat.codes
df["loan"] = df["loan"].astype("category").cat.codes
df["contact"] = df["contact"].astype("category").cat.codes
df["month"] = df["month"].astype("category").cat.codes
df["day_of_week"] = df["day_of_week"].astype("category").cat.codes
df["y"] = df["y"].astype("category").cat.codes
df["age"] = df["age"].astype("category").cat.codes

# %% [markdown]
# We inspect the dataset to make sure everything has work properly:

# %%
df = df.drop('index', axis=1)
df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        2    0        2          3        1        0     0        0      1
# 1        1    0        2          3        0        0     0        0      3
# 2        2    0        2          1        0        2     2        0      6
# 3        2    1        2          0        0        1     1        1      3
# 4        1    0        2          4        0        2     0        1      7
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 38505    2    1        1          0        0        2     0        0      6
# 38506    2    0        0          1        1        0     0        0      1
# 38507    1    6        2          3        0        2     0        1      6
# 38508    1    0        2          3        0        0     0        0      6
# 38509    1    9        1          0        0        2     0        0      0
#
#        day_of_week  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  y
# 0                3           1.4          93.444          -36.1      4.966  0
# 1                1           1.4          93.918          -42.7      4.960  0
# 2                1          -1.8          92.893          -46.2      1.244  0
# 3                0           1.4          93.918          -42.7      4.962  0
# 4                1          -3.4          92.649          -30.1      0.714  0
# ...            ...           ...             ...            ...        ... ..
# 38505            2          -1.8          92.893          -46.2      1.270  0
# 38506            4           1.4          93.444          -36.1      4.967  0
# 38507            3           1.1          93.994          -36.4      4.857  0
# 38508            0          -1.8          92.893          -46.2      1.313  0
# 38509            1          -1.8          93.075          -47.1      1.405  1
#
# [38510 rows x 15 columns]

# %% [markdown]
# Before starting we have to define a random state value in order to achieve reproducibility of the models:

# %%
random_seed = 14

# %% [markdown]
# **We divide the dataset in train and test**

# %%
X = df.drop(["y"], axis=1)
y = df["y"]

# We add stratify for making sure that the random split has 25% of 0's and 75% of 1's.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=random_seed, stratify=y)

# %% [markdown]
# **We check that the shapes of the splitted sets are correct as expected**

# %%
print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (28882, 14)
# X_test shape: (9628, 14)
# y_train: (28882,)
# y_test shape: (9628,)

# %% [markdown]
# **Finally we do the scaling in train and test separately**
#
# We scale variables separately in train and test because this way we avoid biases. In addition, we manage to maintain the relative scale, i.e., all characteristics have a similar scale.

# %%
scaler = MinMaxScaler()
scaler = scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# We check the new scaled values in the respectivew partitions created:

# %%
X_train
# Out:
# array([[0.5       , 0.90909091, 0.33333333, ..., 0.88230709, 0.37656904,
#         0.95941963],
#        [0.25      , 0.09090909, 0.66666667, ..., 0.34060795, 0.15481172,
#         0.1747903 ],
#        [0.5       , 0.45454545, 0.33333333, ..., 0.88230709, 0.37656904,
#         0.98050329],
#        ...,
#        [0.5       , 0.09090909, 0.33333333, ..., 0.48441154, 0.61506276,
#         0.98186352],
#        [0.25      , 0.72727273, 0.66666667, ..., 0.29696025, 0.41841004,
#         0.14191793],
#        [0.25      , 0.        , 0.66666667, ..., 0.48441154, 0.61506276,
#         0.98163682]])

# %%
X_test
# Out:
# array([[0.5       , 0.63636364, 0.33333333, ..., 0.69875292, 0.60251046,
#         0.95692587],
#        [0.5       , 0.09090909, 0.33333333, ..., 0.69875292, 0.60251046,
#         0.95760599],
#        [0.25      , 0.        , 0.33333333, ..., 0.78487919, 0.43933054,
#         0.04670143],
#        ...,
#        [0.5       , 0.09090909, 0.33333333, ..., 0.48441154, 0.61506276,
#         0.98209023],
#        [0.25      , 0.09090909, 0.33333333, ..., 0.69875292, 0.60251046,
#         0.95737928],
#        [0.5       , 0.        , 0.        , ..., 0.26968044, 0.19246862,
#         0.15393335]])

# %% [markdown]
# **We start evaluating the proposed models:**

# %% [markdown]
# ### LOGISTIC REGRESSION:
# #### Linear regression method for binary classification problems

# %% [markdown]
#  We create and train the logistic regression model

# %%
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# We make the predictions on the test partition:

# %%
y_pred_lr = model_lr.predict(X_test)

# %% [markdown]
# We evaluate the model obtained:

# %%
accuracy_lr = accuracy_score(y_test, y_pred_lr)
report_lr = classification_report(y_test, y_pred_lr)
print("Accuracy:", accuracy_lr)
print("Classification Report:\n", report_lr)
# Out:
# Accuracy: 0.8903199002908184
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      8555
#            1       0.53      0.12      0.20      1073
#
#     accuracy                           0.89      9628
#    macro avg       0.72      0.56      0.57      9628
# weighted avg       0.86      0.89      0.86      9628

# %% [markdown]
# We illustrate the results obtained by drawaing the ROC curve and the confusion matrix:

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_lr = model_lr.predict_proba(X_test)[:, 1]
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_pred_prob_lr)
auc_lr = roc_auc_score(y_test, y_pred_prob_lr)

# Plot ROC curve
plt.plot(fpr_lr, tpr_lr, label='ROC curve (AUC = {:.2f})'.format(auc_lr))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_lr = model_lr.predict(X_test)
cm_lr = confusion_matrix(y_test, y_pred_lr)

# Visualize confusion matrix
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
fig_lr = plt.gcf()  # Obtener la figura actual
plt.show()

# %% [markdown]
# ### KNN (K k nearest neighbours)

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_knn = {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'algorithm': ['ball_tree', 'kd_tree', 'brute']}

# %% [markdown]
# We create the classifier

# %%
knn = KNeighborsClassifier()

# %% [markdown]
# We create the GridSearch object

# %%
# refit true, to retrain with all data
grid_search_knn = GridSearchCV(knn, param_grid_knn, cv=3, refit=True, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_knn.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
print("Best hyperparameters:", grid_search_knn.best_params_)
print("Accuracy score:", grid_search_knn.best_score_)
# Out:
# Best hyperparameters: {'algorithm': 'brute', 'n_neighbors': 11, 'weights': 'uniform'}
# Accuracy score: 0.8912125616042

# %% [markdown]
# Get the best model and its predictions

# %%
best_model_knn = grid_search_knn.best_estimator_
y_pred_knn = best_model_knn.predict(X_test)

# %% [markdown]
# Evaluate the best model over test partition

# %%
accuracy_knn = accuracy_score(y_test, y_pred_knn)
report_knn = classification_report(y_test, y_pred_knn)
print("Best Parameters:", grid_search_knn.best_params_)
print("Accuracy:", accuracy_knn)
print("Classification Report:\n", report_knn)
# Out:
# Best Parameters: {'algorithm': 'brute', 'n_neighbors': 11, 'weights': 'uniform'}
# Accuracy: 0.8893851267137516
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8555
#            1       0.51      0.20      0.29      1073
#
#     accuracy                           0.89      9628
#    macro avg       0.71      0.59      0.61      9628
# weighted avg       0.86      0.89      0.87      9628

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_knn = best_model_knn.predict_proba(X_test)[:, 1]
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test, y_pred_prob_knn)
auc_knn = roc_auc_score(y_test, y_pred_prob_knn)

# Plot ROC curve
plt.plot(fpr_knn, tpr_knn, label='ROC curve (AUC = {:.2f})'.format(auc_knn))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_knn = best_model_knn.predict(X_test)
cm_knn = confusion_matrix(y_test, y_pred_knn)

# Visualize confusion matrix
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### CLASSIFICATION TREES

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_ct = {'max_depth': [3, 5, 7, 9, None],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

# %% [markdown]
# We create the model classifier

# %%
model_ct = DecisionTreeClassifier(random_state=random_seed)

# %% [markdown]
# We create the GridSearch object

# %%
grid_search_ct = GridSearchCV(model_ct, param_grid_ct, cv=3, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_ct.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=14), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 9, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %% [markdown]
# We obtain and store the best model and the prediction

# %%
best_model_ct = grid_search_ct.best_estimator_
y_pred_ct = best_model_ct.predict(X_test)

# %% [markdown]
# Evaluate the best model

# %%
accuracy_ct = accuracy_score(y_test, y_pred_ct)
report_ct = classification_report(y_test, y_pred_ct)
print("Best Parameters:", grid_search_ct.best_params_)
print("Accuracy:", accuracy_ct)
print("Classification Report:\n", report_ct)
# Out:
# Best Parameters: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8919817199833818
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8555
#            1       0.54      0.22      0.31      1073
#
#     accuracy                           0.89      9628
#    macro avg       0.72      0.60      0.63      9628
# weighted avg       0.87      0.89      0.87      9628

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_ct = best_model_ct.predict_proba(X_test)[:, 1]
fpr_ct, tpr_ct, thresholds_ct = roc_curve(y_test, y_pred_prob_ct)
auc_ct = roc_auc_score(y_test, y_pred_prob_ct)

# Plot ROC curve
plt.plot(fpr_ct, tpr_ct, label='ROC curve (AUC = {:.2f})'.format(auc_ct))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_ct = best_model_ct.predict(X_test)
cm_ct = confusion_matrix(y_test, y_pred_ct)

# Visualize confusion matrix
sns.heatmap(cm_ct, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### RANDOM FOREST

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_rf = {"n_estimators": [50, 100, 200],
              "max_depth": [None, 5, 10],
              "min_samples_split": [2, 5, 10],
              "min_samples_leaf": [1, 2, 4]}

# %% [markdown]
# We create the classifier

# %%
rfc = RandomForestClassifier(random_state=random_seed)

# %% [markdown]
# We create the GridSearch object

# %%
grid_search_rf = GridSearchCV(rfc, param_grid_rf, cv=3, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=14), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
print("Best hyperparameters:", grid_search_rf.best_params_)
print("Accuracy score:", grid_search_rf.best_score_)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Accuracy score: 0.8961983227681539

# %%
best_model_rf = grid_search_rf.best_estimator_
y_pred_rf = best_model_rf.predict(X_test)

# %%
accuracy_rf = accuracy_score(y_test, y_pred_rf)
report_rf = classification_report(y_test, y_pred_rf)
print("Best Parameters:", grid_search_rf.best_params_)
print("Accuracy:", accuracy_rf)
print("Classification Report:\n", report_rf)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Accuracy: 0.8941628583298712
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8555
#            1       0.56      0.22      0.32      1073
#
#     accuracy                           0.89      9628
#    macro avg       0.74      0.60      0.63      9628
# weighted avg       0.87      0.89      0.87      9628

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_rf = best_model_rf.predict_proba(X_test)[:, 1]
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_prob_rf)
auc_rf = roc_auc_score(y_test, y_pred_prob_rf)

# Plot ROC curve
plt.plot(fpr_rf, tpr_rf, label='ROC curve (AUC = {:.2f})'.format(auc_rf))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_rf = best_model_rf.predict(X_test)
cm_rf = confusion_matrix(y_test, y_pred_rf)

# Visualize confusion matrix
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### SVM (Support Vector Machine)

# %%
param_grid_svm = {"C": [0.1, 0.25, 0.5, 0.75, 1, 2],
              "kernel": ["linear", "poly", "rbf", "sigmoid"],
              "gamma": ["scale", "auto"]}

# %%
svm = SVC()

# %%
grid_search_svm = GridSearchCV(svm, param_grid_svm, cv=3, n_jobs=-1)

# %%
grid_search_svm.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 0.25, 0.5, 0.75, 1, 2],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
print("Best hyperparameters:", grid_search_svm.best_params_)
print("Accuracy score:", grid_search_svm.best_score_)
# Out:
# Best hyperparameters: {'C': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy score: 0.8954019514513712

# %%
best_model_svm = grid_search_svm.best_estimator_
y_pred_svm = best_model_svm.predict(X_test)

# %%
accuracy_svm = accuracy_score(y_test, y_pred_svm)
report_svm = classification_report(y_test, y_pred_svm)
print("Best Parameters:", grid_search_svm.best_params_)
print("Accuracy:", accuracy_svm)
print("Classification Report:\n", report_svm)
# Out:
# Best Parameters: {'C': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy: 0.892085583714167
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      8555
#            1       0.56      0.16      0.25      1073
#
#     accuracy                           0.89      9628
#    macro avg       0.73      0.57      0.59      9628
# weighted avg       0.86      0.89      0.86      9628

# %%
# Generate decision scores
y_pred_scores_svm = best_model_svm.decision_function(X_test)

# Calculate FPR, TPR, and AUC
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, y_pred_scores_svm)
auc_svm = roc_auc_score(y_test, y_pred_scores_svm)

# Plot ROC curve
plt.plot(fpr_svm, tpr_svm, label='ROC curve (AUC = {:.2f})'.format(auc_svm))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_svm = best_model_svm.predict(X_test)
cm_svm = confusion_matrix(y_test, y_pred_svm)

# Visualize confusion matrix
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### NEURAL NETWORK:

# %% [markdown]
# We start creating the model function

# %%
def create_model_nn(hidden_units=128):
    model = Sequential()
    model.add(Dense(hidden_units, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Define the parameter grid
param_grid_nn = {
    'hidden_units': [64, 128, 256],
    'epochs': [10, 20, 30],
    'batch_size': [16, 32, 64]
}

# Create the model
model_nn = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn=create_model_nn)

# Perform grid search
grid_search_nn = GridSearchCV(model_nn, param_grid_nn, cv=3, n_jobs=-1)

# %%
grid_search_nn.fit(X_train, y_train)

# Get the best parameters
best_params_nn = grid_search_nn.best_params_
best_params_nn
# Out:
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2997 - accuracy: 0.8915
#  858/1204 [====================>.........] - ETA: 2s - loss: 0.3059 - accuracy: 0.8898Epoch 2/20
# 1204/1204 [==============================] - 8s 5ms/step - loss: 0.3024 - accuracy: 0.8876
#  836/1204 [===================>..........] - ETA: 2s - loss: 0.3091 - accuracy: 0.8891Epoch 2/20
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.3036 - accuracy: 0.8888
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.3006 - accuracy: 0.8906
# Epoch 2/20
# 1164/1204 [============================>.] - ETA: 0s - loss: 0.2990 - accuracy: 0.8910Epoch 2/10
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.2987 - accuracy: 0.8911
# 1096/1204 [==========================>...] - ETA: 0s - loss: 0.3032 - accuracy: 0.8898Epoch 2/10
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.3041 - accuracy: 0.8886
# 1035/1204 [========================>.....] - ETA: 1s - loss: 0.3088 - accuracy: 0.8862Epoch 2/10
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.3031 - accuracy: 0.8887
# 1007/1204 [========================>.....] - ETA: 1s - loss: 0.3042 - accuracy: 0.8905Epoch 2/10
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.3005 - accuracy: 0.8888
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.2995 - accuracy: 0.8911
#   99/1204 [=>............................] - ETA: 6s - loss: 0.2929 - accuracy: 0.8971Epoch 2/10
# 1167/1204 [============================>.] - ETA: 0s - loss: 0.3017 - accuracy: 0.8900Epoch 2/10
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.3024 - accuracy: 0.8883
# 1095/1204 [==========================>...] - ETA: 0s - loss: 0.3048 - accuracy: 0.8903Epoch 2/20
# 1204/1204 [==============================] - 10s 7ms/step - loss: 0.3009 - accuracy: 0.8905
# 1108/1204 [==========================>...] - ETA: 0s - loss: 0.3048 - accuracy: 0.8902Epoch 2/10
# 1204/1204 [==============================] - 10s 7ms/step - loss: 0.3031 - accuracy: 0.8907
#  330/1204 [=======>......................] - ETA: 5s - loss: 0.2892 - accuracy: 0.8947Epoch 2/10
# 1204/1204 [==============================] - 10s 7ms/step - loss: 0.3027 - accuracy: 0.8905
#  121/1204 [==>...........................] - ETA: 5s - loss: 0.3060 - accuracy: 0.8833Epoch 2/20
# 1204/1204 [==============================] - 10s 7ms/step - loss: 0.3038 - accuracy: 0.8883
# Epoch 2/20
# 1204/1204 [==============================] - 11s 7ms/step - loss: 0.3018 - accuracy: 0.8904
#  101/1204 [=>............................] - ETA: 5s - loss: 0.3017 - accuracy: 0.8923Epoch 2/10
# 1204/1204 [==============================] - 11s 7ms/step - loss: 0.3009 - accuracy: 0.8898
#  323/1204 [=======>......................] - ETA: 5s - loss: 0.2978 - accuracy: 0.8903Epoch 2/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2887 - accuracy: 0.8939
#  937/1204 [======================>.......] - ETA: 1s - loss: 0.2888 - accuracy: 0.8925Epoch 3/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2885 - accuracy: 0.8944
# Epoch 3/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2912 - accuracy: 0.8928
# 1136/1204 [===========================>..] - ETA: 0s - loss: 0.2904 - accuracy: 0.8932Epoch 3/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2894 - accuracy: 0.8937
# Epoch 3/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2895 - accuracy: 0.8935
# 1111/1204 [==========================>...] - ETA: 0s - loss: 0.2906 - accuracy: 0.8938Epoch 3/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2919 - accuracy: 0.8932
#  989/1204 [=======================>......] - ETA: 1s - loss: 0.2858 - accuracy: 0.8935Epoch 3/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2910 - accuracy: 0.8922
#   67/1204 [>.............................] - ETA: 6s - loss: 0.2859 - accuracy: 0.8918Epoch 3/10
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2897 - accuracy: 0.8929
# 1062/1204 [=========================>....] - ETA: 0s - loss: 0.2885 - accuracy: 0.8938Epoch 3/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2890 - accuracy: 0.8944
#  197/1204 [===>..........................] - ETA: 6s - loss: 0.2900 - accuracy: 0.8912Epoch 3/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2897 - accuracy: 0.8939
# 1161/1204 [===========================>..] - ETA: 0s - loss: 0.2904 - accuracy: 0.8930Epoch 3/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2907 - accuracy: 0.8931
#   30/1204 [..............................] - ETA: 9s - loss: 0.2803 - accuracy: 0.8958Epoch 3/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2895 - accuracy: 0.8928
# 1187/1204 [============================>.] - ETA: 0s - loss: 0.2893 - accuracy: 0.8939Epoch 3/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2898 - accuracy: 0.8934
# 1078/1204 [=========================>....] - ETA: 0s - loss: 0.2892 - accuracy: 0.8937Epoch 3/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2883 - accuracy: 0.8933
#  389/1204 [========>.....................] - ETA: 4s - loss: 0.2840 - accuracy: 0.8959Epoch 3/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2879 - accuracy: 0.8935
# Epoch 3/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2899 - accuracy: 0.8936
#  319/1204 [======>.......................] - ETA: 4s - loss: 0.2880 - accuracy: 0.8958Epoch 3/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2893 - accuracy: 0.8928
# 1048/1204 [=========================>....] - ETA: 0s - loss: 0.2905 - accuracy: 0.8940Epoch 4/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2877 - accuracy: 0.8952
# Epoch 4/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2870 - accuracy: 0.8943
#  892/1204 [=====================>........] - ETA: 1s - loss: 0.2921 - accuracy: 0.8918Epoch 4/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2868 - accuracy: 0.8946
#  817/1204 [===================>..........] - ETA: 2s - loss: 0.2836 - accuracy: 0.8938Epoch 4/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2860 - accuracy: 0.8949
# 1194/1204 [============================>.] - ETA: 0s - loss: 0.2901 - accuracy: 0.8924Epoch 4/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2900 - accuracy: 0.8926
#  101/1204 [=>............................] - ETA: 5s - loss: 0.2463 - accuracy: 0.9121Epoch 4/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2894 - accuracy: 0.8931
# Epoch 4/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2862 - accuracy: 0.8956
#   90/1204 [=>............................] - ETA: 6s - loss: 0.2785 - accuracy: 0.8938Epoch 4/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2884 - accuracy: 0.8948
# 1018/1204 [========================>.....] - ETA: 1s - loss: 0.2893 - accuracy: 0.8938Epoch 4/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2890 - accuracy: 0.8927
#  200/1204 [===>..........................] - ETA: 5s - loss: 0.2593 - accuracy: 0.9059Epoch 4/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2896 - accuracy: 0.8933
# Epoch 4/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2872 - accuracy: 0.8932
# 1036/1204 [========================>.....] - ETA: 1s - loss: 0.2886 - accuracy: 0.8931Epoch 4/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2878 - accuracy: 0.8948
# Epoch 4/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2861 - accuracy: 0.8940
# Epoch 4/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2854 - accuracy: 0.8946
#    1/1204 [..............................] - ETA: 4s - loss: 0.2295 - accuracy: 0.8750Epoch 4/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2872 - accuracy: 0.8940
#  476/1204 [==========>...................] - ETA: 4s - loss: 0.2803 - accuracy: 0.8968Epoch 4/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2880 - accuracy: 0.8933
#  732/1204 [=================>............] - ETA: 2s - loss: 0.2857 - accuracy: 0.8939Epoch 5/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2859 - accuracy: 0.8949
#  962/1204 [======================>.......] - ETA: 1s - loss: 0.2923 - accuracy: 0.8905Epoch 5/10
# 1204/1204 [==============================] - 7s 5ms/step - loss: 0.2880 - accuracy: 0.8929
# Epoch 5/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2852 - accuracy: 0.8956
# 1096/1204 [==========================>...] - ETA: 0s - loss: 0.2869 - accuracy: 0.8951Epoch 5/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2856 - accuracy: 0.8943
# 1094/1204 [==========================>...] - ETA: 0s - loss: 0.2870 - accuracy: 0.8938Epoch 5/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2880 - accuracy: 0.8921
#  941/1204 [======================>.......] - ETA: 1s - loss: 0.2838 - accuracy: 0.8961Epoch 5/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2860 - accuracy: 0.8956
# 1090/1204 [==========================>...] - ETA: 0s - loss: 0.2889 - accuracy: 0.8923Epoch 5/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2871 - accuracy: 0.8941
#   12/1204 [..............................] - ETA: 19s - loss: 0.2945 - accuracy: 0.8906Epoch 5/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2850 - accuracy: 0.8952
# 1005/1204 [========================>.....] - ETA: 1s - loss: 0.2849 - accuracy: 0.8953Epoch 5/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2870 - accuracy: 0.8942
# Epoch 5/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2879 - accuracy: 0.8936
# Epoch 5/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2851 - accuracy: 0.8952
#   67/1204 [>.............................] - ETA: 6s - loss: 0.2723 - accuracy: 0.9104Epoch 5/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2857 - accuracy: 0.8948
#  186/1204 [===>..........................] - ETA: 6s - loss: 0.2909 - accuracy: 0.8921Epoch 5/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2851 - accuracy: 0.8953
# Epoch 5/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2868 - accuracy: 0.8939
#  306/1204 [======>.......................] - ETA: 6s - loss: 0.2894 - accuracy: 0.8936Epoch 5/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2862 - accuracy: 0.8957
# Epoch 5/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2870 - accuracy: 0.8927
#  562/1204 [=============>................] - ETA: 4s - loss: 0.2823 - accuracy: 0.8975Epoch 6/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2866 - accuracy: 0.8931
# Epoch 6/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2851 - accuracy: 0.8957
# Epoch 6/10
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2859 - accuracy: 0.8938
#   98/1204 [=>............................] - ETA: 7s - loss: 0.2770 - accuracy: 0.9018Epoch 6/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2835 - accuracy: 0.8971
#  218/1204 [====>.........................] - ETA: 5s - loss: 0.2902 - accuracy: 0.8945Epoch 6/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2850 - accuracy: 0.8956
# Epoch 6/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2842 - accuracy: 0.8959
# 1106/1204 [==========================>...] - ETA: 0s - loss: 0.2873 - accuracy: 0.8934Epoch 6/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2865 - accuracy: 0.8945
#  158/1204 [==>...........................] - ETA: 6s - loss: 0.2869 - accuracy: 0.8920Epoch 6/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2841 - accuracy: 0.8948
# Epoch 6/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2863 - accuracy: 0.8941
#   58/1204 [>.............................] - ETA: 5s - loss: 0.2673 - accuracy: 0.9019Epoch 6/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2849 - accuracy: 0.8952
# 1143/1204 [===========================>..] - ETA: 0s - loss: 0.2854 - accuracy: 0.8935Epoch 6/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2870 - accuracy: 0.8942
#  108/1204 [=>............................] - ETA: 7s - loss: 0.3114 - accuracy: 0.8860Epoch 6/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2844 - accuracy: 0.8943
#  106/1204 [=>............................] - ETA: 6s - loss: 0.3147 - accuracy: 0.8809Epoch 6/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2841 - accuracy: 0.8952
# Epoch 6/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2856 - accuracy: 0.8954
# Epoch 6/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2855 - accuracy: 0.8946
#  537/1204 [============>.................] - ETA: 3s - loss: 0.2803 - accuracy: 0.8964Epoch 6/10
# 1204/1204 [==============================] - 7s 5ms/step - loss: 0.2848 - accuracy: 0.8960
# Epoch 7/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2867 - accuracy: 0.8941
# Epoch 7/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2858 - accuracy: 0.8948
# Epoch 7/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2835 - accuracy: 0.8968
# 1184/1204 [============================>.] - ETA: 0s - loss: 0.2863 - accuracy: 0.8943Epoch 7/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2835 - accuracy: 0.8946
#   84/1204 [=>............................] - ETA: 10s - loss: 0.2873 - accuracy: 0.8988Epoch 7/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2862 - accuracy: 0.8945
#  824/1204 [===================>..........] - ETA: 2s - loss: 0.2937 - accuracy: 0.8908Epoch 7/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2832 - accuracy: 0.8972
#  827/1204 [===================>..........] - ETA: 2s - loss: 0.2942 - accuracy: 0.8906Epoch 7/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2841 - accuracy: 0.8948
#    6/1204 [..............................] - ETA: 29s - loss: 0.2297 - accuracy: 0.9375Epoch 7/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2845 - accuracy: 0.8956
# Epoch 7/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2864 - accuracy: 0.8951
# 1108/1204 [==========================>...] - ETA: 0s - loss: 0.2816 - accuracy: 0.8961Epoch 7/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2836 - accuracy: 0.8969
#  130/1204 [==>...........................] - ETA: 7s - loss: 0.2790 - accuracy: 0.8981Epoch 7/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2833 - accuracy: 0.8958
# Epoch 7/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2827 - accuracy: 0.8952
# Epoch 7/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2843 - accuracy: 0.8949
#  292/1204 [======>.......................] - ETA: 5s - loss: 0.2859 - accuracy: 0.8958Epoch 7/10
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2863 - accuracy: 0.8947
#  347/1204 [=======>......................] - ETA: 6s - loss: 0.2821 - accuracy: 0.8988Epoch 7/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2849 - accuracy: 0.8966
# Epoch 7/10
# 1204/1204 [==============================] - 7s 5ms/step - loss: 0.2840 - accuracy: 0.8947
#  566/1204 [=============>................] - ETA: 3s - loss: 0.2799 - accuracy: 0.8954Epoch 8/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2850 - accuracy: 0.8950
#  242/1204 [=====>........................] - ETA: 5s - loss: 0.2718 - accuracy: 0.9019Epoch 8/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2825 - accuracy: 0.8961
#  145/1204 [==>...........................] - ETA: 6s - loss: 0.2992 - accuracy: 0.8901Epoch 8/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2859 - accuracy: 0.8955
#  998/1204 [=======================>......] - ETA: 1s - loss: 0.2852 - accuracy: 0.8947Epoch 8/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2839 - accuracy: 0.8963
# Epoch 8/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2859 - accuracy: 0.8938
#  777/1204 [==================>...........] - ETA: 2s - loss: 0.2805 - accuracy: 0.8962Epoch 8/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2818 - accuracy: 0.8964
# Epoch 8/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2831 - accuracy: 0.8944
# Epoch 8/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2851 - accuracy: 0.8949
# Epoch 8/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2828 - accuracy: 0.8958
#  910/1204 [=====================>........] - ETA: 1s - loss: 0.2855 - accuracy: 0.8944Epoch 8/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2832 - accuracy: 0.8959
#  214/1204 [====>.........................] - ETA: 6s - loss: 0.2819 - accuracy: 0.8925Epoch 8/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2819 - accuracy: 0.8959
#  284/1204 [======>.......................] - ETA: 5s - loss: 0.2769 - accuracy: 0.8941Epoch 8/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2823 - accuracy: 0.8972
# Epoch 8/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2832 - accuracy: 0.8955
#  442/1204 [==========>...................] - ETA: 4s - loss: 0.2806 - accuracy: 0.8945Epoch 8/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2837 - accuracy: 0.8947
#  458/1204 [==========>...................] - ETA: 4s - loss: 0.2807 - accuracy: 0.8986Epoch 8/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2852 - accuracy: 0.8950
#  732/1204 [=================>............] - ETA: 2s - loss: 0.2917 - accuracy: 0.8934Epoch 8/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2825 - accuracy: 0.8964
#  442/1204 [==========>...................] - ETA: 4s - loss: 0.2820 - accuracy: 0.8945Epoch 9/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2852 - accuracy: 0.8946
# 1034/1204 [========================>.....] - ETA: 1s - loss: 0.2857 - accuracy: 0.8961Epoch 9/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2841 - accuracy: 0.8959
#  805/1204 [===================>..........] - ETA: 2s - loss: 0.2815 - accuracy: 0.8946Epoch 9/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2816 - accuracy: 0.8964
#  596/1204 [=============>................] - ETA: 4s - loss: 0.2978 - accuracy: 0.8885Epoch 9/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2831 - accuracy: 0.8969
# Epoch 9/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2845 - accuracy: 0.8943
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2818 - accuracy: 0.8970
# 1008/1204 [========================>.....] - ETA: 1s - loss: 0.2851 - accuracy: 0.8958Epoch 9/20
#  102/1204 [=>............................] - ETA: 7s - loss: 0.2826 - accuracy: 0.8971Epoch 9/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2831 - accuracy: 0.8963
# 1045/1204 [=========================>....] - ETA: 1s - loss: 0.2804 - accuracy: 0.8978Epoch 9/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2850 - accuracy: 0.8949
#  266/1204 [=====>........................] - ETA: 5s - loss: 0.2819 - accuracy: 0.8966Epoch 9/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2818 - accuracy: 0.8967
#  121/1204 [==>...........................] - ETA: 6s - loss: 0.2856 - accuracy: 0.8962Epoch 9/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2816 - accuracy: 0.8972
#  236/1204 [====>.........................] - ETA: 4s - loss: 0.2633 - accuracy: 0.9031Epoch 9/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2822 - accuracy: 0.8963
#  210/1204 [====>.........................] - ETA: 6s - loss: 0.2877 - accuracy: 0.8923Epoch 9/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2814 - accuracy: 0.8957
# Epoch 9/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2831 - accuracy: 0.8962
#   59/1204 [>.............................] - ETA: 7s - loss: 0.2819 - accuracy: 0.8994Epoch 9/10
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2830 - accuracy: 0.8955
# Epoch 9/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2844 - accuracy: 0.8948
#  631/1204 [==============>...............] - ETA: 3s - loss: 0.2773 - accuracy: 0.8986Epoch 9/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2816 - accuracy: 0.8964
# Epoch 10/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2838 - accuracy: 0.8956
#  999/1204 [=======================>......] - ETA: 1s - loss: 0.2769 - accuracy: 0.8984Epoch 10/10
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2838 - accuracy: 0.8952
# 1141/1204 [===========================>..] - ETA: 0s - loss: 0.2818 - accuracy: 0.8955Epoch 10/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2822 - accuracy: 0.8955
# Epoch 10/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2798 - accuracy: 0.8979
#  896/1204 [=====================>........] - ETA: 2s - loss: 0.2792 - accuracy: 0.8984Epoch 10/10
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2819 - accuracy: 0.8968
#  598/1204 [=============>................] - ETA: 4s - loss: 0.2783 - accuracy: 0.8971Epoch 10/20
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2813 - accuracy: 0.8965
# Epoch 10/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2839 - accuracy: 0.8938
#  905/1204 [=====================>........] - ETA: 2s - loss: 0.2780 - accuracy: 0.8981Epoch 10/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2838 - accuracy: 0.8953
# 1031/1204 [========================>.....] - ETA: 1s - loss: 0.2805 - accuracy: 0.8980Epoch 10/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2811 - accuracy: 0.8969
# Epoch 10/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2816 - accuracy: 0.8969
#  152/1204 [==>...........................] - ETA: 5s - loss: 0.2870 - accuracy: 0.8894Epoch 10/20
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2819 - accuracy: 0.8962
# 1113/1204 [==========================>...] - ETA: 0s - loss: 0.2810 - accuracy: 0.8975Epoch 10/10
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2804 - accuracy: 0.8968
#  500/1204 [===========>..................] - ETA: 4s - loss: 0.2881 - accuracy: 0.8939Epoch 10/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2821 - accuracy: 0.8970
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2816 - accuracy: 0.8960
# Epoch 10/10
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2816 - accuracy: 0.8962
# Epoch 10/10
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2833 - accuracy: 0.8950
#  414/1204 [=========>....................] - ETA: 4s - loss: 0.2732 - accuracy: 0.8993Epoch 10/10
# 1204/1204 [==============================] - 7s 5ms/step - loss: 0.2817 - accuracy: 0.8955
#  589/1204 [=============>................] - ETA: 3s - loss: 0.2826 - accuracy: 0.8964Epoch 11/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2831 - accuracy: 0.8961
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2842 - accuracy: 0.8952
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2801 - accuracy: 0.8979
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2835 - accuracy: 0.8951
#  949/1204 [======================>.......] - ETA: 1s - loss: 0.2791 - accuracy: 0.8967Epoch 11/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2809 - accuracy: 0.8957
#  865/1204 [====================>.........] - ETA: 2s - loss: 0.2809 - accuracy: 0.8973Epoch 11/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2805 - accuracy: 0.8977
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2827 - accuracy: 0.8953
# Epoch 11/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2802 - accuracy: 0.8971
# Epoch 11/20
# 1204/1204 [==============================] - 7s 5ms/step - loss: 0.2794 - accuracy: 0.8966
# Epoch 11/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2808 - accuracy: 0.8966
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2807 - accuracy: 0.8966
#  109/1204 [=>............................] - ETA: 4s - loss: 0.2677 - accuracy: 0.9008Epoch 11/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2808 - accuracy: 0.8967
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2811 - accuracy: 0.8969
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2877 - accuracy: 0.8943
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2923 - accuracy: 0.8910
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2816 - accuracy: 0.8956
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2891 - accuracy: 0.8943
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2811 - accuracy: 0.8963
# Epoch 12/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2794 - accuracy: 0.8967
# Epoch 12/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2796 - accuracy: 0.8974
# Epoch 12/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2818 - accuracy: 0.8957
# Epoch 12/20
# 1204/1204 [==============================] - 5s 5ms/step - loss: 0.2814 - accuracy: 0.8955
# Epoch 12/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2789 - accuracy: 0.8978
# Epoch 12/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2796 - accuracy: 0.8969
#  49/602 [=>............................] - ETA: 1s - loss: 0.2910 - accuracy: 0.8878Epoch 12/20
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2871 - accuracy: 0.8903
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2871 - accuracy: 0.8936
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2875 - accuracy: 0.8932
# 602/602 [==============================] - 2s 3ms/step - loss: 0.2880 - accuracy: 0.8932
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2804 - accuracy: 0.8969
#  953/1204 [======================>.......] - ETA: 1s - loss: 0.2816 - accuracy: 0.8955Epoch 13/20
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2926 - accuracy: 0.8896
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2869 - accuracy: 0.8939
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2815 - accuracy: 0.8961
# 1176/1204 [============================>.] - ETA: 0s - loss: 0.2793 - accuracy: 0.8971Epoch 13/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2803 - accuracy: 0.8959
# Epoch 13/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2790 - accuracy: 0.8973
# Epoch 13/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2787 - accuracy: 0.8974
# Epoch 13/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2775 - accuracy: 0.8970
# Epoch 13/20
# 1103/1204 [==========================>...] - ETA: 0s - loss: 0.2773 - accuracy: 0.8991Epoch 1/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2782 - accuracy: 0.8987
#  410/1204 [=========>....................] - ETA: 3s - loss: 0.2829 - accuracy: 0.8910Epoch 13/20
#  468/1204 [==========>...................] - ETA: 3s - loss: 0.2762 - accuracy: 0.8984Epoch 1/20
#  648/1204 [===============>..............] - ETA: 2s - loss: 0.2715 - accuracy: 0.8996Epoch 1/30
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2789 - accuracy: 0.8966
# Epoch 14/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2777 - accuracy: 0.8951
# Epoch 14/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2804 - accuracy: 0.8964
#   43/1204 [>.............................] - ETA: 4s - loss: 0.2995 - accuracy: 0.8881Epoch 14/20
# 1204/1204 [==============================] - 5s 4ms/step - loss: 0.2808 - accuracy: 0.8960
#  986/1204 [=======================>......] - ETA: 1s - loss: 0.2734 - accuracy: 0.8995Epoch 14/20
#  348/1204 [=======>......................] - ETA: 5s - loss: 0.3079 - accuracy: 0.8892Epoch 1/30
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2775 - accuracy: 0.8982
#  227/1204 [====>.........................] - ETA: 4s - loss: 0.2783 - accuracy: 0.8995Epoch 14/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2772 - accuracy: 0.8979
#  933/1204 [======================>.......] - ETA: 1s - loss: 0.2771 - accuracy: 0.8980Epoch 14/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2788 - accuracy: 0.8975
#  614/1204 [==============>...............] - ETA: 2s - loss: 0.2833 - accuracy: 0.8944Epoch 14/20
#  591/1204 [=============>................] - ETA: 3s - loss: 0.3166 - accuracy: 0.8855Epoch 1/30
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.2982 - accuracy: 0.8912
#    1/1204 [..............................] - ETA: 49:03 - loss: 0.7736 - accuracy: 0.1250Epoch 2/20
# 1180/1204 [============================>.] - ETA: 0s - loss: 0.2787 - accuracy: 0.8970Epoch 1/30
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2781 - accuracy: 0.8971
# Epoch 15/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2772 - accuracy: 0.8964
# Epoch 15/20
# 1076/1204 [=========================>....] - ETA: 0s - loss: 0.2787 - accuracy: 0.8979Epoch 1/30
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2800 - accuracy: 0.8964
# Epoch 15/20
# 1204/1204 [==============================] - 10s 6ms/step - loss: 0.3041 - accuracy: 0.8889
#  189/1204 [===>..........................] - ETA: 4s - loss: 0.2549 - accuracy: 0.9067Epoch 2/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2790 - accuracy: 0.8958
#  224/1204 [====>.........................] - ETA: 4s - loss: 0.2556 - accuracy: 0.9068Epoch 15/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2765 - accuracy: 0.8979
#  292/1204 [======>.......................] - ETA: 4s - loss: 0.3383 - accuracy: 0.8780Epoch 15/20
#  792/1204 [==================>...........] - ETA: 2s - loss: 0.3158 - accuracy: 0.8865Epoch 1/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2762 - accuracy: 0.8985
# Epoch 15/20
# 1204/1204 [==============================] - 11s 7ms/step - loss: 0.3043 - accuracy: 0.8888
# 1019/1204 [========================>.....] - ETA: 1s - loss: 0.3072 - accuracy: 0.8892Epoch 2/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2776 - accuracy: 0.8984
# Epoch 1/30
#  551/1204 [============>.................] - ETA: 3s - loss: 0.2737 - accuracy: 0.8989Epoch 15/20
# 1204/1204 [==============================] - 10s 6ms/step - loss: 0.3058 - accuracy: 0.8892
#   82/1204 [=>............................] - ETA: 9s - loss: 0.2749 - accuracy: 0.9017 Epoch 2/30
# 1204/1204 [==============================] - 9s 6ms/step - loss: 0.3089 - accuracy: 0.8864
#  264/1204 [=====>........................] - ETA: 6s - loss: 0.2800 - accuracy: 0.8942Epoch 2/30
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2775 - accuracy: 0.8971
#  552/1204 [============>.................] - ETA: 4s - loss: 0.3073 - accuracy: 0.8888Epoch 16/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2896 - accuracy: 0.8944
#  600/1204 [=============>................] - ETA: 4s - loss: 0.3077 - accuracy: 0.8881Epoch 3/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2776 - accuracy: 0.8983
#   82/1204 [=>............................] - ETA: 6s - loss: 0.2898 - accuracy: 0.8849Epoch 16/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2765 - accuracy: 0.8977
# Epoch 16/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2765 - accuracy: 0.8980
#  131/1204 [==>...........................] - ETA: 7s - loss: 0.2706 - accuracy: 0.9008Epoch 16/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2779 - accuracy: 0.8969
#  189/1204 [===>..........................] - ETA: 7s - loss: 0.2961 - accuracy: 0.8862Epoch 16/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2908 - accuracy: 0.8933
#  188/1204 [===>..........................] - ETA: 4s - loss: 0.2811 - accuracy: 0.9019Epoch 3/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2754 - accuracy: 0.8985
#  471/1204 [==========>...................] - ETA: 4s - loss: 0.2642 - accuracy: 0.9046Epoch 16/20
# 1204/1204 [==============================] - 11s 7ms/step - loss: 0.3003 - accuracy: 0.8897
# 1091/1204 [==========================>...] - ETA: 0s - loss: 0.2997 - accuracy: 0.8922Epoch 2/30
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2890 - accuracy: 0.8918
# Epoch 3/30
# 1204/1204 [==============================] - 12s 7ms/step - loss: 0.2989 - accuracy: 0.8919
#  789/1204 [==================>...........] - ETA: 2s - loss: 0.2720 - accuracy: 0.8996Epoch 2/30
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2759 - accuracy: 0.9004
# Epoch 16/20
# 1204/1204 [==============================] - 10s 6ms/step - loss: 0.3017 - accuracy: 0.8884
#  911/1204 [=====================>........] - ETA: 1s - loss: 0.2908 - accuracy: 0.8942Epoch 2/30
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2904 - accuracy: 0.8934
#  922/1204 [=====================>........] - ETA: 1s - loss: 0.2883 - accuracy: 0.8934Epoch 3/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2746 - accuracy: 0.8973
#  386/1204 [========>.....................] - ETA: 6s - loss: 0.2764 - accuracy: 0.8994Epoch 17/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2769 - accuracy: 0.8974
# Epoch 17/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2918 - accuracy: 0.8935
#  412/1204 [=========>....................] - ETA: 6s - loss: 0.2735 - accuracy: 0.9011Epoch 3/30
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2781 - accuracy: 0.8976
# 1199/1204 [============================>.] - ETA: 0s - loss: 0.2741 - accuracy: 0.8982Epoch 17/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2741 - accuracy: 0.8984
# Epoch 17/20
# 1204/1204 [==============================] - 11s 6ms/step - loss: 0.2997 - accuracy: 0.8890
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2889 - accuracy: 0.8924
#  313/1204 [======>.......................] - ETA: 4s - loss: 0.2881 - accuracy: 0.8970Epoch 4/20
#   99/1204 [=>............................] - ETA: 4s - loss: 0.2880 - accuracy: 0.8914Epoch 2/30
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2865 - accuracy: 0.8946
#   72/1204 [>.............................] - ETA: 7s - loss: 0.2558 - accuracy: 0.9045Epoch 4/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2769 - accuracy: 0.8961
#  140/1204 [==>...........................] - ETA: 7s - loss: 0.2868 - accuracy: 0.8960Epoch 17/20
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2743 - accuracy: 0.8993
# Epoch 17/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2875 - accuracy: 0.8943
# 1006/1204 [========================>.....] - ETA: 1s - loss: 0.2761 - accuracy: 0.8992Epoch 4/30
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2880 - accuracy: 0.8934
#  831/1204 [===================>..........] - ETA: 2s - loss: 0.2731 - accuracy: 0.8981Epoch 3/30
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2890 - accuracy: 0.8935
#  703/1204 [================>.............] - ETA: 3s - loss: 0.2847 - accuracy: 0.8954Epoch 3/30
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2760 - accuracy: 0.8994
#  155/1204 [==>...........................] - ETA: 8s - loss: 0.2890 - accuracy: 0.8927Epoch 17/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2911 - accuracy: 0.8924
#  907/1204 [=====================>........] - ETA: 1s - loss: 0.2838 - accuracy: 0.8956Epoch 3/30
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2876 - accuracy: 0.8959
# 1062/1204 [=========================>....] - ETA: 0s - loss: 0.2726 - accuracy: 0.8977Epoch 4/30
# 1204/1204 [==============================] - 7s 5ms/step - loss: 0.2894 - accuracy: 0.8934
# Epoch 4/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2740 - accuracy: 0.8969
#  147/1204 [==>...........................] - ETA: 5s - loss: 0.2725 - accuracy: 0.8997Epoch 18/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2768 - accuracy: 0.8980
#  505/1204 [===========>..................] - ETA: 4s - loss: 0.2878 - accuracy: 0.8970Epoch 18/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2757 - accuracy: 0.8980
#  749/1204 [=================>............] - ETA: 2s - loss: 0.2733 - accuracy: 0.8972Epoch 18/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2891 - accuracy: 0.8930
#  235/1204 [====>.........................] - ETA: 7s - loss: 0.2678 - accuracy: 0.9024Epoch 3/30
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2862 - accuracy: 0.8947
# Epoch 5/20
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2741 - accuracy: 0.8999
#  443/1204 [==========>...................] - ETA: 5s - loss: 0.2726 - accuracy: 0.9014Epoch 18/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2758 - accuracy: 0.8974
# 1201/1204 [============================>.] - ETA: 0s - loss: 0.2888 - accuracy: 0.8937Epoch 18/20
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2887 - accuracy: 0.8937
#  192/1204 [===>..........................] - ETA: 5s - loss: 0.2845 - accuracy: 0.8968Epoch 5/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2727 - accuracy: 0.8998
# Epoch 18/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2867 - accuracy: 0.8950
# 1200/1204 [============================>.] - ETA: 0s - loss: 0.2868 - accuracy: 0.8949Epoch 4/30
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2870 - accuracy: 0.8947
# Epoch 4/30
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2855 - accuracy: 0.8955
# 1093/1204 [==========================>...] - ETA: 0s - loss: 0.2739 - accuracy: 0.8995Epoch 5/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2893 - accuracy: 0.8936
#  813/1204 [===================>..........] - ETA: 2s - loss: 0.2740 - accuracy: 0.8978Epoch 4/30
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2744 - accuracy: 0.8995
#  433/1204 [=========>....................] - ETA: 6s - loss: 0.2828 - accuracy: 0.8975Epoch 18/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2877 - accuracy: 0.8934
# 1194/1204 [============================>.] - ETA: 0s - loss: 0.2747 - accuracy: 0.8993Epoch 5/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2752 - accuracy: 0.8990
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2854 - accuracy: 0.8957
#  869/1204 [====================>.........] - ETA: 2s - loss: 0.2887 - accuracy: 0.8946Epoch 5/30
# Epoch 19/20
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2735 - accuracy: 0.8974
#  173/1204 [===>..........................] - ETA: 6s - loss: 0.2763 - accuracy: 0.8960Epoch 19/20
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2754 - accuracy: 0.8968
#  347/1204 [=======>......................] - ETA: 5s - loss: 0.2818 - accuracy: 0.8955Epoch 19/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2756 - accuracy: 0.8976
#  339/1204 [=======>......................] - ETA: 5s - loss: 0.2702 - accuracy: 0.8990Epoch 19/20
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2851 - accuracy: 0.8958
# Epoch 6/20
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2869 - accuracy: 0.8941
#  294/1204 [======>.......................] - ETA: 7s - loss: 0.2844 - accuracy: 0.8907Epoch 4/30
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2725 - accuracy: 0.8991
#  197/1204 [===>..........................] - ETA: 6s - loss: 0.2795 - accuracy: 0.8956Epoch 19/20
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2871 - accuracy: 0.8943
#  629/1204 [==============>...............] - ETA: 4s - loss: 0.2903 - accuracy: 0.8915Epoch 6/20
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2724 - accuracy: 0.8995
#  668/1204 [===============>..............] - ETA: 3s - loss: 0.2722 - accuracy: 0.8982Epoch 19/20
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2866 - accuracy: 0.8951
# 1063/1204 [=========================>....] - ETA: 0s - loss: 0.2887 - accuracy: 0.8935Epoch 5/30
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2873 - accuracy: 0.8940
#  944/1204 [======================>.......] - ETA: 2s - loss: 0.2865 - accuracy: 0.8937Epoch 5/30
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2852 - accuracy: 0.8942
#  949/1204 [======================>.......] - ETA: 2s - loss: 0.2862 - accuracy: 0.8938Epoch 5/30
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2838 - accuracy: 0.8947
#  635/1204 [==============>...............] - ETA: 4s - loss: 0.2796 - accuracy: 0.8989Epoch 6/30
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2868 - accuracy: 0.8949
# 1083/1204 [=========================>....] - ETA: 0s - loss: 0.2746 - accuracy: 0.9001Epoch 6/30
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2742 - accuracy: 0.8995
# Epoch 20/20
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2731 - accuracy: 0.9002
#  454/1204 [==========>...................] - ETA: 6s - loss: 0.2651 - accuracy: 0.9021Epoch 19/20
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2848 - accuracy: 0.8952
# Epoch 6/30
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2730 - accuracy: 0.8979
#  557/1204 [============>.................] - ETA: 5s - loss: 0.2690 - accuracy: 0.9000Epoch 20/20
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2753 - accuracy: 0.8974
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2846 - accuracy: 0.8938
# Epoch 7/20
#  313/1204 [======>.......................] - ETA: 7s - loss: 0.2664 - accuracy: 0.9014Epoch 20/20
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2745 - accuracy: 0.8969
#    1/1204 [..............................] - ETA: 19s - loss: 0.5385 - accuracy: 0.7500Epoch 20/20
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2846 - accuracy: 0.8953
#  525/1204 [============>.................] - ETA: 5s - loss: 0.2852 - accuracy: 0.8967Epoch 5/30
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2719 - accuracy: 0.9021
#  554/1204 [============>.................] - ETA: 5s - loss: 0.2893 - accuracy: 0.8920Epoch 20/20
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2859 - accuracy: 0.8955
#  122/1204 [==>...........................] - ETA: 9s - loss: 0.3049 - accuracy: 0.8873 Epoch 7/20
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2712 - accuracy: 0.9001
#  793/1204 [==================>...........] - ETA: 2s - loss: 0.2736 - accuracy: 0.8975Epoch 20/20
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2851 - accuracy: 0.8942
# Epoch 6/30
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2835 - accuracy: 0.8952
# 1171/1204 [============================>.] - ETA: 0s - loss: 0.2857 - accuracy: 0.8941Epoch 7/30
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2846 - accuracy: 0.8947
#  868/1204 [====================>.........] - ETA: 3s - loss: 0.2850 - accuracy: 0.8933Epoch 6/30
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2865 - accuracy: 0.8945
# Epoch 6/30
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2731 - accuracy: 0.8984
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2863 - accuracy: 0.8952
#  743/1204 [=================>............] - ETA: 4s - loss: 0.2912 - accuracy: 0.8930Epoch 7/30
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2715 - accuracy: 0.8992
# 1204/1204 [==============================] - 11s 9ms/step - loss: 0.2728 - accuracy: 0.8997
# Epoch 20/20
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2737 - accuracy: 0.8969
# 1204/1204 [==============================] - 11s 9ms/step - loss: 0.2842 - accuracy: 0.8950
# Epoch 7/30
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2737 - accuracy: 0.8980
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2844 - accuracy: 0.8957
# 304/602 [==============>...............] - ETA: 1s - loss: 0.2982 - accuracy: 0.8919Epoch 6/30
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2703 - accuracy: 0.9013
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2830 - accuracy: 0.8964
#  943/1204 [======================>.......] - ETA: 2s - loss: 0.2871 - accuracy: 0.8936Epoch 8/20
# 602/602 [==============================] - 4s 5ms/step - loss: 0.2922 - accuracy: 0.8927
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2699 - accuracy: 0.9012
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.2855 - accuracy: 0.8948
#  820/1204 [===================>..........] - ETA: 2s - loss: 0.2778 - accuracy: 0.8983Epoch 8/20
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2844 - accuracy: 0.8947
# Epoch 7/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2851 - accuracy: 0.8946
#   52/1204 [>.............................] - ETA: 7s - loss: 0.2563 - accuracy: 0.9002Epoch 7/30
# 602/602 [==============================] - 4s 5ms/step - loss: 0.2925 - accuracy: 0.8902
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2824 - accuracy: 0.8964
# Epoch 8/30
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2837 - accuracy: 0.8956
#  783/1204 [==================>...........] - ETA: 2s - loss: 0.2839 - accuracy: 0.8957Epoch 7/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2864 - accuracy: 0.8948
# Epoch 8/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2720 - accuracy: 0.9004
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2836 - accuracy: 0.8957
# Epoch 8/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2832 - accuracy: 0.8961
# Epoch 7/30
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2835 - accuracy: 0.8954
# 242/602 [===========>..................] - ETA: 1s - loss: 0.2824 - accuracy: 0.8980Epoch 9/20
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2845 - accuracy: 0.8942
# Epoch 9/20
# 602/602 [==============================] - 3s 4ms/step - loss: 0.2928 - accuracy: 0.8948
# 1204/1204 [==============================] - 6s 5ms/step - loss: 0.2835 - accuracy: 0.8954
# ...
# Epoch 19/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2766 - accuracy: 0.8977
# Epoch 22/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2748 - accuracy: 0.8998
# Epoch 19/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2741 - accuracy: 0.9002
# 285/301 [===========================>..] - ETA: 0s - loss: 0.2812 - accuracy: 0.8965Epoch 25/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2814 - accuracy: 0.8961
# 195/301 [==================>...........] - ETA: 0s - loss: 0.2819 - accuracy: 0.8965Epoch 12/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2795 - accuracy: 0.8965
#   1/301 [..............................] - ETA: 1s - loss: 0.2736 - accuracy: 0.8906Epoch 13/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2719 - accuracy: 0.9000
#  54/301 [====>.........................] - ETA: 1s - loss: 0.2738 - accuracy: 0.8981Epoch 26/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2738 - accuracy: 0.8989
# 259/301 [========================>.....] - ETA: 0s - loss: 0.2774 - accuracy: 0.8986Epoch 21/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2753 - accuracy: 0.8992
# 199/301 [==================>...........] - ETA: 0s - loss: 0.2749 - accuracy: 0.8974Epoch 18/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2775 - accuracy: 0.8969
# 224/301 [=====================>........] - ETA: 0s - loss: 0.2699 - accuracy: 0.9007Epoch 20/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2765 - accuracy: 0.8976
# Epoch 23/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2740 - accuracy: 0.9007
#  56/301 [====>.........................] - ETA: 0s - loss: 0.2734 - accuracy: 0.9001Epoch 26/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2732 - accuracy: 0.9001
# 230/301 [=====================>........] - ETA: 0s - loss: 0.2717 - accuracy: 0.9010Epoch 20/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2807 - accuracy: 0.8961
# Epoch 13/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2789 - accuracy: 0.8988
#  20/301 [>.............................] - ETA: 1s - loss: 0.2726 - accuracy: 0.9070Epoch 14/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2708 - accuracy: 0.9002
# Epoch 27/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2724 - accuracy: 0.8996
# Epoch 22/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2740 - accuracy: 0.9004
# Epoch 19/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2753 - accuracy: 0.8987
#  90/301 [=======>......................] - ETA: 0s - loss: 0.2730 - accuracy: 0.8993Epoch 24/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2763 - accuracy: 0.8987
# Epoch 21/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2733 - accuracy: 0.9001
# Epoch 21/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2736 - accuracy: 0.9000
# Epoch 27/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2805 - accuracy: 0.8974
# Epoch 14/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2777 - accuracy: 0.8979
# Epoch 15/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2712 - accuracy: 0.9009
# Epoch 28/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2718 - accuracy: 0.9002
# Epoch 23/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2733 - accuracy: 0.9006
# Epoch 20/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2745 - accuracy: 0.8971
# Epoch 25/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2767 - accuracy: 0.8971
# 268/301 [=========================>....] - ETA: 0s - loss: 0.2742 - accuracy: 0.8997Epoch 22/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2731 - accuracy: 0.9001
# Epoch 22/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2727 - accuracy: 0.9001
# Epoch 28/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2694 - accuracy: 0.9018
# Epoch 29/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2803 - accuracy: 0.8971
# 116/301 [==========>...................] - ETA: 1s - loss: 0.2643 - accuracy: 0.9054Epoch 15/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2766 - accuracy: 0.8978
# Epoch 16/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2738 - accuracy: 0.8981
# 248/301 [=======================>......] - ETA: 0s - loss: 0.2715 - accuracy: 0.9013Epoch 26/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2702 - accuracy: 0.8994
# 189/301 [=================>............] - ETA: 0s - loss: 0.2717 - accuracy: 0.9024Epoch 24/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2727 - accuracy: 0.9013
# Epoch 21/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2752 - accuracy: 0.8995
#  98/301 [========>.....................] - ETA: 1s - loss: 0.2715 - accuracy: 0.8965Epoch 23/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2722 - accuracy: 0.9016
#  63/301 [=====>........................] - ETA: 1s - loss: 0.2738 - accuracy: 0.8978Epoch 29/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2712 - accuracy: 0.9011
# Epoch 23/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2689 - accuracy: 0.9007
# Epoch 30/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2739 - accuracy: 0.8981
# Epoch 27/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2757 - accuracy: 0.8983
# Epoch 17/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2788 - accuracy: 0.8964
#  11/301 [>.............................] - ETA: 1s - loss: 0.2665 - accuracy: 0.8935Epoch 16/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2694 - accuracy: 0.9005
# Epoch 25/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2743 - accuracy: 0.8990
# 240/301 [======================>.......] - ETA: 0s - loss: 0.2726 - accuracy: 0.9009Epoch 24/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2716 - accuracy: 0.9013
# Epoch 22/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2704 - accuracy: 0.9001
# Epoch 24/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2710 - accuracy: 0.9018
# Epoch 30/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2684 - accuracy: 0.9001
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2744 - accuracy: 0.8987
# 272/301 [==========================>...] - ETA: 0s - loss: 0.2665 - accuracy: 0.9025Epoch 28/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2690 - accuracy: 0.9008
#  23/301 [=>............................] - ETA: 1s - loss: 0.2710 - accuracy: 0.8995Epoch 26/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2779 - accuracy: 0.8970
# Epoch 17/30
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2742 - accuracy: 0.8984
#  75/301 [======>.......................] - ETA: 0s - loss: 0.2688 - accuracy: 0.8988Epoch 18/30
# 151/151 [==============================] - 1s 2ms/step - loss: 0.2927 - accuracy: 0.8918
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2734 - accuracy: 0.8993
# 126/301 [===========>..................] - ETA: 0s - loss: 0.2624 - accuracy: 0.9014Epoch 25/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2693 - accuracy: 0.9010
# Epoch 23/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2710 - accuracy: 0.9012
# 301/301 [==============================] - 2s 6ms/step - loss: 0.2704 - accuracy: 0.9022
# 180/301 [================>.............] - ETA: 0s - loss: 0.2650 - accuracy: 0.9006Epoch 25/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2715 - accuracy: 0.9000
# Epoch 29/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2677 - accuracy: 0.9012
# 242/301 [=======================>......] - ETA: 0s - loss: 0.2741 - accuracy: 0.8996Epoch 27/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2772 - accuracy: 0.8972
# Epoch 18/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2728 - accuracy: 0.8998
# Epoch 19/30
# 151/151 [==============================] - 1s 4ms/step - loss: 0.2943 - accuracy: 0.8932
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2718 - accuracy: 0.8993
# Epoch 26/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2690 - accuracy: 0.9013
# Epoch 24/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2689 - accuracy: 0.9024
#  64/301 [=====>........................] - ETA: 0s - loss: 0.2633 - accuracy: 0.9053Epoch 26/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2723 - accuracy: 0.8988
# Epoch 30/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2765 - accuracy: 0.8982
# Epoch 19/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2659 - accuracy: 0.9036
# Epoch 28/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2725 - accuracy: 0.9001
# Epoch 20/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2705 - accuracy: 0.8996
# 234/301 [======================>.......] - ETA: 0s - loss: 0.2683 - accuracy: 0.9002Epoch 27/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2681 - accuracy: 0.9022
# Epoch 27/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2706 - accuracy: 0.8996
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2682 - accuracy: 0.9015
# Epoch 25/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2764 - accuracy: 0.8968
# Epoch 20/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2670 - accuracy: 0.9023
# Epoch 29/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2860 - accuracy: 0.8953
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2697 - accuracy: 0.9007
# Epoch 28/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2710 - accuracy: 0.9002
# 186/301 [=================>............] - ETA: 0s - loss: 0.2669 - accuracy: 0.9006Epoch 21/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2676 - accuracy: 0.9013
# 234/301 [======================>.......] - ETA: 0s - loss: 0.2693 - accuracy: 0.9002Epoch 28/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2670 - accuracy: 0.9020
# Epoch 26/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2744 - accuracy: 0.8976
# Epoch 21/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2651 - accuracy: 0.9025
# Epoch 30/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2694 - accuracy: 0.8992
# Epoch 29/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2658 - accuracy: 0.9025
# Epoch 29/30
# 301/301 [==============================] - 2s 5ms/step - loss: 0.2700 - accuracy: 0.9001
#  12/301 [>.............................] - ETA: 1s - loss: 0.2810 - accuracy: 0.8984Epoch 22/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2668 - accuracy: 0.9028
# Epoch 27/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2739 - accuracy: 0.8987
# 115/301 [==========>...................] - ETA: 0s - loss: 0.2741 - accuracy: 0.9004Epoch 22/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2633 - accuracy: 0.9039
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2688 - accuracy: 0.9010
# 164/301 [===============>..............] - ETA: 0s - loss: 0.2655 - accuracy: 0.9034Epoch 30/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2647 - accuracy: 0.9039
# Epoch 30/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2688 - accuracy: 0.9008
# Epoch 23/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2946 - accuracy: 0.8913
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2647 - accuracy: 0.9030
# Epoch 28/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2727 - accuracy: 0.8991
# 212/301 [====================>.........] - ETA: 0s - loss: 0.2628 - accuracy: 0.9041Epoch 23/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2685 - accuracy: 0.9012
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2652 - accuracy: 0.9040
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2679 - accuracy: 0.9014
# Epoch 24/30
# 151/151 [==============================] - 1s 2ms/step - loss: 0.2872 - accuracy: 0.8932
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2642 - accuracy: 0.9040
# Epoch 29/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2925 - accuracy: 0.8926
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2713 - accuracy: 0.8989
# Epoch 24/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2674 - accuracy: 0.9001
# Epoch 25/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2630 - accuracy: 0.9033
# Epoch 30/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2709 - accuracy: 0.9002
# Epoch 25/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2653 - accuracy: 0.9022
# 192/301 [==================>...........] - ETA: 0s - loss: 0.2671 - accuracy: 0.9016Epoch 26/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2701 - accuracy: 0.9002
# Epoch 26/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2631 - accuracy: 0.9030
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2648 - accuracy: 0.9016
# Epoch 27/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2681 - accuracy: 0.9015
# Epoch 27/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2638 - accuracy: 0.9026
# Epoch 28/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2681 - accuracy: 0.9014
# Epoch 28/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2621 - accuracy: 0.9027
# Epoch 29/30
# 301/301 [==============================] - 1s 5ms/step - loss: 0.2666 - accuracy: 0.9022
# Epoch 29/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2613 - accuracy: 0.9019
# Epoch 30/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2658 - accuracy: 0.9022
# Epoch 30/30
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2609 - accuracy: 0.9040
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2651 - accuracy: 0.9025
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2952 - accuracy: 0.8908
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2929 - accuracy: 0.8925
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2881 - accuracy: 0.8908
# Epoch 1/10
# 903/903 [==============================] - 6s 5ms/step - loss: 0.2995 - accuracy: 0.8894
# Epoch 2/10
# 903/903 [==============================] - 4s 5ms/step - loss: 0.2890 - accuracy: 0.8945
# Epoch 3/10
# 903/903 [==============================] - 4s 5ms/step - loss: 0.2873 - accuracy: 0.8951
# Epoch 4/10
# 903/903 [==============================] - 4s 5ms/step - loss: 0.2856 - accuracy: 0.8947
# Epoch 5/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2848 - accuracy: 0.8954
# Epoch 6/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2845 - accuracy: 0.8958
# Epoch 7/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2831 - accuracy: 0.8955
# Epoch 8/10
# 903/903 [==============================] - 4s 5ms/step - loss: 0.2826 - accuracy: 0.8959
# Epoch 9/10
# 903/903 [==============================] - 4s 5ms/step - loss: 0.2816 - accuracy: 0.8965
# Epoch 10/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2818 - accuracy: 0.8956
# {'batch_size': 32, 'epochs': 10, 'hidden_units': 256}

# %%
best_model_nn = create_model_nn(best_params_nn['hidden_units'])
best_model_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
best_model_nn.fit(X_train, y_train, epochs=best_params_nn['epochs'], batch_size=best_params_nn['batch_size'])
# Out:
# Epoch 1/10
# 903/903 [==============================] - 5s 4ms/step - loss: 0.3001 - accuracy: 0.8903
# Epoch 2/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2895 - accuracy: 0.8937
# Epoch 3/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2872 - accuracy: 0.8943
# Epoch 4/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2858 - accuracy: 0.8951
# Epoch 5/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2850 - accuracy: 0.8950
# Epoch 6/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2841 - accuracy: 0.8949
# Epoch 7/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2842 - accuracy: 0.8950
# Epoch 8/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2833 - accuracy: 0.8956
# Epoch 9/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2825 - accuracy: 0.8963
# Epoch 10/10
# 903/903 [==============================] - 4s 4ms/step - loss: 0.2824 - accuracy: 0.8957

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred_prob_nn = best_model_nn.predict(X_test)
y_pred_nn = (y_pred_prob_nn > 0.5).astype(int)

accuracy_nn = accuracy_score(y_test, y_pred_nn)
precision_nn = precision_score(y_test, y_pred_nn)
recall_nn = recall_score(y_test, y_pred_nn)
f1_nn = f1_score(y_test, y_pred_nn)

print('Accuracy: %.2f' % (accuracy_nn*100))
print('Precision: %.2f' % (precision_nn*100))
print('Recall: %.2f' % (recall_nn*100))
print('F1-score: %.2f' % (f1_nn*100))
# Out:
# 301/301 [==============================] - 1s 2ms/step
# Accuracy: 89.31
# Precision: 55.79
# Recall: 19.76
# F1-score: 29.18

# %%
print("Best Parameters: ", best_params_nn)

# Evaluate the model
print(f'Test Accuracy: {accuracy_nn*100:.2f}%')
# Out:
# Best Parameters:  {'batch_size': 32, 'epochs': 10, 'hidden_units': 256}
# Test Accuracy: 89.31%

# %%
y_pred_prob_nn = best_model_nn.predict(X_test)

# Generate ROC curve and calculate AUC
fpr_nn, tpr_nn, thresholds_nn = roc_curve(y_test, y_pred_prob_nn)
auc_nn = roc_auc_score(y_test, y_pred_prob_nn)

# Plot ROC curve
plt.plot(fpr_nn, tpr_nn, label='ROC curve (AUC = {:.2f})'.format(auc_nn))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Apply thresholds
umbral = 0.5
y_pred_discret_nn = np.where(y_pred_prob_nn >= umbral, 1, 0)

# Create confusion matrix
cm_nn = confusion_matrix(y_test, y_pred_discret_nn)

# Visualize confusion matrix
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 301/301 [==============================] - 1s 2ms/step

# %% [markdown]
# ### AdaBoost (Adaptative Boosting):

# %%
# Create the base estimator
base_estimator_ab = DecisionTreeClassifier()

# Create the AdaBoost classifier
ada_boost = AdaBoostClassifier(base_estimator=base_estimator_ab)

# Define the parameter grid for AdaBoost
param_grid_ab = {
    'n_estimators': [50, 100, 200], 
    'learning_rate': [0.1, 0.5, 1.0]  
}


# Perform grid search for AdaBoost
grid_search_ab = GridSearchCV(ada_boost, param_grid_ab, cv=3, n_jobs=-1)
grid_search_ab.fit(X_train, y_train)

# Get the best AdaBoost model and its performance
best_ada_boost = grid_search_ab.best_estimator_
best_params_ab = grid_search_ab.best_params_
best_score_ab = grid_search_ab.best_score_

# Train the best AdaBoost model with all data
best_ada_boost.fit(X_train, y_train)

# Evaluate the best AdaBoost model
test_accuracy_ab = best_ada_boost.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_ab*100:.2f}%')
# Out:
# Test Accuracy: 87.15%

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_ab = best_ada_boost.predict_proba(X_test)[:, 1]
fpr_ab, tpr_ab, thresholds_ab = roc_curve(y_test, y_pred_prob_ab)
auc_ab = roc_auc_score(y_test, y_pred_prob_ab)

# Plot ROC curve
plt.plot(fpr_ab, tpr_ab, label='ROC curve (AUC = {:.2f})'.format(auc_ab))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_ab = best_ada_boost.predict(X_test)
cm_ab = confusion_matrix(y_test, y_pred_ab)

# Visualize confusion matrix
sns.heatmap(cm_ab, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### Gradient Boosting:

# %%
# Create the Gradient Boosting classifier
gradient_boosting = GradientBoostingClassifier()

# Define the parameter grid for Gradient Boosting
param_grid_gb = {
    'n_estimators': [50, 100, 200],        
    'learning_rate': [0.1, 0.5, 1.0],     
    'max_depth': [3, 4, 5]                 
}

# Perform grid search for Gradient Boosting
grid_search_gb = GridSearchCV(gradient_boosting, param_grid_gb, cv=3, n_jobs=-1)
grid_search_gb.fit(X_train, y_train)

# Get the best Gradient Boosting model and its performance
best_gradient_boosting = grid_search_gb.best_estimator_
best_params_gb = grid_search_gb.best_params_
best_score_gb = grid_search_gb.best_score_

# Train the best Gradient Boosting model with all data
best_gradient_boosting.fit(X_train, y_train)

# Evaluate the best Gradient Boosting model
test_accuracy_gb = best_gradient_boosting.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_gb*100:.2f}%')
# Out:
# Test Accuracy: 89.54%

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_gb = best_gradient_boosting.predict_proba(X_test)[:, 1]
fpr_gb, tpr_gb, thresholds_gb = roc_curve(y_test, y_pred_prob_gb)
auc_gb = roc_auc_score(y_test, y_pred_prob_gb)

# Plot ROC curve
plt.plot(fpr_gb, tpr_gb, label='ROC curve (AUC = {:.2f})'.format(auc_gb))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_gb = best_gradient_boosting.predict(X_test)
cm_gb = confusion_matrix(y_test, y_pred_gb)

# Visualize confusion matrix
sns.heatmap(cm_gb, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## Dataset unbalance problem

# %% [markdown]
# By showing the ROC curve, the AUC value and the confusion matrix, we can see that, despite having a high accuracy, there is a problem with our models.
#
# The data we have are unbalanced, since we have much more data from the "No" class than from the "Yes" class. This makes that our models do not learn well due to the unbalance.
#
# To fix it, we have different possible solutions:
#
# - **Penalize the majority class:** Since we learn more with it, by putting a penalty we could make the other class to be taken more into account. However, not all models allow us to make this modification. The logistic regression and the Random Forest implemented does allow us to do it by means of the parameter "class_weight='balanced'". Even so, these models are not the best performing, so it is not an effective measure for the whole analysis.
#
#
#
# - **Try more complex ensemble methods** that work better for these types of unbalanced datasets. One of the possible implementations is to make use of the "StackingClassifier".
#
#
#
# - **Make use of subsampling and oversampling:** That is, if we remove records from the majority class, or synthetically add records from the minority class, we can try to reduce the unbalance and make it more balanced, thus improving the results of our models.
#
#
#
# - **Analyze if there are variables that are not relevant in the dataset for most of our models and eliminate them:** By doing this, we can eliminate variables that always take similar values that are causing this unbalance and that do not contribute information to our models.

# %% [markdown]
# ### OVERSAMPLING APPROACH (and penalizing the majority class if the model allows it)

# %% [markdown]
# Let's start by applying oversampling. For this we make use of the "imblearn" library and the SMOTE (Synthetic Minority Over-sampling Technique) function.

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(k_neighbors = 5, random_state=random_seed)
X_train_os, y_train_os = smote.fit_resample(X_train, y_train)

# %%
print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (28882, 14)
# X_test shape: (9628, 14)
# y_train: (28882,)
# y_test shape: (9628,)

# %%
print("X_train shape:",X_train_os.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train_os.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (51328, 14)
# X_test shape: (9628, 14)
# y_train: (51328,)
# y_test shape: (9628,)

# %% [markdown]
# As we can see, more records have been added to the train partitions, from 30882 to 54804 records. It should be noted that it is only applied to the training set and not to the test set to avoid bias in the evaluation of the model.
#
# In this way the model is allowed to more effectively learn the underlying characteristics of the minority classes without compromising the unbiased evaluation of the model on the test set.

# %% [markdown]
# ### We retrain the most successful models with the new train partition.

# %% [markdown]
# #### LOGISTIC REGRESSION (WITH SMOTE):
# #### Linear regression method for binary classification problems
#
# In addition, in this case we use the **penalization to the majority class, as this method allows it**

# %%
model_lr_smote = LogisticRegression(class_weight='balanced')
model_lr_smote.fit( X_train_os, y_train_os)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred_lr_os = model_lr_smote.predict(X_test)

# %%
accuracy_lr_os = accuracy_score(y_test, y_pred_lr_os)
report_lr_os = classification_report(y_test, y_pred_lr_os)
print("Accuracy:", accuracy_lr_os)
print("Classification Report:\n", report_lr_os)
# Out:
# Accuracy: 0.7755504777731617
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      8555
#            1       0.28      0.63      0.38      1073
#
#     accuracy                           0.78      9628
#    macro avg       0.61      0.71      0.62      9628
# weighted avg       0.87      0.78      0.81      9628

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_lr_os = model_lr_smote.predict_proba(X_test)[:, 1]
fpr_lr_os, tpr_lr_os, thresholds_lr_os = roc_curve(y_test, y_pred_prob_lr_os)
auc_lr_os = roc_auc_score(y_test, y_pred_prob_lr_os)

# Plot ROC curve
plt.plot(fpr_lr_os, tpr_lr_os, label='ROC curve (AUC = {:.2f})'.format(auc_lr_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_lr_os = model_lr_smote.predict(X_test)
cm_lr_smote = confusion_matrix(y_test, y_pred_lr_os)

# Visualize confusion matrix
sns.heatmap(cm_lr_smote, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
fig_cm_lr_smote = plt.gcf() 
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO LOGISTIC REGRESSION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Logistic Regression WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_lr_smote, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Logistic Regression WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# As we can see in the figure, by using oversampling and penalization, we obtain a model that classifies the minority class much better. It is true that the majority class is no longer classified as correctly as it was previously. However, we prefer the result to be the latter, since we no longer see the results of the unbalance.

# %% [markdown]
# #### KNN (WITH SMOTE):

# %%
param_grid_knn_os= {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'algorithm': ['ball_tree', 'kd_tree', 'brute']}

knn_os = KNeighborsClassifier()

# refit true, para que entrenemos con todos los datos
grid_search_knn_os = GridSearchCV(knn_os, param_grid_knn_os, cv=3, refit=True, n_jobs=-1)

grid_search_knn_os.fit(X_train_os, y_train_os)

print("Best hyperparameters:", grid_search_knn_os.best_params_)
print("Accuracy score:", grid_search_knn_os.best_score_)

best_model_knn_os = grid_search_knn_os.best_estimator_
y_pred_knn_os = best_model_knn_os.predict(X_test)
# Out:
# Best hyperparameters: {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'distance'}
# Accuracy score: 0.8732861703116984

# %%
accuracy_knn_os = accuracy_score(y_test, y_pred_knn_os)
report_knn_os = classification_report(y_test, y_pred_knn_os)
print("Best Parameters:", grid_search_knn_os.best_params_)
print("Accuracy:", accuracy_knn_os)
print("Classification Report:\n", report_knn_os)
# Out:
# Best Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'distance'}
# Accuracy: 0.8397382633984213
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      8555
#            1       0.31      0.36      0.33      1073
#
#     accuracy                           0.84      9628
#    macro avg       0.61      0.63      0.62      9628
# weighted avg       0.85      0.84      0.84      9628

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_knn_os = best_model_knn_os.predict_proba(X_test)[:, 1]
fpr_knn_os, tpr_knn_os, thresholds_knn_os = roc_curve(y_test, y_pred_prob_knn_os)
auc_knn_os = roc_auc_score(y_test, y_pred_prob_knn_os)

# Plot ROC curve
plt.plot(fpr_knn_os, tpr_knn_os, label='ROC curve (AUC = {:.2f})'.format(auc_knn_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_knn_os = best_model_knn_os.predict(X_test)
cm_knn_os = confusion_matrix(y_test, y_pred_knn_os)

# Visualize confusion matrix
sns.heatmap(cm_knn_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO KNN:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - knn WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_knn_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - knn WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### CLASSIFICATION TREES (WITH SMOTE)

# %%
param_grid_ct_os = {'max_depth': [3, 5, 7, 9, None],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

model_ct_os = DecisionTreeClassifier(random_state=random_seed)
grid_search_ct_os = GridSearchCV(model_ct, param_grid_ct_os, cv=3, n_jobs=-1)
grid_search_ct_os.fit(X_train_os, y_train_os)

best_model_ct_os = grid_search_ct_os.best_estimator_
y_pred_ct_os = best_model_ct_os.predict(X_test)

accuracy_ct_os = accuracy_score(y_test, y_pred_ct_os)
report_ct_os = classification_report(y_test, y_pred_ct_os)
print("Best Parameters:", grid_search_ct_os.best_params_)
print("Accuracy:", accuracy_ct_os)
print("Classification Report:\n", report_ct_os)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.8656003323639385
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      8555
#            1       0.38      0.32      0.34      1073
#
#     accuracy                           0.87      9628
#    macro avg       0.65      0.63      0.63      9628
# weighted avg       0.86      0.87      0.86      9628

# %%
# Generate ROC curve and calculate AUC
y_pred_prob = best_model_ct_os.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
auc = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred = best_model_ct_os.predict(X_test)
cm_ct_os = confusion_matrix(y_test, y_pred_ct_os)

# Visualize confusion matrix
sns.heatmap(cm_ct_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO CT:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_ct, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Classification Trees WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_ct_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix -  Classification Trees WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### RANDOM FOREST (WITH SMOTE):

# %%
param_grid_rf_os = {"n_estimators": [50, 100, 200],
              "max_depth": [None, 5, 10],
              "min_samples_split": [2, 5, 10],
              "min_samples_leaf": [1, 2, 4]}
rfc_os = RandomForestClassifier(random_state=random_seed, class_weight='balanced')
grid_search_rf_os = GridSearchCV(rfc_os, param_grid_rf_os, cv=3, n_jobs=-1)
grid_search_rf_os.fit(X_train_os, y_train_os)

print("Best hyperparameters:", grid_search_rf_os.best_params_)
print("Accuracy score:", grid_search_rf_os.best_score_)

best_model_rf_os = grid_search_rf_os.best_estimator_
y_pred_rf_os = best_model_rf_os.predict(X_test)

accuracy_rf_os = accuracy_score(y_test, y_pred_rf_os)
report_rf_os = classification_report(y_test, y_pred_rf_os)
print("Best Parameters:", grid_search_rf_os.best_params_)
print("Accuracy:", accuracy_rf_os)
print("Classification Report:\n", report_rf_os)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy score: 0.9259090039082789
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy: 0.8803489821354383
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93      8555
#            1       0.45      0.34      0.39      1073
#
#     accuracy                           0.88      9628
#    macro avg       0.69      0.64      0.66      9628
# weighted avg       0.87      0.88      0.87      9628

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_rf_os = best_model_rf_os.predict_proba(X_test)[:, 1]
fpr_rf_os, tpr_rf_os, thresholds_rf_os = roc_curve(y_test, y_pred_prob_rf_os)
auc_rf_os = roc_auc_score(y_test, y_pred_prob_rf_os)

# Plot ROC curve
plt.plot(fpr_rf_os, tpr_rf_os, label='ROC curve (AUC = {:.2f})'.format(auc_rf_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_rf_os = best_model_rf_os.predict(X_test)
cm_rf_os = confusion_matrix(y_test, y_pred_rf_os)

# Visualize confusion matrix
sns.heatmap(cm_rf_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO RANDOM FOREST:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Random Forest WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_rf_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Random Forest WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### GRADIENT BOOSTING (WITH SMOTE):

# %%
# Create the Gradient Boosting classifier
gradient_boosting_smote = GradientBoostingClassifier()

# Define the parameter grid for Gradient Boosting
param_grid_gb_os = {
    'n_estimators': [50, 100, 200],        
    'learning_rate': [0.1, 0.5, 1.0],     
    'max_depth': [3, 4, 5]                 
}

# Perform grid search for Gradient Boosting
grid_search_gb_os = GridSearchCV(gradient_boosting_smote, param_grid_gb_os, cv=3, n_jobs=-1)
grid_search_gb_os.fit(X_train_os, y_train_os)

# Get the best Gradient Boosting model and its performance
best_gradient_boosting_smote = grid_search_gb_os.best_estimator_
best_params_gb_os = grid_search_gb_os.best_params_
best_score_gb_os = grid_search_gb_os.best_score_

# Train the best Gradient Boosting model with all data
best_gradient_boosting_smote.fit(X_train_os, y_train_os)

# Evaluate the best Gradient Boosting model
test_accuracy_gb_os = best_gradient_boosting_smote.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_gb_os*100:.2f}%')
# Out:
# Test Accuracy: 88.74%

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_gb_os = best_gradient_boosting_smote.predict_proba(X_test)[:, 1]
fpr_gb_os, tpr_gb_os, thresholds_gb_os = roc_curve(y_test, y_pred_prob_gb_os)
auc_gb_os = roc_auc_score(y_test, y_pred_prob_gb_os)

# Plot ROC curve
plt.plot(fpr_gb_os, tpr_gb_os, label='ROC curve (AUC = {:.2f})'.format(auc_gb_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_gb_os = best_gradient_boosting_smote.predict(X_test)
cm_gb_smote = confusion_matrix(y_test, y_pred_gb_os)

# Visualize confusion matrix
sns.heatmap(cm_gb_smote, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO GRADIENT BOOSTING:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_gb, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Gradient Boosting WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_gb_smote, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Gradient Boosting WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# As we can see in both confusion matrices, the inclusion of oversampling improves the predictions. However, the improvement obtained with Logistic regression is better than with Gradient Boosting. Therefore, although without oversampling we would choose Gradient Boosting as the best model, using oversampling we choose logistic regression as the best model between these two.

# %% [markdown]
# #### NEURAL NETWORK (WITH SMOTE):

# %%
def create_model_nn(hidden_units=128):
    model = Sequential()
    model.add(Dense(hidden_units, input_dim=X_train_os.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Define the parameter gridB
param_grid_nn_os = {
    'hidden_units': [64, 128, 256],
    'epochs': [10, 20, 30],
    'batch_size': [16, 32, 64]
}

# Create the model
model_nn_os = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn=create_model_nn)

# Perform grid search
grid_search_nn_os = GridSearchCV(model_nn_os, param_grid_nn_os, cv=3, n_jobs=-1)
grid_search_nn_os.fit(X_train_os, y_train_os)

# Get the best parameters
best_params_nn_os = grid_search_nn_os.best_params_
best_params_nn_os
# Out:
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# 2139/2139 [==============================] - 15s 6ms/step - loss: 0.5606 - accuracy: 0.7159
# Epoch 2/20
# 2139/2139 [==============================] - 15s 6ms/step - loss: 0.5135 - accuracy: 0.7183
# 2042/2139 [===========================>..] - ETA: 0s - loss: 0.5610 - accuracy: 0.7135Epoch 2/20
# 2139/2139 [==============================] - 15s 6ms/step - loss: 0.4595 - accuracy: 0.8051
# 1808/2139 [========================>.....] - ETA: 2s - loss: 0.5129 - accuracy: 0.7168Epoch 2/10
# 2139/2139 [==============================] - 15s 6ms/step - loss: 0.4602 - accuracy: 0.8051
# Epoch 2/20
# 2139/2139 [==============================] - 16s 6ms/step - loss: 0.5595 - accuracy: 0.7164
# 1942/2139 [==========================>...] - ETA: 1s - loss: 0.4606 - accuracy: 0.8052Epoch 2/20
# 2139/2139 [==============================] - 16s 6ms/step - loss: 0.5604 - accuracy: 0.7141
# Epoch 2/10
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.5591 - accuracy: 0.7161
# Epoch 2/10
# 2139/2139 [==============================] - 17s 7ms/step - loss: 0.5115 - accuracy: 0.7189
#  357/2139 [====>.........................] - ETA: 10s - loss: 0.5452 - accuracy: 0.7201Epoch 2/20
# 2139/2139 [==============================] - 17s 7ms/step - loss: 0.5113 - accuracy: 0.7226
#  175/2139 [=>............................] - ETA: 16s - loss: 0.4478 - accuracy: 0.8111Epoch 2/10
# 2139/2139 [==============================] - 17s 7ms/step - loss: 0.4586 - accuracy: 0.8066
#  240/2139 [==>...........................] - ETA: 12s - loss: 0.5512 - accuracy: 0.7232Epoch 2/10
# 2139/2139 [==============================] - 17s 7ms/step - loss: 0.5616 - accuracy: 0.7144
#  250/2139 [==>...........................] - ETA: 11s - loss: 0.5492 - accuracy: 0.7255Epoch 2/10
# 2139/2139 [==============================] - 18s 7ms/step - loss: 0.5115 - accuracy: 0.7179
#  413/2139 [====>.........................] - ETA: 10s - loss: 0.5042 - accuracy: 0.7190Epoch 2/10
# 2139/2139 [==============================] - 18s 7ms/step - loss: 0.5115 - accuracy: 0.7213
# Epoch 2/10
# 2139/2139 [==============================] - 18s 7ms/step - loss: 0.4596 - accuracy: 0.8059
# Epoch 2/20
# 2139/2139 [==============================] - 18s 7ms/step - loss: 0.5114 - accuracy: 0.7188
#   90/2139 [>.............................] - ETA: 13s - loss: 0.4909 - accuracy: 0.7424Epoch 2/20
# 2139/2139 [==============================] - 18s 7ms/step - loss: 0.4603 - accuracy: 0.8056
#  406/2139 [====>.........................] - ETA: 10s - loss: 0.5510 - accuracy: 0.7238Epoch 2/10
# 2139/2139 [==============================] - 12s 6ms/step - loss: 0.5003 - accuracy: 0.7325
# 1834/2139 [========================>.....] - ETA: 2s - loss: 0.4996 - accuracy: 0.7286Epoch 3/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5017 - accuracy: 0.7286
# 2077/2139 [============================>.] - ETA: 0s - loss: 0.4511 - accuracy: 0.8115Epoch 3/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5477 - accuracy: 0.7217
# 2103/2139 [============================>.] - ETA: 0s - loss: 0.4508 - accuracy: 0.8118Epoch 3/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4504 - accuracy: 0.8121
# Epoch 3/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5484 - accuracy: 0.7211
#   45/2139 [..............................] - ETA: 15s - loss: 0.5461 - accuracy: 0.7292Epoch 3/10
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5480 - accuracy: 0.7235
# 1981/2139 [==========================>...] - ETA: 1s - loss: 0.4995 - accuracy: 0.7290Epoch 3/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4502 - accuracy: 0.8109
# 1742/2139 [=======================>......] - ETA: 2s - loss: 0.4472 - accuracy: 0.8138Epoch 3/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5003 - accuracy: 0.7296
# Epoch 3/20
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.5471 - accuracy: 0.7226
#   91/2139 [>.............................] - ETA: 11s - loss: 0.4777 - accuracy: 0.7521Epoch 3/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4504 - accuracy: 0.8120
#  434/2139 [=====>........................] - ETA: 11s - loss: 0.4954 - accuracy: 0.7404Epoch 3/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4501 - accuracy: 0.8117
# 2083/2139 [============================>.] - ETA: 0s - loss: 0.4997 - accuracy: 0.7318Epoch 3/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5001 - accuracy: 0.7324
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5004 - accuracy: 0.7298
#  217/2139 [==>...........................] - ETA: 13s - loss: 0.4848 - accuracy: 0.7399Epoch 3/20
#    1/2139 [..............................] - ETA: 18s - loss: 0.4572 - accuracy: 0.7500Epoch 3/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5497 - accuracy: 0.7219
#   78/2139 [>.............................] - ETA: 14s - loss: 0.4448 - accuracy: 0.8157Epoch 3/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4502 - accuracy: 0.8124
# 2128/2139 [============================>.] - ETA: 0s - loss: 0.4997 - accuracy: 0.7321Epoch 3/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5003 - accuracy: 0.7319
# Epoch 3/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4911 - accuracy: 0.7428
# 1815/2139 [========================>.....] - ETA: 2s - loss: 0.5388 - accuracy: 0.7275Epoch 4/10
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5395 - accuracy: 0.7278
#   31/2139 [..............................] - ETA: 20s - loss: 0.4872 - accuracy: 0.7621Epoch 4/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5410 - accuracy: 0.7253
# 1733/2139 [=======================>......] - ETA: 2s - loss: 0.4449 - accuracy: 0.8150Epoch 4/10
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5405 - accuracy: 0.7266
# 1756/2139 [=======================>......] - ETA: 2s - loss: 0.4935 - accuracy: 0.7391Epoch 4/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4947 - accuracy: 0.7366
# 1569/2139 [=====================>........] - ETA: 4s - loss: 0.4467 - accuracy: 0.8131Epoch 4/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4469 - accuracy: 0.8132
# 1925/2139 [=========================>....] - ETA: 1s - loss: 0.4908 - accuracy: 0.7410Epoch 4/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4461 - accuracy: 0.8124
# Epoch 4/10
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.5380 - accuracy: 0.7285
# Epoch 4/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4923 - accuracy: 0.7408
# Epoch 4/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4940 - accuracy: 0.7396
#  440/2139 [=====>........................] - ETA: 13s - loss: 0.4829 - accuracy: 0.7530Epoch 4/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4457 - accuracy: 0.8141
#   81/2139 [>.............................] - ETA: 14s - loss: 0.4690 - accuracy: 0.7446Epoch 4/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4461 - accuracy: 0.8137
# 2050/2139 [===========================>..] - ETA: 0s - loss: 0.4948 - accuracy: 0.7403Epoch 4/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4462 - accuracy: 0.8137
#  534/2139 [======>.......................] - ETA: 10s - loss: 0.4382 - accuracy: 0.8165Epoch 4/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5407 - accuracy: 0.7268
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4917 - accuracy: 0.7434
#   63/2139 [..............................] - ETA: 16s - loss: 0.4518 - accuracy: 0.7937Epoch 4/10
# 2123/2139 [============================>.] - ETA: 0s - loss: 0.4940 - accuracy: 0.7404Epoch 4/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4941 - accuracy: 0.7405
#  600/2139 [=======>......................] - ETA: 10s - loss: 0.5283 - accuracy: 0.7355Epoch 4/20
# 2139/2139 [==============================] - 11s 5ms/step - loss: 0.5307 - accuracy: 0.7325
# Epoch 5/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.5313 - accuracy: 0.7323
# Epoch 5/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4831 - accuracy: 0.7531
# Epoch 5/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5288 - accuracy: 0.7341
# 1474/2139 [===================>..........] - ETA: 4s - loss: 0.4393 - accuracy: 0.8164Epoch 5/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5331 - accuracy: 0.7321
# 1708/2139 [======================>.......] - ETA: 2s - loss: 0.4420 - accuracy: 0.8137Epoch 5/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4856 - accuracy: 0.7506
# 1488/2139 [===================>..........] - ETA: 4s - loss: 0.4854 - accuracy: 0.7527Epoch 5/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4424 - accuracy: 0.8143
#  127/2139 [>.............................] - ETA: 12s - loss: 0.5184 - accuracy: 0.7406Epoch 5/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4441 - accuracy: 0.8144
# 2053/2139 [===========================>..] - ETA: 0s - loss: 0.4823 - accuracy: 0.7520Epoch 5/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4815 - accuracy: 0.7524
#  121/2139 [>.............................] - ETA: 13s - loss: 0.4719 - accuracy: 0.7944Epoch 5/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4434 - accuracy: 0.8140
#  367/2139 [====>.........................] - ETA: 12s - loss: 0.4527 - accuracy: 0.8069Epoch 5/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4421 - accuracy: 0.8140
#  607/2139 [=======>......................] - ETA: 9s - loss: 0.5169 - accuracy: 0.7430Epoch 5/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4857 - accuracy: 0.7464
# 1958/2139 [==========================>...] - ETA: 1s - loss: 0.4819 - accuracy: 0.7541Epoch 5/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4427 - accuracy: 0.8152
#  575/2139 [=======>......................] - ETA: 10s - loss: 0.4804 - accuracy: 0.7550Epoch 5/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4866 - accuracy: 0.7489
#  412/2139 [====>.........................] - ETA: 12s - loss: 0.4763 - accuracy: 0.7585Epoch 5/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5307 - accuracy: 0.7314
#  161/2139 [=>............................] - ETA: 15s - loss: 0.4421 - accuracy: 0.8113Epoch 5/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4815 - accuracy: 0.7544
#    5/2139 [..............................] - ETA: 27s - loss: 0.4964 - accuracy: 0.7250Epoch 5/10
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5215 - accuracy: 0.7401
# 1788/2139 [========================>.....] - ETA: 2s - loss: 0.4759 - accuracy: 0.7619Epoch 6/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5209 - accuracy: 0.7402
# 1189/2139 [===============>..............] - ETA: 6s - loss: 0.4741 - accuracy: 0.7617Epoch 6/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4715 - accuracy: 0.7654
# 1270/2139 [================>.............] - ETA: 5s - loss: 0.4740 - accuracy: 0.7617Epoch 6/10
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4386 - accuracy: 0.8157
# Epoch 6/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5245 - accuracy: 0.7375
# Epoch 6/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5186 - accuracy: 0.7407
#  324/2139 [===>..........................] - ETA: 11s - loss: 0.5075 - accuracy: 0.7475Epoch 6/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4396 - accuracy: 0.8150
# Epoch 6/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4743 - accuracy: 0.7631
# Epoch 6/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4715 - accuracy: 0.7639
# 1859/2139 [=========================>....] - ETA: 1s - loss: 0.4773 - accuracy: 0.7606Epoch 6/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4383 - accuracy: 0.8154
# Epoch 6/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4401 - accuracy: 0.8157
#  474/2139 [=====>........................] - ETA: 14s - loss: 0.4546 - accuracy: 0.7727Epoch 6/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4760 - accuracy: 0.7612
#  440/2139 [=====>........................] - ETA: 11s - loss: 0.4293 - accuracy: 0.8183Epoch 6/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4790 - accuracy: 0.7569
#  304/2139 [===>..........................] - ETA: 11s - loss: 0.4569 - accuracy: 0.7734Epoch 6/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4696 - accuracy: 0.7634
#   51/2139 [..............................] - ETA: 15s - loss: 0.4780 - accuracy: 0.7574Epoch 6/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4386 - accuracy: 0.8176
#  936/2139 [============>.................] - ETA: 8s - loss: 0.5092 - accuracy: 0.7505Epoch 6/10
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.5202 - accuracy: 0.7370
#  901/2139 [===========>..................] - ETA: 8s - loss: 0.5208 - accuracy: 0.7357Epoch 6/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5106 - accuracy: 0.7447
# 1058/2139 [=============>................] - ETA: 7s - loss: 0.4306 - accuracy: 0.8228Epoch 7/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5117 - accuracy: 0.7457
# 2000/2139 [===========================>..] - ETA: 0s - loss: 0.4335 - accuracy: 0.8194Epoch 7/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4337 - accuracy: 0.8191
# 1947/2139 [==========================>...] - ETA: 1s - loss: 0.4328 - accuracy: 0.8182Epoch 7/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5070 - accuracy: 0.7474
#  313/2139 [===>..........................] - ETA: 12s - loss: 0.5018 - accuracy: 0.7538Epoch 7/20
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.4615 - accuracy: 0.7707
# Epoch 7/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5165 - accuracy: 0.7394
# 2088/2139 [============================>.] - ETA: 0s - loss: 0.4650 - accuracy: 0.7710Epoch 7/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4354 - accuracy: 0.8164
# 1321/2139 [=================>............] - ETA: 5s - loss: 0.5108 - accuracy: 0.7454Epoch 7/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4643 - accuracy: 0.7714
#   95/2139 [>.............................] - ETA: 11s - loss: 0.4989 - accuracy: 0.7618Epoch 7/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4607 - accuracy: 0.7717
# 1685/2139 [======================>.......] - ETA: 3s - loss: 0.4629 - accuracy: 0.7711Epoch 7/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4363 - accuracy: 0.8167
# Epoch 7/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4346 - accuracy: 0.8197
#  195/2139 [=>............................] - ETA: 12s - loss: 0.4311 - accuracy: 0.8253Epoch 7/10
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4678 - accuracy: 0.7671
#  416/2139 [====>.........................] - ETA: 11s - loss: 0.4578 - accuracy: 0.7728Epoch 7/10
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4687 - accuracy: 0.7671
#  509/2139 [======>.......................] - ETA: 9s - loss: 0.5033 - accuracy: 0.7491Epoch 7/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4351 - accuracy: 0.8200
# Epoch 7/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4595 - accuracy: 0.7736
# 1904/2139 [=========================>....] - ETA: 1s - loss: 0.5123 - accuracy: 0.7443Epoch 7/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5103 - accuracy: 0.7453
#  526/2139 [======>.......................] - ETA: 9s - loss: 0.4556 - accuracy: 0.7758Epoch 7/10
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.5037 - accuracy: 0.7516
# Epoch 8/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5025 - accuracy: 0.7513
# 1006/2139 [=============>................] - ETA: 8s - loss: 0.4293 - accuracy: 0.8232Epoch 8/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4315 - accuracy: 0.8195
#  239/2139 [==>...........................] - ETA: 14s - loss: 0.5036 - accuracy: 0.7589Epoch 8/10
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5079 - accuracy: 0.7458
# 2018/2139 [===========================>..] - ETA: 0s - loss: 0.4545 - accuracy: 0.7800Epoch 8/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4303 - accuracy: 0.8200
# 2048/2139 [===========================>..] - ETA: 0s - loss: 0.4546 - accuracy: 0.7802Epoch 8/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4980 - accuracy: 0.7540
# 1731/2139 [=======================>......] - ETA: 2s - loss: 0.4597 - accuracy: 0.7741Epoch 8/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4537 - accuracy: 0.7806
# 1968/2139 [==========================>...] - ETA: 1s - loss: 0.4346 - accuracy: 0.8182Epoch 8/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4521 - accuracy: 0.7811
#  170/2139 [=>............................] - ETA: 13s - loss: 0.4259 - accuracy: 0.8195Epoch 8/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4330 - accuracy: 0.8189
# Epoch 8/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4510 - accuracy: 0.7798
# 1518/2139 [====================>.........] - ETA: 4s - loss: 0.5019 - accuracy: 0.7502Epoch 8/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4599 - accuracy: 0.7734
#   50/2139 [..............................] - ETA: 11s - loss: 0.4076 - accuracy: 0.8062Epoch 8/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4582 - accuracy: 0.7738
# Epoch 8/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4306 - accuracy: 0.8205
# Epoch 8/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4503 - accuracy: 0.7780
#  769/2139 [=========>....................] - ETA: 9s - loss: 0.4218 - accuracy: 0.8235Epoch 8/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4307 - accuracy: 0.8223
# 1878/2139 [=========================>....] - ETA: 1s - loss: 0.5013 - accuracy: 0.7504Epoch 8/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5002 - accuracy: 0.7512
# 1137/2139 [==============>...............] - ETA: 6s - loss: 0.4280 - accuracy: 0.8208Epoch 8/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4942 - accuracy: 0.7560
# 1490/2139 [===================>..........] - ETA: 4s - loss: 0.4453 - accuracy: 0.7870Epoch 9/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4952 - accuracy: 0.7542
# Epoch 9/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4265 - accuracy: 0.8233
# 1719/2139 [=======================>......] - ETA: 2s - loss: 0.4287 - accuracy: 0.8202Epoch 9/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4881 - accuracy: 0.7600
# 1101/2139 [==============>...............] - ETA: 7s - loss: 0.4241 - accuracy: 0.8240Epoch 9/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4282 - accuracy: 0.8215
# 1152/2139 [===============>..............] - ETA: 7s - loss: 0.4237 - accuracy: 0.8241Epoch 9/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5003 - accuracy: 0.7505
# 1334/2139 [=================>............] - ETA: 5s - loss: 0.4247 - accuracy: 0.8240Epoch 9/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4432 - accuracy: 0.7872
# Epoch 9/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4439 - accuracy: 0.7862
# 1700/2139 [======================>.......] - ETA: 3s - loss: 0.4281 - accuracy: 0.8220Epoch 9/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4286 - accuracy: 0.8203
#   57/2139 [..............................] - ETA: 14s - loss: 0.4327 - accuracy: 0.8081Epoch 9/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4498 - accuracy: 0.7832
# Epoch 9/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4498 - accuracy: 0.7818
#  560/2139 [======>.......................] - ETA: 10s - loss: 0.4241 - accuracy: 0.8260Epoch 9/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4395 - accuracy: 0.7893
# Epoch 9/20
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.4281 - accuracy: 0.8224
#  320/2139 [===>..........................] - ETA: 10s - loss: 0.4446 - accuracy: 0.7836Epoch 9/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4420 - accuracy: 0.7867
#  352/2139 [===>..........................] - ETA: 10s - loss: 0.4446 - accuracy: 0.7852Epoch 9/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4281 - accuracy: 0.8231
# 1155/2139 [===============>..............] - ETA: 6s - loss: 0.4862 - accuracy: 0.7595Epoch 9/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4892 - accuracy: 0.7581
# 1202/2139 [===============>..............] - ETA: 6s - loss: 0.4226 - accuracy: 0.8263Epoch 9/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4863 - accuracy: 0.7608
#  513/2139 [======>.......................] - ETA: 12s - loss: 0.4825 - accuracy: 0.7634Epoch 10/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4882 - accuracy: 0.7590
# Epoch 10/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4246 - accuracy: 0.8245
# 1533/2139 [====================>.........] - ETA: 4s - loss: 0.4417 - accuracy: 0.7867Epoch 10/10
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.4244 - accuracy: 0.8244
# Epoch 10/20
# 2139/2139 [==============================] - 16s 8ms/step - loss: 0.4798 - accuracy: 0.7654
# 1929/2139 [==========================>...] - ETA: 1s - loss: 0.4273 - accuracy: 0.8207Epoch 10/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4923 - accuracy: 0.7564
#  205/2139 [=>............................] - ETA: 10s - loss: 0.4395 - accuracy: 0.8207Epoch 10/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4349 - accuracy: 0.7941
#  624/2139 [=======>......................] - ETA: 10s - loss: 0.4802 - accuracy: 0.7650Epoch 10/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4334 - accuracy: 0.7942
#  219/2139 [==>...........................] - ETA: 10s - loss: 0.4385 - accuracy: 0.8216Epoch 10/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4260 - accuracy: 0.8217
# 1758/2139 [=======================>......] - ETA: 2s - loss: 0.4239 - accuracy: 0.8247Epoch 10/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4430 - accuracy: 0.7879
# 1798/2139 [========================>.....] - ETA: 2s - loss: 0.4241 - accuracy: 0.8246Epoch 10/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4405 - accuracy: 0.7901
#  326/2139 [===>..........................] - ETA: 12s - loss: 0.4198 - accuracy: 0.8050Epoch 10/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4310 - accuracy: 0.7939
# Epoch 10/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4246 - accuracy: 0.8233
#  630/2139 [=======>......................] - ETA: 11s - loss: 0.4173 - accuracy: 0.8258Epoch 10/10
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4315 - accuracy: 0.7944
#  479/2139 [=====>........................] - ETA: 10s - loss: 0.4307 - accuracy: 0.7929Epoch 10/10
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.4248 - accuracy: 0.8252
# Epoch 10/10
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.4805 - accuracy: 0.7636
# 1095/2139 [==============>...............] - ETA: 7s - loss: 0.4224 - accuracy: 0.8018Epoch 10/10
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4762 - accuracy: 0.7662
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4822 - accuracy: 0.7607
# 1296/2139 [=================>............] - ETA: 5s - loss: 0.4237 - accuracy: 0.8009Epoch 11/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4856 - accuracy: 0.7601
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4221 - accuracy: 0.8244
# Epoch 11/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4219 - accuracy: 0.8240
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4693 - accuracy: 0.7709
#   17/1070 [..............................] - ETA: 3s - loss: 0.4489 - accuracy: 0.8272  Epoch 11/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4243 - accuracy: 0.8013
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4260 - accuracy: 0.7993
#  572/2139 [=======>......................] - ETA: 9s - loss: 0.4691 - accuracy: 0.7733Epoch 11/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4361 - accuracy: 0.7922
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4232 - accuracy: 0.8243
#  209/2139 [=>............................] - ETA: 11s - loss: 0.4205 - accuracy: 0.8047Epoch 11/20
# 1070/1070 [==============================] - 6s 5ms/step - loss: 0.5159 - accuracy: 0.7517
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4215 - accuracy: 0.8025
# 1223/2139 [================>.............] - ETA: 6s - loss: 0.4724 - accuracy: 0.7679Epoch 11/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4346 - accuracy: 0.7920
# Epoch 11/20
#   73/2139 [>.............................] - ETA: 13s - loss: 0.4113 - accuracy: 0.8074Epoch 1/20
# 1070/1070 [==============================] - 4s 3ms/step - loss: 1.0187 - accuracy: 0.5168
#  665/1070 [=================>............] - ETA: 2s - loss: 0.8032 - accuracy: 0.5650Epoch 1/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4220 - accuracy: 0.8245
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4219 - accuracy: 0.8013
# 1070/1070 [==============================] - 6s 5ms/step - loss: 0.5159 - accuracy: 0.7512
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4206 - accuracy: 0.8262
#  681/2139 [========>.....................] - ETA: 7s - loss: 0.4129 - accuracy: 0.8073Epoch 1/30
# 1070/1070 [==============================] - 5s 4ms/step - loss: 0.7227 - accuracy: 0.6417
# 1070/1070 [==============================] - 6s 5ms/step - loss: 0.8032 - accuracy: 0.5635
# 1855/2139 [=========================>....] - ETA: 1s - loss: 0.4714 - accuracy: 0.7698Epoch 1/30
#  728/2139 [=========>....................] - ETA: 7s - loss: 0.4259 - accuracy: 0.8005Epoch 1/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4721 - accuracy: 0.7693
# 1070/1070 [==============================] - 5s 4ms/step - loss: 0.8379 - accuracy: 0.5059
# 2139/2139 [==============================] - 12s 6ms/step - loss: 0.4750 - accuracy: 0.7669
# Epoch 12/20
# 1070/1070 [==============================] - 5s 4ms/step - loss: 1.0246 - accuracy: 0.5101
#  769/2139 [=========>....................] - ETA: 8s - loss: 0.5721 - accuracy: 0.7109Epoch 1/30
# 1657/2139 [======================>.......] - ETA: 2s - loss: 0.4171 - accuracy: 0.8284Epoch 1/30
# 2139/2139 [==============================] - 11s 5ms/step - loss: 0.4616 - accuracy: 0.7777
#  263/2139 [==>...........................] - ETA: 9s - loss: 0.4939 - accuracy: 0.7657Epoch 12/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4188 - accuracy: 0.8267
# Epoch 12/20
# 2139/2139 [==============================] - 12s 6ms/step - loss: 0.4168 - accuracy: 0.8084
# 1961/2139 [==========================>...] - ETA: 0s - loss: 0.4269 - accuracy: 0.8001Epoch 12/20
# 2139/2139 [==============================] - 11s 5ms/step - loss: 0.4194 - accuracy: 0.8263
# 2023/2139 [===========================>..] - ETA: 0s - loss: 0.4124 - accuracy: 0.8068Epoch 12/20
# 2139/2139 [==============================] - 11s 5ms/step - loss: 0.4259 - accuracy: 0.8006
# Epoch 12/20
# 2139/2139 [==============================] - 11s 5ms/step - loss: 0.4126 - accuracy: 0.8073
#  708/2139 [========>.....................] - ETA: 8s - loss: 0.5671 - accuracy: 0.7180Epoch 12/20
# 1070/1070 [==============================] - 6s 5ms/step - loss: 0.5007 - accuracy: 0.7538
#  547/2139 [======>.......................] - ETA: 9s - loss: 0.4515 - accuracy: 0.7858Epoch 1/30
# 2139/2139 [==============================] - 15s 6ms/step - loss: 0.5608 - accuracy: 0.7156
# 1110/2139 [==============>...............] - ETA: 6s - loss: 0.4545 - accuracy: 0.7829Epoch 2/20
# 2139/2139 [==============================] - 15s 6ms/step - loss: 0.5127 - accuracy: 0.7160
# 1071/2139 [==============>...............] - ETA: 6s - loss: 0.3996 - accuracy: 0.8123Epoch 2/30
# 2139/2139 [==============================] - 17s 6ms/step - loss: 0.4593 - accuracy: 0.8068
# 1893/2139 [=========================>....] - ETA: 1s - loss: 0.4667 - accuracy: 0.7712Epoch 2/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4674 - accuracy: 0.7710
# 1405/2139 [==================>...........] - ETA: 4s - loss: 0.4025 - accuracy: 0.8119Epoch 13/20
# 2139/2139 [==============================] - 17s 6ms/step - loss: 0.5610 - accuracy: 0.7167
# 1826/2139 [========================>.....] - ETA: 1s - loss: 0.4163 - accuracy: 0.8281Epoch 2/30
# 2139/2139 [==============================] - 17s 6ms/step - loss: 0.4621 - accuracy: 0.8013
#  310/2139 [===>..........................] - ETA: 13s - loss: 0.4408 - accuracy: 0.8173Epoch 2/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4529 - accuracy: 0.7820
# 1874/2139 [=========================>....] - ETA: 1s - loss: 0.4083 - accuracy: 0.8131Epoch 13/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4173 - accuracy: 0.8275
#   87/2139 [>.............................] - ETA: 11s - loss: 0.4296 - accuracy: 0.7989Epoch 13/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4088 - accuracy: 0.8131
#  808/2139 [==========>...................] - ETA: 8s - loss: 0.4516 - accuracy: 0.8102Epoch 13/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4189 - accuracy: 0.8041
#  524/2139 [======>.......................] - ETA: 10s - loss: 0.5526 - accuracy: 0.7176Epoch 13/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4169 - accuracy: 0.8273
#  973/2139 [============>.................] - ETA: 7s - loss: 0.5009 - accuracy: 0.7258Epoch 13/20
# 2139/2139 [==============================] - 17s 7ms/step - loss: 0.5598 - accuracy: 0.7176
#  688/2139 [========>.....................] - ETA: 9s - loss: 0.4609 - accuracy: 0.7748Epoch 2/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4057 - accuracy: 0.8100
#   60/2139 [..............................] - ETA: 9s - loss: 0.5656 - accuracy: 0.7094Epoch 13/20
# 2139/2139 [==============================] - 18s 7ms/step - loss: 0.5125 - accuracy: 0.7192
#  278/2139 [==>...........................] - ETA: 10s - loss: 0.4078 - accuracy: 0.8089Epoch 2/30
# 2139/2139 [==============================] - 16s 6ms/step - loss: 0.4611 - accuracy: 0.8041
#  469/2139 [=====>........................] - ETA: 9s - loss: 0.5515 - accuracy: 0.7174 Epoch 2/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5476 - accuracy: 0.7229
#  354/2139 [===>..........................] - ETA: 13s - loss: 0.4519 - accuracy: 0.8114Epoch 3/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5014 - accuracy: 0.7296
#  240/2139 [==>...........................] - ETA: 13s - loss: 0.5465 - accuracy: 0.7281Epoch 3/30
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4497 - accuracy: 0.8124
# 1690/2139 [======================>.......] - ETA: 3s - loss: 0.4457 - accuracy: 0.7883Epoch 3/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4625 - accuracy: 0.7735
#  635/2139 [=======>......................] - ETA: 9s - loss: 0.5417 - accuracy: 0.7290Epoch 14/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5493 - accuracy: 0.7215
# Epoch 3/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4511 - accuracy: 0.8109
# 1482/2139 [===================>..........] - ETA: 4s - loss: 0.5019 - accuracy: 0.7305Epoch 3/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4457 - accuracy: 0.7883
# Epoch 14/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4128 - accuracy: 0.8086
# 1886/2139 [=========================>....] - ETA: 1s - loss: 0.5020 - accuracy: 0.7300Epoch 14/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4128 - accuracy: 0.8276
#   29/2139 [..............................] - ETA: 17s - loss: 0.4132 - accuracy: 0.8039Epoch 14/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4132 - accuracy: 0.8271
#   36/2139 [..............................] - ETA: 16s - loss: 0.4247 - accuracy: 0.8003Epoch 14/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4019 - accuracy: 0.8160
#   41/2139 [..............................] - ETA: 20s - loss: 0.3941 - accuracy: 0.8384Epoch 14/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5478 - accuracy: 0.7230
#  116/2139 [>.............................] - ETA: 13s - loss: 0.3973 - accuracy: 0.8130Epoch 3/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.3954 - accuracy: 0.8179
#  645/2139 [========>.....................] - ETA: 8s - loss: 0.4526 - accuracy: 0.8116Epoch 14/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5012 - accuracy: 0.7310
# Epoch 3/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4506 - accuracy: 0.8123
#  211/2139 [=>............................] - ETA: 12s - loss: 0.4956 - accuracy: 0.7417Epoch 3/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5378 - accuracy: 0.7282
# 1193/2139 [===============>..............] - ETA: 5s - loss: 0.4113 - accuracy: 0.8297Epoch 4/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4946 - accuracy: 0.7381
# 1004/2139 [=============>................] - ETA: 6s - loss: 0.4927 - accuracy: 0.7412Epoch 4/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4467 - accuracy: 0.8133
# Epoch 4/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.5420 - accuracy: 0.7258
# Epoch 4/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4555 - accuracy: 0.7784
# 1648/2139 [======================>.......] - ETA: 3s - loss: 0.4093 - accuracy: 0.8299Epoch 15/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4478 - accuracy: 0.8136
#  615/2139 [=======>......................] - ETA: 8s - loss: 0.5265 - accuracy: 0.7351Epoch 4/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4049 - accuracy: 0.8135
# 2101/2139 [============================>.] - ETA: 0s - loss: 0.4110 - accuracy: 0.8293Epoch 15/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4102 - accuracy: 0.8298
#   54/2139 [..............................] - ETA: 10s - loss: 0.3929 - accuracy: 0.8148Epoch 15/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4105 - accuracy: 0.8300
# Epoch 15/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4365 - accuracy: 0.7934
# Epoch 15/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.3938 - accuracy: 0.8221
# Epoch 15/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.3886 - accuracy: 0.8245
# 1809/2139 [========================>.....] - ETA: 2s - loss: 0.4471 - accuracy: 0.8131Epoch 15/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4921 - accuracy: 0.7424
#   93/2139 [>.............................] - ETA: 11s - loss: 0.4050 - accuracy: 0.8219Epoch 4/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5392 - accuracy: 0.7280
#  149/2139 [=>............................] - ETA: 10s - loss: 0.3983 - accuracy: 0.8238Epoch 4/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4467 - accuracy: 0.8131
# Epoch 4/30
# 2139/2139 [==============================] - 12s 6ms/step - loss: 0.4871 - accuracy: 0.7467
# 1256/2139 [================>.............] - ETA: 5s - loss: 0.4080 - accuracy: 0.8300Epoch 5/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5292 - accuracy: 0.7319
# 1365/2139 [==================>...........] - ETA: 4s - loss: 0.3974 - accuracy: 0.8196Epoch 5/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4422 - accuracy: 0.8158
# 1377/2139 [==================>...........] - ETA: 4s - loss: 0.3847 - accuracy: 0.8290Epoch 5/20
# 2139/2139 [==============================] - 12s 6ms/step - loss: 0.4517 - accuracy: 0.7830
#  971/2139 [============>.................] - ETA: 7s - loss: 0.4459 - accuracy: 0.8126Epoch 16/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.5352 - accuracy: 0.7314
#  738/1070 [===================>..........] - ETA: 1s - loss: 0.8799 - accuracy: 0.5385Epoch 5/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4450 - accuracy: 0.8139
# 1624/2139 [=====================>........] - ETA: 3s - loss: 0.4050 - accuracy: 0.8318Epoch 5/30
# 1070/1070 [==============================] - 6s 5ms/step - loss: 0.8857 - accuracy: 0.5338
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.3993 - accuracy: 0.8186
#  383/2139 [====>.........................] - ETA: 10s - loss: 0.5301 - accuracy: 0.7337Epoch 16/20
# 1463/2139 [===================>..........] - ETA: 4s - loss: 0.4439 - accuracy: 0.8148Epoch 1/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4085 - accuracy: 0.8298
# 1979/2139 [==========================>...] - ETA: 0s - loss: 0.3855 - accuracy: 0.8282Epoch 16/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4081 - accuracy: 0.8304
#  135/2139 [>.............................] - ETA: 10s - loss: 0.3875 - accuracy: 0.8407Epoch 16/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.3851 - accuracy: 0.8285
#  180/2139 [=>............................] - ETA: 15s - loss: 0.3849 - accuracy: 0.8302Epoch 16/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4305 - accuracy: 0.7984
#  852/2139 [==========>...................] - ETA: 7s - loss: 0.4404 - accuracy: 0.7889Epoch 16/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4809 - accuracy: 0.7550
# Epoch 5/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.3808 - accuracy: 0.8293
#   46/2139 [..............................] - ETA: 14s - loss: 0.4675 - accuracy: 0.7609Epoch 16/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5297 - accuracy: 0.7305
#  525/2139 [======>.......................] - ETA: 9s - loss: 0.4026 - accuracy: 0.8332Epoch 5/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4432 - accuracy: 0.8143
#  658/2139 [========>.....................] - ETA: 10s - loss: 0.3939 - accuracy: 0.8221Epoch 5/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4773 - accuracy: 0.7582
#  640/2139 [=======>......................] - ETA: 11s - loss: 0.5266 - accuracy: 0.7057Epoch 6/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.5170 - accuracy: 0.7427
# 1072/2139 [==============>...............] - ETA: 7s - loss: 0.4221 - accuracy: 0.8032Epoch 6/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4442 - accuracy: 0.7864
# 1621/2139 [=====================>........] - ETA: 3s - loss: 0.4054 - accuracy: 0.8305Epoch 17/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4385 - accuracy: 0.8171
# 1177/2139 [===============>..............] - ETA: 6s - loss: 0.5181 - accuracy: 0.7131Epoch 6/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.5268 - accuracy: 0.7363
#  286/2139 [===>..........................] - ETA: 12s - loss: 0.5217 - accuracy: 0.7362Epoch 6/30
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4418 - accuracy: 0.8155
# 1153/2139 [===============>..............] - ETA: 6s - loss: 0.5237 - accuracy: 0.7314Epoch 6/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4059 - accuracy: 0.8301
#  579/2139 [=======>......................] - ETA: 10s - loss: 0.5128 - accuracy: 0.7418Epoch 17/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.3928 - accuracy: 0.8216
# Epoch 17/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4032 - accuracy: 0.8309
# Epoch 17/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4224 - accuracy: 0.8033
# Epoch 17/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.3802 - accuracy: 0.8302
#  282/2139 [==>...........................] - ETA: 11s - loss: 0.3915 - accuracy: 0.8344Epoch 17/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4698 - accuracy: 0.7652
# 1502/2139 [====================>.........] - ETA: 3s - loss: 0.4657 - accuracy: 0.7675Epoch 6/30
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.3739 - accuracy: 0.8342
# Epoch 17/20
# 2139/2139 [==============================] - 18s 7ms/step - loss: 0.5121 - accuracy: 0.7205
# 1643/2139 [======================>.......] - ETA: 3s - loss: 0.4667 - accuracy: 0.7667Epoch 2/30
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5187 - accuracy: 0.7388
# 1029/2139 [=============>................] - ETA: 7s - loss: 0.4307 - accuracy: 0.8217Epoch 6/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4400 - accuracy: 0.8165
# 1338/2139 [=================>............] - ETA: 5s - loss: 0.5058 - accuracy: 0.7476Epoch 6/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4667 - accuracy: 0.7665
# 1753/2139 [=======================>......] - ETA: 2s - loss: 0.5055 - accuracy: 0.7487Epoch 7/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4387 - accuracy: 0.7922
# Epoch 18/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5065 - accuracy: 0.7490
#   62/2139 [..............................] - ETA: 11s - loss: 0.4114 - accuracy: 0.8095Epoch 7/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4385 - accuracy: 0.8154
#  957/2139 [============>.................] - ETA: 8s - loss: 0.5095 - accuracy: 0.7446Epoch 7/30
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4341 - accuracy: 0.8211
# Epoch 7/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5187 - accuracy: 0.7409
# 1112/2139 [==============>...............] - ETA: 7s - loss: 0.4358 - accuracy: 0.8195Epoch 7/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4022 - accuracy: 0.8318
# 1204/2139 [===============>..............] - ETA: 6s - loss: 0.4344 - accuracy: 0.8206Epoch 18/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.3880 - accuracy: 0.8243
# Epoch 18/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4001 - accuracy: 0.8314
# 1684/2139 [======================>.......] - ETA: 2s - loss: 0.3625 - accuracy: 0.8390Epoch 18/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4161 - accuracy: 0.8074
# 1643/2139 [======================>.......] - ETA: 3s - loss: 0.5027 - accuracy: 0.7299Epoch 18/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.3727 - accuracy: 0.8336
#  400/2139 [====>.........................] - ETA: 11s - loss: 0.3709 - accuracy: 0.8350Epoch 18/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.3659 - accuracy: 0.8371
#  665/2139 [========>.....................] - ETA: 9s - loss: 0.3946 - accuracy: 0.8388Epoch 18/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4573 - accuracy: 0.7735
# 1602/2139 [=====================>........] - ETA: 3s - loss: 0.4581 - accuracy: 0.7711Epoch 7/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4365 - accuracy: 0.8193
# 1184/2139 [===============>..............] - ETA: 7s - loss: 0.5007 - accuracy: 0.7516Epoch 7/30
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5006 - accuracy: 0.7300
# 1800/2139 [========================>.....] - ETA: 2s - loss: 0.4587 - accuracy: 0.7707Epoch 3/30
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.5088 - accuracy: 0.7458
#  822/2139 [==========>...................] - ETA: 8s - loss: 0.3740 - accuracy: 0.8333Epoch 7/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4570 - accuracy: 0.7718
# Epoch 8/30
# 2139/2139 [==============================] - 12s 6ms/step - loss: 0.4337 - accuracy: 0.7944
#  636/2139 [=======>......................] - ETA: 11s - loss: 0.3575 - accuracy: 0.8434Epoch 19/20
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4338 - accuracy: 0.8188
#  446/2139 [=====>........................] - ETA: 10s - loss: 0.4483 - accuracy: 0.7786Epoch 8/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.5104 - accuracy: 0.7472
# 1436/2139 [===================>..........] - ETA: 4s - loss: 0.3688 - accuracy: 0.8369Epoch 8/30
# 2139/2139 [==============================] - 16s 7ms/step - loss: 0.4982 - accuracy: 0.7539
# 1069/2139 [=============>................] - ETA: 8s - loss: 0.4450 - accuracy: 0.7863Epoch 8/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4298 - accuracy: 0.8219
# Epoch 8/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.3995 - accuracy: 0.8344
#  374/2139 [====>.........................] - ETA: 9s - loss: 0.5115 - accuracy: 0.7375Epoch 19/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.3821 - accuracy: 0.8298
# Epoch 19/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.3955 - accuracy: 0.8328
# 1887/2139 [=========================>....] - ETA: 1s - loss: 0.4073 - accuracy: 0.8122Epoch 19/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4096 - accuracy: 0.8105
# 1702/2139 [======================>.......] - ETA: 3s - loss: 0.4504 - accuracy: 0.7809Epoch 19/20
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.3671 - accuracy: 0.8375
#  346/2139 [===>..........................] - ETA: 13s - loss: 0.3786 - accuracy: 0.8470Epoch 19/20
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.3604 - accuracy: 0.8412
#  591/2139 [=======>......................] - ETA: 10s - loss: 0.3941 - accuracy: 0.8316Epoch 19/20
# 2139/2139 [==============================] - 14s 6ms/step - loss: 0.4336 - accuracy: 0.8205
# Epoch 8/30
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4467 - accuracy: 0.7834
# 2059/2139 [===========================>..] - ETA: 0s - loss: 0.4923 - accuracy: 0.7417Epoch 8/30
# 2139/2139 [==============================] - 14s 7ms/step - loss: 0.4993 - accuracy: 0.7520
#  781/2139 [=========>....................] - ETA: 8s - loss: 0.3941 - accuracy: 0.8315Epoch 8/30
# 2139/2139 [==============================] - 15s 7ms/step - loss: 0.4929 - accuracy: 0.7417
# 1866/2139 [=========================>....] - ETA: 1s - loss: 0.4501 - accuracy: 0.7780Epoch 4/30
# 2139/2139 [==============================] - 13s 6ms/step - loss: 0.4278 - accuracy: 0.7979
# ...
# Epoch 23/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4063 - accuracy: 0.8310
# 139/535 [======>.......................] - ETA: 2s - loss: 0.4305 - accuracy: 0.7984Epoch 16/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.3946 - accuracy: 0.8349
# Epoch 21/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3757 - accuracy: 0.8333
# Epoch 29/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.4452 - accuracy: 0.7877
# 205/535 [==========>...................] - ETA: 1s - loss: 0.4286 - accuracy: 0.7989Epoch 16/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3963 - accuracy: 0.8341
# Epoch 25/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3778 - accuracy: 0.8306
# Epoch 22/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4288 - accuracy: 0.7980
# 344/535 [==================>...........] - ETA: 0s - loss: 0.3964 - accuracy: 0.8344Epoch 22/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4505 - accuracy: 0.7847
#  82/535 [===>..........................] - ETA: 2s - loss: 0.3942 - accuracy: 0.8184Epoch 24/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.3715 - accuracy: 0.8361
# 523/535 [============================>.] - ETA: 0s - loss: 0.4045 - accuracy: 0.8317Epoch 19/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4037 - accuracy: 0.8319
# 523/535 [============================>.] - ETA: 0s - loss: 0.3728 - accuracy: 0.8369Epoch 17/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3726 - accuracy: 0.8370
# 521/535 [============================>.] - ETA: 0s - loss: 0.3969 - accuracy: 0.8346Epoch 30/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3970 - accuracy: 0.8344
# 470/535 [=========================>....] - ETA: 0s - loss: 0.3922 - accuracy: 0.8360Epoch 26/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.3924 - accuracy: 0.8362
# Epoch 22/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.4388 - accuracy: 0.7935
# 224/535 [===========>..................] - ETA: 1s - loss: 0.4428 - accuracy: 0.7878Epoch 17/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.3750 - accuracy: 0.8331
# 482/535 [==========================>...] - ETA: 0s - loss: 0.4250 - accuracy: 0.7983Epoch 23/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.4226 - accuracy: 0.8003
# 340/535 [==================>...........] - ETA: 1s - loss: 0.3950 - accuracy: 0.8347Epoch 23/30
# 535/535 [==============================] - 3s 4ms/step - loss: 0.7096 - accuracy: 0.6055
# 535/535 [==============================] - 3s 6ms/step - loss: 0.4463 - accuracy: 0.7873
# 361/535 [===================>..........] - ETA: 1s - loss: 0.3964 - accuracy: 0.8340Epoch 25/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3940 - accuracy: 0.8352
# Epoch 27/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.3689 - accuracy: 0.8377
# 535/535 [==============================] - 3s 6ms/step - loss: 0.3641 - accuracy: 0.8405
# 514/535 [===========================>..] - ETA: 0s - loss: 0.3996 - accuracy: 0.8324Epoch 20/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.4001 - accuracy: 0.8319
# Epoch 18/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.3890 - accuracy: 0.8368
# Epoch 23/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.4280 - accuracy: 0.7995
# Epoch 18/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3693 - accuracy: 0.8360
# Epoch 24/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.4419 - accuracy: 0.7908
# Epoch 26/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4161 - accuracy: 0.8045
# 291/535 [===============>..............] - ETA: 1s - loss: 0.3956 - accuracy: 0.8368Epoch 24/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3918 - accuracy: 0.8372
# Epoch 28/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3601 - accuracy: 0.8425
# 172/535 [========>.....................] - ETA: 1s - loss: 0.4054 - accuracy: 0.8130Epoch 21/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3861 - accuracy: 0.8393
# Epoch 24/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3962 - accuracy: 0.8352
#  27/535 [>.............................] - ETA: 2s - loss: 0.3849 - accuracy: 0.8420Epoch 19/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3654 - accuracy: 0.8384
# Epoch 25/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.4202 - accuracy: 0.8036
# Epoch 19/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3918 - accuracy: 0.8363
# Epoch 29/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4391 - accuracy: 0.7906
# 509/535 [===========================>..] - ETA: 0s - loss: 0.4117 - accuracy: 0.8100Epoch 27/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4125 - accuracy: 0.8089
# Epoch 25/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3537 - accuracy: 0.8459
# Epoch 22/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3936 - accuracy: 0.8361
# Epoch 20/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3842 - accuracy: 0.8381
# 363/535 [===================>..........] - ETA: 0s - loss: 0.3591 - accuracy: 0.8423Epoch 25/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3885 - accuracy: 0.8375
# 172/535 [========>.....................] - ETA: 1s - loss: 0.3449 - accuracy: 0.8522Epoch 30/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3609 - accuracy: 0.8411
# 424/535 [======================>.......] - ETA: 0s - loss: 0.4081 - accuracy: 0.8114Epoch 26/30
# 535/535 [==============================] - 3s 6ms/step - loss: 0.4136 - accuracy: 0.8100
#  78/535 [===>..........................] - ETA: 1s - loss: 0.3722 - accuracy: 0.8474Epoch 20/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4363 - accuracy: 0.7928
#  97/535 [====>.........................] - ETA: 1s - loss: 0.3720 - accuracy: 0.8484Epoch 28/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.4084 - accuracy: 0.8100
#  14/535 [..............................] - ETA: 2s - loss: 0.3960 - accuracy: 0.8203Epoch 26/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3805 - accuracy: 0.8399
# 372/535 [===================>..........] - ETA: 0s - loss: 0.3850 - accuracy: 0.8393Epoch 26/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3464 - accuracy: 0.8507
# 517/535 [===========================>..] - ETA: 0s - loss: 0.3906 - accuracy: 0.8354Epoch 23/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3906 - accuracy: 0.8354
# 315/535 [================>.............] - ETA: 0s - loss: 0.4017 - accuracy: 0.8135Epoch 21/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3870 - accuracy: 0.8382
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3551 - accuracy: 0.8446
# 415/535 [======================>.......] - ETA: 0s - loss: 0.4051 - accuracy: 0.8121Epoch 27/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.4333 - accuracy: 0.7967
# Epoch 29/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4026 - accuracy: 0.8123
# Epoch 27/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4071 - accuracy: 0.8107
#  70/535 [==>...........................] - ETA: 2s - loss: 0.4217 - accuracy: 0.8054Epoch 21/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3794 - accuracy: 0.8396
# Epoch 27/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3880 - accuracy: 0.8380
# Epoch 22/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3412 - accuracy: 0.8532
# Epoch 24/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3529 - accuracy: 0.8469
# Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4279 - accuracy: 0.7990
# Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3966 - accuracy: 0.8160
# Epoch 28/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4005 - accuracy: 0.8167
# Epoch 22/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3758 - accuracy: 0.8414
# Epoch 28/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3841 - accuracy: 0.8385
# 516/535 [===========================>..] - ETA: 0s - loss: 0.3360 - accuracy: 0.8556Epoch 23/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3358 - accuracy: 0.8554
# Epoch 25/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4278 - accuracy: 0.7998
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3496 - accuracy: 0.8472
# Epoch 29/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3942 - accuracy: 0.8201
# Epoch 29/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3938 - accuracy: 0.8201
# Epoch 23/30
# 268/268 [==============================] - 1s 2ms/step - loss: 0.4960 - accuracy: 0.7647
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3751 - accuracy: 0.8423
# Epoch 29/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3807 - accuracy: 0.8408
# Epoch 24/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3436 - accuracy: 0.8493
# Epoch 30/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3324 - accuracy: 0.8571
# Epoch 26/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3913 - accuracy: 0.8187
# Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3706 - accuracy: 0.8437
# Epoch 30/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3880 - accuracy: 0.8223
# Epoch 24/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3782 - accuracy: 0.8407
# Epoch 25/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3415 - accuracy: 0.8549
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3301 - accuracy: 0.8579
# 535/535 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.8249Epoch 27/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3833 - accuracy: 0.8249
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3677 - accuracy: 0.8442
# 268/268 [==============================] - 1s 2ms/step - loss: 0.6668 - accuracy: 0.6731
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3806 - accuracy: 0.8284
# Epoch 25/30
# 268/268 [==============================] - 1s 3ms/step - loss: 0.4801 - accuracy: 0.7740
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3743 - accuracy: 0.8414
# Epoch 26/30
# 268/268 [==============================] - 1s 3ms/step - loss: 0.8952 - accuracy: 0.5547
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3208 - accuracy: 0.8644
# Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3755 - accuracy: 0.8323
# Epoch 26/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3714 - accuracy: 0.8430
# Epoch 27/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3185 - accuracy: 0.8636
# Epoch 29/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3700 - accuracy: 0.8323
# Epoch 27/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3671 - accuracy: 0.8446
# Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3133 - accuracy: 0.8665
# Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3647 - accuracy: 0.8368
# Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3654 - accuracy: 0.8446
# Epoch 29/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3104 - accuracy: 0.8690
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3610 - accuracy: 0.8388
# 161/268 [=================>............] - ETA: 0s - loss: 0.6107 - accuracy: 0.7268Epoch 29/30
# 268/268 [==============================] - 1s 3ms/step - loss: 0.6101 - accuracy: 0.7243
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3611 - accuracy: 0.8458
# Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3553 - accuracy: 0.8414
# Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3595 - accuracy: 0.8479
# 268/268 [==============================] - 1s 3ms/step - loss: 0.7779 - accuracy: 0.6023
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3540 - accuracy: 0.8430
# 268/268 [==============================] - 1s 3ms/step - loss: 0.4311 - accuracy: 0.8055
# 268/268 [==============================] - 1s 3ms/step - loss: 0.6921 - accuracy: 0.6567
# 268/268 [==============================] - 1s 3ms/step - loss: 0.9389 - accuracy: 0.5525
# Epoch 1/30
# 802/802 [==============================] - 5s 4ms/step - loss: 0.5623 - accuracy: 0.7212
# Epoch 2/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.5479 - accuracy: 0.7324
# Epoch 3/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.5373 - accuracy: 0.7384
# Epoch 4/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.5259 - accuracy: 0.7426
# Epoch 5/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.5133 - accuracy: 0.7502
# Epoch 6/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.5021 - accuracy: 0.7567
# Epoch 7/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4916 - accuracy: 0.7616
# Epoch 8/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4818 - accuracy: 0.7672
# Epoch 9/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4729 - accuracy: 0.7716
# Epoch 10/30
# 802/802 [==============================] - 4s 4ms/step - loss: 0.4636 - accuracy: 0.7801
# Epoch 11/30
# 802/802 [==============================] - 4s 5ms/step - loss: 0.4530 - accuracy: 0.7825
# Epoch 12/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4465 - accuracy: 0.7877
# Epoch 13/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4375 - accuracy: 0.7916
# Epoch 14/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4298 - accuracy: 0.7976
# Epoch 15/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4224 - accuracy: 0.8008
# Epoch 16/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4140 - accuracy: 0.8070
# Epoch 17/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4086 - accuracy: 0.8094
# Epoch 18/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.4011 - accuracy: 0.8140
# Epoch 19/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3959 - accuracy: 0.8162
# Epoch 20/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3867 - accuracy: 0.8200
# Epoch 21/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3833 - accuracy: 0.8234
# Epoch 22/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3764 - accuracy: 0.8275
# Epoch 23/30
# 802/802 [==============================] - 4s 5ms/step - loss: 0.3708 - accuracy: 0.8299
# Epoch 24/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3675 - accuracy: 0.8327
# Epoch 25/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3609 - accuracy: 0.8365
# Epoch 26/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3576 - accuracy: 0.8383
# Epoch 27/30
# 802/802 [==============================] - 4s 4ms/step - loss: 0.3535 - accuracy: 0.8396
# Epoch 28/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3476 - accuracy: 0.8434
# Epoch 29/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3450 - accuracy: 0.8441
# Epoch 30/30
# 802/802 [==============================] - 3s 4ms/step - loss: 0.3408 - accuracy: 0.8472
# {'batch_size': 64, 'epochs': 30, 'hidden_units': 256}

# %%
best_model_nn_os = create_model_nn(best_params_nn_os['hidden_units'])
best_model_nn_os.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
best_model_nn_os.fit(X_train, y_train, epochs=best_params_nn_os['epochs'], batch_size=best_params_nn_os['batch_size'])
# Out:
# Epoch 1/30
# 452/452 [==============================] - 4s 5ms/step - loss: 0.3041 - accuracy: 0.8890
# Epoch 2/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2892 - accuracy: 0.8921
# Epoch 3/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2867 - accuracy: 0.8950
# Epoch 4/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2861 - accuracy: 0.8952
# Epoch 5/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2845 - accuracy: 0.8945
# Epoch 6/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2843 - accuracy: 0.8955
# Epoch 7/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2832 - accuracy: 0.8952
# Epoch 8/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2833 - accuracy: 0.8958
# Epoch 9/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2818 - accuracy: 0.8968
# Epoch 10/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2814 - accuracy: 0.8968
# Epoch 11/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2808 - accuracy: 0.8964
# Epoch 12/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2797 - accuracy: 0.8969
# Epoch 13/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2790 - accuracy: 0.8970
# Epoch 14/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2786 - accuracy: 0.8975
# Epoch 15/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2769 - accuracy: 0.8977
# Epoch 16/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2765 - accuracy: 0.8979
# Epoch 17/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2757 - accuracy: 0.8980
# Epoch 18/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2748 - accuracy: 0.8981
# Epoch 19/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2743 - accuracy: 0.8983
# Epoch 20/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2733 - accuracy: 0.8983
# Epoch 21/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2729 - accuracy: 0.8984
# Epoch 22/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2720 - accuracy: 0.9003
# Epoch 23/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2712 - accuracy: 0.9004
# Epoch 24/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2712 - accuracy: 0.8999
# Epoch 25/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2706 - accuracy: 0.9005
# Epoch 26/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2699 - accuracy: 0.9011
# Epoch 27/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2683 - accuracy: 0.8999
# Epoch 28/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2677 - accuracy: 0.9016
# Epoch 29/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2671 - accuracy: 0.9013
# Epoch 30/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.2664 - accuracy: 0.9016

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred_prob_nn_os = best_model_nn_os.predict(X_test)
y_pred_nn_os = (y_pred_prob_nn_os > 0.5).astype(int)

accuracy_nn_os = accuracy_score(y_test, y_pred_nn_os)
precision_nn_os = precision_score(y_test, y_pred_nn_os)
recall_nn_os = recall_score(y_test, y_pred_nn_os)
f1_nn_os = f1_score(y_test, y_pred_nn_os)

print('Accuracy: %.2f' % (accuracy_nn_os*100))
print('Precision: %.2f' % (precision_nn_os*100))
print('Recall: %.2f' % (recall_nn_os*100))
print('F1-score: %.2f' % (f1_nn_os*100))
# Out:
# 301/301 [==============================] - 1s 3ms/step
# Accuracy: 88.81
# Precision: 49.71
# Recall: 31.50
# F1-score: 38.56

# %%
print("Best Parameters: ", best_params_nn_os)

# Evaluate the model
print(f'Test Accuracy: {accuracy_nn_os*100:.2f}%')
# Out:
# Best Parameters:  {'batch_size': 64, 'epochs': 30, 'hidden_units': 256}
# Test Accuracy: 88.81%

# %%
y_pred_prob_nn_os = best_model_nn_os.predict(X_test)

fpr_nn_os, tpr_nn_os, thresholds_nn_os = roc_curve(y_test, y_pred_prob_nn_os)
auc_nn_os = roc_auc_score(y_test, y_pred_prob_nn_os)

plt.plot(fpr_nn_os, tpr_nn_os, label='ROC curve (AUC = {:.2f})'.format(auc_nn_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()


umbral = 0.5
y_pred_discret_nn_os = np.where(y_pred_prob_nn_os >= umbral, 1, 0)

cm_nn_os = confusion_matrix(y_test, y_pred_discret_nn_os)

sns.heatmap(cm_nn_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
#  51/301 [====>.........................] - ETA: 0s
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 301/301 [==============================] - 1s 2ms/step

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO GRADIENT NEURAL NETWORK:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Graph 1
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - NN WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Graph 2
sns.heatmap(cm_nn_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - NN WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# ### Stacked Generalization Ensemble

# %% [markdown]
# In order to solve the problem of the unbalanced dataset, we can also use different algorithms, as I stated before. One of the ones that behaves better is the Stacked Generalization Ensemble. For this algorithm, we will evaluate it with and without oversampling to analyse the impact of both solutions independently:

# %%
import pandas as pd
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier


# Define base classifiers
rf_classifier = RandomForestClassifier(random_state=random_seed)
lr_classifier = LogisticRegression(random_state=random_seed)
knn_classifier = KNeighborsClassifier()

# Define the StackingClassifier
estimators = [
    ('rf', rf_classifier),
    ('lr', lr_classifier),
    ('knn', knn_classifier)
]

stacking_classifier = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())

# Define params grid
param_grid_sc = {
    'rf__n_estimators': [100, 200, 300],
    'knn__n_neighbors': [3, 5, 7],
    'final_estimator__C': [0.1, 1, 10]
}

# Hiperparms search using GridSearchCV
grid_search_sc = GridSearchCV(stacking_classifier, param_grid_sc, cv=3, n_jobs=-1)
grid_search_sc.fit(X_train, y_train)

# Get the best params
best_params_sc = grid_search_sc.best_params_
print("Mejores parámetros:", best_params_sc)

# Use the best model to predict
best_model_sc = grid_search_sc.best_estimator_
y_pred_sc = best_model_sc.predict(X_test)

# Get the accuracy
accuracy_sc = accuracy_score(y_test, y_pred_sc)
print("Precisión:", accuracy_sc)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Mejores parámetros: {'final_estimator__C': 1, 'knn__n_neighbors': 5, 'rf__n_estimators': 300}
# Precisión: 0.8928126298296635

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_sc = best_model_sc.predict_proba(X_test)[:, 1]
fpr_sc, tpr_sc, thresholds_sc = roc_curve(y_test, y_pred_prob_sc)
auc_sc = roc_auc_score(y_test, y_pred_prob_sc)

# Plot ROC curve
plt.plot(fpr_sc, tpr_sc, label='ROC curve (AUC = {:.2f})'.format(auc_sc))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_sc = best_model_sc.predict(X_test)
cm_sc = confusion_matrix(y_test, y_pred_sc)

# Visualize confusion matrix
sns.heatmap(cm_sc, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### Stacked Generalization Ensemble (with SMOTE)

# %%
import pandas as pd
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

# Define base classifiers
rf_classifier = RandomForestClassifier(random_state=random_seed)
lr_classifier = LogisticRegression(random_state=random_seed)
knn_classifier = KNeighborsClassifier()

# Definir el StackingClassifier
estimators = [
    ('rf', rf_classifier),
    ('lr', lr_classifier),
    ('knn', knn_classifier)
]

stacking_classifier_os = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression(random_state=random_seed))

# Train StackingClassifier with the oversampled dataset
stacking_classifier_os.fit(X_train_os, y_train_os)

# Predict of test
y_pred_sc_os = stacking_classifier_os.predict(X_test)

# Get accuracy
accuracy_sc_os = accuracy_score(y_test, y_pred_sc_os)
print("Precisión:", accuracy_sc_os)
# Out:
# Precisión: 0.8674698795180723

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_sc_os = stacking_classifier_os.predict_proba(X_test)[:, 1]
fpr_sc_os, tpr_sc_os, thresholds_sc_os = roc_curve(y_test, y_pred_prob_sc_os)
auc_sc_os = roc_auc_score(y_test, y_pred_prob_sc_os)

# Plot ROC curve
plt.plot(fpr_sc_os, tpr_sc_os, label='ROC curve (AUC = {:.2f})'.format(auc_sc_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_sc_os = stacking_classifier_os.predict(X_test)
cm_sc_os = confusion_matrix(y_test, y_pred_sc_os)

# Visualize confusion matrix
sns.heatmap(cm_sc_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(16, 10))

# Graph 1
sns.heatmap(cm_sc, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Stack.Generalization Ensemble WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Graph 2
sns.heatmap(cm_sc_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Stack.Generalization Ensemble WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# ### ACCURACY AND AUC TABLE SUMMARY

# %%
import pandas as pd

# Define the variables with the models and the desired data
models = ['Logistic Regression', 'k-Nearest Neighbors(k-NN)', 'Support Vector Machines (SVM)', 'Classification Trees', 'Random Forest', 'Ada Boost', 'Gradient Boosting', 'Neural Networks (NN)', 'Stacked Generalization Ensemble']
accuracy = [accuracy_lr, accuracy_knn, accuracy_svm, accuracy_ct, accuracy_rf, test_accuracy_ab, test_accuracy_gb, accuracy_nn, accuracy_sc]
auc = [auc_lr, auc_knn, auc_svm, auc_ct, auc_rf, auc_ab, auc_gb, auc_nn, auc_sc]

# Create a dict
data_summary_no_smote = {
    'Model': models,
    'Accuracy': accuracy,
    'AUC':auc
}

# Create a DataFrame 
df_summary_no_smote = pd.DataFrame(data_summary_no_smote)

print(df_summary_no_smote)
# Out:
#                              Model  Accuracy       AUC
# 0              Logistic Regression  0.890320  0.772115
# 1        k-Nearest Neighbors(k-NN)  0.889385  0.739422
# 2    Support Vector Machines (SVM)  0.892086  0.665925
# 3             Classification Trees  0.891982  0.764056
# 4                    Random Forest  0.894163  0.784235
# 5                        Ada Boost  0.871521  0.603211
# 6                Gradient Boosting  0.895409  0.795904
# 7             Neural Networks (NN)  0.893124  0.782209
# 8  Stacked Generalization Ensemble  0.892813  0.783604

# %%
import pandas as pd

# Define the variables with the models and the desired data
models = ['Logistic Regression', 'k-Nearest Neighbors(k-NN)', 'Random Forest', 'Gradient Boosting', 'Neural Networks (NN)', 'Stacked Generalization Ensemble']
accuracy = [accuracy_lr_os, accuracy_knn_os, accuracy_rf_os, test_accuracy_gb_os, accuracy_nn_os, accuracy_sc_os]
auc = [auc_lr, auc_knn_os, auc_rf_os, auc_gb_os, auc_nn_os, auc_sc_os]

# Create a dict
data_summary_smote = {
    'Model': models,
    'Accuracy': accuracy,
    'AUC':auc
}

# Create a DataFrame 
df_summary_smote = pd.DataFrame(data_summary_smote)

# Mostrar el DataFrame
print(df_summary_smote)
# Out:
#                              Model  Accuracy       AUC
# 0              Logistic Regression  0.775550  0.772115
# 1        k-Nearest Neighbors(k-NN)  0.839738  0.669491
# 2                    Random Forest  0.880349  0.764005
# 3                Gradient Boosting  0.887412  0.749553
# 4             Neural Networks (NN)  0.888139  0.771055
# 5  Stacked Generalization Ensemble  0.867470  0.731271
