# %% [markdown]
# ### MACHINE LEARNING MODELS FOR THE BANK MARKETING DATASET (K=10 l=2)

# %% [markdown]
# First of all, we will perform data curation and preparation. Next, we will apply the following Machine Learning models:
#
# - Linear Regression
# - k-Nearest Neighbors(k-NN)
# - Support Vector Machines (SVM)
# - Classification Trees
# - Random Forest
# - Ada Boosting
# - Gradient Boosting
# - Neural Networks(NN)

# %% [markdown]
# **Import the necessary libraries:**

# %% [markdown]
# We try to eliminate the warnings that come up when some cells are executed:

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.warn("ignore")
warnings.simplefilter('ignore')

# %% [markdown]
# Now we import the libraries needed for executing the models and visualize the plots:

# %%
from imblearn.over_sampling import SMOTE

# %%
# %matplotlib inline
import pandas as pd
import pandas_profiling as pp
import numpy as np

from sklearn.metrics import accuracy_score, classification_report, make_scorer, roc_curve, roc_auc_score, confusion_matrix, precision_score, recall_score, f1_score

from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

import matplotlib.pyplot as plt
import shap
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2023-07-07 18:55:22.081805: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-07 18:55:22.128347: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# **Load the dataset**

# %%
file_name = "/home/carmen/Escritorio/TFM/ml_anonymization/datasets/bank_dataset/csv/bank_k_10_l2-anonymized.csv"
df = pd.read_csv(file_name, sep=";")

# %% [markdown]
# **We check that we have loaded the dataset correctly by showing the first 5 rows of the dataset**

# %%
df.head()
# Out:
#         age       job  marital            education  default housing loan  \
# 0  [40, 60[  Employed  married  Professional Course  unknown      no   no
# 1  [40, 60[   Unknown  married                Basic       no      no   no
# 2  [40, 60[  Employed  married    University Degree       no     yes   no
# 3  [40, 60[  Employed  married    University Degree       no      no   no
# 4  [40, 60[  Employed  married                Basic  unknown     yes   no
#
#      contact month day_of_week  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0  telephone   jun         thu           1.4          94.465          -41.8
# 1  telephone   may         thu           1.1          93.994          -36.4
# 2   cellular   sep         thu          -3.4          92.379          -29.8
# 3   cellular   apr         mon          -1.8          93.075          -47.1
# 4  telephone   jun         wed           1.4          94.465          -41.8
#
#    euribor3m    y
# 0      4.961   no
# 1      4.855   no
# 2      0.778  yes
# 3      1.405   no
# 4      4.864   no

# %% [markdown]
# **We explore the original dataset**

# %%
print(df.head())
print(df.info())
print(df.describe())
print(df.shape)
# Out:
#         age       job  marital            education  default housing loan  \
# 0  [40, 60[  Employed  married  Professional Course  unknown      no   no
# 1  [40, 60[   Unknown  married                Basic       no      no   no
# 2  [40, 60[  Employed  married    University Degree       no     yes   no
# 3  [40, 60[  Employed  married    University Degree       no      no   no
# 4  [40, 60[  Employed  married                Basic  unknown     yes   no
#
#      contact month day_of_week  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0  telephone   jun         thu           1.4          94.465          -41.8
# 1  telephone   may         thu           1.1          93.994          -36.4
# 2   cellular   sep         thu          -3.4          92.379          -29.8
# 3   cellular   apr         mon          -1.8          93.075          -47.1
# 4  telephone   jun         wed           1.4          94.465          -41.8
#
#    euribor3m    y
# 0      4.961   no
# 1      4.855   no
# 2      0.778  yes
# 3      1.405   no
# 4      4.864   no
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  object
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  emp.var.rate    41188 non-null  float64
#  11  cons.price.idx  41188 non-null  float64
#  12  cons.conf.idx   41188 non-null  float64
#  13  euribor3m       41188 non-null  float64
#  14  y               41188 non-null  object
# dtypes: float64(4), object(11)
# memory usage: 4.7+ MB
# None
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m
# count  41188.000000    41188.000000   41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291
# std        1.570960        0.578840       4.628198      1.734447
# min       -3.400000       92.201000     -50.800000      0.634000
# 25%       -1.800000       93.075000     -42.700000      1.344000
# 50%        1.100000       93.749000     -41.800000      4.857000
# 75%        1.400000       93.994000     -36.400000      4.961000
# max        1.400000       94.767000     -26.900000      5.045000
# (41188, 15)

# %% [markdown]
# **We check if there is any null value to remove it if exists:**

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# y                 0
# dtype: int64

# %% [markdown]
# **Delete anonymized records**:

# %%
q_i=["age","job","marital","education","default","housing","loan"]
a_s = ["y"]

def delete_rows(file_name, quasi_ident, fillna=True):
    """Delete the rows of the given file in which all QIs are set to *."""
    df = pd.read_csv(file_name, sep = ";")
    df_qi = df[quasi_ident]
    tmp = df_qi[df_qi == ["*"] * len(quasi_ident)]
    tmp.dropna(inplace=True)
    df_new=df.drop(tmp.index.values, axis = 0).reset_index()
    print(df_new)
    return df_new

# %%
df = delete_rows(file_name,q_i)
# Out:
#        index       age         job   marital            education  default  \
# 0          0  [40, 60[    Employed   married  Professional Course  unknown
# 1          1  [40, 60[     Unknown   married                Basic       no
# 2          2  [40, 60[    Employed   married    University Degree       no
# 3          3  [40, 60[    Employed   married    University Degree       no
# 4          4  [40, 60[    Employed   married                Basic  unknown
# ...      ...       ...         ...       ...                  ...      ...
# 38534  41183  [20, 40[  unemployed   married    University Degree       no
# 38535  41184  [20, 40[    Employed   married    University Degree       no
# 38536  41185  [40, 60[    Employed   married  Professional Course       no
# 38537  41186  [40, 60[    Employed  divorced              Unknown       no
# 38538  41187  [40, 60[    Employed   married          HIgh School  unknown
#
#       housing loan    contact month day_of_week  emp.var.rate  cons.price.idx  \
# 0          no   no  telephone   jun         thu           1.4          94.465
# 1          no   no  telephone   may         thu           1.1          93.994
# 2         yes   no   cellular   sep         thu          -3.4          92.379
# 3          no   no   cellular   apr         mon          -1.8          93.075
# 4         yes   no  telephone   jun         wed           1.4          94.465
# ...       ...  ...        ...   ...         ...           ...             ...
# 38534      no   no  telephone   jun         fri           1.4          94.465
# 38535     yes   no   cellular   aug         wed           1.4          93.444
# 38536      no  yes  telephone   oct         tue          -3.4          92.431
# 38537     yes   no   cellular   nov         thu          -3.4          92.649
# 38538      no   no  telephone   may         thu           1.1          93.994
#
#        cons.conf.idx  euribor3m    y
# 0              -41.8      4.961   no
# 1              -36.4      4.855   no
# 2              -29.8      0.778  yes
# 3              -47.1      1.405   no
# 4              -41.8      4.864   no
# ...              ...        ...  ...
# 38534          -41.8      4.967   no
# 38535          -36.1      4.964   no
# 38536          -26.9      0.742   no
# 38537          -30.1      0.714  yes
# 38538          -36.4      4.860   no
#
# [38539 rows x 16 columns]

# %% [markdown]
# **Convert categorical to factors and store in a dictionary all the mapping:**
#
# We discretise the variables in order to better manage the data in the dataset.

# %%
df["job"] = df["job"].astype("category").cat.codes
df["marital"] = df["marital"].astype("category").cat.codes
df["education"] = df["education"].astype("category").cat.codes
df["default"] = df["default"].astype("category").cat.codes
df["housing"] = df["housing"].astype("category").cat.codes
df["loan"] = df["loan"].astype("category").cat.codes
df["contact"] = df["contact"].astype("category").cat.codes
df["month"] = df["month"].astype("category").cat.codes
df["day_of_week"] = df["day_of_week"].astype("category").cat.codes
df["y"] = df["y"].astype("category").cat.codes
df["age"] = df["age"].astype("category").cat.codes

# %% [markdown]
# We inspect the dataset to make sure everything has work properly:

# %%
df = df.drop('index', axis=1)
df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        2    0        1          2        1        0     0        1      4
# 1        2    3        1          0        0        0     0        1      6
# 2        2    0        1          3        0        2     0        0      9
# 3        2    0        1          3        0        0     0        0      0
# 4        2    0        1          0        1        2     0        1      4
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 38534    1    4        1          3        0        0     0        1      4
# 38535    1    0        1          3        0        2     0        0      1
# 38536    2    0        1          2        0        0     2        1      8
# 38537    2    0        0          4        0        2     0        0      7
# 38538    2    0        1          1        1        0     0        1      6
#
#        day_of_week  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  y
# 0                2           1.4          94.465          -41.8      4.961  0
# 1                2           1.1          93.994          -36.4      4.855  0
# 2                2          -3.4          92.379          -29.8      0.778  1
# 3                1          -1.8          93.075          -47.1      1.405  0
# 4                4           1.4          94.465          -41.8      4.864  0
# ...            ...           ...             ...            ...        ... ..
# 38534            0           1.4          94.465          -41.8      4.967  0
# 38535            4           1.4          93.444          -36.1      4.964  0
# 38536            3          -3.4          92.431          -26.9      0.742  0
# 38537            2          -3.4          92.649          -30.1      0.714  1
# 38538            2           1.1          93.994          -36.4      4.860  0
#
# [38539 rows x 15 columns]

# %% [markdown]
# Before starting we have to define a random state value in order to achieve reproducibility of the models:

# %%
random_seed = 14

# %% [markdown]
# **We divide the dataset in train and test**

# %%
X = df.drop(["y"], axis=1)
y = df["y"]

# We add stratify for making sure that the random split has 25% of 0's and 75% of 1's.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=random_seed, stratify=y)

# %% [markdown]
# **We check that the shapes of the splitted sets are correct as expected**

# %%
print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (28904, 14)
# X_test shape: (9635, 14)
# y_train: (28904,)
# y_test shape: (9635,)

# %% [markdown]
# **Finally we do the scaling in train and test separately**
#
# We scale variables separately in train and test because this way we avoid biases. In addition, we manage to maintain the relative scale, i.e., all characteristics have a similar scale.

# %%
scaler = MinMaxScaler()
scaler = scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# We check the new scaled values in the respectivew partitions created:

# %%
X_train
# Out:
# array([[0.5       , 0.        , 0.33333333, ..., 0.66913484, 0.33891213,
#         0.9809567 ],
#        [0.5       , 0.        , 0.33333333, ..., 0.69875292, 0.60251046,
#         0.95692587],
#        [0.25      , 0.        , 0.33333333, ..., 0.26968044, 0.19246862,
#         0.14667876],
#        ...,
#        [0.25      , 0.        , 0.33333333, ..., 0.26968044, 0.19246862,
#         0.13965087],
#        [0.5       , 0.        , 0.33333333, ..., 0.06936867, 0.87866109,
#         0.03332578],
#        [0.25      , 0.        , 0.66666667, ..., 0.66913484, 0.33891213,
#         0.98072999]])

# %%
X_test
# Out:
# array([[0.25      , 0.        , 0.33333333, ..., 0.3893219 , 0.36820084,
#         0.78032192],
#        [0.75      , 0.        , 0.33333333, ..., 0.93530787, 0.05439331,
#         0.0913625 ],
#        [0.5       , 0.        , 0.33333333, ..., 0.3893219 , 0.36820084,
#         0.79777828],
#        ...,
#        [0.5       , 0.        , 0.33333333, ..., 0.69875292, 0.60251046,
#         0.95737928],
#        [0.25      , 0.        , 0.33333333, ..., 0.66913484, 0.33891213,
#         0.98050329],
#        [0.25      , 0.        , 0.33333333, ..., 0.3893219 , 0.36820084,
#         0.78032192]])

# %% [markdown]
# **We start evaluating the proposed models:**

# %% [markdown]
# ### LOGISTIC REGRESSION:
# #### Linear regression method for binary classification problems

# %% [markdown]
#  We create and train the logistic regression model

# %%
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# We make the predictions on the test partition:

# %%
y_pred_lr = model_lr.predict(X_test)

# %% [markdown]
# We evaluate the model obtained:

# %%
accuracy_lr = accuracy_score(y_test, y_pred_lr)
report_lr = classification_report(y_test, y_pred_lr)
print("Accuracy:", accuracy_lr)
print("Classification Report:\n", report_lr)
# Out:
# Accuracy: 0.8919564089257914
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      8550
#            1       0.59      0.13      0.21      1085
#
#     accuracy                           0.89      9635
#    macro avg       0.75      0.56      0.58      9635
# weighted avg       0.86      0.89      0.86      9635

# %% [markdown]
# We illustrate the results obtained by drawaing the ROC curve and the confusion matrix:

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_lr = model_lr.predict_proba(X_test)[:, 1]
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_pred_prob_lr)
auc_lr = roc_auc_score(y_test, y_pred_prob_lr)

# Plot ROC curve
plt.plot(fpr_lr, tpr_lr, label='ROC curve (AUC = {:.2f})'.format(auc_lr))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_lr = model_lr.predict(X_test)
cm_lr = confusion_matrix(y_test, y_pred_lr)

# Visualize confusion matrix
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
fig_lr = plt.gcf()  # Obtener la figura actual
plt.show()

# %% [markdown]
# ### KNN (K k nearest neighbours)

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_knn = {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'algorithm': ['ball_tree', 'kd_tree', 'brute']}

# %% [markdown]
# We create the classifier

# %%
knn = KNeighborsClassifier()

# %% [markdown]
# We create the GridSearch object

# %%
# refit true, to retrain with all data
grid_search_knn = GridSearchCV(knn, param_grid_knn, cv=3, refit=True, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_knn.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
print("Best hyperparameters:", grid_search_knn.best_params_)
print("Accuracy score:", grid_search_knn.best_score_)
# Out:
# Best hyperparameters: {'algorithm': 'brute', 'n_neighbors': 11, 'weights': 'uniform'}
# Accuracy score: 0.8873167298671958

# %% [markdown]
# Get the best model and its predictions

# %%
best_model_knn = grid_search_knn.best_estimator_
y_pred_knn = best_model_knn.predict(X_test)

# %% [markdown]
# Evaluate the best model over test partition

# %%
accuracy_knn = accuracy_score(y_test, y_pred_knn)
report_knn = classification_report(y_test, y_pred_knn)
print("Best Parameters:", grid_search_knn.best_params_)
print("Accuracy:", accuracy_knn)
print("Classification Report:\n", report_knn)
# Out:
# Best Parameters: {'algorithm': 'brute', 'n_neighbors': 11, 'weights': 'uniform'}
# Accuracy: 0.8892579138557343
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      8550
#            1       0.52      0.19      0.28      1085
#
#     accuracy                           0.89      9635
#    macro avg       0.71      0.58      0.61      9635
# weighted avg       0.86      0.89      0.87      9635

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_knn = best_model_knn.predict_proba(X_test)[:, 1]
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test, y_pred_prob_knn)
auc_knn = roc_auc_score(y_test, y_pred_prob_knn)

# Plot ROC curve
plt.plot(fpr_knn, tpr_knn, label='ROC curve (AUC = {:.2f})'.format(auc_knn))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_knn = best_model_knn.predict(X_test)
cm_knn = confusion_matrix(y_test, y_pred_knn)

# Visualize confusion matrix
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### CLASSIFICATION TREES

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_ct = {'max_depth': [3, 5, 7, 9, None],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

# %% [markdown]
# We create the model classifier

# %%
model_ct = DecisionTreeClassifier(random_state=random_seed)

# %% [markdown]
# We create the GridSearch object

# %%
grid_search_ct = GridSearchCV(model_ct, param_grid_ct, cv=3, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_ct.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=14), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 9, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %% [markdown]
# We obtain and store the best model and the prediction

# %%
best_model_ct = grid_search_ct.best_estimator_
y_pred_ct = best_model_ct.predict(X_test)

# %% [markdown]
# Evaluate the best model

# %%
accuracy_ct = accuracy_score(y_test, y_pred_ct)
report_ct = classification_report(y_test, y_pred_ct)
print("Best Parameters:", grid_search_ct.best_params_)
print("Accuracy:", accuracy_ct)
print("Classification Report:\n", report_ct)
# Out:
# Best Parameters: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.8942397509081473
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8550
#            1       0.59      0.21      0.31      1085
#
#     accuracy                           0.89      9635
#    macro avg       0.75      0.59      0.62      9635
# weighted avg       0.87      0.89      0.87      9635

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_ct = best_model_ct.predict_proba(X_test)[:, 1]
fpr_ct, tpr_ct, thresholds_ct = roc_curve(y_test, y_pred_prob_ct)
auc_ct = roc_auc_score(y_test, y_pred_prob_ct)

# Plot ROC curve
plt.plot(fpr_ct, tpr_ct, label='ROC curve (AUC = {:.2f})'.format(auc_ct))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_ct = best_model_ct.predict(X_test)
cm_ct = confusion_matrix(y_test, y_pred_ct)

# Visualize confusion matrix
sns.heatmap(cm_ct, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### RANDOM FOREST

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_rf = {"n_estimators": [50, 100, 200],
              "max_depth": [None, 5, 10],
              "min_samples_split": [2, 5, 10],
              "min_samples_leaf": [1, 2, 4]}

# %% [markdown]
# We create the classifier

# %%
rfc = RandomForestClassifier(random_state=random_seed)

# %% [markdown]
# We create the GridSearch object

# %%
grid_search_rf = GridSearchCV(rfc, param_grid_rf, cv=3, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=14), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
print("Best hyperparameters:", grid_search_rf.best_params_)
print("Accuracy score:", grid_search_rf.best_score_)
# Out:
# Best hyperparameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy score: 0.8938209062301224

# %%
best_model_rf = grid_search_rf.best_estimator_
y_pred_rf = best_model_rf.predict(X_test)

# %%
accuracy_rf = accuracy_score(y_test, y_pred_rf)
report_rf = classification_report(y_test, y_pred_rf)
print("Best Parameters:", grid_search_rf.best_params_)
print("Accuracy:", accuracy_rf)
print("Classification Report:\n", report_rf)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.8968344577062792
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8550
#            1       0.62      0.21      0.32      1085
#
#     accuracy                           0.90      9635
#    macro avg       0.76      0.60      0.63      9635
# weighted avg       0.88      0.90      0.87      9635

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_rf = best_model_rf.predict_proba(X_test)[:, 1]
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_prob_rf)
auc_rf = roc_auc_score(y_test, y_pred_prob_rf)

# Plot ROC curve
plt.plot(fpr_rf, tpr_rf, label='ROC curve (AUC = {:.2f})'.format(auc_rf))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_rf = best_model_rf.predict(X_test)
cm_rf = confusion_matrix(y_test, y_pred_rf)

# Visualize confusion matrix
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### SVM (Support Vector Machine)

# %%
param_grid_svm = {"C": [0.1, 0.25, 0.5, 0.75, 1, 2],
              "kernel": ["linear", "poly", "rbf", "sigmoid"],
              "gamma": ["scale", "auto"]}

# %%
svm = SVC()

# %%
grid_search_svm = GridSearchCV(svm, param_grid_svm, cv=3, n_jobs=-1)

# %%
grid_search_svm.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 0.25, 0.5, 0.75, 1, 2],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
print("Best hyperparameters:", grid_search_svm.best_params_)
print("Accuracy score:", grid_search_svm.best_score_)
# Out:
# Best hyperparameters: {'C': 0.5, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy score: 0.8931635445975173

# %%
best_model_svm = grid_search_svm.best_estimator_
y_pred_svm = best_model_svm.predict(X_test)

# %%
accuracy_svm = accuracy_score(y_test, y_pred_svm)
report_svm = classification_report(y_test, y_pred_svm)
print("Best Parameters:", grid_search_svm.best_params_)
print("Accuracy:", accuracy_svm)
print("Classification Report:\n", report_svm)
# Out:
# Best Parameters: {'C': 0.5, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy: 0.8938245978204463
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      8550
#            1       0.60      0.17      0.26      1085
#
#     accuracy                           0.89      9635
#    macro avg       0.75      0.58      0.60      9635
# weighted avg       0.87      0.89      0.87      9635

# %%
# Generate decision scores
y_pred_scores_svm = best_model_svm.decision_function(X_test)

# Calculate FPR, TPR, and AUC
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, y_pred_scores_svm)
auc_svm = roc_auc_score(y_test, y_pred_scores_svm)

# Plot ROC curve
plt.plot(fpr_svm, tpr_svm, label='ROC curve (AUC = {:.2f})'.format(auc_svm))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_svm = best_model_svm.predict(X_test)
cm_svm = confusion_matrix(y_test, y_pred_svm)

# Visualize confusion matrix
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### NEURAL NETWORK:

# %% [markdown]
# We start creating the model function

# %%
def create_model_nn(hidden_units=128):
    model = Sequential()
    model.add(Dense(hidden_units, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Define the parameter grid
param_grid_nn = {
    'hidden_units': [64, 128, 256],
    'epochs': [10, 20, 30],
    'batch_size': [16, 32, 64]
}

# Create the model
model_nn = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn=create_model_nn)

# Perform grid search
grid_search_nn = GridSearchCV(model_nn, param_grid_nn, cv=3, n_jobs=-1)

# %%
grid_search_nn.fit(X_train, y_train)

# Get the best parameters
best_params_nn = grid_search_nn.best_params_
best_params_nn
# Out:
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2983 - accuracy: 0.8902
# 1191/1205 [============================>.] - ETA: 0s - loss: 0.3041 - accuracy: 0.8902Epoch 2/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.3039 - accuracy: 0.8900
# 1201/1205 [============================>.] - ETA: 0s - loss: 0.3056 - accuracy: 0.8855Epoch 2/10
# 1205/1205 [==============================] - 9s 6ms/step - loss: 0.3059 - accuracy: 0.8854
# 1068/1205 [=========================>....] - ETA: 0s - loss: 0.3007 - accuracy: 0.8914Epoch 2/10
# 1205/1205 [==============================] - 9s 6ms/step - loss: 0.2988 - accuracy: 0.8897
# 1205/1205 [==============================] - 9s 6ms/step - loss: 0.3038 - accuracy: 0.8885
# Epoch 2/10
# 1136/1205 [===========================>..] - ETA: 0s - loss: 0.3044 - accuracy: 0.8881Epoch 2/20
# 1205/1205 [==============================] - 9s 6ms/step - loss: 0.3060 - accuracy: 0.8864
#   19/1205 [..............................] - ETA: 6s - loss: 0.3280 - accuracy: 0.8849Epoch 2/10
# 1205/1205 [==============================] - 9s 6ms/step - loss: 0.3038 - accuracy: 0.8900
#   61/1205 [>.............................] - ETA: 7s - loss: 0.2707 - accuracy: 0.8975Epoch 2/20
# 1205/1205 [==============================] - 9s 6ms/step - loss: 0.3034 - accuracy: 0.8887
# Epoch 2/10
# 1205/1205 [==============================] - 9s 6ms/step - loss: 0.3083 - accuracy: 0.8865
#  131/1205 [==>...........................] - ETA: 6s - loss: 0.2581 - accuracy: 0.9055Epoch 2/20
# 1205/1205 [==============================] - 10s 6ms/step - loss: 0.2981 - accuracy: 0.8915
# 1205/1205 [==============================] - 10s 7ms/step - loss: 0.3010 - accuracy: 0.8900
#  122/1205 [==>...........................] - ETA: 6s - loss: 0.3091 - accuracy: 0.8776Epoch 2/20
# Epoch 2/20
# 1205/1205 [==============================] - 9s 6ms/step - loss: 0.2989 - accuracy: 0.8915
#   85/1205 [=>............................] - ETA: 10s - loss: 0.3028 - accuracy: 0.8963Epoch 2/20
# 1205/1205 [==============================] - 10s 7ms/step - loss: 0.3077 - accuracy: 0.8859
#   87/1205 [=>............................] - ETA: 8s - loss: 0.2855 - accuracy: 0.9016Epoch 2/10
# 1205/1205 [==============================] - 10s 7ms/step - loss: 0.2978 - accuracy: 0.8899
#  197/1205 [===>..........................] - ETA: 6s - loss: 0.2752 - accuracy: 0.8978Epoch 2/10
# 1205/1205 [==============================] - 10s 7ms/step - loss: 0.3059 - accuracy: 0.8860
#  292/1205 [======>.......................] - ETA: 5s - loss: 0.2860 - accuracy: 0.8902Epoch 2/10
# 1205/1205 [==============================] - 10s 7ms/step - loss: 0.3061 - accuracy: 0.8859
#  152/1205 [==>...........................] - ETA: 8s - loss: 0.2732 - accuracy: 0.8964Epoch 2/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2911 - accuracy: 0.8918
#  911/1205 [=====================>........] - ETA: 2s - loss: 0.2818 - accuracy: 0.8965Epoch 3/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2918 - accuracy: 0.8910
#  892/1205 [=====================>........] - ETA: 2s - loss: 0.2957 - accuracy: 0.8898Epoch 3/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2880 - accuracy: 0.8930
# Epoch 3/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2867 - accuracy: 0.8940
#  964/1205 [=======================>......] - ETA: 1s - loss: 0.2953 - accuracy: 0.8902Epoch 3/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2955 - accuracy: 0.8902
# 1003/1205 [=======================>......] - ETA: 1s - loss: 0.2897 - accuracy: 0.8923Epoch 3/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2950 - accuracy: 0.8901
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2926 - accuracy: 0.8924
# Epoch 3/10
#    1/1205 [..............................] - ETA: 4s - loss: 0.1363 - accuracy: 0.9375Epoch 3/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2922 - accuracy: 0.8921
# Epoch 3/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2919 - accuracy: 0.8935
#  141/1205 [==>...........................] - ETA: 9s - loss: 0.2849 - accuracy: 0.8963Epoch 3/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2877 - accuracy: 0.8927
# Epoch 3/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2917 - accuracy: 0.8920
# 1059/1205 [=========================>....] - ETA: 0s - loss: 0.2932 - accuracy: 0.8899Epoch 3/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2875 - accuracy: 0.8930
# 1160/1205 [===========================>..] - ETA: 0s - loss: 0.2956 - accuracy: 0.8895Epoch 3/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2874 - accuracy: 0.8939
# 1181/1205 [============================>.] - ETA: 0s - loss: 0.2960 - accuracy: 0.8897Epoch 3/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2955 - accuracy: 0.8896
#  113/1205 [=>............................] - ETA: 6s - loss: 0.3003 - accuracy: 0.8921Epoch 3/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2950 - accuracy: 0.8895
#  402/1205 [=========>....................] - ETA: 4s - loss: 0.3005 - accuracy: 0.8910Epoch 3/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2951 - accuracy: 0.8904
#  323/1205 [=======>......................] - ETA: 5s - loss: 0.2930 - accuracy: 0.8920Epoch 3/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2903 - accuracy: 0.8924
#  813/1205 [===================>..........] - ETA: 2s - loss: 0.2906 - accuracy: 0.8942Epoch 4/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2850 - accuracy: 0.8943
# 1007/1205 [========================>.....] - ETA: 1s - loss: 0.2954 - accuracy: 0.8909Epoch 4/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2940 - accuracy: 0.8914
#  979/1205 [=======================>......] - ETA: 1s - loss: 0.2902 - accuracy: 0.8925Epoch 4/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2900 - accuracy: 0.8928
# 1111/1205 [==========================>...] - ETA: 0s - loss: 0.2881 - accuracy: 0.8937Epoch 4/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2943 - accuracy: 0.8899
#  137/1205 [==>...........................] - ETA: 6s - loss: 0.2974 - accuracy: 0.8887Epoch 4/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2851 - accuracy: 0.8939
#  169/1205 [===>..........................] - ETA: 6s - loss: 0.2979 - accuracy: 0.8879Epoch 4/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2898 - accuracy: 0.8927
# Epoch 4/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2899 - accuracy: 0.8932
# Epoch 4/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2865 - accuracy: 0.8935
# 1109/1205 [==========================>...] - ETA: 0s - loss: 0.2847 - accuracy: 0.8960Epoch 4/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2900 - accuracy: 0.8917
#  136/1205 [==>...........................] - ETA: 7s - loss: 0.2808 - accuracy: 0.8961Epoch 4/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2902 - accuracy: 0.8918
#    1/1205 [..............................] - ETA: 16s - loss: 0.2813 - accuracy: 0.8750Epoch 4/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2860 - accuracy: 0.8936
#  194/1205 [===>..........................] - ETA: 7s - loss: 0.2863 - accuracy: 0.8918Epoch 4/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2847 - accuracy: 0.8953
# Epoch 4/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2938 - accuracy: 0.8922
# Epoch 4/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2932 - accuracy: 0.8892
#  295/1205 [======>.......................] - ETA: 6s - loss: 0.2842 - accuracy: 0.8966Epoch 4/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2935 - accuracy: 0.8909
#  173/1205 [===>..........................] - ETA: 6s - loss: 0.2893 - accuracy: 0.8927Epoch 4/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2895 - accuracy: 0.8932
#  778/1205 [==================>...........] - ETA: 2s - loss: 0.2805 - accuracy: 0.8964Epoch 5/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2834 - accuracy: 0.8950
#  905/1205 [=====================>........] - ETA: 1s - loss: 0.2866 - accuracy: 0.8956Epoch 5/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2894 - accuracy: 0.8926
# Epoch 5/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2843 - accuracy: 0.8941
#   50/1205 [>.............................] - ETA: 4s - loss: 0.3204 - accuracy: 0.8838Epoch 5/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2924 - accuracy: 0.8915
#  871/1205 [====================>.........] - ETA: 2s - loss: 0.2863 - accuracy: 0.8945Epoch 5/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2886 - accuracy: 0.8941
#  227/1205 [====>.........................] - ETA: 5s - loss: 0.2862 - accuracy: 0.8937Epoch 5/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2893 - accuracy: 0.8943
# 1095/1205 [==========================>...] - ETA: 0s - loss: 0.2844 - accuracy: 0.8927Epoch 5/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2849 - accuracy: 0.8945
# 1140/1205 [===========================>..] - ETA: 0s - loss: 0.2898 - accuracy: 0.8925Epoch 5/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2928 - accuracy: 0.8914
# Epoch 5/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2899 - accuracy: 0.8945
# Epoch 5/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2895 - accuracy: 0.8923
#   65/1205 [>.............................] - ETA: 6s - loss: 0.2624 - accuracy: 0.9115Epoch 5/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2846 - accuracy: 0.8929
# Epoch 5/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2927 - accuracy: 0.8914
#  181/1205 [===>..........................] - ETA: 6s - loss: 0.2922 - accuracy: 0.8943Epoch 5/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2925 - accuracy: 0.8910
#  634/1205 [==============>...............] - ETA: 3s - loss: 0.2874 - accuracy: 0.8943Epoch 5/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2844 - accuracy: 0.8939
#  386/1205 [========>.....................] - ETA: 4s - loss: 0.2919 - accuracy: 0.8905Epoch 5/10
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2936 - accuracy: 0.8913
# Epoch 5/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2882 - accuracy: 0.8941
# Epoch 6/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2827 - accuracy: 0.8937
#  658/1205 [===============>..............] - ETA: 4s - loss: 0.2912 - accuracy: 0.8929Epoch 6/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2831 - accuracy: 0.8940
#  960/1205 [======================>.......] - ETA: 1s - loss: 0.2889 - accuracy: 0.8947Epoch 6/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2877 - accuracy: 0.8946
#  876/1205 [====================>.........] - ETA: 2s - loss: 0.2968 - accuracy: 0.8869Epoch 6/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2913 - accuracy: 0.8920
# 1097/1205 [==========================>...] - ETA: 0s - loss: 0.2894 - accuracy: 0.8943Epoch 6/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2835 - accuracy: 0.8944
#  968/1205 [=======================>......] - ETA: 1s - loss: 0.2906 - accuracy: 0.8900Epoch 6/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2880 - accuracy: 0.8952
#  983/1205 [=======================>......] - ETA: 1s - loss: 0.2919 - accuracy: 0.8910Epoch 6/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2884 - accuracy: 0.8941
# 1020/1205 [========================>.....] - ETA: 1s - loss: 0.2917 - accuracy: 0.8910Epoch 6/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2915 - accuracy: 0.8900
#  113/1205 [=>............................] - ETA: 6s - loss: 0.2868 - accuracy: 0.8916Epoch 6/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2882 - accuracy: 0.8935
# Epoch 6/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2883 - accuracy: 0.8912
#   89/1205 [=>............................] - ETA: 6s - loss: 0.2397 - accuracy: 0.9136Epoch 6/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2913 - accuracy: 0.8919
# 1188/1205 [============================>.] - ETA: 0s - loss: 0.2841 - accuracy: 0.8930Epoch 6/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2832 - accuracy: 0.8931
#  217/1205 [====>.........................] - ETA: 6s - loss: 0.2840 - accuracy: 0.8949Epoch 6/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2914 - accuracy: 0.8908
# 1117/1205 [==========================>...] - ETA: 0s - loss: 0.2838 - accuracy: 0.8936Epoch 6/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2828 - accuracy: 0.8940
#  618/1205 [==============>...............] - ETA: 4s - loss: 0.2797 - accuracy: 0.8956Epoch 6/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2921 - accuracy: 0.8901
# Epoch 6/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2879 - accuracy: 0.8948
#  648/1205 [===============>..............] - ETA: 3s - loss: 0.2815 - accuracy: 0.8961Epoch 7/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2812 - accuracy: 0.8954
#  666/1205 [===============>..............] - ETA: 3s - loss: 0.2904 - accuracy: 0.8916Epoch 7/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2875 - accuracy: 0.8945
# Epoch 7/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2911 - accuracy: 0.8920
# Epoch 7/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2827 - accuracy: 0.8939
#  877/1205 [====================>.........] - ETA: 2s - loss: 0.2878 - accuracy: 0.8940Epoch 7/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2831 - accuracy: 0.8944
# Epoch 7/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2864 - accuracy: 0.8958
#  141/1205 [==>...........................] - ETA: 6s - loss: 0.2943 - accuracy: 0.8887Epoch 7/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2879 - accuracy: 0.8944
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2908 - accuracy: 0.8915
#  939/1205 [======================>.......] - ETA: 1s - loss: 0.2871 - accuracy: 0.8932Epoch 7/10
#  880/1205 [====================>.........] - ETA: 2s - loss: 0.2806 - accuracy: 0.8952Epoch 7/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2913 - accuracy: 0.8917
# 1058/1205 [=========================>....] - ETA: 0s - loss: 0.2886 - accuracy: 0.8927Epoch 7/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2872 - accuracy: 0.8940
#  154/1205 [==>...........................] - ETA: 7s - loss: 0.2822 - accuracy: 0.8985Epoch 7/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2875 - accuracy: 0.8932
#  512/1205 [===========>..................] - ETA: 4s - loss: 0.2877 - accuracy: 0.8912Epoch 7/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2908 - accuracy: 0.8920
#  216/1205 [====>.........................] - ETA: 6s - loss: 0.2891 - accuracy: 0.8935Epoch 7/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2830 - accuracy: 0.8951
# 1152/1205 [===========================>..] - ETA: 0s - loss: 0.2832 - accuracy: 0.8943Epoch 7/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2821 - accuracy: 0.8948
# Epoch 7/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2911 - accuracy: 0.8914
#  229/1205 [====>.........................] - ETA: 6s - loss: 0.2904 - accuracy: 0.8963Epoch 7/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2869 - accuracy: 0.8950
#  434/1205 [=========>....................] - ETA: 4s - loss: 0.2899 - accuracy: 0.8939Epoch 8/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2810 - accuracy: 0.8962
# 1048/1205 [=========================>....] - ETA: 0s - loss: 0.2871 - accuracy: 0.8934Epoch 8/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2897 - accuracy: 0.8923
# Epoch 8/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2814 - accuracy: 0.8948
#  713/1205 [================>.............] - ETA: 3s - loss: 0.2876 - accuracy: 0.8942Epoch 8/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2865 - accuracy: 0.8951
# 1187/1205 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.8934Epoch 8/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2818 - accuracy: 0.8942
#  212/1205 [====>.........................] - ETA: 5s - loss: 0.2897 - accuracy: 0.8933Epoch 8/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2860 - accuracy: 0.8955
# Epoch 8/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2907 - accuracy: 0.8920
# 1182/1205 [============================>.] - ETA: 0s - loss: 0.2877 - accuracy: 0.8930Epoch 8/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2873 - accuracy: 0.8932
# Epoch 8/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2862 - accuracy: 0.8946
#  168/1205 [===>..........................] - ETA: 6s - loss: 0.3130 - accuracy: 0.8854Epoch 8/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2901 - accuracy: 0.8916
# Epoch 8/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2868 - accuracy: 0.8932
#  213/1205 [====>.........................] - ETA: 6s - loss: 0.2666 - accuracy: 0.9035Epoch 8/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2810 - accuracy: 0.8965
#  424/1205 [=========>....................] - ETA: 4s - loss: 0.2865 - accuracy: 0.8917Epoch 8/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2902 - accuracy: 0.8918
#  381/1205 [========>.....................] - ETA: 5s - loss: 0.2852 - accuracy: 0.8899Epoch 8/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2809 - accuracy: 0.8953
# Epoch 8/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2905 - accuracy: 0.8923
#  347/1205 [=======>......................] - ETA: 6s - loss: 0.2882 - accuracy: 0.8930Epoch 8/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2863 - accuracy: 0.8951
#  401/1205 [========>.....................] - ETA: 5s - loss: 0.2844 - accuracy: 0.8939Epoch 9/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2803 - accuracy: 0.8952
#  458/1205 [==========>...................] - ETA: 5s - loss: 0.2760 - accuracy: 0.8966Epoch 9/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2900 - accuracy: 0.8923
#  906/1205 [=====================>........] - ETA: 1s - loss: 0.2827 - accuracy: 0.8963Epoch 9/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2804 - accuracy: 0.8950
# 1001/1205 [=======================>......] - ETA: 1s - loss: 0.2841 - accuracy: 0.8950Epoch 9/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2853 - accuracy: 0.8959
# Epoch 9/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2860 - accuracy: 0.8946
# 1137/1205 [===========================>..] - ETA: 0s - loss: 0.2851 - accuracy: 0.8943Epoch 9/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2813 - accuracy: 0.8945
# Epoch 9/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2858 - accuracy: 0.8951
#  155/1205 [==>...........................] - ETA: 6s - loss: 0.2647 - accuracy: 0.9065Epoch 9/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2862 - accuracy: 0.8938
# Epoch 9/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2901 - accuracy: 0.8921
#  894/1205 [=====================>........] - ETA: 2s - loss: 0.2820 - accuracy: 0.8956Epoch 9/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2890 - accuracy: 0.8925
# Epoch 9/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2860 - accuracy: 0.8936
#  219/1205 [====>.........................] - ETA: 6s - loss: 0.2857 - accuracy: 0.8938Epoch 9/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2898 - accuracy: 0.8919
# Epoch 9/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2809 - accuracy: 0.8963
#  400/1205 [========>.....................] - ETA: 4s - loss: 0.2857 - accuracy: 0.8969Epoch 9/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2808 - accuracy: 0.8962
#  104/1205 [=>............................] - ETA: 8s - loss: 0.2903 - accuracy: 0.8906Epoch 9/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2901 - accuracy: 0.8928
#  300/1205 [======>.......................] - ETA: 7s - loss: 0.3001 - accuracy: 0.8906Epoch 9/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2847 - accuracy: 0.8951
#  679/1205 [===============>..............] - ETA: 3s - loss: 0.2855 - accuracy: 0.8933Epoch 10/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2852 - accuracy: 0.8959
# Epoch 10/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2896 - accuracy: 0.8929
#  647/1205 [===============>..............] - ETA: 4s - loss: 0.2859 - accuracy: 0.8948Epoch 10/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2794 - accuracy: 0.8966
#   19/1205 [..............................] - ETA: 11s - loss: 0.2481 - accuracy: 0.9112Epoch 10/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2803 - accuracy: 0.8953
#  889/1205 [=====================>........] - ETA: 2s - loss: 0.2858 - accuracy: 0.8931Epoch 10/10
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2859 - accuracy: 0.8959
# 1144/1205 [===========================>..] - ETA: 0s - loss: 0.2853 - accuracy: 0.8952Epoch 10/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2808 - accuracy: 0.8954
# 1114/1205 [==========================>...] - ETA: 0s - loss: 0.2892 - accuracy: 0.8917Epoch 10/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2887 - accuracy: 0.8917
#  251/1205 [=====>........................] - ETA: 6s - loss: 0.2748 - accuracy: 0.8984Epoch 10/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2845 - accuracy: 0.8956
#    1/1205 [..............................] - ETA: 7s - loss: 0.5097 - accuracy: 0.8125Epoch 10/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2891 - accuracy: 0.8920
#  935/1205 [======================>.......] - ETA: 1s - loss: 0.2870 - accuracy: 0.8948Epoch 10/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2854 - accuracy: 0.8940
# Epoch 10/10
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2887 - accuracy: 0.8921
#  690/1205 [================>.............] - ETA: 3s - loss: 0.2865 - accuracy: 0.8960Epoch 10/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2802 - accuracy: 0.8961
# Epoch 10/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2845 - accuracy: 0.8963
# Epoch 10/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2800 - accuracy: 0.8951
#  825/1205 [===================>..........] - ETA: 2s - loss: 0.2745 - accuracy: 0.8974Epoch 10/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2885 - accuracy: 0.8922
# Epoch 10/10
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2841 - accuracy: 0.8964
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2884 - accuracy: 0.8920
#  570/1205 [=============>................] - ETA: 3s - loss: 0.2862 - accuracy: 0.8936Epoch 11/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2843 - accuracy: 0.8968
# 1102/1205 [==========================>...] - ETA: 0s - loss: 0.2765 - accuracy: 0.8969Epoch 11/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2784 - accuracy: 0.8961
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2801 - accuracy: 0.8958
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2791 - accuracy: 0.8958
#  953/1205 [======================>.......] - ETA: 1s - loss: 0.2800 - accuracy: 0.8968Epoch 11/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2847 - accuracy: 0.8947
# 1169/1205 [============================>.] - ETA: 0s - loss: 0.2845 - accuracy: 0.8949Epoch 11/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2880 - accuracy: 0.8914
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2854 - accuracy: 0.8949
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2879 - accuracy: 0.8917
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2881 - accuracy: 0.8937
# Epoch 11/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2847 - accuracy: 0.8953
# 1205/1205 [==============================] - 7s 5ms/step - loss: 0.2795 - accuracy: 0.8965
#  160/1205 [==>...........................] - ETA: 4s - loss: 0.2788 - accuracy: 0.8969Epoch 11/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2845 - accuracy: 0.8952
# 282/603 [=============>................] - ETA: 1s - loss: 0.2851 - accuracy: 0.8943Epoch 11/20
# 603/603 [==============================] - 3s 4ms/step - loss: 0.2932 - accuracy: 0.8980
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2797 - accuracy: 0.8960
# 603/603 [==============================] - 3s 4ms/step - loss: 0.2879 - accuracy: 0.8906
# 1205/1205 [==============================] - 7s 5ms/step - loss: 0.2888 - accuracy: 0.8936
# 1205/1205 [==============================] - 5s 5ms/step - loss: 0.2882 - accuracy: 0.8935
# Epoch 12/20
# 1205/1205 [==============================] - 5s 4ms/step - loss: 0.2837 - accuracy: 0.8954
#   30/1205 [..............................] - ETA: 4s - loss: 0.2381 - accuracy: 0.9104Epoch 12/20
# 603/603 [==============================] - 3s 4ms/step - loss: 0.2879 - accuracy: 0.8910
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2786 - accuracy: 0.8957
# 365/603 [=================>............] - ETA: 1s - loss: 0.2862 - accuracy: 0.8923Epoch 12/20
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2839 - accuracy: 0.8968
# 310/603 [==============>...............] - ETA: 1s - loss: 0.2892 - accuracy: 0.8879Epoch 12/20
# 603/603 [==============================] - 3s 4ms/step - loss: 0.2996 - accuracy: 0.8866
# 603/603 [==============================] - 3s 4ms/step - loss: 0.2986 - accuracy: 0.8879
# 603/603 [==============================] - 3s 5ms/step - loss: 0.2802 - accuracy: 0.8949
# 603/603 [==============================] - 3s 4ms/step - loss: 0.2843 - accuracy: 0.8904
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2786 - accuracy: 0.8956
# Epoch 12/20
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2874 - accuracy: 0.8938
# Epoch 12/20
# 603/603 [==============================] - 3s 5ms/step - loss: 0.2889 - accuracy: 0.8887
# 603/603 [==============================] - 3s 4ms/step - loss: 0.2992 - accuracy: 0.8878
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2839 - accuracy: 0.8955
#  223/1205 [====>.........................] - ETA: 4s - loss: 0.2676 - accuracy: 0.9030Epoch 12/20
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2828 - accuracy: 0.8968
# Epoch 13/20
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2878 - accuracy: 0.8939
#  655/1205 [===============>..............] - ETA: 2s - loss: 0.2780 - accuracy: 0.8974Epoch 13/20
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2780 - accuracy: 0.8955
#  741/1205 [=================>............] - ETA: 2s - loss: 0.2801 - accuracy: 0.8979Epoch 13/20
# 1205/1205 [==============================] - 5s 5ms/step - loss: 0.2825 - accuracy: 0.8963
#  884/1205 [=====================>........] - ETA: 1s - loss: 0.2790 - accuracy: 0.8974Epoch 13/20
#  924/1205 [======================>.......] - ETA: 1s - loss: 0.2803 - accuracy: 0.8963Epoch 1/20
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2868 - accuracy: 0.8927
#  535/1205 [============>.................] - ETA: 3s - loss: 0.2899 - accuracy: 0.8910Epoch 13/20
#  611/1205 [==============>...............] - ETA: 2s - loss: 0.2874 - accuracy: 0.8924Epoch 1/20
#   95/1205 [=>............................] - ETA: 4s - loss: 0.2928 - accuracy: 0.8868Epoch 1/30
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2782 - accuracy: 0.8967
# Epoch 13/20
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2834 - accuracy: 0.8966
# Epoch 13/20
#  987/1205 [=======================>......] - ETA: 1s - loss: 0.2791 - accuracy: 0.8986Epoch 1/30
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2870 - accuracy: 0.8939
#  259/1205 [=====>........................] - ETA: 5s - loss: 0.2779 - accuracy: 0.8972Epoch 14/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2818 - accuracy: 0.8971
# Epoch 14/20
#  123/1205 [==>...........................] - ETA: 5s - loss: 0.3033 - accuracy: 0.8872Epoch 1/30
# 1205/1205 [==============================] - 6s 5ms/step - loss: 0.2764 - accuracy: 0.8955
#  539/1205 [============>.................] - ETA: 4s - loss: 0.2738 - accuracy: 0.8988Epoch 14/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2823 - accuracy: 0.8967
#  342/1205 [=======>......................] - ETA: 5s - loss: 0.3373 - accuracy: 0.8808Epoch 14/20
#  918/1205 [=====================>........] - ETA: 1s - loss: 0.2892 - accuracy: 0.8922Epoch 1/30
#  989/1205 [=======================>......] - ETA: 1s - loss: 0.2776 - accuracy: 0.8953Epoch 1/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2864 - accuracy: 0.8934
# Epoch 14/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2769 - accuracy: 0.8963
#  127/1205 [==>...........................] - ETA: 6s - loss: 0.2855 - accuracy: 0.8898Epoch 14/20
#  214/1205 [====>.........................] - ETA: 6s - loss: 0.2854 - accuracy: 0.8916Epoch 1/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2827 - accuracy: 0.8959
#  893/1205 [=====================>........] - ETA: 1s - loss: 0.3068 - accuracy: 0.8853Epoch 14/20
#  872/1205 [====================>.........] - ETA: 2s - loss: 0.2812 - accuracy: 0.8979Epoch 1/30
# 1205/1205 [==============================] - 11s 7ms/step - loss: 0.3017 - accuracy: 0.8898
#  108/1205 [=>............................] - ETA: 5s - loss: 0.3750 - accuracy: 0.8773Epoch 2/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2870 - accuracy: 0.8934
#  527/1205 [============>.................] - ETA: 4s - loss: 0.2860 - accuracy: 0.8922Epoch 15/20
# 1205/1205 [==============================] - 10s 7ms/step - loss: 0.3075 - accuracy: 0.8846
#  149/1205 [==>...........................] - ETA: 8s - loss: 0.2900 - accuracy: 0.8867Epoch 2/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2812 - accuracy: 0.8977
#  983/1205 [=======================>......] - ETA: 1s - loss: 0.2857 - accuracy: 0.8969Epoch 15/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2757 - accuracy: 0.8966
#  616/1205 [==============>...............] - ETA: 3s - loss: 0.3165 - accuracy: 0.8832Epoch 15/20
# 1205/1205 [==============================] - 13s 8ms/step - loss: 0.3054 - accuracy: 0.8889
#  278/1205 [=====>........................] - ETA: 7s - loss: 0.2854 - accuracy: 0.8977Epoch 2/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2813 - accuracy: 0.8987
#  539/1205 [============>.................] - ETA: 5s - loss: 0.3102 - accuracy: 0.8878Epoch 15/20
# 1205/1205 [==============================] - 11s 7ms/step - loss: 0.3008 - accuracy: 0.8890
#  958/1205 [======================>.......] - ETA: 1s - loss: 0.2864 - accuracy: 0.8943Epoch 2/30
# 1205/1205 [==============================] - 10s 7ms/step - loss: 0.3059 - accuracy: 0.8857
#  107/1205 [=>............................] - ETA: 7s - loss: 0.2707 - accuracy: 0.8984Epoch 2/30
# 1205/1205 [==============================] - 9s 8ms/step - loss: 0.2855 - accuracy: 0.8944
#  774/1205 [==================>...........] - ETA: 3s - loss: 0.2954 - accuracy: 0.8882Epoch 15/20
# 1205/1205 [==============================] - 11s 6ms/step - loss: 0.3088 - accuracy: 0.8855
#  564/1205 [=============>................] - ETA: 5s - loss: 0.3057 - accuracy: 0.8930Epoch 2/30
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2823 - accuracy: 0.8975
#  417/1205 [=========>....................] - ETA: 6s - loss: 0.2839 - accuracy: 0.8955Epoch 15/20
# 1205/1205 [==============================] - 10s 8ms/step - loss: 0.2759 - accuracy: 0.8977
#  558/1205 [============>.................] - ETA: 5s - loss: 0.2910 - accuracy: 0.8922Epoch 15/20
# 1205/1205 [==============================] - 13s 8ms/step - loss: 0.3000 - accuracy: 0.8895
# 1037/1205 [========================>.....] - ETA: 1s - loss: 0.2860 - accuracy: 0.8945Epoch 2/30
# 1205/1205 [==============================] - 10s 8ms/step - loss: 0.2874 - accuracy: 0.8911
# Epoch 3/20
# 1205/1205 [==============================] - 10s 8ms/step - loss: 0.2867 - accuracy: 0.8944
#   52/1205 [>.............................] - ETA: 13s - loss: 0.2831 - accuracy: 0.8942Epoch 16/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2809 - accuracy: 0.8970
# Epoch 16/20
# 1205/1205 [==============================] - 10s 9ms/step - loss: 0.2956 - accuracy: 0.8892
# 1100/1205 [==========================>...] - ETA: 0s - loss: 0.2723 - accuracy: 0.8984Epoch 3/20
# 1205/1205 [==============================] - 12s 7ms/step - loss: 0.3088 - accuracy: 0.8861
#  496/1205 [===========>..................] - ETA: 5s - loss: 0.2674 - accuracy: 0.9021Epoch 2/30
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2929 - accuracy: 0.8912
#  251/1205 [=====>........................] - ETA: 7s - loss: 0.2865 - accuracy: 0.8952Epoch 3/30
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2750 - accuracy: 0.8975
# Epoch 16/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2869 - accuracy: 0.8934
#  647/1205 [===============>..............] - ETA: 4s - loss: 0.2969 - accuracy: 0.8897Epoch 3/30
# 1205/1205 [==============================] - 14s 9ms/step - loss: 0.3058 - accuracy: 0.8886
#  155/1205 [==>...........................] - ETA: 8s - loss: 0.2721 - accuracy: 0.9012Epoch 2/30
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2918 - accuracy: 0.8930
#  727/1205 [=================>............] - ETA: 3s - loss: 0.2721 - accuracy: 0.8968Epoch 3/30
# 1205/1205 [==============================] - 9s 8ms/step - loss: 0.2809 - accuracy: 0.8966
#  204/1205 [====>.........................] - ETA: 5s - loss: 0.2752 - accuracy: 0.8958Epoch 16/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2847 - accuracy: 0.8946
# 1072/1205 [=========================>....] - ETA: 0s - loss: 0.2748 - accuracy: 0.8962Epoch 16/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2812 - accuracy: 0.8975
# Epoch 16/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2950 - accuracy: 0.8906
# Epoch 3/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2756 - accuracy: 0.8962
#  505/1205 [===========>..................] - ETA: 4s - loss: 0.2913 - accuracy: 0.8943Epoch 16/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2863 - accuracy: 0.8936
#  303/1205 [======>.......................] - ETA: 6s - loss: 0.2672 - accuracy: 0.9020Epoch 17/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2801 - accuracy: 0.8978
# Epoch 17/20
# 1205/1205 [==============================] - 9s 8ms/step - loss: 0.2876 - accuracy: 0.8927
#  931/1205 [======================>.......] - ETA: 2s - loss: 0.2935 - accuracy: 0.8898Epoch 3/30
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2858 - accuracy: 0.8943
#  964/1205 [=======================>......] - ETA: 1s - loss: 0.2886 - accuracy: 0.8944Epoch 4/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2739 - accuracy: 0.8950
#  848/1205 [====================>.........] - ETA: 2s - loss: 0.2812 - accuracy: 0.8964Epoch 17/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2903 - accuracy: 0.8938
# Epoch 4/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2958 - accuracy: 0.8912
# Epoch 3/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2852 - accuracy: 0.8942
#  174/1205 [===>..........................] - ETA: 6s - loss: 0.2712 - accuracy: 0.9005Epoch 4/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2932 - accuracy: 0.8920
# 1179/1205 [============================>.] - ETA: 0s - loss: 0.2906 - accuracy: 0.8934Epoch 3/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2897 - accuracy: 0.8938
#  250/1205 [=====>........................] - ETA: 5s - loss: 0.2876 - accuracy: 0.8942Epoch 4/30
# 1205/1205 [==============================] - 9s 8ms/step - loss: 0.2939 - accuracy: 0.8895
#   70/1205 [>.............................] - ETA: 9s - loss: 0.3020 - accuracy: 0.8929Epoch 4/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2803 - accuracy: 0.8982
#  408/1205 [=========>....................] - ETA: 4s - loss: 0.2684 - accuracy: 0.9013Epoch 17/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2839 - accuracy: 0.8942
# Epoch 17/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2942 - accuracy: 0.8902
# Epoch 4/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2806 - accuracy: 0.8968
# Epoch 17/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2742 - accuracy: 0.8992
#  153/1205 [==>...........................] - ETA: 6s - loss: 0.2787 - accuracy: 0.8962Epoch 17/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2852 - accuracy: 0.8947
# 1058/1205 [=========================>....] - ETA: 0s - loss: 0.2949 - accuracy: 0.8898Epoch 18/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2850 - accuracy: 0.8950
# Epoch 4/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2802 - accuracy: 0.8970
# 1098/1205 [==========================>...] - ETA: 0s - loss: 0.2874 - accuracy: 0.8937Epoch 18/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2894 - accuracy: 0.8940
#  754/1205 [=================>............] - ETA: 2s - loss: 0.2834 - accuracy: 0.8974Epoch 5/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2852 - accuracy: 0.8936
#  553/1205 [============>.................] - ETA: 4s - loss: 0.2932 - accuracy: 0.8887Epoch 5/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2944 - accuracy: 0.8900
#   53/1205 [>.............................] - ETA: 7s - loss: 0.3102 - accuracy: 0.8785Epoch 4/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2735 - accuracy: 0.8967
#   60/1205 [>.............................] - ETA: 9s - loss: 0.2654 - accuracy: 0.9000 Epoch 18/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2891 - accuracy: 0.8932
#  494/1205 [===========>..................] - ETA: 4s - loss: 0.2793 - accuracy: 0.8928Epoch 5/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2841 - accuracy: 0.8949
#  704/1205 [================>.............] - ETA: 3s - loss: 0.2957 - accuracy: 0.8872Epoch 5/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2905 - accuracy: 0.8934
#  238/1205 [====>.........................] - ETA: 6s - loss: 0.2812 - accuracy: 0.8950Epoch 4/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2932 - accuracy: 0.8914
#  894/1205 [=====================>........] - ETA: 1s - loss: 0.2821 - accuracy: 0.8951Epoch 5/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2797 - accuracy: 0.8980
#  494/1205 [===========>..................] - ETA: 4s - loss: 0.2822 - accuracy: 0.8966Epoch 18/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2921 - accuracy: 0.8901
# Epoch 5/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2835 - accuracy: 0.8942
# 1081/1205 [=========================>....] - ETA: 0s - loss: 0.2783 - accuracy: 0.8993Epoch 18/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2790 - accuracy: 0.8989
#  951/1205 [======================>.......] - ETA: 1s - loss: 0.2876 - accuracy: 0.8945Epoch 18/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2733 - accuracy: 0.8965
#  844/1205 [====================>.........] - ETA: 2s - loss: 0.2821 - accuracy: 0.8971Epoch 18/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2849 - accuracy: 0.8951
#  284/1205 [======>.......................] - ETA: 5s - loss: 0.2886 - accuracy: 0.8946Epoch 19/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2884 - accuracy: 0.8933
# 1028/1205 [========================>.....] - ETA: 1s - loss: 0.2831 - accuracy: 0.8955Epoch 6/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2794 - accuracy: 0.8982
#  838/1205 [===================>..........] - ETA: 2s - loss: 0.2930 - accuracy: 0.8911Epoch 19/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2874 - accuracy: 0.8945
#  412/1205 [=========>....................] - ETA: 5s - loss: 0.2911 - accuracy: 0.8931Epoch 6/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2842 - accuracy: 0.8946
# 1034/1205 [========================>.....] - ETA: 1s - loss: 0.2876 - accuracy: 0.8948Epoch 5/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2832 - accuracy: 0.8948
# Epoch 6/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2731 - accuracy: 0.8971
#  294/1205 [======>.......................] - ETA: 5s - loss: 0.2806 - accuracy: 0.8956Epoch 19/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2839 - accuracy: 0.8948
#  764/1205 [==================>...........] - ETA: 2s - loss: 0.2870 - accuracy: 0.8922Epoch 6/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2927 - accuracy: 0.8907
#  555/1205 [============>.................] - ETA: 4s - loss: 0.2702 - accuracy: 0.8995Epoch 5/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2889 - accuracy: 0.8936
# Epoch 5/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2787 - accuracy: 0.8987
#  262/1205 [=====>........................] - ETA: 5s - loss: 0.2981 - accuracy: 0.8900Epoch 19/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2920 - accuracy: 0.8907
# Epoch 6/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2916 - accuracy: 0.8910
#  423/1205 [=========>....................] - ETA: 4s - loss: 0.2864 - accuracy: 0.8936Epoch 6/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2821 - accuracy: 0.8954
#  723/1205 [=================>............] - ETA: 3s - loss: 0.2846 - accuracy: 0.8958Epoch 19/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2730 - accuracy: 0.8980
# Epoch 19/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2786 - accuracy: 0.8978
# 1086/1205 [==========================>...] - ETA: 0s - loss: 0.2847 - accuracy: 0.8940Epoch 19/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2848 - accuracy: 0.8942
#  499/1205 [===========>..................] - ETA: 5s - loss: 0.2749 - accuracy: 0.9012Epoch 20/20
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2879 - accuracy: 0.8955
#  830/1205 [===================>..........] - ETA: 2s - loss: 0.2848 - accuracy: 0.8952Epoch 7/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2822 - accuracy: 0.8939
#  510/1205 [===========>..................] - ETA: 4s - loss: 0.2671 - accuracy: 0.9022Epoch 7/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2871 - accuracy: 0.8945
# 1098/1205 [==========================>...] - ETA: 0s - loss: 0.2730 - accuracy: 0.8984Epoch 7/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2783 - accuracy: 0.8985
#  346/1205 [=======>......................] - ETA: 6s - loss: 0.2764 - accuracy: 0.9001Epoch 20/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2829 - accuracy: 0.8952
#   81/1205 [=>............................] - ETA: 7s - loss: 0.3186 - accuracy: 0.8843Epoch 6/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2919 - accuracy: 0.8920
# 1190/1205 [============================>.] - ETA: 0s - loss: 0.2830 - accuracy: 0.8946Epoch 6/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2826 - accuracy: 0.8948
# Epoch 7/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2730 - accuracy: 0.8985
#  870/1205 [====================>.........] - ETA: 2s - loss: 0.2781 - accuracy: 0.9001Epoch 20/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2883 - accuracy: 0.8938
#  182/1205 [===>..........................] - ETA: 6s - loss: 0.2738 - accuracy: 0.9001Epoch 6/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2905 - accuracy: 0.8916
#  256/1205 [=====>........................] - ETA: 5s - loss: 0.3016 - accuracy: 0.8835Epoch 7/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2907 - accuracy: 0.8923
# Epoch 7/20
# 1205/1205 [==============================] - 9s 7ms/step - loss: 0.2781 - accuracy: 0.8996
# Epoch 20/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2818 - accuracy: 0.8954
#   72/1205 [>.............................] - ETA: 5s - loss: 0.3107 - accuracy: 0.8898Epoch 20/20
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2715 - accuracy: 0.8989
#  185/1205 [===>..........................] - ETA: 6s - loss: 0.2780 - accuracy: 0.8983Epoch 20/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2784 - accuracy: 0.8993
# Epoch 20/20
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2871 - accuracy: 0.8946
#  226/1205 [====>.........................] - ETA: 4s - loss: 0.2792 - accuracy: 0.8957Epoch 8/30
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2837 - accuracy: 0.8939
# 1205/1205 [==============================] - 7s 5ms/step - loss: 0.2779 - accuracy: 0.8989
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2815 - accuracy: 0.8957
#  370/1205 [========>.....................] - ETA: 5s - loss: 0.2709 - accuracy: 0.8986Epoch 8/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2864 - accuracy: 0.8939
#   16/1205 [..............................] - ETA: 4s - loss: 0.2010 - accuracy: 0.9102Epoch 8/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2914 - accuracy: 0.8917
#  740/1205 [=================>............] - ETA: 2s - loss: 0.2782 - accuracy: 0.8986Epoch 7/30
# 1205/1205 [==============================] - 7s 6ms/step - loss: 0.2818 - accuracy: 0.8942
# Epoch 7/30
# 1205/1205 [==============================] - 8s 6ms/step - loss: 0.2714 - accuracy: 0.8977
# 1205/1205 [==============================] - 8s 7ms/step - loss: 0.2819 - accuracy: 0.8944
# Epoch 8/20
# ...
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2840 - accuracy: 0.8950
# Epoch 17/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2740 - accuracy: 0.8973
# 265/302 [=========================>....] - ETA: 0s - loss: 0.2798 - accuracy: 0.8971Epoch 23/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2808 - accuracy: 0.8969
# 174/302 [================>.............] - ETA: 0s - loss: 0.2725 - accuracy: 0.9005Epoch 16/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2827 - accuracy: 0.8953
# 238/302 [======================>.......] - ETA: 0s - loss: 0.2767 - accuracy: 0.8988Epoch 24/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2750 - accuracy: 0.8983
# Epoch 20/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2754 - accuracy: 0.9000
#  81/302 [=======>......................] - ETA: 1s - loss: 0.2641 - accuracy: 0.9030Epoch 25/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2789 - accuracy: 0.8948
# Epoch 12/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2779 - accuracy: 0.8989
# Epoch 22/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2831 - accuracy: 0.8941
# 150/302 [=============>................] - ETA: 0s - loss: 0.2746 - accuracy: 0.8995Epoch 18/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2886 - accuracy: 0.8921
# Epoch 11/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2737 - accuracy: 0.8981
# Epoch 24/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2823 - accuracy: 0.8953
# 239/302 [======================>.......] - ETA: 0s - loss: 0.2755 - accuracy: 0.8979Epoch 25/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2813 - accuracy: 0.8958
# Epoch 17/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2741 - accuracy: 0.8984
#   1/302 [..............................] - ETA: 1s - loss: 0.2335 - accuracy: 0.9375Epoch 21/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2753 - accuracy: 0.8994
#  24/302 [=>............................] - ETA: 1s - loss: 0.2966 - accuracy: 0.8854Epoch 26/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2767 - accuracy: 0.8986
# Epoch 23/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2823 - accuracy: 0.8950
# 302/302 [==============================] - 2s 6ms/step - loss: 0.2787 - accuracy: 0.8969
# Epoch 19/30
# Epoch 13/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2735 - accuracy: 0.8980
# Epoch 25/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2886 - accuracy: 0.8926
# Epoch 12/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2805 - accuracy: 0.8952
# Epoch 26/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2738 - accuracy: 0.8990
# 193/302 [==================>...........] - ETA: 0s - loss: 0.2786 - accuracy: 0.8967Epoch 22/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2740 - accuracy: 0.8992
# Epoch 27/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2801 - accuracy: 0.8976
#  78/302 [======>.......................] - ETA: 1s - loss: 0.2811 - accuracy: 0.8954Epoch 18/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2756 - accuracy: 0.9005
#  11/302 [>.............................] - ETA: 1s - loss: 0.2782 - accuracy: 0.9020Epoch 24/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2811 - accuracy: 0.8957
# Epoch 20/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2725 - accuracy: 0.8991
# Epoch 26/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2775 - accuracy: 0.8965
# Epoch 14/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2871 - accuracy: 0.8926
# Epoch 13/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2808 - accuracy: 0.8958
# Epoch 27/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2732 - accuracy: 0.8992
# Epoch 23/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2732 - accuracy: 0.8994
# Epoch 28/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2768 - accuracy: 0.8997
# Epoch 25/30
# 302/302 [==============================] - 2s 6ms/step - loss: 0.2794 - accuracy: 0.8981
# Epoch 19/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2806 - accuracy: 0.8952
# Epoch 21/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2719 - accuracy: 0.8997
#  99/302 [========>.....................] - ETA: 0s - loss: 0.2678 - accuracy: 0.9050Epoch 27/30
# 302/302 [==============================] - 2s 6ms/step - loss: 0.2780 - accuracy: 0.8964
# Epoch 15/30
# 302/302 [==============================] - 2s 6ms/step - loss: 0.2867 - accuracy: 0.8939
# Epoch 14/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2798 - accuracy: 0.8963
# Epoch 28/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2728 - accuracy: 0.9015
# Epoch 29/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2720 - accuracy: 0.8995
# Epoch 24/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2740 - accuracy: 0.8996
# Epoch 26/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2708 - accuracy: 0.9002
# Epoch 28/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2803 - accuracy: 0.8948
# Epoch 22/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2786 - accuracy: 0.8973
# 138/302 [============>.................] - ETA: 0s - loss: 0.2703 - accuracy: 0.9018Epoch 20/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2766 - accuracy: 0.8965
# 248/302 [=======================>......] - ETA: 0s - loss: 0.2871 - accuracy: 0.8946Epoch 16/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2798 - accuracy: 0.8962
# Epoch 29/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2726 - accuracy: 0.9016
# Epoch 30/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2860 - accuracy: 0.8944
# 281/302 [==========================>...] - ETA: 0s - loss: 0.2753 - accuracy: 0.9002Epoch 15/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2739 - accuracy: 0.9003
# Epoch 27/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2718 - accuracy: 0.8999
# Epoch 25/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2708 - accuracy: 0.8991
# Epoch 29/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2786 - accuracy: 0.8964
# Epoch 23/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2792 - accuracy: 0.8983
# Epoch 21/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2769 - accuracy: 0.8973
# Epoch 17/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2778 - accuracy: 0.8981
# 234/302 [======================>.......] - ETA: 0s - loss: 0.2804 - accuracy: 0.8963Epoch 30/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2716 - accuracy: 0.9007
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2715 - accuracy: 0.8993
# Epoch 26/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2729 - accuracy: 0.9007
#  72/302 [======>.......................] - ETA: 1s - loss: 0.2811 - accuracy: 0.8967Epoch 28/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2856 - accuracy: 0.8946
#  39/302 [==>...........................] - ETA: 1s - loss: 0.2846 - accuracy: 0.8938Epoch 16/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2702 - accuracy: 0.8998
# Epoch 30/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2785 - accuracy: 0.8970
# Epoch 24/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2906 - accuracy: 0.8896
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2772 - accuracy: 0.8986
# Epoch 22/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2780 - accuracy: 0.8970
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2755 - accuracy: 0.8982
# Epoch 18/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2702 - accuracy: 0.9005
#  36/302 [==>...........................] - ETA: 1s - loss: 0.2698 - accuracy: 0.8954Epoch 27/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2719 - accuracy: 0.9019
# Epoch 29/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2846 - accuracy: 0.8945
# Epoch 17/30
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2694 - accuracy: 0.9002
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2788 - accuracy: 0.8954
# Epoch 25/30
# 151/151 [==============================] - 1s 4ms/step - loss: 0.2857 - accuracy: 0.8915
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2770 - accuracy: 0.8983
# Epoch 23/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2719 - accuracy: 0.9004
# 229/302 [=====================>........] - ETA: 0s - loss: 0.2833 - accuracy: 0.8939Epoch 30/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2748 - accuracy: 0.8978
#  80/302 [======>.......................] - ETA: 1s - loss: 0.2731 - accuracy: 0.9004Epoch 19/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2702 - accuracy: 0.8994
# 238/302 [======================>.......] - ETA: 0s - loss: 0.2835 - accuracy: 0.8940Epoch 28/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.3022 - accuracy: 0.8823
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2835 - accuracy: 0.8943
# Epoch 18/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2766 - accuracy: 0.8972
# Epoch 26/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2761 - accuracy: 0.9005
# Epoch 24/30
# 302/302 [==============================] - 1s 3ms/step - loss: 0.2685 - accuracy: 0.9007
# Epoch 29/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2711 - accuracy: 0.9022
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2740 - accuracy: 0.8978
# Epoch 20/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2830 - accuracy: 0.8948
# Epoch 19/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2767 - accuracy: 0.8980
# 125/302 [===========>..................] - ETA: 0s - loss: 0.2805 - accuracy: 0.8953Epoch 27/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2964 - accuracy: 0.8857
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2755 - accuracy: 0.8991
# Epoch 25/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2686 - accuracy: 0.9011
#  17/302 [>.............................] - ETA: 1s - loss: 0.2906 - accuracy: 0.8925Epoch 30/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2742 - accuracy: 0.8978
#  37/302 [==>...........................] - ETA: 1s - loss: 0.2646 - accuracy: 0.9020Epoch 21/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2827 - accuracy: 0.8956
# Epoch 20/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2757 - accuracy: 0.8980
# Epoch 28/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2680 - accuracy: 0.9017
# 302/302 [==============================] - 2s 5ms/step - loss: 0.2743 - accuracy: 0.8997
# Epoch 26/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2731 - accuracy: 0.8991
# Epoch 22/30
# 151/151 [==============================] - 1s 2ms/step - loss: 0.2998 - accuracy: 0.8864
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2815 - accuracy: 0.8950
# 140/302 [============>.................] - ETA: 0s - loss: 0.2696 - accuracy: 0.9035Epoch 21/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2754 - accuracy: 0.8976
# Epoch 29/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2726 - accuracy: 0.8998
# Epoch 23/30
# 302/302 [==============================] - 1s 5ms/step - loss: 0.2743 - accuracy: 0.9004
# Epoch 27/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2743 - accuracy: 0.8990
# Epoch 30/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2809 - accuracy: 0.8958
# Epoch 22/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2717 - accuracy: 0.8992
# Epoch 24/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2729 - accuracy: 0.9016
# Epoch 28/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2729 - accuracy: 0.8994
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2800 - accuracy: 0.8961
# Epoch 23/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2709 - accuracy: 0.8992
# Epoch 25/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2865 - accuracy: 0.8951
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2724 - accuracy: 0.8997
# Epoch 29/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2800 - accuracy: 0.8962
# Epoch 24/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2707 - accuracy: 0.9001
# Epoch 26/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2707 - accuracy: 0.9020
# Epoch 30/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2781 - accuracy: 0.8976
# 116/302 [==========>...................] - ETA: 0s - loss: 0.2797 - accuracy: 0.8987Epoch 25/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2698 - accuracy: 0.9001
# Epoch 27/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2702 - accuracy: 0.9024
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2784 - accuracy: 0.8970
# Epoch 26/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2953 - accuracy: 0.8889
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2690 - accuracy: 0.9009
# Epoch 28/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2797 - accuracy: 0.8958
# Epoch 27/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2686 - accuracy: 0.9013
# Epoch 29/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2770 - accuracy: 0.8977
# Epoch 28/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2680 - accuracy: 0.9022
# Epoch 30/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2751 - accuracy: 0.8978
# Epoch 29/30
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2663 - accuracy: 0.9023
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2748 - accuracy: 0.8977
# Epoch 30/30
# 151/151 [==============================] - 1s 3ms/step - loss: 0.3091 - accuracy: 0.8852
# 302/302 [==============================] - 1s 4ms/step - loss: 0.2734 - accuracy: 0.8985
# 151/151 [==============================] - 1s 3ms/step - loss: 0.2839 - accuracy: 0.8949
# Epoch 1/10
# 904/904 [==============================] - 5s 4ms/step - loss: 0.3066 - accuracy: 0.8874
# Epoch 2/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2906 - accuracy: 0.8925
# Epoch 3/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2895 - accuracy: 0.8933
# Epoch 4/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2882 - accuracy: 0.8930
# Epoch 5/10
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2877 - accuracy: 0.8927
# Epoch 6/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2861 - accuracy: 0.8934
# Epoch 7/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2859 - accuracy: 0.8927
# Epoch 8/10
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2848 - accuracy: 0.8932
# Epoch 9/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2841 - accuracy: 0.8945
# Epoch 10/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2836 - accuracy: 0.8940
# {'batch_size': 32, 'epochs': 10, 'hidden_units': 64}

# %%
best_model_nn = create_model_nn(best_params_nn['hidden_units'])
best_model_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
best_model_nn.fit(X_train, y_train, epochs=best_params_nn['epochs'], batch_size=best_params_nn['batch_size'])
# Out:
# Epoch 1/10
# 904/904 [==============================] - 5s 4ms/step - loss: 0.3040 - accuracy: 0.8877
# Epoch 2/10
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2907 - accuracy: 0.8923
# Epoch 3/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2894 - accuracy: 0.8924
# Epoch 4/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2878 - accuracy: 0.8922
# Epoch 5/10
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2876 - accuracy: 0.8934
# Epoch 6/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2870 - accuracy: 0.8937
# Epoch 7/10
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2860 - accuracy: 0.8943
# Epoch 8/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2857 - accuracy: 0.8937
# Epoch 9/10
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2847 - accuracy: 0.8949
# Epoch 10/10
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2841 - accuracy: 0.8945

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred_prob_nn = best_model_nn.predict(X_test)
y_pred_nn = (y_pred_prob_nn > 0.5).astype(int)

accuracy_nn = accuracy_score(y_test, y_pred_nn)
precision_nn = precision_score(y_test, y_pred_nn)
recall_nn = recall_score(y_test, y_pred_nn)
f1_nn = f1_score(y_test, y_pred_nn)

print('Accuracy: %.2f' % (accuracy_nn*100))
print('Precision: %.2f' % (precision_nn*100))
print('Recall: %.2f' % (recall_nn*100))
print('F1-score: %.2f' % (f1_nn*100))
# Out:
# 302/302 [==============================] - 1s 2ms/step
# Accuracy: 89.25
# Precision: 61.95
# Recall: 11.71
# F1-score: 19.69

# %%
print("Best Parameters: ", best_params_nn)

# Evaluate the model
print(f'Test Accuracy: {accuracy_nn*100:.2f}%')
# Out:
# Best Parameters:  {'batch_size': 32, 'epochs': 10, 'hidden_units': 64}
# Test Accuracy: 89.25%

# %%
y_pred_prob_nn = best_model_nn.predict(X_test)

# Generate ROC curve and calculate AUC
fpr_nn, tpr_nn, thresholds_nn = roc_curve(y_test, y_pred_prob_nn)
auc_nn = roc_auc_score(y_test, y_pred_prob_nn)

# Plot ROC curve
plt.plot(fpr_nn, tpr_nn, label='ROC curve (AUC = {:.2f})'.format(auc_nn))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Apply thresholds
umbral = 0.5
y_pred_discret_nn = np.where(y_pred_prob_nn >= umbral, 1, 0)

# Create confusion matrix
cm_nn = confusion_matrix(y_test, y_pred_discret_nn)

# Visualize confusion matrix
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 302/302 [==============================] - 1s 2ms/step

# %% [markdown]
# ### AdaBoost (Adaptative Boosting):

# %%
# Create the base estimator
base_estimator_ab = DecisionTreeClassifier()

# Create the AdaBoost classifier
ada_boost = AdaBoostClassifier(base_estimator=base_estimator_ab)

# Define the parameter grid for AdaBoost
param_grid_ab = {
    'n_estimators': [50, 100, 200], 
    'learning_rate': [0.1, 0.5, 1.0]  
}


# Perform grid search for AdaBoost
grid_search_ab = GridSearchCV(ada_boost, param_grid_ab, cv=3, n_jobs=-1)
grid_search_ab.fit(X_train, y_train)

# Get the best AdaBoost model and its performance
best_ada_boost = grid_search_ab.best_estimator_
best_params_ab = grid_search_ab.best_params_
best_score_ab = grid_search_ab.best_score_

# Train the best AdaBoost model with all data
best_ada_boost.fit(X_train, y_train)

# Evaluate the best AdaBoost model
test_accuracy_ab = best_ada_boost.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_ab*100:.2f}%')
# Out:
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /home/carmen/mambaforge/envs/TFM/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Test Accuracy: 87.69%

# %%
best_params_ab
# Out:
# {'learning_rate': 0.5, 'n_estimators': 200}

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_ab = best_ada_boost.predict_proba(X_test)[:, 1]
fpr_ab, tpr_ab, thresholds_ab = roc_curve(y_test, y_pred_prob_ab)
auc_ab = roc_auc_score(y_test, y_pred_prob_ab)

# Plot ROC curve
plt.plot(fpr_ab, tpr_ab, label='ROC curve (AUC = {:.2f})'.format(auc_ab))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_ab = best_ada_boost.predict(X_test)
cm_ab = confusion_matrix(y_test, y_pred_ab)

# Visualize confusion matrix
sns.heatmap(cm_ab, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### Gradient Boosting:

# %%
# Create the Gradient Boosting classifier
gradient_boosting = GradientBoostingClassifier()

# Define the parameter grid for Gradient Boosting
param_grid_gb = {
    'n_estimators': [50, 100, 200],        
    'learning_rate': [0.1, 0.5, 1.0],     
    'max_depth': [3, 4, 5]                 
}

# Perform grid search for Gradient Boosting
grid_search_gb = GridSearchCV(gradient_boosting, param_grid_gb, cv=3, n_jobs=-1)
grid_search_gb.fit(X_train, y_train)

# Get the best Gradient Boosting model and its performance
best_gradient_boosting = grid_search_gb.best_estimator_
best_params_gb = grid_search_gb.best_params_
best_score_gb = grid_search_gb.best_score_

# Train the best Gradient Boosting model with all data
best_gradient_boosting.fit(X_train, y_train)

# Evaluate the best Gradient Boosting model
test_accuracy_gb = best_gradient_boosting.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_gb*100:.2f}%')
# Out:
# Test Accuracy: 89.62%

# %%
best_params_gb
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_gb = best_gradient_boosting.predict_proba(X_test)[:, 1]
fpr_gb, tpr_gb, thresholds_gb = roc_curve(y_test, y_pred_prob_gb)
auc_gb = roc_auc_score(y_test, y_pred_prob_gb)

# Plot ROC curve
plt.plot(fpr_gb, tpr_gb, label='ROC curve (AUC = {:.2f})'.format(auc_gb))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_gb = best_gradient_boosting.predict(X_test)
cm_gb = confusion_matrix(y_test, y_pred_gb)

# Visualize confusion matrix
sns.heatmap(cm_gb, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## Dataset unbalance problem

# %% [markdown]
# By showing the ROC curve, the AUC value and the confusion matrix, we can see that, despite having a high accuracy, there is a problem with our models.
#
# The data we have are unbalanced, since we have much more data from the "No" class than from the "Yes" class. This makes that our models do not learn well due to the unbalance.
#
# To fix it, we have different possible solutions:
#
# - **Penalize the majority class:** Since we learn more with it, by putting a penalty we could make the other class to be taken more into account. However, not all models allow us to make this modification. The logistic regression and the Random Forest implemented does allow us to do it by means of the parameter "class_weight='balanced'". Even so, these models are not the best performing, so it is not an effective measure for the whole analysis.
#
#
#
# - **Try more complex ensemble methods** that work better for these types of unbalanced datasets. One of the possible implementations is to make use of the "StackingClassifier".
#
#
#
# - **Make use of subsampling and oversampling:** That is, if we remove records from the majority class, or synthetically add records from the minority class, we can try to reduce the unbalance and make it more balanced, thus improving the results of our models.
#
#
#
# - **Analyze if there are variables that are not relevant in the dataset for most of our models and eliminate them:** By doing this, we can eliminate variables that always take similar values that are causing this unbalance and that do not contribute information to our models.

# %% [markdown]
# ### OVERSAMPLING APPROACH (and penalizing the majority class if the model allows it)

# %% [markdown]
# Let's start by applying oversampling. For this we make use of the "imblearn" library and the SMOTE (Synthetic Minority Over-sampling Technique) function.

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(k_neighbors = 5, random_state=random_seed)
X_train_os, y_train_os = smote.fit_resample(X_train, y_train)

# %%
print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (28904, 14)
# X_test shape: (9635, 14)
# y_train: (28904,)
# y_test shape: (9635,)

# %%
print("X_train shape:",X_train_os.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train_os.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (51302, 14)
# X_test shape: (9635, 14)
# y_train: (51302,)
# y_test shape: (9635,)

# %% [markdown]
# As we can see, more records have been added to the train partitions, from 30882 to 54804 records. It should be noted that it is only applied to the training set and not to the test set to avoid bias in the evaluation of the model.
#
# In this way the model is allowed to more effectively learn the underlying characteristics of the minority classes without compromising the unbiased evaluation of the model on the test set.

# %% [markdown]
# ### We retrain the most successful models with the new train partition.

# %% [markdown]
# #### LOGISTIC REGRESSION (WITH SMOTE):
# #### Linear regression method for binary classification problems
#
# In addition, in this case we use the **penalization to the majority class, as this method allows it**

# %%
model_lr_smote = LogisticRegression(class_weight='balanced')
model_lr_smote.fit( X_train_os, y_train_os)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred_lr_os = model_lr_smote.predict(X_test)

# %%
accuracy_lr_os = accuracy_score(y_test, y_pred_lr_os)
report_lr_os = classification_report(y_test, y_pred_lr_os)
print("Accuracy:", accuracy_lr_os)
print("Classification Report:\n", report_lr_os)
# Out:
# Accuracy: 0.7727036844836533
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      8550
#            1       0.27      0.60      0.37      1085
#
#     accuracy                           0.77      9635
#    macro avg       0.61      0.70      0.62      9635
# weighted avg       0.87      0.77      0.81      9635

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_lr_os = model_lr_smote.predict_proba(X_test)[:, 1]
fpr_lr_os, tpr_lr_os, thresholds_lr_os = roc_curve(y_test, y_pred_prob_lr_os)
auc_lr_os = roc_auc_score(y_test, y_pred_prob_lr_os)

# Plot ROC curve
plt.plot(fpr_lr_os, tpr_lr_os, label='ROC curve (AUC = {:.2f})'.format(auc_lr_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_lr_os = model_lr_smote.predict(X_test)
cm_lr_smote = confusion_matrix(y_test, y_pred_lr_os)

# Visualize confusion matrix
sns.heatmap(cm_lr_smote, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
fig_cm_lr_smote = plt.gcf() 
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO LOGISTIC REGRESSION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Logistic Regression WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_lr_smote, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Logistic Regression WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# As we can see in the figure, by using oversampling and penalization, we obtain a model that classifies the minority class much better. It is true that the majority class is no longer classified as correctly as it was previously. However, we prefer the result to be the latter, since we no longer see the results of the unbalance.

# %% [markdown]
# #### KNN (WITH SMOTE):

# %%
param_grid_knn_os= {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'algorithm': ['ball_tree', 'kd_tree', 'brute']}

knn_os = KNeighborsClassifier()

# refit true, para que entrenemos con todos los datos
grid_search_knn_os = GridSearchCV(knn_os, param_grid_knn_os, cv=3, refit=True, n_jobs=-1)

grid_search_knn_os.fit(X_train_os, y_train_os)

print("Best hyperparameters:", grid_search_knn_os.best_params_)
print("Accuracy score:", grid_search_knn_os.best_score_)

best_model_knn_os = grid_search_knn_os.best_estimator_
y_pred_knn_os = best_model_knn_os.predict(X_test)
# Out:
# Best hyperparameters: {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'distance'}
# Accuracy score: 0.8619940901510154

# %%
accuracy_knn_os = accuracy_score(y_test, y_pred_knn_os)
report_knn_os = classification_report(y_test, y_pred_knn_os)
print("Best Parameters:", grid_search_knn_os.best_params_)
print("Accuracy:", accuracy_knn_os)
print("Classification Report:\n", report_knn_os)
# Out:
# Best Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'distance'}
# Accuracy: 0.8625843279709393
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92      8550
#            1       0.37      0.33      0.35      1085
#
#     accuracy                           0.86      9635
#    macro avg       0.64      0.63      0.64      9635
# weighted avg       0.85      0.86      0.86      9635

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_knn_os = best_model_knn_os.predict_proba(X_test)[:, 1]
fpr_knn_os, tpr_knn_os, thresholds_knn_os = roc_curve(y_test, y_pred_prob_knn_os)
auc_knn_os = roc_auc_score(y_test, y_pred_prob_knn_os)

# Plot ROC curve
plt.plot(fpr_knn_os, tpr_knn_os, label='ROC curve (AUC = {:.2f})'.format(auc_knn_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_knn_os = best_model_knn_os.predict(X_test)
cm_knn_os = confusion_matrix(y_test, y_pred_knn_os)

# Visualize confusion matrix
sns.heatmap(cm_knn_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO KNN:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - knn WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_knn_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - knn WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### CLASSIFICATION TREES (WITH SMOTE)

# %%
param_grid_ct_os = {'max_depth': [3, 5, 7, 9, None],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

model_ct_os = DecisionTreeClassifier(random_state=random_seed)
grid_search_ct_os = GridSearchCV(model_ct, param_grid_ct_os, cv=3, n_jobs=-1)
grid_search_ct_os.fit(X_train_os, y_train_os)

best_model_ct_os = grid_search_ct_os.best_estimator_
y_pred_ct_os = best_model_ct_os.predict(X_test)

accuracy_ct_os = accuracy_score(y_test, y_pred_ct_os)
report_ct_os = classification_report(y_test, y_pred_ct_os)
print("Best Parameters:", grid_search_ct_os.best_params_)
print("Accuracy:", accuracy_ct_os)
print("Classification Report:\n", report_ct_os)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.867047223663726
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93      8550
#            1       0.38      0.29      0.33      1085
#
#     accuracy                           0.87      9635
#    macro avg       0.65      0.61      0.63      9635
# weighted avg       0.85      0.87      0.86      9635

# %%
# Generate ROC curve and calculate AUC
y_pred_prob = best_model_ct_os.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
auc = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred = best_model_ct_os.predict(X_test)
cm_ct_os = confusion_matrix(y_test, y_pred_ct_os)

# Visualize confusion matrix
sns.heatmap(cm_ct_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO CT:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_ct, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Classification Trees WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_ct_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix -  Classification Trees WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### RANDOM FOREST (WITH SMOTE):

# %%
param_grid_rf_os = {"n_estimators": [50, 100, 200],
              "max_depth": [None, 5, 10],
              "min_samples_split": [2, 5, 10],
              "min_samples_leaf": [1, 2, 4]}
rfc_os = RandomForestClassifier(random_state=random_seed, class_weight='balanced')
grid_search_rf_os = GridSearchCV(rfc_os, param_grid_rf_os, cv=3, n_jobs=-1)
grid_search_rf_os.fit(X_train_os, y_train_os)

print("Best hyperparameters:", grid_search_rf_os.best_params_)
print("Accuracy score:", grid_search_rf_os.best_score_)

best_model_rf_os = grid_search_rf_os.best_estimator_
y_pred_rf_os = best_model_rf_os.predict(X_test)

accuracy_rf_os = accuracy_score(y_test, y_pred_rf_os)
report_rf_os = classification_report(y_test, y_pred_rf_os)
print("Best Parameters:", grid_search_rf_os.best_params_)
print("Accuracy:", accuracy_rf_os)
print("Classification Report:\n", report_rf_os)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Accuracy score: 0.9142924019923826
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Accuracy: 0.8772184743124027
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      8550
#            1       0.44      0.35      0.39      1085
#
#     accuracy                           0.88      9635
#    macro avg       0.68      0.65      0.66      9635
# weighted avg       0.87      0.88      0.87      9635

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_rf_os = best_model_rf_os.predict_proba(X_test)[:, 1]
fpr_rf_os, tpr_rf_os, thresholds_rf_os = roc_curve(y_test, y_pred_prob_rf_os)
auc_rf_os = roc_auc_score(y_test, y_pred_prob_rf_os)

# Plot ROC curve
plt.plot(fpr_rf_os, tpr_rf_os, label='ROC curve (AUC = {:.2f})'.format(auc_rf_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_rf_os = best_model_rf_os.predict(X_test)
cm_rf_os = confusion_matrix(y_test, y_pred_rf_os)

# Visualize confusion matrix
sns.heatmap(cm_rf_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO RANDOM FOREST:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Random Forest WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_rf_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Random Forest WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### GRADIENT BOOSTING (WITH SMOTE):

# %%
# Create the Gradient Boosting classifier
gradient_boosting_smote = GradientBoostingClassifier()

# Define the parameter grid for Gradient Boosting
param_grid_gb_os = {
    'n_estimators': [50, 100, 200],        
    'learning_rate': [0.1, 0.5, 1.0],     
    'max_depth': [3, 4, 5]                 
}

# Perform grid search for Gradient Boosting
grid_search_gb_os = GridSearchCV(gradient_boosting_smote, param_grid_gb_os, cv=3, n_jobs=-1)
grid_search_gb_os.fit(X_train_os, y_train_os)

# Get the best Gradient Boosting model and its performance
best_gradient_boosting_smote = grid_search_gb_os.best_estimator_
best_params_gb_os = grid_search_gb_os.best_params_
best_score_gb_os = grid_search_gb_os.best_score_

# Train the best Gradient Boosting model with all data
best_gradient_boosting_smote.fit(X_train_os, y_train_os)

# Evaluate the best Gradient Boosting model
test_accuracy_gb_os = best_gradient_boosting_smote.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_gb_os*100:.2f}%')
# Out:
# Test Accuracy: 88.60%

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_gb_os = best_gradient_boosting_smote.predict_proba(X_test)[:, 1]
fpr_gb_os, tpr_gb_os, thresholds_gb_os = roc_curve(y_test, y_pred_prob_gb_os)
auc_gb_os = roc_auc_score(y_test, y_pred_prob_gb_os)

# Plot ROC curve
plt.plot(fpr_gb_os, tpr_gb_os, label='ROC curve (AUC = {:.2f})'.format(auc_gb_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_gb_os = best_gradient_boosting_smote.predict(X_test)
cm_gb_smote = confusion_matrix(y_test, y_pred_gb_os)

# Visualize confusion matrix
sns.heatmap(cm_gb_smote, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO GRADIENT BOOSTING:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_gb, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Gradient Boosting WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_gb_smote, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Gradient Boosting WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# As we can see in both confusion matrices, the inclusion of oversampling improves the predictions. However, the improvement obtained with Logistic regression is better than with Gradient Boosting. Therefore, although without oversampling we would choose Gradient Boosting as the best model, using oversampling we choose logistic regression as the best model between these two.

# %% [markdown]
# #### NEURAL NETWORK (WITH SMOTE):

# %%
def create_model_nn(hidden_units=128):
    model = Sequential()
    model.add(Dense(hidden_units, input_dim=X_train_os.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Define the parameter gridB
param_grid_nn_os = {
    'hidden_units': [64, 128, 256],
    'epochs': [10, 20, 30],
    'batch_size': [16, 32, 64]
}

# Create the model
model_nn_os = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn=create_model_nn)

# Perform grid search
grid_search_nn_os = GridSearchCV(model_nn_os, param_grid_nn_os, cv=3, n_jobs=-1)
grid_search_nn_os.fit(X_train_os, y_train_os)

# Get the best parameters
best_params_nn_os = grid_search_nn_os.best_params_
best_params_nn_os
# Out:
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4608 - accuracy: 0.8061
# 1761/2138 [=======================>......] - ETA: 2s - loss: 0.5580 - accuracy: 0.7166Epoch 2/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4591 - accuracy: 0.8062
# Epoch 2/20
# 2138/2138 [==============================] - 16s 6ms/step - loss: 0.5115 - accuracy: 0.7238
# 1964/2138 [==========================>...] - ETA: 1s - loss: 0.5129 - accuracy: 0.7225Epoch 2/10
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4611 - accuracy: 0.8045
# 1905/2138 [=========================>....] - ETA: 1s - loss: 0.5586 - accuracy: 0.7175Epoch 2/10
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.5577 - accuracy: 0.7170
# 1913/2138 [=========================>....] - ETA: 1s - loss: 0.5590 - accuracy: 0.7173Epoch 2/10
# 2138/2138 [==============================] - 17s 7ms/step - loss: 0.5116 - accuracy: 0.7237
# 1902/2138 [=========================>....] - ETA: 1s - loss: 0.5112 - accuracy: 0.7228Epoch 2/20
# 2138/2138 [==============================] - 17s 7ms/step - loss: 0.5103 - accuracy: 0.7240
# 2061/2138 [===========================>..] - ETA: 0s - loss: 0.5582 - accuracy: 0.7176Epoch 2/10
# 2138/2138 [==============================] - 17s 6ms/step - loss: 0.5557 - accuracy: 0.7164
#  181/2138 [=>............................] - ETA: 14s - loss: 0.5504 - accuracy: 0.7289Epoch 2/10
# 2138/2138 [==============================] - 18s 7ms/step - loss: 0.5099 - accuracy: 0.7240
# 2138/2138 [==============================] - 18s 7ms/step - loss: 0.5111 - accuracy: 0.7209
# Epoch 2/20
# 2019/2138 [===========================>..] - ETA: 0s - loss: 0.5573 - accuracy: 0.7172Epoch 2/10
# 2138/2138 [==============================] - 18s 7ms/step - loss: 0.5586 - accuracy: 0.7169
#   27/2138 [..............................] - ETA: 13s - loss: 0.4708 - accuracy: 0.7384Epoch 2/20
# 2138/2138 [==============================] - 18s 7ms/step - loss: 0.4589 - accuracy: 0.8082
#  205/2138 [=>............................] - ETA: 12s - loss: 0.4853 - accuracy: 0.7363Epoch 2/10
# 2138/2138 [==============================] - 18s 8ms/step - loss: 0.5100 - accuracy: 0.7238
#   61/2138 [..............................] - ETA: 10s - loss: 0.5434 - accuracy: 0.7193Epoch 2/20
# 2138/2138 [==============================] - 18s 7ms/step - loss: 0.5564 - accuracy: 0.7178
#  107/2138 [>.............................] - ETA: 16s - loss: 0.5010 - accuracy: 0.7290Epoch 2/20
# 2138/2138 [==============================] - 19s 7ms/step - loss: 0.5562 - accuracy: 0.7180
#   30/2138 [..............................] - ETA: 23s - loss: 0.5041 - accuracy: 0.7271Epoch 2/10
# 2138/2138 [==============================] - 20s 7ms/step - loss: 0.4586 - accuracy: 0.8072
# Epoch 2/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4504 - accuracy: 0.8140
# 1484/2138 [===================>..........] - ETA: 4s - loss: 0.4509 - accuracy: 0.8117Epoch 3/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4505 - accuracy: 0.8132
# Epoch 3/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4990 - accuracy: 0.7338
# Epoch 3/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5444 - accuracy: 0.7230
# 1808/2138 [========================>.....] - ETA: 2s - loss: 0.5011 - accuracy: 0.7314Epoch 3/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4977 - accuracy: 0.7365
# 1960/2138 [==========================>...] - ETA: 1s - loss: 0.5424 - accuracy: 0.7237Epoch 3/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4506 - accuracy: 0.8133
# 1950/2138 [==========================>...] - ETA: 1s - loss: 0.5461 - accuracy: 0.7233Epoch 3/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4986 - accuracy: 0.7345
#  240/2138 [==>...........................] - ETA: 11s - loss: 0.4851 - accuracy: 0.7437Epoch 3/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4995 - accuracy: 0.7345
# 1945/2138 [==========================>...] - ETA: 1s - loss: 0.5018 - accuracy: 0.7315Epoch 3/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5431 - accuracy: 0.7230
# 1759/2138 [=======================>......] - ETA: 2s - loss: 0.4527 - accuracy: 0.8106Epoch 3/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5449 - accuracy: 0.7239
#  570/2138 [======>.......................] - ETA: 10s - loss: 0.4487 - accuracy: 0.8086Epoch 3/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5458 - accuracy: 0.7230
# 2104/2138 [============================>.] - ETA: 0s - loss: 0.4507 - accuracy: 0.8123Epoch 3/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4503 - accuracy: 0.8124
#  113/2138 [>.............................] - ETA: 10s - loss: 0.4896 - accuracy: 0.7467Epoch 3/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5453 - accuracy: 0.7230
# Epoch 3/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4996 - accuracy: 0.7328
#  184/2138 [=>............................] - ETA: 11s - loss: 0.4905 - accuracy: 0.7395Epoch 3/20
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4995 - accuracy: 0.7326
#  321/2138 [===>..........................] - ETA: 13s - loss: 0.4883 - accuracy: 0.7444Epoch 3/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4495 - accuracy: 0.8135
#  662/2138 [========>.....................] - ETA: 8s - loss: 0.5402 - accuracy: 0.7265Epoch 3/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4477 - accuracy: 0.8139
# 1550/2138 [====================>.........] - ETA: 3s - loss: 0.4911 - accuracy: 0.7431Epoch 4/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4473 - accuracy: 0.8141
# 1636/2138 [=====================>........] - ETA: 3s - loss: 0.5421 - accuracy: 0.7229Epoch 4/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4935 - accuracy: 0.7403
# 1866/2138 [=========================>....] - ETA: 1s - loss: 0.4896 - accuracy: 0.7454Epoch 4/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5376 - accuracy: 0.7264
# 1790/2138 [========================>.....] - ETA: 2s - loss: 0.4919 - accuracy: 0.7422Epoch 4/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4472 - accuracy: 0.8142
# Epoch 4/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4900 - accuracy: 0.7456
# Epoch 4/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4939 - accuracy: 0.7401
# 1847/2138 [========================>.....] - ETA: 2s - loss: 0.4906 - accuracy: 0.7420Epoch 4/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5347 - accuracy: 0.7303
#  171/2138 [=>............................] - ETA: 10s - loss: 0.4495 - accuracy: 0.8118Epoch 4/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4916 - accuracy: 0.7436
#   18/2138 [..............................] - ETA: 14s - loss: 0.5093 - accuracy: 0.7396Epoch 4/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5405 - accuracy: 0.7243
#   39/2138 [..............................] - ETA: 15s - loss: 0.4952 - accuracy: 0.7420Epoch 4/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5379 - accuracy: 0.7264
# Epoch 4/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4462 - accuracy: 0.8143
#  189/2138 [=>............................] - ETA: 13s - loss: 0.5293 - accuracy: 0.7259Epoch 4/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5379 - accuracy: 0.7268
# Epoch 4/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4924 - accuracy: 0.7404
#  216/2138 [==>...........................] - ETA: 13s - loss: 0.5255 - accuracy: 0.7297Epoch 4/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4921 - accuracy: 0.7426
#  780/2138 [=========>....................] - ETA: 9s - loss: 0.4457 - accuracy: 0.8154Epoch 4/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4461 - accuracy: 0.8143
# Epoch 4/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4444 - accuracy: 0.8147
# 1379/2138 [==================>...........] - ETA: 5s - loss: 0.4892 - accuracy: 0.7464Epoch 5/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5305 - accuracy: 0.7303
# Epoch 5/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4874 - accuracy: 0.7474
# Epoch 5/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4443 - accuracy: 0.8144
# 1671/2138 [======================>.......] - ETA: 3s - loss: 0.5328 - accuracy: 0.7298Epoch 5/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4818 - accuracy: 0.7559
# 1474/2138 [===================>..........] - ETA: 4s - loss: 0.5317 - accuracy: 0.7318Epoch 5/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4450 - accuracy: 0.8153
# Epoch 5/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5345 - accuracy: 0.7298
# 2037/2138 [===========================>..] - ETA: 0s - loss: 0.5318 - accuracy: 0.7313Epoch 5/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4840 - accuracy: 0.7512
# 1672/2138 [======================>.......] - ETA: 3s - loss: 0.4841 - accuracy: 0.7494Epoch 5/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5256 - accuracy: 0.7345
#  143/2138 [=>............................] - ETA: 16s - loss: 0.4117 - accuracy: 0.8344Epoch 5/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4868 - accuracy: 0.7478
#  736/2138 [=========>....................] - ETA: 10s - loss: 0.4403 - accuracy: 0.8185Epoch 5/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5310 - accuracy: 0.7319
# Epoch 5/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4855 - accuracy: 0.7460
#  931/2138 [============>.................] - ETA: 8s - loss: 0.4415 - accuracy: 0.8168Epoch 5/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5305 - accuracy: 0.7321
# 1000/2138 [=============>................] - ETA: 6s - loss: 0.4788 - accuracy: 0.7566Epoch 5/20
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4443 - accuracy: 0.8154
#  246/2138 [==>...........................] - ETA: 13s - loss: 0.4734 - accuracy: 0.7530Epoch 5/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4845 - accuracy: 0.7504
#  466/2138 [=====>........................] - ETA: 10s - loss: 0.5280 - accuracy: 0.7295Epoch 5/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4442 - accuracy: 0.8158
#  567/2138 [======>.......................] - ETA: 10s - loss: 0.4724 - accuracy: 0.7585Epoch 5/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4421 - accuracy: 0.8155
# 1926/2138 [==========================>...] - ETA: 1s - loss: 0.4428 - accuracy: 0.8156Epoch 6/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4818 - accuracy: 0.7540
# 1563/2138 [====================>.........] - ETA: 3s - loss: 0.4803 - accuracy: 0.7531Epoch 6/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4429 - accuracy: 0.8152
# 1610/2138 [=====================>........] - ETA: 3s - loss: 0.4795 - accuracy: 0.7536Epoch 6/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5244 - accuracy: 0.7345
# Epoch 6/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4745 - accuracy: 0.7619
# 1818/2138 [========================>.....] - ETA: 2s - loss: 0.4770 - accuracy: 0.7589Epoch 6/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5287 - accuracy: 0.7332
# Epoch 6/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5240 - accuracy: 0.7354
# Epoch 6/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4412 - accuracy: 0.8171
# Epoch 6/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4793 - accuracy: 0.7549
# 1763/2138 [=======================>......] - ETA: 2s - loss: 0.4776 - accuracy: 0.7564Epoch 6/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5173 - accuracy: 0.7408
# Epoch 6/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4758 - accuracy: 0.7595
# Epoch 6/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4772 - accuracy: 0.7558
# 1967/2138 [==========================>...] - ETA: 1s - loss: 0.4414 - accuracy: 0.8171Epoch 6/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5215 - accuracy: 0.7385
# Epoch 6/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4413 - accuracy: 0.8169
# 1909/2138 [=========================>....] - ETA: 1s - loss: 0.4786 - accuracy: 0.7550Epoch 6/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4414 - accuracy: 0.8168
#  682/2138 [========>.....................] - ETA: 9s - loss: 0.5203 - accuracy: 0.7393Epoch 6/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4777 - accuracy: 0.7564
#  590/2138 [=======>......................] - ETA: 10s - loss: 0.4687 - accuracy: 0.7667Epoch 6/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4398 - accuracy: 0.8171
# Epoch 7/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4755 - accuracy: 0.7557
#  322/2138 [===>..........................] - ETA: 9s - loss: 0.4306 - accuracy: 0.8245Epoch 7/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5181 - accuracy: 0.7393
#  220/2138 [==>...........................] - ETA: 13s - loss: 0.4597 - accuracy: 0.7651Epoch 7/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4406 - accuracy: 0.8164
# Epoch 7/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5231 - accuracy: 0.7359
# 1335/2138 [=================>............] - ETA: 4s - loss: 0.4681 - accuracy: 0.7640Epoch 7/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4688 - accuracy: 0.7657
# 1455/2138 [===================>..........] - ETA: 4s - loss: 0.4685 - accuracy: 0.7637Epoch 7/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5162 - accuracy: 0.7413
#  706/2138 [========>.....................] - ETA: 9s - loss: 0.4537 - accuracy: 0.7700Epoch 7/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4721 - accuracy: 0.7609
#   52/2138 [..............................] - ETA: 15s - loss: 0.4992 - accuracy: 0.7452Epoch 7/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4673 - accuracy: 0.7671
# 1637/2138 [=====================>........] - ETA: 3s - loss: 0.4700 - accuracy: 0.7626Epoch 7/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4392 - accuracy: 0.8173
#  530/2138 [======>.......................] - ETA: 10s - loss: 0.4380 - accuracy: 0.8167Epoch 7/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5095 - accuracy: 0.7459
#   38/2138 [..............................] - ETA: 17s - loss: 0.4995 - accuracy: 0.7336Epoch 7/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5128 - accuracy: 0.7428
# 1765/2138 [=======================>......] - ETA: 2s - loss: 0.4394 - accuracy: 0.8181Epoch 7/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4388 - accuracy: 0.8180
#  351/2138 [===>..........................] - ETA: 13s - loss: 0.4700 - accuracy: 0.7634Epoch 7/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4710 - accuracy: 0.7618
# 1995/2138 [==========================>...] - ETA: 0s - loss: 0.4395 - accuracy: 0.8181Epoch 7/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4706 - accuracy: 0.7616
# Epoch 7/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4387 - accuracy: 0.8184
#  518/2138 [======>.......................] - ETA: 12s - loss: 0.4581 - accuracy: 0.7757Epoch 7/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4374 - accuracy: 0.8188
# Epoch 8/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4691 - accuracy: 0.7622
# Epoch 8/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5125 - accuracy: 0.7442
#  919/2138 [===========>..................] - ETA: 8s - loss: 0.4650 - accuracy: 0.7643Epoch 8/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4382 - accuracy: 0.8169
#  339/2138 [===>..........................] - ETA: 14s - loss: 0.4421 - accuracy: 0.8153Epoch 8/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5163 - accuracy: 0.7400
# Epoch 8/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5086 - accuracy: 0.7472
#  459/2138 [=====>........................] - ETA: 10s - loss: 0.4293 - accuracy: 0.8182Epoch 8/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4613 - accuracy: 0.7728
# 1554/2138 [====================>.........] - ETA: 3s - loss: 0.4373 - accuracy: 0.8203Epoch 8/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5006 - accuracy: 0.7501
# Epoch 8/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4356 - accuracy: 0.8185
#  757/2138 [=========>....................] - ETA: 10s - loss: 0.4681 - accuracy: 0.7663Epoch 8/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4645 - accuracy: 0.7701
#   58/2138 [..............................] - ETA: 16s - loss: 0.4723 - accuracy: 0.7748Epoch 8/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4601 - accuracy: 0.7721
#  819/2138 [==========>...................] - ETA: 10s - loss: 0.4654 - accuracy: 0.7678Epoch 8/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5046 - accuracy: 0.7481
#  375/2138 [====>.........................] - ETA: 12s - loss: 0.5050 - accuracy: 0.7573Epoch 8/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4358 - accuracy: 0.8207
# 1927/2138 [==========================>...] - ETA: 1s - loss: 0.4619 - accuracy: 0.7694Epoch 8/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4637 - accuracy: 0.7695
#  645/2138 [========>.....................] - ETA: 10s - loss: 0.5058 - accuracy: 0.7526Epoch 8/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4629 - accuracy: 0.7683
#  614/2138 [=======>......................] - ETA: 8s - loss: 0.4325 - accuracy: 0.8222Epoch 8/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4357 - accuracy: 0.8188
# 1535/2138 [====================>.........] - ETA: 3s - loss: 0.5057 - accuracy: 0.7485Epoch 8/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4344 - accuracy: 0.8200
# Epoch 9/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4634 - accuracy: 0.7688
# 1162/2138 [===============>..............] - ETA: 6s - loss: 0.5029 - accuracy: 0.7508Epoch 9/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5067 - accuracy: 0.7478
# 1497/2138 [====================>.........] - ETA: 4s - loss: 0.5013 - accuracy: 0.7510Epoch 9/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4358 - accuracy: 0.8172
#  550/2138 [======>.......................] - ETA: 11s - loss: 0.4346 - accuracy: 0.8175Epoch 9/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5100 - accuracy: 0.7428
# 1273/2138 [================>.............] - ETA: 5s - loss: 0.4567 - accuracy: 0.7760Epoch 9/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4995 - accuracy: 0.7526
# 1542/2138 [====================>.........] - ETA: 4s - loss: 0.4319 - accuracy: 0.8218Epoch 9/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4935 - accuracy: 0.7525
# 1204/2138 [===============>..............] - ETA: 7s - loss: 0.4323 - accuracy: 0.8201Epoch 9/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4553 - accuracy: 0.7766
# Epoch 9/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4583 - accuracy: 0.7722
# Epoch 9/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4972 - accuracy: 0.7530
# Epoch 9/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4322 - accuracy: 0.8210
# 2064/2138 [===========================>..] - ETA: 0s - loss: 0.4513 - accuracy: 0.7782Epoch 9/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4523 - accuracy: 0.7773
#  942/2138 [============>.................] - ETA: 8s - loss: 0.5011 - accuracy: 0.7489Epoch 9/10
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4557 - accuracy: 0.7747
#  747/2138 [=========>....................] - ETA: 9s - loss: 0.5017 - accuracy: 0.7462Epoch 9/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4327 - accuracy: 0.8218
# 1164/2138 [===============>..............] - ETA: 6s - loss: 0.5010 - accuracy: 0.7490Epoch 9/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4565 - accuracy: 0.7759
#  477/2138 [=====>........................] - ETA: 10s - loss: 0.4141 - accuracy: 0.8302Epoch 9/20
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4336 - accuracy: 0.8199
# Epoch 9/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4337 - accuracy: 0.8183
# Epoch 10/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4575 - accuracy: 0.7737
# 1087/2138 [==============>...............] - ETA: 7s - loss: 0.4247 - accuracy: 0.8250Epoch 10/10
# 2138/2138 [==============================] - 16s 8ms/step - loss: 0.4319 - accuracy: 0.8208
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5015 - accuracy: 0.7497
# 1259/2138 [================>.............] - ETA: 6s - loss: 0.4240 - accuracy: 0.8261Epoch 10/10
#  213/2138 [=>............................] - ETA: 10s - loss: 0.4531 - accuracy: 0.7758Epoch 10/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5034 - accuracy: 0.7473
# Epoch 10/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4917 - accuracy: 0.7567
# 1073/2138 [==============>...............] - ETA: 7s - loss: 0.4298 - accuracy: 0.8222Epoch 10/10
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4904 - accuracy: 0.7570
#   63/2138 [..............................] - ETA: 16s - loss: 0.4893 - accuracy: 0.7480Epoch 10/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4855 - accuracy: 0.7584
#  738/2138 [=========>....................] - ETA: 9s - loss: 0.4956 - accuracy: 0.7521Epoch 10/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4492 - accuracy: 0.7801
# 1258/2138 [================>.............] - ETA: 6s - loss: 0.4284 - accuracy: 0.8227Epoch 10/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4289 - accuracy: 0.8226
#  222/2138 [==>...........................] - ETA: 15s - loss: 0.4791 - accuracy: 0.7624Epoch 10/10
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4443 - accuracy: 0.7861
# Epoch 10/10
# 2138/2138 [==============================] - 16s 8ms/step - loss: 0.4510 - accuracy: 0.7799
#   97/2138 [>.............................] - ETA: 13s - loss: 0.4423 - accuracy: 0.8144Epoch 10/20
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4483 - accuracy: 0.7805
#  306/2138 [===>..........................] - ETA: 13s - loss: 0.4388 - accuracy: 0.7876Epoch 10/10
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4303 - accuracy: 0.8222
#  277/2138 [==>...........................] - ETA: 12s - loss: 0.4514 - accuracy: 0.7793Epoch 10/10
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4493 - accuracy: 0.7814
# 1744/2138 [=======================>......] - ETA: 2s - loss: 0.4516 - accuracy: 0.7783Epoch 10/20
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4305 - accuracy: 0.8209
# 1482/2138 [===================>..........] - ETA: 4s - loss: 0.4977 - accuracy: 0.7503Epoch 10/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4312 - accuracy: 0.8181
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4518 - accuracy: 0.7780
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4949 - accuracy: 0.7541
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4286 - accuracy: 0.8221
# 1172/2138 [===============>..............] - ETA: 7s - loss: 0.4345 - accuracy: 0.7923Epoch 11/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4967 - accuracy: 0.7504
# Epoch 11/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4786 - accuracy: 0.7629
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4848 - accuracy: 0.7621
# 1069/1069 [==============================] - 6s 5ms/step - loss: 0.7919 - accuracy: 0.5287
# 1605/2138 [=====================>........] - ETA: 3s - loss: 0.4413 - accuracy: 0.7868Epoch 1/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4439 - accuracy: 0.7855
# 2112/2138 [============================>.] - ETA: 0s - loss: 0.4832 - accuracy: 0.7617Epoch 11/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4830 - accuracy: 0.7616
# 1069/1069 [==============================] - 5s 4ms/step - loss: 0.5379 - accuracy: 0.7505
# Epoch 11/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4256 - accuracy: 0.8230
#  215/1069 [=====>........................] - ETA: 3s - loss: 0.6341 - accuracy: 0.6898Epoch 1/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4443 - accuracy: 0.7841
# Epoch 11/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4356 - accuracy: 0.7918
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4412 - accuracy: 0.7866
# 1069/1069 [==============================] - 6s 5ms/step - loss: 1.0164 - accuracy: 0.5131
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4269 - accuracy: 0.8227
#  601/1069 [===============>..............] - ETA: 1s - loss: 1.0340 - accuracy: 0.5142Epoch 1/30
# 1069/1069 [==============================] - 5s 4ms/step - loss: 0.5191 - accuracy: 0.7572
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4399 - accuracy: 0.7878
# Epoch 11/20
# 1069/1069 [==============================] - 5s 4ms/step - loss: 0.5528 - accuracy: 0.7253
#  441/1069 [===========>..................] - ETA: 2s - loss: 0.7071 - accuracy: 0.6436Epoch 1/30
# 1069/1069 [==============================] - 5s 4ms/step - loss: 1.0245 - accuracy: 0.5218
#  959/2138 [============>.................] - ETA: 6s - loss: 0.4407 - accuracy: 0.7875Epoch 1/30
# 1009/2138 [=============>................] - ETA: 6s - loss: 0.4770 - accuracy: 0.7621Epoch 1/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4276 - accuracy: 0.8214
# Epoch 11/20
# 1069/1069 [==============================] - 5s 4ms/step - loss: 0.7143 - accuracy: 0.6406
#  766/2138 [=========>....................] - ETA: 7s - loss: 0.4695 - accuracy: 0.7979Epoch 1/30
# 1069/1069 [==============================] - 4s 4ms/step - loss: 0.7413 - accuracy: 0.5847
# 2138/2138 [==============================] - 12s 6ms/step - loss: 0.4263 - accuracy: 0.8222
#  842/2138 [==========>...................] - ETA: 6s - loss: 0.4681 - accuracy: 0.7984Epoch 12/20
#   25/2138 [..............................] - ETA: 13s - loss: 0.6186 - accuracy: 0.6825Epoch 1/30
# 2138/2138 [==============================] - 11s 5ms/step - loss: 0.4902 - accuracy: 0.7577
# Epoch 12/20
# 2138/2138 [==============================] - 11s 5ms/step - loss: 0.4380 - accuracy: 0.7893
# Epoch 12/20
# 2138/2138 [==============================] - 12s 6ms/step - loss: 0.4746 - accuracy: 0.7652
# 1136/2138 [==============>...............] - ETA: 5s - loss: 0.4283 - accuracy: 0.8217Epoch 12/20
# 2138/2138 [==============================] - 12s 6ms/step - loss: 0.4359 - accuracy: 0.7897
# 1320/2138 [=================>............] - ETA: 4s - loss: 0.4274 - accuracy: 0.8217Epoch 12/20
# 2138/2138 [==============================] - 17s 6ms/step - loss: 0.5560 - accuracy: 0.7173
# Epoch 2/20
# 2138/2138 [==============================] - 16s 6ms/step - loss: 0.4594 - accuracy: 0.8071
# Epoch 2/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4328 - accuracy: 0.7948
# Epoch 12/20
# 2138/2138 [==============================] - 12s 6ms/step - loss: 0.4258 - accuracy: 0.8229
# 1640/2138 [======================>.......] - ETA: 3s - loss: 0.4635 - accuracy: 0.8032Epoch 12/20
# 2138/2138 [==============================] - 16s 6ms/step - loss: 0.5095 - accuracy: 0.7218
# 2006/2138 [===========================>..] - ETA: 0s - loss: 0.5577 - accuracy: 0.7168Epoch 2/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4224 - accuracy: 0.8246
# Epoch 13/20
# 2138/2138 [==============================] - 16s 6ms/step - loss: 0.5580 - accuracy: 0.7169
# 1919/2138 [=========================>....] - ETA: 1s - loss: 0.5565 - accuracy: 0.7163Epoch 2/30
# 2138/2138 [==============================] - 16s 6ms/step - loss: 0.4603 - accuracy: 0.8048
# 2024/2138 [===========================>..] - ETA: 0s - loss: 0.4842 - accuracy: 0.7617Epoch 2/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4844 - accuracy: 0.7621
#  124/2138 [>.............................] - ETA: 13s - loss: 0.4038 - accuracy: 0.8306Epoch 13/20
# 2138/2138 [==============================] - 16s 6ms/step - loss: 0.5096 - accuracy: 0.7240
#   13/2138 [..............................] - ETA: 8s - loss: 0.4260 - accuracy: 0.7837Epoch 2/30
# 2138/2138 [==============================] - 15s 6ms/step - loss: 0.5549 - accuracy: 0.7167
#  634/2138 [=======>......................] - ETA: 10s - loss: 0.4205 - accuracy: 0.8262Epoch 2/30
# 2138/2138 [==============================] - 17s 6ms/step - loss: 0.4582 - accuracy: 0.8072
# 1694/2138 [======================>.......] - ETA: 3s - loss: 0.4282 - accuracy: 0.7964Epoch 2/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4329 - accuracy: 0.7939
#  726/2138 [=========>....................] - ETA: 8s - loss: 0.4484 - accuracy: 0.8133Epoch 13/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4680 - accuracy: 0.7716
#  693/2138 [========>.....................] - ETA: 11s - loss: 0.5441 - accuracy: 0.7274Epoch 13/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4280 - accuracy: 0.7956
#  279/2138 [==>...........................] - ETA: 11s - loss: 0.4661 - accuracy: 0.7666Epoch 13/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4499 - accuracy: 0.8136
# Epoch 3/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5445 - accuracy: 0.7233
# Epoch 3/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4251 - accuracy: 0.7987
#  931/2138 [============>.................] - ETA: 7s - loss: 0.4650 - accuracy: 0.7703Epoch 13/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4221 - accuracy: 0.8241
# Epoch 13/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4987 - accuracy: 0.7304
#  402/2138 [====>.........................] - ETA: 10s - loss: 0.4159 - accuracy: 0.8018Epoch 3/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4503 - accuracy: 0.8122
# 1558/2138 [====================>.........] - ETA: 3s - loss: 0.4291 - accuracy: 0.7957Epoch 3/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4775 - accuracy: 0.7681
# 2049/2138 [===========================>..] - ETA: 0s - loss: 0.4205 - accuracy: 0.8248Epoch 14/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5449 - accuracy: 0.7242
# 1435/2138 [===================>..........] - ETA: 4s - loss: 0.4623 - accuracy: 0.7723Epoch 3/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4205 - accuracy: 0.8249
#   17/2138 [..............................] - ETA: 20s - loss: 0.4858 - accuracy: 0.7610Epoch 14/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4989 - accuracy: 0.7335
#  243/2138 [==>...........................] - ETA: 10s - loss: 0.4847 - accuracy: 0.7395Epoch 3/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5435 - accuracy: 0.7242
#  592/2138 [=======>......................] - ETA: 8s - loss: 0.4142 - accuracy: 0.8264Epoch 3/30
# 2138/2138 [==============================] - 12s 6ms/step - loss: 0.4260 - accuracy: 0.7977
# Epoch 14/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4501 - accuracy: 0.8128
#  397/2138 [====>.........................] - ETA: 11s - loss: 0.5353 - accuracy: 0.7261Epoch 3/30
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4628 - accuracy: 0.7736
#  808/2138 [==========>...................] - ETA: 9s - loss: 0.4509 - accuracy: 0.8116Epoch 14/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4214 - accuracy: 0.8011
# Epoch 14/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4472 - accuracy: 0.8144
#  235/2138 [==>...........................] - ETA: 14s - loss: 0.4168 - accuracy: 0.8035Epoch 4/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5375 - accuracy: 0.7274
# Epoch 4/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4181 - accuracy: 0.8036
# Epoch 14/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4194 - accuracy: 0.8254
# 1723/2138 [=======================>......] - ETA: 2s - loss: 0.5366 - accuracy: 0.7262Epoch 14/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4930 - accuracy: 0.7405
# 2011/2138 [===========================>..] - ETA: 0s - loss: 0.4472 - accuracy: 0.8130Epoch 4/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4702 - accuracy: 0.7712
# Epoch 15/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5373 - accuracy: 0.7274
# Epoch 4/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4468 - accuracy: 0.8133
# 2092/2138 [============================>.] - ETA: 0s - loss: 0.4176 - accuracy: 0.8257Epoch 4/30
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4168 - accuracy: 0.8261
# Epoch 15/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5355 - accuracy: 0.7259
#  185/2138 [=>............................] - ETA: 12s - loss: 0.5250 - accuracy: 0.7402Epoch 4/30
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4920 - accuracy: 0.7437
#  195/2138 [=>............................] - ETA: 12s - loss: 0.5292 - accuracy: 0.7378Epoch 4/30
# 2138/2138 [==============================] - 12s 6ms/step - loss: 0.4212 - accuracy: 0.8041
#  412/2138 [====>.........................] - ETA: 10s - loss: 0.4596 - accuracy: 0.7819Epoch 15/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4461 - accuracy: 0.8144
# 1131/2138 [==============>...............] - ETA: 6s - loss: 0.5314 - accuracy: 0.7314Epoch 4/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4540 - accuracy: 0.7801
#  743/2138 [=========>....................] - ETA: 8s - loss: 0.4156 - accuracy: 0.8064Epoch 15/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4157 - accuracy: 0.8040
# 1018/2138 [=============>................] - ETA: 7s - loss: 0.4853 - accuracy: 0.7494Epoch 15/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4444 - accuracy: 0.8159
# 1672/2138 [======================>.......] - ETA: 2s - loss: 0.4694 - accuracy: 0.7722Epoch 5/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5296 - accuracy: 0.7334
# 1499/2138 [====================>.........] - ETA: 4s - loss: 0.4835 - accuracy: 0.7503Epoch 5/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4113 - accuracy: 0.8066
# Epoch 15/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4180 - accuracy: 0.8268
# 1574/2138 [=====================>........] - ETA: 3s - loss: 0.4161 - accuracy: 0.8067Epoch 15/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4862 - accuracy: 0.7500
#   66/2138 [..............................] - ETA: 11s - loss: 0.4065 - accuracy: 0.8172Epoch 5/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4657 - accuracy: 0.7753
# 1791/2138 [========================>.....] - ETA: 2s - loss: 0.5282 - accuracy: 0.7329Epoch 16/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.5302 - accuracy: 0.7349
# 2036/2138 [===========================>..] - ETA: 0s - loss: 0.4443 - accuracy: 0.8154Epoch 5/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4136 - accuracy: 0.8280
#  290/2138 [===>..........................] - ETA: 12s - loss: 0.4083 - accuracy: 0.8080Epoch 16/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4448 - accuracy: 0.8149
#  321/2138 [===>..........................] - ETA: 12s - loss: 0.4105 - accuracy: 0.8072Epoch 5/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4855 - accuracy: 0.7487
# 1682/2138 [======================>.......] - ETA: 2s - loss: 0.4438 - accuracy: 0.8170Epoch 5/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5277 - accuracy: 0.7340
#  898/2138 [===========>..................] - ETA: 8s - loss: 0.4431 - accuracy: 0.8130Epoch 5/30
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4164 - accuracy: 0.8061
#   52/2138 [..............................] - ETA: 16s - loss: 0.5040 - accuracy: 0.7416Epoch 16/20
# 1069/1069 [==============================] - 6s 5ms/step - loss: 0.8381 - accuracy: 0.5429
#  585/2138 [=======>......................] - ETA: 11s - loss: 0.4603 - accuracy: 0.7725Epoch 1/30
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4438 - accuracy: 0.8161
# Epoch 5/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4475 - accuracy: 0.7839
# 1223/2138 [================>.............] - ETA: 6s - loss: 0.4592 - accuracy: 0.7788Epoch 16/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4089 - accuracy: 0.8069
# 1621/2138 [=====================>........] - ETA: 3s - loss: 0.4759 - accuracy: 0.7593Epoch 16/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4420 - accuracy: 0.8170
# 1816/2138 [========================>.....] - ETA: 1s - loss: 0.4132 - accuracy: 0.8280Epoch 6/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4155 - accuracy: 0.8268
# Epoch 16/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5210 - accuracy: 0.7368
# 1745/2138 [=======================>......] - ETA: 2s - loss: 0.4101 - accuracy: 0.8305Epoch 6/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4787 - accuracy: 0.7576
#  253/2138 [==>...........................] - ETA: 11s - loss: 0.3930 - accuracy: 0.8382Epoch 6/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4032 - accuracy: 0.8124
#  911/2138 [===========>..................] - ETA: 7s - loss: 0.4386 - accuracy: 0.7924Epoch 16/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4591 - accuracy: 0.7786
# 1365/2138 [==================>...........] - ETA: 5s - loss: 0.4398 - accuracy: 0.8165Epoch 17/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4111 - accuracy: 0.8292
#  995/2138 [============>.................] - ETA: 7s - loss: 0.4374 - accuracy: 0.7927Epoch 17/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5231 - accuracy: 0.7384
#   88/2138 [>.............................] - ETA: 16s - loss: 0.3716 - accuracy: 0.8303Epoch 6/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4421 - accuracy: 0.8160
#   83/2138 [>.............................] - ETA: 11s - loss: 0.4147 - accuracy: 0.8283Epoch 6/30
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5199 - accuracy: 0.7385
# Epoch 6/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4782 - accuracy: 0.7543
#  529/2138 [======>.......................] - ETA: 11s - loss: 0.4761 - accuracy: 0.7612Epoch 6/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4106 - accuracy: 0.8096
#   43/2138 [..............................] - ETA: 16s - loss: 0.4509 - accuracy: 0.7718Epoch 17/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4408 - accuracy: 0.8159
# Epoch 6/30
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4412 - accuracy: 0.7881
#  758/2138 [=========>....................] - ETA: 9s - loss: 0.4663 - accuracy: 0.7642Epoch 17/20
# 2138/2138 [==============================] - 19s 7ms/step - loss: 0.5096 - accuracy: 0.7247
# 1374/2138 [==================>...........] - ETA: 4s - loss: 0.4057 - accuracy: 0.8300Epoch 2/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4389 - accuracy: 0.8180
# 1753/2138 [=======================>......] - ETA: 2s - loss: 0.5121 - accuracy: 0.7458Epoch 7/20
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4025 - accuracy: 0.8116
#  296/2138 [===>..........................] - ETA: 15s - loss: 0.5039 - accuracy: 0.7306Epoch 17/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4128 - accuracy: 0.8271
#  285/2138 [==>...........................] - ETA: 13s - loss: 0.4247 - accuracy: 0.8272Epoch 17/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4711 - accuracy: 0.7633
# 2132/2138 [============================>.] - ETA: 0s - loss: 0.5120 - accuracy: 0.7462Epoch 7/30
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4531 - accuracy: 0.7828
# 1645/2138 [======================>.......] - ETA: 3s - loss: 0.4675 - accuracy: 0.7648Epoch 18/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5119 - accuracy: 0.7461
#  244/2138 [==>...........................] - ETA: 13s - loss: 0.4023 - accuracy: 0.8194Epoch 7/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.4396 - accuracy: 0.8170
# 1007/2138 [=============>................] - ETA: 7s - loss: 0.4352 - accuracy: 0.7915Epoch 7/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.3964 - accuracy: 0.8174
#  453/2138 [=====>........................] - ETA: 9s - loss: 0.4132 - accuracy: 0.8271Epoch 17/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4081 - accuracy: 0.8298
#  236/2138 [==>...........................] - ETA: 15s - loss: 0.4541 - accuracy: 0.7871Epoch 18/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5153 - accuracy: 0.7441
# 1559/2138 [====================>.........] - ETA: 3s - loss: 0.4354 - accuracy: 0.8200Epoch 7/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.5118 - accuracy: 0.7461
#  903/2138 [===========>..................] - ETA: 9s - loss: 0.5020 - accuracy: 0.7327Epoch 7/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4703 - accuracy: 0.7632
#  128/2138 [>.............................] - ETA: 10s - loss: 0.4958 - accuracy: 0.7539Epoch 7/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4067 - accuracy: 0.8122
#  805/2138 [==========>...................] - ETA: 9s - loss: 0.3984 - accuracy: 0.8139Epoch 18/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4380 - accuracy: 0.8185
#  370/2138 [====>.........................] - ETA: 10s - loss: 0.3993 - accuracy: 0.8166Epoch 7/30
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4359 - accuracy: 0.7905
#  712/2138 [========>.....................] - ETA: 10s - loss: 0.4645 - accuracy: 0.7688Epoch 18/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4983 - accuracy: 0.7347
# 1794/2138 [========================>.....] - ETA: 2s - loss: 0.3972 - accuracy: 0.8167Epoch 3/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4365 - accuracy: 0.8191
# 1329/2138 [=================>............] - ETA: 5s - loss: 0.4673 - accuracy: 0.7687Epoch 8/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4109 - accuracy: 0.8282
# Epoch 18/20
# 2138/2138 [==============================] - 13s 6ms/step - loss: 0.4643 - accuracy: 0.7727
# 1564/2138 [====================>.........] - ETA: 3s - loss: 0.5009 - accuracy: 0.7495Epoch 8/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.3966 - accuracy: 0.8164
# Epoch 18/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4492 - accuracy: 0.7853
# 1700/2138 [======================>.......] - ETA: 3s - loss: 0.3907 - accuracy: 0.8192Epoch 19/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5049 - accuracy: 0.7491
# Epoch 8/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5032 - accuracy: 0.7492
# Epoch 8/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.5092 - accuracy: 0.7467
#  617/2138 [=======>......................] - ETA: 10s - loss: 0.4172 - accuracy: 0.8247Epoch 8/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4053 - accuracy: 0.8314
# 1819/2138 [========================>.....] - ETA: 2s - loss: 0.4017 - accuracy: 0.8159Epoch 19/20
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.4371 - accuracy: 0.8182
# Epoch 8/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.3911 - accuracy: 0.8197
# Epoch 18/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.4627 - accuracy: 0.7715
#  967/2138 [============>.................] - ETA: 8s - loss: 0.4954 - accuracy: 0.7360Epoch 8/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4017 - accuracy: 0.8156
#  379/2138 [====>.........................] - ETA: 10s - loss: 0.3773 - accuracy: 0.8231Epoch 19/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4352 - accuracy: 0.8199
# 1282/2138 [================>.............] - ETA: 5s - loss: 0.4086 - accuracy: 0.8292Epoch 8/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4297 - accuracy: 0.7961
#  325/2138 [===>..........................] - ETA: 13s - loss: 0.4349 - accuracy: 0.8163Epoch 19/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4930 - accuracy: 0.7384
# 1410/2138 [==================>...........] - ETA: 4s - loss: 0.3845 - accuracy: 0.8230Epoch 4/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4090 - accuracy: 0.8297
# 1519/2138 [====================>.........] - ETA: 4s - loss: 0.4303 - accuracy: 0.8202Epoch 19/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4567 - accuracy: 0.7773
# 1429/2138 [===================>..........] - ETA: 4s - loss: 0.4584 - accuracy: 0.7756Epoch 9/30
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4429 - accuracy: 0.7866
# 1562/2138 [====================>.........] - ETA: 3s - loss: 0.4578 - accuracy: 0.7760Epoch 20/20
# 2138/2138 [==============================] - 16s 8ms/step - loss: 0.4339 - accuracy: 0.8204
# 1842/2138 [========================>.....] - ETA: 1s - loss: 0.5019 - accuracy: 0.7497Epoch 9/20
# 2138/2138 [==============================] - 16s 7ms/step - loss: 0.3915 - accuracy: 0.8205
# Epoch 19/20
# 2138/2138 [==============================] - 14s 6ms/step - loss: 0.5022 - accuracy: 0.7502
# Epoch 9/30
# 2138/2138 [==============================] - 16s 8ms/step - loss: 0.4959 - accuracy: 0.7551
# 1845/2138 [========================>.....] - ETA: 1s - loss: 0.3967 - accuracy: 0.8183Epoch 9/20
# 2138/2138 [==============================] - 14s 7ms/step - loss: 0.3837 - accuracy: 0.8240
# Epoch 19/20
# 2138/2138 [==============================] - 15s 7ms/step - loss: 0.4946 - accuracy: 0.7556
# ...
# Epoch 23/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4101 - accuracy: 0.8092
#  93/535 [====>.........................] - ETA: 1s - loss: 0.4077 - accuracy: 0.8323Epoch 17/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4007 - accuracy: 0.8308
#  88/535 [===>..........................] - ETA: 2s - loss: 0.3822 - accuracy: 0.8232Epoch 26/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4377 - accuracy: 0.7946
# Epoch 28/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4099 - accuracy: 0.8289
# Epoch 17/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4542 - accuracy: 0.7793
# Epoch 17/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4016 - accuracy: 0.8327
# Epoch 22/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4377 - accuracy: 0.7939
# Epoch 24/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3841 - accuracy: 0.8255
# Epoch 25/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3991 - accuracy: 0.8325
# Epoch 27/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4353 - accuracy: 0.7906
# Epoch 29/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4036 - accuracy: 0.8153
# Epoch 18/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4065 - accuracy: 0.8326
# Epoch 18/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4480 - accuracy: 0.7857
# Epoch 18/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3974 - accuracy: 0.8322
# 356/535 [==================>...........] - ETA: 0s - loss: 0.3958 - accuracy: 0.8187Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4346 - accuracy: 0.7928
# 528/535 [============================>.] - ETA: 0s - loss: 0.3991 - accuracy: 0.8325Epoch 25/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3990 - accuracy: 0.8326
# Epoch 23/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4318 - accuracy: 0.7942
# Epoch 30/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3790 - accuracy: 0.8294
# Epoch 26/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3973 - accuracy: 0.8191
#  93/535 [====>.........................] - ETA: 2s - loss: 0.4203 - accuracy: 0.8023Epoch 19/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4039 - accuracy: 0.8306
# 173/535 [========>.....................] - ETA: 1s - loss: 0.3789 - accuracy: 0.8290Epoch 19/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3968 - accuracy: 0.8341
# Epoch 29/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3960 - accuracy: 0.8334
# Epoch 24/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4427 - accuracy: 0.7871
# Epoch 19/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4296 - accuracy: 0.7978
# Epoch 26/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4304 - accuracy: 0.7971
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3766 - accuracy: 0.8311
# 104/535 [====>.........................] - ETA: 2s - loss: 0.4345 - accuracy: 0.7897Epoch 27/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3936 - accuracy: 0.8207
# Epoch 20/30
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5235 - accuracy: 0.7453
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4006 - accuracy: 0.8317
# 340/535 [==================>...........] - ETA: 0s - loss: 0.4273 - accuracy: 0.8002Epoch 20/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3948 - accuracy: 0.8328
# 240/535 [============>.................] - ETA: 1s - loss: 0.3858 - accuracy: 0.8247Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3951 - accuracy: 0.8342
# Epoch 25/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4276 - accuracy: 0.7999
# Epoch 27/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.4364 - accuracy: 0.7918
# Epoch 20/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3713 - accuracy: 0.8346
# Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3868 - accuracy: 0.8239
# Epoch 21/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3933 - accuracy: 0.8346
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3986 - accuracy: 0.8329
# Epoch 21/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3928 - accuracy: 0.8357
#  47/268 [====>.........................] - ETA: 0s - loss: 0.9692 - accuracy: 0.5246Epoch 26/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4237 - accuracy: 0.7979
# 487/535 [==========================>...] - ETA: 0s - loss: 0.4283 - accuracy: 0.7960Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4281 - accuracy: 0.7964
# 335/535 [=================>............] - ETA: 0s - loss: 0.3830 - accuracy: 0.8258Epoch 21/30
# 268/268 [==============================] - 1s 2ms/step - loss: 0.9797 - accuracy: 0.5204
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3688 - accuracy: 0.8342
# Epoch 29/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3831 - accuracy: 0.8258
# Epoch 22/30
# 535/535 [==============================] - 2s 3ms/step - loss: 0.3900 - accuracy: 0.8347
# Epoch 27/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4191 - accuracy: 0.8033
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3953 - accuracy: 0.8342
# Epoch 29/30
# Epoch 22/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4237 - accuracy: 0.7989
# 124/535 [=====>........................] - ETA: 1s - loss: 0.4136 - accuracy: 0.8095Epoch 22/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3659 - accuracy: 0.8377
# Epoch 30/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3757 - accuracy: 0.8296
# Epoch 23/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3869 - accuracy: 0.8382
# Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4153 - accuracy: 0.8057
# Epoch 30/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3917 - accuracy: 0.8358
# Epoch 23/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3610 - accuracy: 0.8403
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4165 - accuracy: 0.8043
# Epoch 23/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3853 - accuracy: 0.8378
# Epoch 29/30
# 268/268 [==============================] - 1s 3ms/step - loss: 0.6838 - accuracy: 0.6434
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3720 - accuracy: 0.8331
# Epoch 24/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4115 - accuracy: 0.8065
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3882 - accuracy: 0.8353
# Epoch 24/30
# 535/535 [==============================] - 3s 5ms/step - loss: 0.4120 - accuracy: 0.8060
# Epoch 24/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3840 - accuracy: 0.8377
# Epoch 30/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3667 - accuracy: 0.8364
# Epoch 25/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3857 - accuracy: 0.8376
# Epoch 25/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.4055 - accuracy: 0.8082
# Epoch 25/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3800 - accuracy: 0.8403
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3631 - accuracy: 0.8368
# 127/268 [=============>................] - ETA: 0s - loss: 0.9886 - accuracy: 0.5199Epoch 26/30
# 268/268 [==============================] - 1s 3ms/step - loss: 0.9809 - accuracy: 0.5246
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3836 - accuracy: 0.8378
# Epoch 26/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.4018 - accuracy: 0.8124
# Epoch 26/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3596 - accuracy: 0.8393
# Epoch 27/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3807 - accuracy: 0.8383
# Epoch 27/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3954 - accuracy: 0.8156
# 227/535 [===========>..................] - ETA: 1s - loss: 0.3758 - accuracy: 0.8445Epoch 27/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3558 - accuracy: 0.8419
# Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3779 - accuracy: 0.8416
# Epoch 28/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3898 - accuracy: 0.8183
# Epoch 28/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3518 - accuracy: 0.8448
# Epoch 29/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3750 - accuracy: 0.8421
# Epoch 29/30
# 535/535 [==============================] - 2s 5ms/step - loss: 0.3868 - accuracy: 0.8195
# Epoch 29/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3486 - accuracy: 0.8437
# Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3719 - accuracy: 0.8424
# Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3825 - accuracy: 0.8248
# Epoch 30/30
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3451 - accuracy: 0.8464
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3692 - accuracy: 0.8435
# 268/268 [==============================] - 1s 2ms/step - loss: 0.6923 - accuracy: 0.6383
# 268/268 [==============================] - 1s 3ms/step - loss: 0.9375 - accuracy: 0.5390
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3763 - accuracy: 0.8256
# 268/268 [==============================] - 1s 3ms/step - loss: 0.4567 - accuracy: 0.7957
# 268/268 [==============================] - 1s 3ms/step - loss: 0.4914 - accuracy: 0.7656
# Epoch 1/30
# 1604/1604 [==============================] - 8s 4ms/step - loss: 0.5569 - accuracy: 0.7238
# Epoch 2/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.5449 - accuracy: 0.7321
# Epoch 3/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.5362 - accuracy: 0.7367
# Epoch 4/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.5260 - accuracy: 0.7419
# Epoch 5/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.5152 - accuracy: 0.7482
# Epoch 6/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.5049 - accuracy: 0.7546
# Epoch 7/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4965 - accuracy: 0.7595
# Epoch 8/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4868 - accuracy: 0.7642
# Epoch 9/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4768 - accuracy: 0.7691
# Epoch 10/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4682 - accuracy: 0.7739
# Epoch 11/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4589 - accuracy: 0.7794
# Epoch 12/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4506 - accuracy: 0.7845
# Epoch 13/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4430 - accuracy: 0.7883
# Epoch 14/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4333 - accuracy: 0.7923
# Epoch 15/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4262 - accuracy: 0.7999
# Epoch 16/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4185 - accuracy: 0.8028
# Epoch 17/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.4122 - accuracy: 0.8077
# Epoch 18/30
# 1604/1604 [==============================] - 7s 5ms/step - loss: 0.4057 - accuracy: 0.8108
# Epoch 19/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3997 - accuracy: 0.8145
# Epoch 20/30
# 1604/1604 [==============================] - 7s 5ms/step - loss: 0.3923 - accuracy: 0.8194
# Epoch 21/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3876 - accuracy: 0.8210
# Epoch 22/30
# 1604/1604 [==============================] - 7s 5ms/step - loss: 0.3796 - accuracy: 0.8266
# Epoch 23/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3760 - accuracy: 0.8274
# Epoch 24/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3709 - accuracy: 0.8310
# Epoch 25/30
#  880/1604 [===============>..............] - ETA: 3s - loss: 0.3698 - accuracy: 0.8299
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3675 - accuracy: 0.8304
# Epoch 26/30
#  807/1604 [==============>...............] - ETA: 3s - loss: 0.3603 - accuracy: 0.8347
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3630 - accuracy: 0.8339
# Epoch 27/30
#  580/1604 [=========>....................] - ETA: 4s - loss: 0.3577 - accuracy: 0.8357
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3572 - accuracy: 0.8358
# Epoch 28/30
#  994/1604 [=================>............] - ETA: 2s - loss: 0.3556 - accuracy: 0.8383
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 1296/1604 [=======================>......] - ETA: 1s - loss: 0.3541 - accuracy: 0.8393
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3544 - accuracy: 0.8393
# Epoch 29/30
#  544/1604 [=========>....................] - ETA: 4s - loss: 0.3520 - accuracy: 0.8352
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 1390/1604 [========================>.....] - ETA: 0s - loss: 0.3499 - accuracy: 0.8380
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3508 - accuracy: 0.8372
# Epoch 30/30
# 1604/1604 [==============================] - 7s 4ms/step - loss: 0.3463 - accuracy: 0.8418
# {'batch_size': 32, 'epochs': 30, 'hidden_units': 256}

# %%
best_model_nn_os = create_model_nn(best_params_nn_os['hidden_units'])
best_model_nn_os.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
best_model_nn_os.fit(X_train, y_train, epochs=best_params_nn_os['epochs'], batch_size=best_params_nn_os['batch_size'])
# Out:
# Epoch 1/30
# 904/904 [==============================] - 6s 5ms/step - loss: 0.2998 - accuracy: 0.8892
# Epoch 2/30
# 782/904 [========================>.....] - ETA: 0s - loss: 0.2882 - accuracy: 0.8924
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2898 - accuracy: 0.8915
# Epoch 3/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2885 - accuracy: 0.8918
# Epoch 4/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2877 - accuracy: 0.8928
# Epoch 5/30
# 306/904 [=========>....................] - ETA: 2s - loss: 0.2948 - accuracy: 0.8879
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2867 - accuracy: 0.8927
# Epoch 6/30
# 220/904 [======>.......................] - ETA: 2s - loss: 0.2891 - accuracy: 0.8895
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2857 - accuracy: 0.8934
# Epoch 7/30
# 682/904 [=====================>........] - ETA: 0s - loss: 0.2875 - accuracy: 0.8936
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2845 - accuracy: 0.8940
# Epoch 8/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2847 - accuracy: 0.8931
# Epoch 9/30
#  87/904 [=>............................] - ETA: 3s - loss: 0.2807 - accuracy: 0.8987
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2839 - accuracy: 0.8935
# Epoch 10/30
# 904/904 [==============================] - 4s 5ms/step - loss: 0.2827 - accuracy: 0.8952
# Epoch 11/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2823 - accuracy: 0.8946
# Epoch 12/30
# 158/904 [====>.........................] - ETA: 2s - loss: 0.2877 - accuracy: 0.8920
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 459/904 [==============>...............] - ETA: 1s - loss: 0.2872 - accuracy: 0.8922
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 787/904 [=========================>....] - ETA: 0s - loss: 0.2822 - accuracy: 0.8933
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2815 - accuracy: 0.8943
# Epoch 13/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2812 - accuracy: 0.8952
# Epoch 14/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2800 - accuracy: 0.8952
# Epoch 15/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2793 - accuracy: 0.8955
# Epoch 16/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2782 - accuracy: 0.8959
# Epoch 17/30
# 904/904 [==============================] - 3s 3ms/step - loss: 0.2776 - accuracy: 0.8966
# Epoch 18/30
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2771 - accuracy: 0.8958
# Epoch 19/30
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2766 - accuracy: 0.8968
# Epoch 20/30
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2758 - accuracy: 0.8959
# Epoch 21/30
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2746 - accuracy: 0.8984
# Epoch 22/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2741 - accuracy: 0.8985
# Epoch 23/30
# 904/904 [==============================] - 3s 4ms/step - loss: 0.2731 - accuracy: 0.8983
# Epoch 24/30
# 366/904 [===========>..................] - ETA: 2s - loss: 0.2703 - accuracy: 0.9005
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2729 - accuracy: 0.8990
# Epoch 25/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2716 - accuracy: 0.8991
# Epoch 26/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2707 - accuracy: 0.8997
# Epoch 27/30
# 904/904 [==============================] - 4s 5ms/step - loss: 0.2702 - accuracy: 0.8996
# Epoch 28/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2689 - accuracy: 0.9016
# Epoch 29/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2687 - accuracy: 0.9010
# Epoch 30/30
# 904/904 [==============================] - 4s 4ms/step - loss: 0.2676 - accuracy: 0.9029

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred_prob_nn_os = best_model_nn_os.predict(X_test)
y_pred_nn_os = (y_pred_prob_nn_os > 0.5).astype(int)

accuracy_nn_os = accuracy_score(y_test, y_pred_nn_os)
precision_nn_os = precision_score(y_test, y_pred_nn_os)
recall_nn_os = recall_score(y_test, y_pred_nn_os)
f1_nn_os = f1_score(y_test, y_pred_nn_os)

print('Accuracy: %.2f' % (accuracy_nn_os*100))
print('Precision: %.2f' % (precision_nn_os*100))
print('Recall: %.2f' % (recall_nn_os*100))
print('F1-score: %.2f' % (f1_nn_os*100))
# Out:
# 302/302 [==============================] - 1s 2ms/step
# Accuracy: 89.20
# Precision: 55.19
# Recall: 21.57
# F1-score: 31.01

# %%
print("Best Parameters: ", best_params_nn_os)

# Evaluate the model
print(f'Test Accuracy: {accuracy_nn_os*100:.2f}%')
# Out:
# Best Parameters:  {'batch_size': 32, 'epochs': 30, 'hidden_units': 256}
# Test Accuracy: 89.20%

# %%
y_pred_prob_nn_os = best_model_nn_os.predict(X_test)

fpr_nn_os, tpr_nn_os, thresholds_nn_os = roc_curve(y_test, y_pred_prob_nn_os)
auc_nn_os = roc_auc_score(y_test, y_pred_prob_nn_os)

plt.plot(fpr_nn_os, tpr_nn_os, label='ROC curve (AUC = {:.2f})'.format(auc_nn_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()


umbral = 0.5
y_pred_discret_nn_os = np.where(y_pred_prob_nn_os >= umbral, 1, 0)

cm_nn_os = confusion_matrix(y_test, y_pred_discret_nn_os)

sns.heatmap(cm_nn_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 302/302 [==============================] - 1s 2ms/step

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO GRADIENT NEURAL NETWORK:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Graph 1
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - NN WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Graph 2
sns.heatmap(cm_nn_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - NN WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# ### Stacked Generalization Ensemble

# %% [markdown]
# In order to solve the problem of the unbalanced dataset, we can also use different algorithms, as I stated before. One of the ones that behaves better is the Stacked Generalization Ensemble. For this algorithm, we will evaluate it with and without oversampling to analyse the impact of both solutions independently:

# %%
import pandas as pd
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier


# Define base classifiers
rf_classifier = RandomForestClassifier(random_state=random_seed)
lr_classifier = LogisticRegression(random_state=random_seed)
knn_classifier = KNeighborsClassifier()

# Define the StackingClassifier
estimators = [
    ('rf', rf_classifier),
    ('lr', lr_classifier),
    ('knn', knn_classifier)
]

stacking_classifier = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())

# Define params grid
param_grid_sc = {
    'rf__n_estimators': [100, 200, 300],
    'knn__n_neighbors': [3, 5, 7],
    'final_estimator__C': [0.1, 1, 10]
}

# Hiperparms search using GridSearchCV
grid_search_sc = GridSearchCV(stacking_classifier, param_grid_sc, cv=3, n_jobs=-1)
grid_search_sc.fit(X_train, y_train)

# Get the best params
best_params_sc = grid_search_sc.best_params_
print("Mejores parámetros:", best_params_sc)

# Use the best model to predict
best_model_sc = grid_search_sc.best_estimator_
y_pred_sc = best_model_sc.predict(X_test)

# Get the accuracy
accuracy_sc = accuracy_score(y_test, y_pred_sc)
print("Precisión:", accuracy_sc)
# Out:
# Mejores parámetros: {'final_estimator__C': 1, 'knn__n_neighbors': 3, 'rf__n_estimators': 100}
# Precisión: 0.8928905033731188

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_sc = best_model_sc.predict_proba(X_test)[:, 1]
fpr_sc, tpr_sc, thresholds_sc = roc_curve(y_test, y_pred_prob_sc)
auc_sc = roc_auc_score(y_test, y_pred_prob_sc)

# Plot ROC curve
plt.plot(fpr_sc, tpr_sc, label='ROC curve (AUC = {:.2f})'.format(auc_sc))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_sc = best_model_sc.predict(X_test)
cm_sc = confusion_matrix(y_test, y_pred_sc)

# Visualize confusion matrix
sns.heatmap(cm_sc, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### Stacked Generalization Ensemble (with SMOTE)

# %%
import pandas as pd
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

# Define base classifiers
rf_classifier = RandomForestClassifier(random_state=random_seed)
lr_classifier = LogisticRegression(random_state=random_seed)
knn_classifier = KNeighborsClassifier()

# Definir el StackingClassifier
estimators = [
    ('rf', rf_classifier),
    ('lr', lr_classifier),
    ('knn', knn_classifier)
]

stacking_classifier_os = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression(random_state=random_seed))

# Train StackingClassifier with the oversampled dataset
stacking_classifier_os.fit(X_train_os, y_train_os)

# Predict of test
y_pred_sc_os = stacking_classifier_os.predict(X_test)

# Get accuracy
accuracy_sc_os = accuracy_score(y_test, y_pred_sc_os)
print("Precisión:", accuracy_sc_os)
# Out:
# Precisión: 0.8671510119356513

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_sc_os = stacking_classifier_os.predict_proba(X_test)[:, 1]
fpr_sc_os, tpr_sc_os, thresholds_sc_os = roc_curve(y_test, y_pred_prob_sc_os)
auc_sc_os = roc_auc_score(y_test, y_pred_prob_sc_os)

# Plot ROC curve
plt.plot(fpr_sc_os, tpr_sc_os, label='ROC curve (AUC = {:.2f})'.format(auc_sc_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_sc_os = stacking_classifier_os.predict(X_test)
cm_sc_os = confusion_matrix(y_test, y_pred_sc_os)

# Visualize confusion matrix
sns.heatmap(cm_sc_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(16, 10))

# Graph 1
sns.heatmap(cm_sc, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Stack.Generalization Ensemble WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Graph 2
sns.heatmap(cm_sc_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Stack.Generalization Ensemble WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# ### ACCURACY AND AUC TABLE SUMMARY

# %%
import pandas as pd

# Define the variables with the models and the desired data
models = ['Logistic Regression', 'k-Nearest Neighbors(k-NN)', 'Support Vector Machines (SVM)', 'Classification Trees', 'Random Forest', 'Ada Boost', 'Gradient Boosting', 'Neural Networks (NN)', 'Stacked Generalization Ensemble']
accuracy = [accuracy_lr, accuracy_knn, accuracy_svm, accuracy_ct, accuracy_rf, test_accuracy_ab, test_accuracy_gb, accuracy_nn, accuracy_sc]
auc = [auc_lr, auc_knn, auc_svm, auc_ct, auc_rf, auc_ab, auc_gb, auc_nn, auc_sc]

# Create a dict
data_summary_no_smote = {
    'Model': models,
    'Accuracy': accuracy,
    'AUC':auc
}

# Create a DataFrame 
df_summary_no_smote = pd.DataFrame(data_summary_no_smote)

print(df_summary_no_smote)
# Out:
#                              Model  Accuracy       AUC
# 0              Logistic Regression  0.891956  0.757993
# 1        k-Nearest Neighbors(k-NN)  0.889258  0.720572
# 2    Support Vector Machines (SVM)  0.893825  0.634944
# 3             Classification Trees  0.894240  0.759244
# 4                    Random Forest  0.896834  0.790017
# 5                        Ada Boost  0.875454  0.600612
# 6                Gradient Boosting  0.896212  0.781554
# 7             Neural Networks (NN)  0.892475  0.765986
# 8  Stacked Generalization Ensemble  0.892891  0.772927

# %%
import pandas as pd

# Define the variables with the models and the desired data
models = ['Logistic Regression', 'k-Nearest Neighbors(k-NN)', 'Random Forest', 'Gradient Boosting', 'Neural Networks (NN)', 'Stacked Generalization Ensemble']
accuracy = [accuracy_lr_os, accuracy_knn_os, accuracy_rf_os, test_accuracy_gb_os, accuracy_nn_os, accuracy_sc_os]
auc = [auc_lr, auc_knn_os, auc_rf_os, auc_gb_os, auc_nn_os, auc_sc_os]

# Create a dict
data_summary_smote = {
    'Model': models,
    'Accuracy': accuracy,
    'AUC':auc
}

# Create a DataFrame 
df_summary_smote = pd.DataFrame(data_summary_smote)

# Mostrar el DataFrame
print(df_summary_smote)
# Out:
#                              Model  Accuracy       AUC
# 0              Logistic Regression  0.772704  0.757993
# 1        k-Nearest Neighbors(k-NN)  0.862584  0.662763
# 2                    Random Forest  0.877218  0.754049
# 3                Gradient Boosting  0.886040  0.743425
# 4             Neural Networks (NN)  0.891956  0.757766
# 5  Stacked Generalization Ensemble  0.867151  0.732168
