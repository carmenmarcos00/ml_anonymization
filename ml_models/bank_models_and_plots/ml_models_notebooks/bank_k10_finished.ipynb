# %% [markdown]
# ### MACHINE LEARNING MODELS FOR THE BANK MARKETING DATASET (K=2)

# %% [markdown]
# First of all, we will perform data curation and preparation. Next, we will apply the following Machine Learning models:
#
# - Linear Regression
# - k-Nearest Neighbors(k-NN)
# - Support Vector Machines (SVM)
# - Classification Trees
# - Random Forest
# - Ada Boosting
# - Gradient Boosting
# - Neural Networks(NN)

# %% [markdown]
# **Import the necessary libraries:**

# %% [markdown]
# We try to eliminate the warnings that come up when some cells are executed:

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.warn("ignore")
warnings.simplefilter('ignore')

# %% [markdown]
# Now we import the libraries needed for executing the models and visualize the plots:

# %%
from imblearn.over_sampling import SMOTE

# %%
# %matplotlib inline
import pandas as pd
import pandas_profiling as pp
import numpy as np

from sklearn.metrics import accuracy_score, classification_report, make_scorer, roc_curve, roc_auc_score, confusion_matrix, precision_score, recall_score, f1_score

from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

import matplotlib.pyplot as plt
import shap
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Load the dataset**

# %%
file_name = "bank_k_10-anonymized.csv"
df = pd.read_csv(file_name, sep=";")

# %% [markdown]
# **We check that we have loaded the dataset correctly by showing the first 5 rows of the dataset**

# %%
df.head()
# Out:
#         age         job   marital            education  default housing loan  \
# 0  [20, 40[    Employed    single  Professional Course       no     yes   no
# 1  [60, 80[     Retired   married                Basic       no     yes   no
# 2  [40, 60[    Employed  divorced                Basic  unknown     yes  yes
# 3  [40, 60[  unemployed   married                Basic  unknown     yes   no
# 4  [40, 60[    Employed   married          HIgh School       no     yes   no
#
#     contact month day_of_week  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0  cellular   may         wed          -1.8          92.893          -46.2
# 1  cellular   aug         fri          -2.9          92.201          -31.4
# 2  cellular   jul         mon           1.4          93.918          -42.7
# 3  cellular   jul         mon           1.4          93.918          -42.7
# 4  cellular   apr         wed          -1.8          93.075          -47.1
#
#    euribor3m    y
# 0      1.281   no
# 1      0.849  yes
# 2      4.962  yes
# 3      4.962   no
# 4      1.415   no

# %% [markdown]
# **We explore the original dataset**

# %%
print(df.head())
print(df.info())
print(df.describe())
print(df.shape)
# Out:
#         age         job   marital            education  default housing loan  \
# 0  [20, 40[    Employed    single  Professional Course       no     yes   no
# 1  [60, 80[     Retired   married                Basic       no     yes   no
# 2  [40, 60[    Employed  divorced                Basic  unknown     yes  yes
# 3  [40, 60[  unemployed   married                Basic  unknown     yes   no
# 4  [40, 60[    Employed   married          HIgh School       no     yes   no
#
#     contact month day_of_week  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0  cellular   may         wed          -1.8          92.893          -46.2
# 1  cellular   aug         fri          -2.9          92.201          -31.4
# 2  cellular   jul         mon           1.4          93.918          -42.7
# 3  cellular   jul         mon           1.4          93.918          -42.7
# 4  cellular   apr         wed          -1.8          93.075          -47.1
#
#    euribor3m    y
# 0      1.281   no
# 1      0.849  yes
# 2      4.962  yes
# 3      4.962   no
# 4      1.415   no
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  object
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  emp.var.rate    41188 non-null  float64
#  11  cons.price.idx  41188 non-null  float64
#  12  cons.conf.idx   41188 non-null  float64
#  13  euribor3m       41188 non-null  float64
#  14  y               41188 non-null  object
# dtypes: float64(4), object(11)
# memory usage: 4.7+ MB
# None
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m
# count  41188.000000    41188.000000   41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291
# std        1.570960        0.578840       4.628198      1.734447
# min       -3.400000       92.201000     -50.800000      0.634000
# 25%       -1.800000       93.075000     -42.700000      1.344000
# 50%        1.100000       93.749000     -41.800000      4.857000
# 75%        1.400000       93.994000     -36.400000      4.961000
# max        1.400000       94.767000     -26.900000      5.045000
# (41188, 15)

# %% [markdown]
# **We check if there is any null value to remove it if exists:**

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# y                 0
# dtype: int64

# %% [markdown]
# **Delete anonymized records**:

# %%
q_i=["age","job","marital","education","default","housing","loan"]
a_s = ["y"]

def delete_rows(file_name, quasi_ident, fillna=True):
    """Delete the rows of the given file in which all QIs are set to *."""
    df = pd.read_csv(file_name, sep = ";")
    df_qi = df[quasi_ident]
    tmp = df_qi[df_qi == ["*"] * len(quasi_ident)]
    tmp.dropna(inplace=True)
    df_new=df.drop(tmp.index.values, axis = 0).reset_index()
    print(df_new)
    return df_new

# %%
df = delete_rows(file_name,q_i)
# Out:
#        index       age         job   marital            education  default  \
# 0          0  [20, 40[    Employed    single  Professional Course       no
# 1          1  [60, 80[     Retired   married                Basic       no
# 2          2  [40, 60[    Employed  divorced                Basic  unknown
# 3          3  [40, 60[  unemployed   married                Basic  unknown
# 4          4  [40, 60[    Employed   married          HIgh School       no
# ...      ...       ...         ...       ...                  ...      ...
# 39340  41182  [40, 60[    Employed  divorced    University Degree       no
# 39341  41183  [20, 40[    Employed    single    University Degree       no
# 39342  41184  [20, 40[    Employed   married    University Degree  unknown
# 39343  41186  [40, 60[     Unknown   married              Unknown  unknown
# 39344  41187  [20, 40[    Employed   married          HIgh School       no
#
#       housing loan    contact month day_of_week  emp.var.rate  cons.price.idx  \
# 0         yes   no   cellular   may         wed          -1.8          92.893
# 1         yes   no   cellular   aug         fri          -2.9          92.201
# 2         yes  yes   cellular   jul         mon           1.4          93.918
# 3         yes   no   cellular   jul         mon           1.4          93.918
# 4         yes   no   cellular   apr         wed          -1.8          93.075
# ...       ...  ...        ...   ...         ...           ...             ...
# 39340     yes   no   cellular   may         thu          -1.8          92.893
# 39341      no   no   cellular   aug         wed           1.4          93.444
# 39342     yes   no   cellular   aug         tue           1.4          93.444
# 39343     yes   no   cellular   aug         tue           1.4          93.444
# 39344      no  yes  telephone   may         fri           1.1          93.994
#
#        cons.conf.idx  euribor3m    y
# 0              -46.2      1.281   no
# 1              -31.4      0.849  yes
# 2              -42.7      4.962  yes
# 3              -42.7      4.962   no
# 4              -47.1      1.415   no
# ...              ...        ...  ...
# 39340          -46.2      1.266   no
# 39341          -36.1      4.964   no
# 39342          -36.1      4.963   no
# 39343          -36.1      4.965   no
# 39344          -36.4      4.864   no
#
# [39345 rows x 16 columns]

# %% [markdown]
# **Convert categorical to factors and store in a dictionary all the mapping:**
#
# We discretise the variables in order to better manage the data in the dataset.

# %%
df["job"] = df["job"].astype("category").cat.codes
df["marital"] = df["marital"].astype("category").cat.codes
df["education"] = df["education"].astype("category").cat.codes
df["default"] = df["default"].astype("category").cat.codes
df["housing"] = df["housing"].astype("category").cat.codes
df["loan"] = df["loan"].astype("category").cat.codes
df["contact"] = df["contact"].astype("category").cat.codes
df["month"] = df["month"].astype("category").cat.codes
df["day_of_week"] = df["day_of_week"].astype("category").cat.codes
df["y"] = df["y"].astype("category").cat.codes
df["age"] = df["age"].astype("category").cat.codes

# %% [markdown]
# We inspect the dataset to make sure everything has work properly:

# %%
df = df.drop('index', axis=1)
df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        1    0        2          2        0        2     0        0      6
# 1        3    1        1          0        0        2     0        0      1
# 2        2    0        0          0        1        2     2        0      3
# 3        2    4        1          0        1        2     0        0      3
# 4        2    0        1          1        0        2     0        0      0
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 39340    2    0        0          3        0        2     0        0      6
# 39341    1    0        2          3        0        0     0        0      1
# 39342    1    0        1          3        1        2     0        0      1
# 39343    2    3        1          4        1        2     0        0      1
# 39344    1    0        1          1        0        0     2        1      6
#
#        day_of_week  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  y
# 0                4          -1.8          92.893          -46.2      1.281  0
# 1                0          -2.9          92.201          -31.4      0.849  1
# 2                1           1.4          93.918          -42.7      4.962  1
# 3                1           1.4          93.918          -42.7      4.962  0
# 4                4          -1.8          93.075          -47.1      1.415  0
# ...            ...           ...             ...            ...        ... ..
# 39340            2          -1.8          92.893          -46.2      1.266  0
# 39341            4           1.4          93.444          -36.1      4.964  0
# 39342            3           1.4          93.444          -36.1      4.963  0
# 39343            3           1.4          93.444          -36.1      4.965  0
# 39344            0           1.1          93.994          -36.4      4.864  0
#
# [39345 rows x 15 columns]

# %% [markdown]
# Before starting we have to define a random state value in order to achieve reproducibility of the models:

# %%
random_seed = 14

# %% [markdown]
# **We divide the dataset in train and test**

# %%
X = df.drop(["y"], axis=1)
y = df["y"]

# We add stratify for making sure that the random split has 25% of 0's and 75% of 1's.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=random_seed, stratify=y)

# %% [markdown]
# **We check that the shapes of the splitted sets are correct as expected**

# %%
print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (29508, 14)
# X_test shape: (9837, 14)
# y_train: (29508,)
# y_test shape: (9837,)

# %% [markdown]
# **Finally we do the scaling in train and test separately**
#
# We scale variables separately in train and test because this way we avoid biases. In addition, we manage to maintain the relative scale, i.e., all characteristics have a similar scale.

# %%
scaler = MinMaxScaler()
scaler = scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# We check the new scaled values in the respectivew partitions created:

# %%
X_train
# Out:
# array([[0.25      , 0.        , 0.33333333, ..., 0.3893219 , 0.36820084,
#         0.79029698],
#        [0.5       , 0.        , 0.33333333, ..., 0.48441154, 0.61506276,
#         0.98186352],
#        [0.5       , 0.        , 0.33333333, ..., 0.66913484, 0.33891213,
#         0.98072999],
#        ...,
#        [0.5       , 0.        , 0.66666667, ..., 0.66913484, 0.33891213,
#         0.98118341],
#        [0.25      , 0.        , 0.33333333, ..., 0.34060795, 0.15481172,
#         0.17705736],
#        [0.25      , 0.        , 0.33333333, ..., 0.66913484, 0.33891213,
#         0.98050329]])

# %%
X_test
# Out:
# array([[0.25      , 0.        , 0.33333333, ..., 0.1745908 , 0.86610879,
#         0.01995012],
#        [0.25      , 0.        , 0.66666667, ..., 0.62236945, 0.43514644,
#         0.9430968 ],
#        [0.5       , 0.        , 0.33333333, ..., 0.66913484, 0.33891213,
#         0.98118341],
#        ...,
#        [0.25      , 0.        , 0.33333333, ..., 0.88230709, 0.37656904,
#         0.98050329],
#        [0.25      , 0.        , 0.        , ..., 0.26968044, 0.19246862,
#         0.15710723],
#        [0.25      , 0.        , 0.66666667, ..., 0.26968044, 0.19246862,
#         0.15075946]])

# %% [markdown]
# **We start evaluating the proposed models:**

# %% [markdown]
# ### LOGISTIC REGRESSION:
# #### Linear regression method for binary classification problems

# %% [markdown]
#  We create and train the logistic regression model

# %%
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# We make the predictions on the test partition:

# %%
y_pred_lr = model_lr.predict(X_test)

# %% [markdown]
# We evaluate the model obtained:

# %%
accuracy_lr = accuracy_score(y_test, y_pred_lr)
report_lr = classification_report(y_test, y_pred_lr)
print("Accuracy:", accuracy_lr)
print("Classification Report:\n", report_lr)
# Out:
# Accuracy: 0.8924468842126665
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      8752
#            1       0.55      0.14      0.22      1085
#
#     accuracy                           0.89      9837
#    macro avg       0.73      0.56      0.58      9837
# weighted avg       0.86      0.89      0.86      9837

# %% [markdown]
# We illustrate the results obtained by drawaing the ROC curve and the confusion matrix:

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_lr = model_lr.predict_proba(X_test)[:, 1]
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_pred_prob_lr)
auc_lr = roc_auc_score(y_test, y_pred_prob_lr)

# Plot ROC curve
plt.plot(fpr_lr, tpr_lr, label='ROC curve (AUC = {:.2f})'.format(auc_lr))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_lr = model_lr.predict(X_test)
cm_lr = confusion_matrix(y_test, y_pred_lr)

# Visualize confusion matrix
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
fig_lr = plt.gcf()  # Obtener la figura actual
plt.show()

# %% [markdown]
# ### KNN (K k nearest neighbours)

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_knn = {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'algorithm': ['ball_tree', 'kd_tree', 'brute']}

# %% [markdown]
# We create the classifier

# %%
knn = KNeighborsClassifier()

# %% [markdown]
# We create the GridSearch object

# %%
# refit true, to retrain with all data
grid_search_knn = GridSearchCV(knn, param_grid_knn, cv=3, refit=True, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_knn.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
print("Best hyperparameters:", grid_search_knn.best_params_)
print("Accuracy score:", grid_search_knn.best_score_)
# Out:
# Best hyperparameters: {'algorithm': 'kd_tree', 'n_neighbors': 11, 'weights': 'uniform'}
# Accuracy score: 0.8913853870136911

# %% [markdown]
# Get the best model and its predictions

# %%
best_model_knn = grid_search_knn.best_estimator_
y_pred_knn = best_model_knn.predict(X_test)

# %% [markdown]
# Evaluate the best model over test partition

# %%
accuracy_knn = accuracy_score(y_test, y_pred_knn)
report_knn = classification_report(y_test, y_pred_knn)
print("Best Parameters:", grid_search_knn.best_params_)
print("Accuracy:", accuracy_knn)
print("Classification Report:\n", report_knn)
# Out:
# Best Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 11, 'weights': 'uniform'}
# Accuracy: 0.8922435701941649
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8752
#            1       0.53      0.19      0.28      1085
#
#     accuracy                           0.89      9837
#    macro avg       0.72      0.58      0.61      9837
# weighted avg       0.87      0.89      0.87      9837

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_knn = best_model_knn.predict_proba(X_test)[:, 1]
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test, y_pred_prob_knn)
auc_knn = roc_auc_score(y_test, y_pred_prob_knn)

# Plot ROC curve
plt.plot(fpr_knn, tpr_knn, label='ROC curve (AUC = {:.2f})'.format(auc_knn))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_knn = best_model_knn.predict(X_test)
cm_knn = confusion_matrix(y_test, y_pred_knn)

# Visualize confusion matrix
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### CLASSIFICATION TREES

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_ct = {'max_depth': [3, 5, 7, 9, None],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

# %% [markdown]
# We create the model classifier

# %%
model_ct = DecisionTreeClassifier(random_state=random_seed)

# %% [markdown]
# We create the GridSearch object

# %%
grid_search_ct = GridSearchCV(model_ct, param_grid_ct, cv=3, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_ct.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=14), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 9, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %% [markdown]
# We obtain and store the best model and the prediction

# %%
best_model_ct = grid_search_ct.best_estimator_
y_pred_ct = best_model_ct.predict(X_test)

# %% [markdown]
# Evaluate the best model

# %%
accuracy_ct = accuracy_score(y_test, y_pred_ct)
report_ct = classification_report(y_test, y_pred_ct)
print("Best Parameters:", grid_search_ct.best_params_)
print("Accuracy:", accuracy_ct)
print("Classification Report:\n", report_ct)
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.8942767103791807
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8752
#            1       0.55      0.23      0.32      1085
#
#     accuracy                           0.89      9837
#    macro avg       0.73      0.60      0.63      9837
# weighted avg       0.87      0.89      0.87      9837

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_ct = best_model_ct.predict_proba(X_test)[:, 1]
fpr_ct, tpr_ct, thresholds_ct = roc_curve(y_test, y_pred_prob_ct)
auc_ct = roc_auc_score(y_test, y_pred_prob_ct)

# Plot ROC curve
plt.plot(fpr_ct, tpr_ct, label='ROC curve (AUC = {:.2f})'.format(auc_ct))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_ct = best_model_ct.predict(X_test)
cm_ct = confusion_matrix(y_test, y_pred_ct)

# Visualize confusion matrix
sns.heatmap(cm_ct, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### RANDOM FOREST

# %% [markdown]
# We choose the different parameters for gridSearch

# %%
param_grid_rf = {"n_estimators": [50, 100, 200],
              "max_depth": [None, 5, 10],
              "min_samples_split": [2, 5, 10],
              "min_samples_leaf": [1, 2, 4]}

# %% [markdown]
# We create the classifier

# %%
rfc = RandomForestClassifier(random_state=random_seed)

# %% [markdown]
# We create the GridSearch object

# %%
grid_search_rf = GridSearchCV(rfc, param_grid_rf, cv=3, n_jobs=-1)

# %% [markdown]
# We make the model fit

# %%
grid_search_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=14), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
print("Best hyperparameters:", grid_search_rf.best_params_)
print("Accuracy score:", grid_search_rf.best_score_)
# Out:
# Best hyperparameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Accuracy score: 0.8974176494509963

# %%
best_model_rf = grid_search_rf.best_estimator_
y_pred_rf = best_model_rf.predict(X_test)

# %%
accuracy_rf = accuracy_score(y_test, y_pred_rf)
report_rf = classification_report(y_test, y_pred_rf)
print("Best Parameters:", grid_search_rf.best_params_)
print("Accuracy:", accuracy_rf)
print("Classification Report:\n", report_rf)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Accuracy: 0.8961065365456948
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8752
#            1       0.58      0.22      0.32      1085
#
#     accuracy                           0.90      9837
#    macro avg       0.74      0.60      0.63      9837
# weighted avg       0.87      0.90      0.87      9837

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_rf = best_model_rf.predict_proba(X_test)[:, 1]
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_prob_rf)
auc_rf = roc_auc_score(y_test, y_pred_prob_rf)

# Plot ROC curve
plt.plot(fpr_rf, tpr_rf, label='ROC curve (AUC = {:.2f})'.format(auc_rf))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_rf = best_model_rf.predict(X_test)
cm_rf = confusion_matrix(y_test, y_pred_rf)

# Visualize confusion matrix
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### SVM (Support Vector Machine)

# %%
param_grid_svm = {"C": [0.1, 0.25, 0.5, 0.75, 1, 2],
              "kernel": ["linear", "poly", "rbf", "sigmoid"],
              "gamma": ["scale", "auto"]}

# %%
svm = SVC()

# %%
grid_search_svm = GridSearchCV(svm, param_grid_svm, cv=3, n_jobs=-1)

# %%
grid_search_svm.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 0.25, 0.5, 0.75, 1, 2],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
print("Best hyperparameters:", grid_search_svm.best_params_)
print("Accuracy score:", grid_search_svm.best_score_)
# Out:
# Best hyperparameters: {'C': 0.5, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy score: 0.8963331977768741

# %%
best_model_svm = grid_search_svm.best_estimator_
y_pred_svm = best_model_svm.predict(X_test)

# %%
accuracy_svm = accuracy_score(y_test, y_pred_svm)
report_svm = classification_report(y_test, y_pred_svm)
print("Best Parameters:", grid_search_svm.best_params_)
print("Accuracy:", accuracy_svm)
print("Classification Report:\n", report_svm)
# Out:
# Best Parameters: {'C': 0.5, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy: 0.8933617972959236
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8752
#            1       0.55      0.18      0.28      1085
#
#     accuracy                           0.89      9837
#    macro avg       0.73      0.58      0.61      9837
# weighted avg       0.87      0.89      0.87      9837

# %%
# Generate decision scores
y_pred_scores_svm = best_model_svm.decision_function(X_test)

# Calculate FPR, TPR, and AUC
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, y_pred_scores_svm)
auc_svm = roc_auc_score(y_test, y_pred_scores_svm)

# Plot ROC curve
plt.plot(fpr_svm, tpr_svm, label='ROC curve (AUC = {:.2f})'.format(auc_svm))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_svm = best_model_svm.predict(X_test)
cm_svm = confusion_matrix(y_test, y_pred_svm)

# Visualize confusion matrix
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### NEURAL NETWORK:

# %% [markdown]
# We start creating the model function

# %%
def create_model_nn(hidden_units=128):
    model = Sequential()
    model.add(Dense(hidden_units, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Define the parameter grid
param_grid_nn = {
    'hidden_units': [64, 128, 256],
    'epochs': [10, 20, 30],
    'batch_size': [16, 32, 64]
}

# Create the model
model_nn = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn=create_model_nn)

# Perform grid search
grid_search_nn = GridSearchCV(model_nn, param_grid_nn, cv=3, n_jobs=-1)

# %%
grid_search_nn.fit(X_train, y_train)

# Get the best parameters
best_params_nn = grid_search_nn.best_params_
best_params_nn
# Out:
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# 1230/1230 [==============================] - 8s 5ms/step - loss: 0.3014 - accuracy: 0.8904
#  926/1230 [=====================>........] - ETA: 1s - loss: 0.3028 - accuracy: 0.8887Epoch 2/20
# 1230/1230 [==============================] - 8s 5ms/step - loss: 0.2972 - accuracy: 0.8923
# 1007/1230 [=======================>......] - ETA: 1s - loss: 0.3071 - accuracy: 0.8870Epoch 2/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2962 - accuracy: 0.8930
# 1044/1230 [========================>.....] - ETA: 1s - loss: 0.3062 - accuracy: 0.8874Epoch 2/10
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.3031 - accuracy: 0.8891
# Epoch 2/10
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.2988 - accuracy: 0.8907
# 1195/1230 [============================>.] - ETA: 0s - loss: 0.3062 - accuracy: 0.8897Epoch 2/20
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.2994 - accuracy: 0.8892
# 1208/1230 [============================>.] - ETA: 0s - loss: 0.2965 - accuracy: 0.8928Epoch 2/20
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.3035 - accuracy: 0.8905
# 1164/1230 [===========================>..] - ETA: 0s - loss: 0.3010 - accuracy: 0.8880Epoch 2/20
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.2968 - accuracy: 0.8923
# 1219/1230 [============================>.] - ETA: 0s - loss: 0.2960 - accuracy: 0.8932Epoch 2/10
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.2960 - accuracy: 0.8934
# 1224/1230 [============================>.] - ETA: 0s - loss: 0.3055 - accuracy: 0.8899Epoch 2/20
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.3055 - accuracy: 0.8897
#   81/1230 [>.............................] - ETA: 6s - loss: 0.2886 - accuracy: 0.8904Epoch 2/10
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.3046 - accuracy: 0.8884
# 1228/1230 [============================>.] - ETA: 0s - loss: 0.2998 - accuracy: 0.8885Epoch 2/10
# 1230/1230 [==============================] - 10s 6ms/step - loss: 0.3000 - accuracy: 0.8884
#  304/1230 [======>.......................] - ETA: 5s - loss: 0.2901 - accuracy: 0.8951Epoch 2/20
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.2979 - accuracy: 0.8910
# Epoch 2/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2981 - accuracy: 0.8909
# 1230/1230 [==============================] - 10s 7ms/step - loss: 0.3029 - accuracy: 0.8889
# Epoch 2/10
#    1/1230 [..............................] - ETA: 7s - loss: 0.1400 - accuracy: 1.0000Epoch 2/10
# 1230/1230 [==============================] - 10s 7ms/step - loss: 0.3007 - accuracy: 0.8896
# Epoch 2/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2856 - accuracy: 0.8946
# 1094/1230 [=========================>....] - ETA: 0s - loss: 0.2888 - accuracy: 0.8920Epoch 3/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2923 - accuracy: 0.8942
# 1008/1230 [=======================>......] - ETA: 1s - loss: 0.2841 - accuracy: 0.8953Epoch 3/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2861 - accuracy: 0.8960
# 1099/1230 [=========================>....] - ETA: 0s - loss: 0.2853 - accuracy: 0.8954Epoch 3/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2866 - accuracy: 0.8949
# 1147/1230 [==========================>...] - ETA: 0s - loss: 0.2930 - accuracy: 0.8928Epoch 3/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2861 - accuracy: 0.8961
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2914 - accuracy: 0.8936
# Epoch 3/10
#  937/1230 [=====================>........] - ETA: 2s - loss: 0.2867 - accuracy: 0.8947Epoch 3/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2868 - accuracy: 0.8941
#  196/1230 [===>..........................] - ETA: 6s - loss: 0.2887 - accuracy: 0.8976Epoch 3/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2920 - accuracy: 0.8933
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2864 - accuracy: 0.8955
# Epoch 3/20
# 1134/1230 [==========================>...] - ETA: 0s - loss: 0.2925 - accuracy: 0.8932Epoch 3/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2917 - accuracy: 0.8948
# Epoch 3/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2864 - accuracy: 0.8961
# Epoch 3/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2922 - accuracy: 0.8936
#   31/1230 [..............................] - ETA: 6s - loss: 0.3392 - accuracy: 0.8871Epoch 3/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2863 - accuracy: 0.8949
# 1075/1230 [=========================>....] - ETA: 1s - loss: 0.2868 - accuracy: 0.8947Epoch 3/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2868 - accuracy: 0.8938
#  120/1230 [=>............................] - ETA: 7s - loss: 0.2948 - accuracy: 0.8901Epoch 3/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2870 - accuracy: 0.8944
#  206/1230 [====>.........................] - ETA: 5s - loss: 0.2836 - accuracy: 0.8975Epoch 3/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2858 - accuracy: 0.8957
# Epoch 3/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2855 - accuracy: 0.8960
# 1217/1230 [============================>.] - ETA: 0s - loss: 0.2845 - accuracy: 0.8966Epoch 4/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2897 - accuracy: 0.8939
# Epoch 4/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2844 - accuracy: 0.8969
# 1185/1230 [===========================>..] - ETA: 0s - loss: 0.2838 - accuracy: 0.8959Epoch 4/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2848 - accuracy: 0.8940
# 1180/1230 [===========================>..] - ETA: 0s - loss: 0.2892 - accuracy: 0.8940Epoch 4/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2848 - accuracy: 0.8961
# 1189/1230 [============================>.] - ETA: 0s - loss: 0.2893 - accuracy: 0.8940Epoch 4/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2850 - accuracy: 0.8956
# 1077/1230 [=========================>....] - ETA: 1s - loss: 0.2875 - accuracy: 0.8950Epoch 4/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2901 - accuracy: 0.8938
# 1212/1230 [============================>.] - ETA: 0s - loss: 0.2898 - accuracy: 0.8938Epoch 4/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2902 - accuracy: 0.8934
#   36/1230 [..............................] - ETA: 7s - loss: 0.3503 - accuracy: 0.8681Epoch 4/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2910 - accuracy: 0.8934
#   12/1230 [..............................] - ETA: 11s - loss: 0.3004 - accuracy: 0.9010Epoch 4/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2846 - accuracy: 0.8967
#  139/1230 [==>...........................] - ETA: 7s - loss: 0.2874 - accuracy: 0.8894Epoch 4/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2844 - accuracy: 0.8964
# Epoch 4/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2851 - accuracy: 0.8952
# Epoch 4/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2855 - accuracy: 0.8955
#  305/1230 [======>.......................] - ETA: 5s - loss: 0.2873 - accuracy: 0.8990Epoch 4/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2848 - accuracy: 0.8965
#  334/1230 [=======>......................] - ETA: 5s - loss: 0.2779 - accuracy: 0.8969Epoch 4/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2899 - accuracy: 0.8935
# 1073/1230 [=========================>....] - ETA: 1s - loss: 0.2857 - accuracy: 0.8954Epoch 4/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2856 - accuracy: 0.8954
#  570/1230 [============>.................] - ETA: 4s - loss: 0.2815 - accuracy: 0.8975Epoch 4/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2832 - accuracy: 0.8957
# 1179/1230 [===========================>..] - ETA: 0s - loss: 0.2835 - accuracy: 0.8956Epoch 5/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2839 - accuracy: 0.8962
# Epoch 5/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2833 - accuracy: 0.8961
# Epoch 5/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2838 - accuracy: 0.8959
#  965/1230 [======================>.......] - ETA: 1s - loss: 0.2838 - accuracy: 0.8959Epoch 5/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2888 - accuracy: 0.8946
#   59/1230 [>.............................] - ETA: 8s - loss: 0.2392 - accuracy: 0.9131Epoch 5/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2884 - accuracy: 0.8942
#  890/1230 [====================>.........] - ETA: 2s - loss: 0.2816 - accuracy: 0.8971Epoch 5/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2886 - accuracy: 0.8942
#   22/1230 [..............................] - ETA: 6s - loss: 0.2694 - accuracy: 0.8949Epoch 5/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2840 - accuracy: 0.8967
#  163/1230 [==>...........................] - ETA: 5s - loss: 0.2835 - accuracy: 0.8957Epoch 5/20
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2892 - accuracy: 0.8948
# 1166/1230 [===========================>..] - ETA: 0s - loss: 0.2854 - accuracy: 0.8954Epoch 5/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2831 - accuracy: 0.8973
#   40/1230 [..............................] - ETA: 6s - loss: 0.3213 - accuracy: 0.8781Epoch 5/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2829 - accuracy: 0.8970
#  224/1230 [====>.........................] - ETA: 5s - loss: 0.2881 - accuracy: 0.8931Epoch 5/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2842 - accuracy: 0.8959
#  243/1230 [====>.........................] - ETA: 5s - loss: 0.2848 - accuracy: 0.8940Epoch 5/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2834 - accuracy: 0.8968
# 1139/1230 [==========================>...] - ETA: 0s - loss: 0.2830 - accuracy: 0.8968Epoch 5/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2844 - accuracy: 0.8964
#  287/1230 [======>.......................] - ETA: 6s - loss: 0.2810 - accuracy: 0.8992Epoch 5/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2884 - accuracy: 0.8939
# Epoch 5/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2845 - accuracy: 0.8956
# Epoch 5/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2833 - accuracy: 0.8963
# Epoch 6/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2818 - accuracy: 0.8976
#  701/1230 [================>.............] - ETA: 3s - loss: 0.2822 - accuracy: 0.8959Epoch 6/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2825 - accuracy: 0.8968
# Epoch 6/20
# 1230/1230 [==============================] - 7s 5ms/step - loss: 0.2879 - accuracy: 0.8943
# Epoch 6/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2878 - accuracy: 0.8958
#  816/1230 [==================>...........] - ETA: 2s - loss: 0.2832 - accuracy: 0.8962Epoch 6/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2874 - accuracy: 0.8949
# Epoch 6/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2830 - accuracy: 0.8972
#  132/1230 [==>...........................] - ETA: 4s - loss: 0.2828 - accuracy: 0.8973Epoch 6/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2826 - accuracy: 0.8958
# Epoch 6/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2826 - accuracy: 0.8971
#  329/1230 [=======>......................] - ETA: 5s - loss: 0.2743 - accuracy: 0.8995Epoch 6/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2825 - accuracy: 0.8969
# 1110/1230 [==========================>...] - ETA: 0s - loss: 0.2895 - accuracy: 0.8947Epoch 6/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2830 - accuracy: 0.8967
#  531/1230 [===========>..................] - ETA: 3s - loss: 0.2820 - accuracy: 0.8982Epoch 6/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2882 - accuracy: 0.8953
#  248/1230 [=====>........................] - ETA: 6s - loss: 0.2912 - accuracy: 0.8967Epoch 6/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2830 - accuracy: 0.8956
#  142/1230 [==>...........................] - ETA: 6s - loss: 0.2935 - accuracy: 0.8917Epoch 6/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2825 - accuracy: 0.8955
# Epoch 6/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2875 - accuracy: 0.8942
# Epoch 6/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2829 - accuracy: 0.8971
#  415/1230 [=========>....................] - ETA: 5s - loss: 0.2814 - accuracy: 0.8988Epoch 6/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2825 - accuracy: 0.8964
#  520/1230 [===========>..................] - ETA: 4s - loss: 0.2903 - accuracy: 0.8946Epoch 7/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2809 - accuracy: 0.8977
# Epoch 7/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2867 - accuracy: 0.8951
#   32/1230 [..............................] - ETA: 6s - loss: 0.3209 - accuracy: 0.8867Epoch 7/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2875 - accuracy: 0.8961
# Epoch 7/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2812 - accuracy: 0.8969
# Epoch 7/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2869 - accuracy: 0.8946
#   48/1230 [>.............................] - ETA: 9s - loss: 0.2755 - accuracy: 0.9062Epoch 7/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2822 - accuracy: 0.8970
#  653/1230 [==============>...............] - ETA: 3s - loss: 0.2911 - accuracy: 0.8931Epoch 7/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2820 - accuracy: 0.8962
#  221/1230 [====>.........................] - ETA: 6s - loss: 0.2820 - accuracy: 0.9016Epoch 7/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2829 - accuracy: 0.8954
# Epoch 7/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2817 - accuracy: 0.8976
# 1127/1230 [==========================>...] - ETA: 0s - loss: 0.2823 - accuracy: 0.8970Epoch 7/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2830 - accuracy: 0.8972
#  501/1230 [===========>..................] - ETA: 5s - loss: 0.2837 - accuracy: 0.8967Epoch 7/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2826 - accuracy: 0.8968
#  644/1230 [==============>...............] - ETA: 3s - loss: 0.2838 - accuracy: 0.8957Epoch 7/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2877 - accuracy: 0.8943
# 1210/1230 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.8961Epoch 7/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2823 - accuracy: 0.8965
#  133/1230 [==>...........................] - ETA: 5s - loss: 0.3013 - accuracy: 0.8877Epoch 7/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2870 - accuracy: 0.8942
#  104/1230 [=>............................] - ETA: 7s - loss: 0.2879 - accuracy: 0.8936Epoch 7/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2823 - accuracy: 0.8973
# Epoch 7/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2804 - accuracy: 0.8967
# 1206/1230 [============================>.] - ETA: 0s - loss: 0.2816 - accuracy: 0.8966Epoch 8/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2815 - accuracy: 0.8968
# Epoch 8/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2851 - accuracy: 0.8965
#  583/1230 [=============>................] - ETA: 4s - loss: 0.2876 - accuracy: 0.8931Epoch 8/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2854 - accuracy: 0.8954
#  880/1230 [====================>.........] - ETA: 2s - loss: 0.2846 - accuracy: 0.8950Epoch 8/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2863 - accuracy: 0.8959
#  176/1230 [===>..........................] - ETA: 6s - loss: 0.2785 - accuracy: 0.8949Epoch 8/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2810 - accuracy: 0.8973
#  936/1230 [=====================>........] - ETA: 1s - loss: 0.2802 - accuracy: 0.8969Epoch 8/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2812 - accuracy: 0.8969
# Epoch 8/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2819 - accuracy: 0.8966
#  357/1230 [=======>......................] - ETA: 4s - loss: 0.2744 - accuracy: 0.8979Epoch 8/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2814 - accuracy: 0.8970
# Epoch 8/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2821 - accuracy: 0.8978
#  336/1230 [=======>......................] - ETA: 6s - loss: 0.2769 - accuracy: 0.8994Epoch 8/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2805 - accuracy: 0.8980
#  611/1230 [=============>................] - ETA: 4s - loss: 0.2832 - accuracy: 0.8953Epoch 8/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2863 - accuracy: 0.8955
#  632/1230 [==============>...............] - ETA: 3s - loss: 0.2821 - accuracy: 0.8965Epoch 8/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2814 - accuracy: 0.8972
#  321/1230 [======>.......................] - ETA: 4s - loss: 0.2873 - accuracy: 0.8974Epoch 8/20
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2806 - accuracy: 0.8976
#  847/1230 [===================>..........] - ETA: 2s - loss: 0.2764 - accuracy: 0.8978Epoch 8/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2861 - accuracy: 0.8940
#  586/1230 [=============>................] - ETA: 3s - loss: 0.2812 - accuracy: 0.8974Epoch 8/10
# 1230/1230 [==============================] - 9s 8ms/step - loss: 0.2813 - accuracy: 0.8977
# 1037/1230 [========================>.....] - ETA: 1s - loss: 0.2839 - accuracy: 0.8957Epoch 8/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2793 - accuracy: 0.8970
# 1079/1230 [=========================>....] - ETA: 1s - loss: 0.2838 - accuracy: 0.8979Epoch 9/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2809 - accuracy: 0.8973
#  661/1230 [===============>..............] - ETA: 3s - loss: 0.2792 - accuracy: 0.9000Epoch 9/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2842 - accuracy: 0.8956
# Epoch 9/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2846 - accuracy: 0.8971
#  158/1230 [==>...........................] - ETA: 7s - loss: 0.2731 - accuracy: 0.9007Epoch 9/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2808 - accuracy: 0.8970
# 1143/1230 [==========================>...] - ETA: 0s - loss: 0.2809 - accuracy: 0.8980Epoch 9/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2861 - accuracy: 0.8959
# Epoch 9/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2805 - accuracy: 0.8977
#  657/1230 [===============>..............] - ETA: 3s - loss: 0.2805 - accuracy: 0.8999Epoch 9/20
# 1230/1230 [==============================] - 7s 5ms/step - loss: 0.2805 - accuracy: 0.8980
#  742/1230 [=================>............] - ETA: 3s - loss: 0.2864 - accuracy: 0.8961Epoch 9/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2809 - accuracy: 0.8979
#  298/1230 [======>.......................] - ETA: 5s - loss: 0.2767 - accuracy: 0.8970Epoch 9/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2814 - accuracy: 0.8978
#  481/1230 [==========>...................] - ETA: 4s - loss: 0.2821 - accuracy: 0.8942Epoch 9/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2799 - accuracy: 0.8992
#  852/1230 [===================>..........] - ETA: 2s - loss: 0.2818 - accuracy: 0.8966Epoch 9/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2857 - accuracy: 0.8965
# 1115/1230 [==========================>...] - ETA: 0s - loss: 0.2789 - accuracy: 0.8985Epoch 9/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2807 - accuracy: 0.8979
#  647/1230 [==============>...............] - ETA: 3s - loss: 0.2805 - accuracy: 0.9009Epoch 9/20
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2804 - accuracy: 0.8976
# 1045/1230 [========================>.....] - ETA: 1s - loss: 0.2808 - accuracy: 0.8966Epoch 9/10
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2855 - accuracy: 0.8952
#  992/1230 [=======================>......] - ETA: 1s - loss: 0.2798 - accuracy: 0.8969Epoch 9/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2804 - accuracy: 0.8969
#  151/1230 [==>...........................] - ETA: 5s - loss: 0.2969 - accuracy: 0.8895Epoch 10/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2784 - accuracy: 0.8970
# Epoch 10/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2795 - accuracy: 0.8979
# 1070/1230 [=========================>....] - ETA: 1s - loss: 0.2852 - accuracy: 0.8972Epoch 10/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2837 - accuracy: 0.8969
# 1188/1230 [===========================>..] - ETA: 0s - loss: 0.2851 - accuracy: 0.8956Epoch 10/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2799 - accuracy: 0.8978
#  304/1230 [======>.......................] - ETA: 4s - loss: 0.2956 - accuracy: 0.8894Epoch 10/20
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2813 - accuracy: 0.8966
#  150/1230 [==>...........................] - ETA: 5s - loss: 0.2731 - accuracy: 0.9050Epoch 9/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2843 - accuracy: 0.8957
# 1016/1230 [=======================>......] - ETA: 1s - loss: 0.2795 - accuracy: 0.8987Epoch 10/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2851 - accuracy: 0.8968
# Epoch 10/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2794 - accuracy: 0.8984
# Epoch 10/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2805 - accuracy: 0.8987
# Epoch 10/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2800 - accuracy: 0.8968
#   24/1230 [..............................] - ETA: 5s - loss: 0.3361 - accuracy: 0.8698Epoch 10/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2789 - accuracy: 0.8988
#  582/1230 [=============>................] - ETA: 3s - loss: 0.2809 - accuracy: 0.8953Epoch 10/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2802 - accuracy: 0.8967
#  624/1230 [==============>...............] - ETA: 3s - loss: 0.2880 - accuracy: 0.8976Epoch 10/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2851 - accuracy: 0.8947
#  527/1230 [===========>..................] - ETA: 4s - loss: 0.2839 - accuracy: 0.8988Epoch 10/10
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2850 - accuracy: 0.8959
#  775/1230 [=================>............] - ETA: 2s - loss: 0.2883 - accuracy: 0.8969Epoch 10/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2796 - accuracy: 0.8977
#  877/1230 [====================>.........] - ETA: 2s - loss: 0.2808 - accuracy: 0.8974Epoch 10/10
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2804 - accuracy: 0.8970
#  633/1230 [==============>...............] - ETA: 3s - loss: 0.2752 - accuracy: 0.8995Epoch 11/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2777 - accuracy: 0.8976
# 1069/1230 [=========================>....] - ETA: 1s - loss: 0.2842 - accuracy: 0.8959Epoch 11/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2793 - accuracy: 0.8974
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2823 - accuracy: 0.8972
# Epoch 11/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2837 - accuracy: 0.8971
#  417/1230 [=========>....................] - ETA: 5s - loss: 0.2832 - accuracy: 0.8961Epoch 11/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2798 - accuracy: 0.8974
# Epoch 11/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2844 - accuracy: 0.8969
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2812 - accuracy: 0.8975
# 1181/1230 [===========================>..] - ETA: 0s - loss: 0.2777 - accuracy: 0.8997Epoch 10/10
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2784 - accuracy: 0.8995
# Epoch 11/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2798 - accuracy: 0.8978
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2802 - accuracy: 0.8976
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2785 - accuracy: 0.8993
# 615/615 [==============================] - 3s 4ms/step - loss: 0.2884 - accuracy: 0.8921
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2794 - accuracy: 0.8973
#  926/1230 [=====================>........] - ETA: 1s - loss: 0.2802 - accuracy: 0.8956Epoch 11/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2836 - accuracy: 0.8965
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2840 - accuracy: 0.8955
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2780 - accuracy: 0.8991
# 615/615 [==============================] - 3s 4ms/step - loss: 0.2885 - accuracy: 0.8954
# 615/615 [==============================] - 3s 5ms/step - loss: 0.2868 - accuracy: 0.8950
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2798 - accuracy: 0.8988
# Epoch 12/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2772 - accuracy: 0.8974
# Epoch 12/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2809 - accuracy: 0.8970
# Epoch 12/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2822 - accuracy: 0.8982
# Epoch 12/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2784 - accuracy: 0.8977
# 258/615 [===========>..................] - ETA: 1s - loss: 0.2977 - accuracy: 0.8905Epoch 12/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2798 - accuracy: 0.8973
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2775 - accuracy: 0.8985
#  211/1230 [====>.........................] - ETA: 5s - loss: 0.2881 - accuracy: 0.8922Epoch 12/20
# 615/615 [==============================] - 3s 4ms/step - loss: 0.2774 - accuracy: 0.8995
# 615/615 [==============================] - 3s 4ms/step - loss: 0.2894 - accuracy: 0.8943
# 615/615 [==============================] - 3s 5ms/step - loss: 0.2792 - accuracy: 0.8977
# 615/615 [==============================] - 3s 3ms/step - loss: 0.2780 - accuracy: 0.8972
# 615/615 [==============================] - 3s 3ms/step - loss: 0.2902 - accuracy: 0.8938
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2792 - accuracy: 0.8978
# Epoch 12/20
# 1230/1230 [==============================] - 6s 4ms/step - loss: 0.2793 - accuracy: 0.8975
# 1011/1230 [=======================>......] - ETA: 1s - loss: 0.2790 - accuracy: 0.8977Epoch 13/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2762 - accuracy: 0.8987
# Epoch 13/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2820 - accuracy: 0.8981
# Epoch 13/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2800 - accuracy: 0.8976
# Epoch 13/20
#   12/1230 [..............................] - ETA: 5s - loss: 0.2553 - accuracy: 0.9062Epoch 1/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2787 - accuracy: 0.8985
# Epoch 13/20
# 1230/1230 [==============================] - 5s 4ms/step - loss: 0.2765 - accuracy: 0.8991
# Epoch 13/20
#  425/1230 [=========>....................] - ETA: 3s - loss: 0.2784 - accuracy: 0.8950Epoch 1/20
#  714/1230 [================>.............] - ETA: 2s - loss: 0.2814 - accuracy: 0.8965Epoch 1/30
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2779 - accuracy: 0.8981
# Epoch 13/20
# 1185/1230 [===========================>..] - ETA: 0s - loss: 0.2781 - accuracy: 0.8980Epoch 1/30
# 1230/1230 [==============================] - 5s 4ms/step - loss: 0.2780 - accuracy: 0.8981
#   45/1230 [>.............................] - ETA: 7s - loss: 0.2531 - accuracy: 0.9125Epoch 14/20
# 1230/1230 [==============================] - 5s 4ms/step - loss: 0.2808 - accuracy: 0.8988
#  940/1230 [=====================>........] - ETA: 1s - loss: 0.2765 - accuracy: 0.8977Epoch 14/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2753 - accuracy: 0.8976
#    1/1230 [..............................] - ETA: 3s - loss: 0.1331 - accuracy: 0.9375Epoch 14/20
#  242/1230 [====>.........................] - ETA: 5s - loss: 0.2791 - accuracy: 0.8988Epoch 1/30
# 1230/1230 [==============================] - 5s 4ms/step - loss: 0.2793 - accuracy: 0.8978
# Epoch 14/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2776 - accuracy: 0.8970
# Epoch 14/20
#  472/1230 [==========>...................] - ETA: 3s - loss: 0.2748 - accuracy: 0.9000Epoch 1/30
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2753 - accuracy: 0.9005
#  391/1230 [========>.....................] - ETA: 4s - loss: 0.2711 - accuracy: 0.8991Epoch 14/20
#  831/1230 [===================>..........] - ETA: 1s - loss: 0.2763 - accuracy: 0.8993Epoch 1/30
#  435/1230 [=========>....................] - ETA: 5s - loss: 0.3171 - accuracy: 0.8888Epoch 1/30
# 1230/1230 [==============================] - 9s 6ms/step - loss: 0.2970 - accuracy: 0.8925
# Epoch 2/20
# 1230/1230 [==============================] - 9s 5ms/step - loss: 0.3025 - accuracy: 0.8886
#  437/1230 [=========>....................] - ETA: 4s - loss: 0.2692 - accuracy: 0.9017Epoch 2/20
# 1230/1230 [==============================] - 5s 4ms/step - loss: 0.2804 - accuracy: 0.8981
#  177/1230 [===>..........................] - ETA: 6s - loss: 0.3530 - accuracy: 0.8778Epoch 15/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2778 - accuracy: 0.8981
# Epoch 15/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2774 - accuracy: 0.8990
# Epoch 14/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2742 - accuracy: 0.8987
# Epoch 15/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2772 - accuracy: 0.8988
# 1127/1230 [==========================>...] - ETA: 0s - loss: 0.2800 - accuracy: 0.8988Epoch 15/20
# 1230/1230 [==============================] - 10s 6ms/step - loss: 0.2995 - accuracy: 0.8911
#  576/1230 [=============>................] - ETA: 3s - loss: 0.2835 - accuracy: 0.8982Epoch 2/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2790 - accuracy: 0.8991
#  585/1230 [=============>................] - ETA: 3s - loss: 0.2695 - accuracy: 0.9029Epoch 15/20
# 1230/1230 [==============================] - 10s 6ms/step - loss: 0.2971 - accuracy: 0.8921
# Epoch 2/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2746 - accuracy: 0.9003
#   15/1230 [..............................] - ETA: 4s - loss: 0.2729 - accuracy: 0.9042Epoch 15/20
# 1230/1230 [==============================] - 9s 5ms/step - loss: 0.3053 - accuracy: 0.8888
#  807/1230 [==================>...........] - ETA: 2s - loss: 0.2736 - accuracy: 0.9006Epoch 2/30
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2774 - accuracy: 0.8990
# Epoch 16/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2789 - accuracy: 0.8987
#  460/1230 [==========>...................] - ETA: 4s - loss: 0.2827 - accuracy: 0.8982Epoch 16/20
# 1230/1230 [==============================] - 10s 6ms/step - loss: 0.2992 - accuracy: 0.8907
#  899/1230 [====================>.........] - ETA: 2s - loss: 0.2687 - accuracy: 0.9013Epoch 2/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2874 - accuracy: 0.8956
# Epoch 3/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2923 - accuracy: 0.8931
#  588/1230 [=============>................] - ETA: 3s - loss: 0.2916 - accuracy: 0.8943Epoch 3/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2765 - accuracy: 0.8994
# Epoch 15/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2733 - accuracy: 0.8999
#  316/1230 [======>.......................] - ETA: 5s - loss: 0.2857 - accuracy: 0.8952Epoch 16/20
# 1230/1230 [==============================] - 11s 6ms/step - loss: 0.2988 - accuracy: 0.8912
#  563/1230 [============>.................] - ETA: 3s - loss: 0.2848 - accuracy: 0.8959Epoch 2/30
# 1230/1230 [==============================] - 11s 6ms/step - loss: 0.3035 - accuracy: 0.8907
#  569/1230 [============>.................] - ETA: 3s - loss: 0.2833 - accuracy: 0.8964Epoch 2/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2867 - accuracy: 0.8941
#  325/1230 [======>.......................] - ETA: 4s - loss: 0.2595 - accuracy: 0.9062Epoch 3/30
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2761 - accuracy: 0.8983
# 1023/1230 [=======================>......] - ETA: 1s - loss: 0.2741 - accuracy: 0.9015Epoch 16/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2767 - accuracy: 0.8980
# Epoch 16/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2920 - accuracy: 0.8924
#   78/1230 [>.............................] - ETA: 7s - loss: 0.2597 - accuracy: 0.9127Epoch 3/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2864 - accuracy: 0.8955
# Epoch 3/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2738 - accuracy: 0.9005
#  967/1230 [======================>.......] - ETA: 1s - loss: 0.2803 - accuracy: 0.8981Epoch 16/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2788 - accuracy: 0.8984
# 1010/1230 [=======================>......] - ETA: 1s - loss: 0.2818 - accuracy: 0.8986Epoch 17/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2862 - accuracy: 0.8953
# 1187/1230 [===========================>..] - ETA: 0s - loss: 0.2764 - accuracy: 0.8991Epoch 3/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2771 - accuracy: 0.8990
#  756/1230 [=================>............] - ETA: 2s - loss: 0.2957 - accuracy: 0.8932Epoch 17/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2849 - accuracy: 0.8963
# 1035/1230 [========================>.....] - ETA: 1s - loss: 0.2699 - accuracy: 0.9022Epoch 4/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2896 - accuracy: 0.8938
#  766/1230 [=================>............] - ETA: 3s - loss: 0.2965 - accuracy: 0.8913Epoch 4/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2721 - accuracy: 0.9004
#  167/1230 [===>..........................] - ETA: 6s - loss: 0.2980 - accuracy: 0.8911Epoch 17/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2761 - accuracy: 0.8988
# Epoch 16/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2859 - accuracy: 0.8959
#  200/1230 [===>..........................] - ETA: 6s - loss: 0.2575 - accuracy: 0.9109Epoch 3/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2912 - accuracy: 0.8949
#  221/1230 [====>.........................] - ETA: 6s - loss: 0.2615 - accuracy: 0.9067Epoch 3/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2757 - accuracy: 0.8979
#  628/1230 [==============>...............] - ETA: 3s - loss: 0.2866 - accuracy: 0.8950Epoch 17/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2845 - accuracy: 0.8954
# 1192/1230 [============================>.] - ETA: 0s - loss: 0.2847 - accuracy: 0.8967Epoch 4/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2904 - accuracy: 0.8943
#  585/1230 [=============>................] - ETA: 4s - loss: 0.2853 - accuracy: 0.8968Epoch 4/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2768 - accuracy: 0.8984
# 1060/1230 [========================>.....] - ETA: 1s - loss: 0.2726 - accuracy: 0.8998Epoch 17/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2847 - accuracy: 0.8966
#  410/1230 [=========>....................] - ETA: 4s - loss: 0.2708 - accuracy: 0.8995Epoch 4/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2719 - accuracy: 0.9010
#  418/1230 [=========>....................] - ETA: 4s - loss: 0.2952 - accuracy: 0.8934Epoch 17/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2769 - accuracy: 0.9008
#  298/1230 [======>.......................] - ETA: 6s - loss: 0.3032 - accuracy: 0.8859Epoch 18/20
# 1230/1230 [==============================] - 7s 5ms/step - loss: 0.2757 - accuracy: 0.9002
# Epoch 18/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2846 - accuracy: 0.8961
#  271/1230 [=====>........................] - ETA: 5s - loss: 0.2775 - accuracy: 0.8992Epoch 4/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2838 - accuracy: 0.8972
#  962/1230 [======================>.......] - ETA: 1s - loss: 0.2849 - accuracy: 0.8968Epoch 5/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2721 - accuracy: 0.9005
#  588/1230 [=============>................] - ETA: 3s - loss: 0.2745 - accuracy: 0.9003Epoch 18/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2892 - accuracy: 0.8946
# Epoch 5/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2752 - accuracy: 0.8998
#  226/1230 [====>.........................] - ETA: 7s - loss: 0.2815 - accuracy: 0.8941Epoch 17/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2851 - accuracy: 0.8967
# Epoch 4/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2894 - accuracy: 0.8940
# Epoch 4/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2747 - accuracy: 0.8988
# Epoch 18/20
# 1230/1230 [==============================] - 7s 5ms/step - loss: 0.2842 - accuracy: 0.8960
#  378/1230 [========>.....................] - ETA: 6s - loss: 0.2821 - accuracy: 0.8958Epoch 5/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2755 - accuracy: 0.8992
#   61/1230 [>.............................] - ETA: 8s - loss: 0.2972 - accuracy: 0.8934Epoch 18/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2837 - accuracy: 0.8966
#  237/1230 [====>.........................] - ETA: 4s - loss: 0.2935 - accuracy: 0.8900Epoch 5/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2888 - accuracy: 0.8939
# Epoch 5/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2712 - accuracy: 0.9021
#  628/1230 [==============>...............] - ETA: 3s - loss: 0.2904 - accuracy: 0.8938Epoch 18/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2758 - accuracy: 0.8992
# 1077/1230 [=========================>....] - ETA: 1s - loss: 0.2735 - accuracy: 0.9012Epoch 19/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2759 - accuracy: 0.9000
#  760/1230 [=================>............] - ETA: 3s - loss: 0.2894 - accuracy: 0.8938Epoch 19/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2825 - accuracy: 0.8972
#  866/1230 [====================>.........] - ETA: 2s - loss: 0.2904 - accuracy: 0.8946Epoch 6/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2832 - accuracy: 0.8967
#  876/1230 [====================>.........] - ETA: 2s - loss: 0.2787 - accuracy: 0.8964Epoch 5/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2712 - accuracy: 0.9007
# 1063/1230 [========================>.....] - ETA: 1s - loss: 0.2752 - accuracy: 0.8986Epoch 19/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2873 - accuracy: 0.8954
#  144/1230 [==>...........................] - ETA: 5s - loss: 0.2776 - accuracy: 0.8954Epoch 6/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2833 - accuracy: 0.8978
#  783/1230 [==================>...........] - ETA: 2s - loss: 0.2831 - accuracy: 0.8965Epoch 5/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2747 - accuracy: 0.8990
# Epoch 18/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2832 - accuracy: 0.8962
#  915/1230 [=====================>........] - ETA: 2s - loss: 0.2838 - accuracy: 0.8962Epoch 6/30
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2890 - accuracy: 0.8951
#  801/1230 [==================>...........] - ETA: 2s - loss: 0.2690 - accuracy: 0.9022Epoch 5/30
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2740 - accuracy: 0.8995
# Epoch 19/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2886 - accuracy: 0.8946
# Epoch 6/30
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2747 - accuracy: 0.9004
# Epoch 19/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2737 - accuracy: 0.9003
#   61/1230 [>.............................] - ETA: 8s - loss: 0.2694 - accuracy: 0.9027Epoch 20/20
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2821 - accuracy: 0.8974
#  367/1230 [=======>......................] - ETA: 4s - loss: 0.2682 - accuracy: 0.9005Epoch 6/30
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2712 - accuracy: 0.9015
# Epoch 19/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2751 - accuracy: 0.8991
#  715/1230 [================>.............] - ETA: 3s - loss: 0.2850 - accuracy: 0.8967Epoch 20/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2830 - accuracy: 0.8972
# Epoch 6/30
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2823 - accuracy: 0.8976
#  712/1230 [================>.............] - ETA: 2s - loss: 0.2901 - accuracy: 0.8954Epoch 7/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2706 - accuracy: 0.8998
#   65/1230 [>.............................] - ETA: 5s - loss: 0.3068 - accuracy: 0.8923Epoch 20/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2737 - accuracy: 0.8994
# Epoch 19/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2826 - accuracy: 0.8980
# Epoch 6/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2826 - accuracy: 0.8979
# Epoch 7/30
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2882 - accuracy: 0.8959
#  165/1230 [===>..........................] - ETA: 7s - loss: 0.2919 - accuracy: 0.8917Epoch 7/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2873 - accuracy: 0.8951
# 1039/1230 [========================>.....] - ETA: 1s - loss: 0.2877 - accuracy: 0.8953Epoch 6/30
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2730 - accuracy: 0.8993
#  535/1230 [============>.................] - ETA: 4s - loss: 0.2820 - accuracy: 0.8974Epoch 20/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2744 - accuracy: 0.9000
#  508/1230 [===========>..................] - ETA: 4s - loss: 0.2599 - accuracy: 0.9042Epoch 20/20
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2876 - accuracy: 0.8946
# Epoch 7/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2743 - accuracy: 0.8999
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2819 - accuracy: 0.8977
# 1133/1230 [==========================>...] - ETA: 0s - loss: 0.2681 - accuracy: 0.9036Epoch 7/30
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2689 - accuracy: 0.9037
#  609/1230 [=============>................] - ETA: 4s - loss: 0.2839 - accuracy: 0.8951Epoch 20/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2737 - accuracy: 0.9000
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2825 - accuracy: 0.8965
# Epoch 7/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2696 - accuracy: 0.9011
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2812 - accuracy: 0.8978
# Epoch 8/20
# 615/615 [==============================] - 4s 5ms/step - loss: 0.2874 - accuracy: 0.8948
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2723 - accuracy: 0.9001
#  531/1230 [===========>..................] - ETA: 4s - loss: 0.2682 - accuracy: 0.9020Epoch 20/20
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2865 - accuracy: 0.8965
# Epoch 7/30
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2822 - accuracy: 0.8966
# 1121/1230 [==========================>...] - ETA: 0s - loss: 0.2825 - accuracy: 0.8975Epoch 8/30
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2823 - accuracy: 0.8977
#  466/1230 [==========>...................] - ETA: 4s - loss: 0.2787 - accuracy: 0.8961Epoch 7/30
# 615/615 [==============================] - 4s 4ms/step - loss: 0.2817 - accuracy: 0.8957
# 615/615 [==============================] - 4s 4ms/step - loss: 0.2868 - accuracy: 0.8966
# 1230/1230 [==============================] - 9s 7ms/step - loss: 0.2867 - accuracy: 0.8950
#  284/1230 [=====>........................] - ETA: 6s - loss: 0.2812 - accuracy: 0.8950Epoch 8/20
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2737 - accuracy: 0.9004
# 1230/1230 [==============================] - 8s 7ms/step - loss: 0.2734 - accuracy: 0.9000
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2809 - accuracy: 0.8966
# Epoch 8/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2872 - accuracy: 0.8953
# Epoch 8/30
# 1230/1230 [==============================] - 8s 6ms/step - loss: 0.2681 - accuracy: 0.9026
# 1230/1230 [==============================] - 7s 5ms/step - loss: 0.2818 - accuracy: 0.8957
# Epoch 8/30
# 615/615 [==============================] - 3s 4ms/step - loss: 0.2785 - accuracy: 0.8966
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2798 - accuracy: 0.8979
#  583/1230 [=============>................] - ETA: 3s - loss: 0.2820 - accuracy: 0.8964Epoch 9/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2856 - accuracy: 0.8968
# 314/615 [==============>...............] - ETA: 1s - loss: 0.3073 - accuracy: 0.8871Epoch 8/30
# 1230/1230 [==============================] - 7s 5ms/step - loss: 0.2808 - accuracy: 0.8971
#  952/1230 [======================>.......] - ETA: 1s - loss: 0.2893 - accuracy: 0.8946Epoch 9/30
# 1230/1230 [==============================] - 7s 6ms/step - loss: 0.2720 - accuracy: 0.8996
# 615/615 [==============================] - 3s 3ms/step - loss: 0.2939 - accuracy: 0.8914
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2809 - accuracy: 0.8981
# Epoch 8/30
# 1222/1230 [============================>.] - ETA: 0s - loss: 0.2858 - accuracy: 0.8959Epoch 1/30
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2860 - accuracy: 0.8958
# Epoch 9/30
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2855 - accuracy: 0.8958
# Epoch 9/20
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2797 - accuracy: 0.8978
# Epoch 9/30
#  138/1230 [==>...........................] - ETA: 5s - loss: 0.3411 - accuracy: 0.8822Epoch 1/30
# 1230/1230 [==============================] - 6s 5ms/step - loss: 0.2817 - accuracy: 0.8953
# Epoch 9/30
# ...
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2731 - accuracy: 0.9008
# Epoch 23/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2753 - accuracy: 0.8998
# 156/308 [==============>...............] - ETA: 0s - loss: 0.2645 - accuracy: 0.9042Epoch 18/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2832 - accuracy: 0.8971
# Epoch 12/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2741 - accuracy: 0.8997
# Epoch 18/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2733 - accuracy: 0.9014
# Epoch 20/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2772 - accuracy: 0.8978
# Epoch 23/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2748 - accuracy: 0.8994
# Epoch 24/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2741 - accuracy: 0.9009
# Epoch 21/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2729 - accuracy: 0.9011
# Epoch 24/30
# 308/308 [==============================] - 2s 6ms/step - loss: 0.2765 - accuracy: 0.8997
# 137/308 [============>.................] - ETA: 0s - loss: 0.2715 - accuracy: 0.9043Epoch 14/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2751 - accuracy: 0.9000
# 130/308 [===========>..................] - ETA: 0s - loss: 0.2761 - accuracy: 0.9012Epoch 19/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2724 - accuracy: 0.9023
# Epoch 21/30
# 308/308 [==============================] - 2s 6ms/step - loss: 0.2729 - accuracy: 0.9010
# 308/308 [==============================] - 2s 6ms/step - loss: 0.2819 - accuracy: 0.8976
# Epoch 19/30
# Epoch 13/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2745 - accuracy: 0.8987
# Epoch 25/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2759 - accuracy: 0.8992
# 304/308 [============================>.] - ETA: 0s - loss: 0.2732 - accuracy: 0.9011Epoch 24/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2735 - accuracy: 0.9007
# Epoch 22/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2718 - accuracy: 0.9019
# 242/308 [======================>.......] - ETA: 0s - loss: 0.2731 - accuracy: 0.9000Epoch 25/30
# 308/308 [==============================] - 2s 6ms/step - loss: 0.2763 - accuracy: 0.8996
# Epoch 15/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2747 - accuracy: 0.8997
# Epoch 20/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2721 - accuracy: 0.9007
# Epoch 22/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2750 - accuracy: 0.9000
# Epoch 25/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2728 - accuracy: 0.9009
# Epoch 23/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2804 - accuracy: 0.8981
# 137/308 [============>.................] - ETA: 0s - loss: 0.2807 - accuracy: 0.8961Epoch 14/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2710 - accuracy: 0.9025
# Epoch 26/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2737 - accuracy: 0.8989
#  31/308 [==>...........................] - ETA: 1s - loss: 0.2997 - accuracy: 0.8947Epoch 26/30
# 308/308 [==============================] - 2s 6ms/step - loss: 0.2729 - accuracy: 0.9004
#  59/308 [====>.........................] - ETA: 0s - loss: 0.2803 - accuracy: 0.9017Epoch 20/30
# 308/308 [==============================] - 2s 4ms/step - loss: 0.2852 - accuracy: 0.8931
# 308/308 [==============================] - 2s 6ms/step - loss: 0.2753 - accuracy: 0.9000
# Epoch 16/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2739 - accuracy: 0.8995
# Epoch 26/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2735 - accuracy: 0.9003
# 247/308 [=======================>......] - ETA: 0s - loss: 0.2714 - accuracy: 0.9011Epoch 21/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2720 - accuracy: 0.9008
#  13/308 [>.............................] - ETA: 1s - loss: 0.2726 - accuracy: 0.9014Epoch 24/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2710 - accuracy: 0.9029
# Epoch 23/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2713 - accuracy: 0.9007
# Epoch 27/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2737 - accuracy: 0.8996
# Epoch 27/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2801 - accuracy: 0.8980
#  59/308 [====>.........................] - ETA: 1s - loss: 0.2737 - accuracy: 0.8994Epoch 15/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2725 - accuracy: 0.9006
# Epoch 21/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2737 - accuracy: 0.9010
# Epoch 27/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2705 - accuracy: 0.9014
# 286/308 [==========================>...] - ETA: 0s - loss: 0.2701 - accuracy: 0.9023Epoch 24/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2724 - accuracy: 0.9013
# Epoch 22/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2717 - accuracy: 0.9010
#  18/308 [>.............................] - ETA: 0s - loss: 0.2727 - accuracy: 0.8976Epoch 25/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2746 - accuracy: 0.9003
# Epoch 17/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2705 - accuracy: 0.9019
# 292/308 [===========================>..] - ETA: 0s - loss: 0.2731 - accuracy: 0.8990Epoch 28/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2726 - accuracy: 0.8995
# Epoch 28/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2798 - accuracy: 0.8984
# 288/308 [===========================>..] - ETA: 0s - loss: 0.2727 - accuracy: 0.8997Epoch 16/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2711 - accuracy: 0.9006
# Epoch 22/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2732 - accuracy: 0.8998
# 200/308 [==================>...........] - ETA: 0s - loss: 0.2662 - accuracy: 0.9041Epoch 28/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2722 - accuracy: 0.9013
# Epoch 23/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2700 - accuracy: 0.9018
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2690 - accuracy: 0.9030
# Epoch 29/30
# Epoch 25/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2704 - accuracy: 0.9005
# 290/308 [===========================>..] - ETA: 0s - loss: 0.2723 - accuracy: 0.9008Epoch 26/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2723 - accuracy: 0.9006
#  46/308 [===>..........................] - ETA: 1s - loss: 0.2396 - accuracy: 0.9147Epoch 29/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2741 - accuracy: 0.9005
# Epoch 18/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2785 - accuracy: 0.8991
# Epoch 17/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2711 - accuracy: 0.9017
# Epoch 23/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2717 - accuracy: 0.9014
# Epoch 29/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2694 - accuracy: 0.9028
# Epoch 30/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2688 - accuracy: 0.9033
# Epoch 26/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2690 - accuracy: 0.9019
# Epoch 27/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2707 - accuracy: 0.9019
# Epoch 24/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2717 - accuracy: 0.8996
# 207/308 [===================>..........] - ETA: 0s - loss: 0.2749 - accuracy: 0.8982Epoch 30/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2734 - accuracy: 0.9000
# Epoch 19/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2783 - accuracy: 0.8986
# Epoch 18/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2715 - accuracy: 0.9005
# Epoch 30/30
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2704 - accuracy: 0.9018
# Epoch 24/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2682 - accuracy: 0.9020
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2678 - accuracy: 0.9033
# Epoch 27/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2684 - accuracy: 0.9027
# Epoch 28/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2699 - accuracy: 0.9029
#  17/308 [>.............................] - ETA: 0s - loss: 0.2597 - accuracy: 0.9062Epoch 25/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2710 - accuracy: 0.9007
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2717 - accuracy: 0.9005
#  65/308 [=====>........................] - ETA: 1s - loss: 0.2686 - accuracy: 0.9002Epoch 20/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2710 - accuracy: 0.9011
# 308/308 [==============================] - 2s 5ms/step - loss: 0.2775 - accuracy: 0.8989
# Epoch 19/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2687 - accuracy: 0.9009
# Epoch 25/30
# 154/154 [==============================] - 1s 2ms/step - loss: 0.2912 - accuracy: 0.8903
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2873 - accuracy: 0.8926
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2673 - accuracy: 0.9025
#  95/154 [=================>............] - ETA: 0s - loss: 0.2776 - accuracy: 0.8952Epoch 28/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2690 - accuracy: 0.9025
#   1/308 [..............................] - ETA: 1s - loss: 0.3282 - accuracy: 0.8750Epoch 26/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2686 - accuracy: 0.9011
# Epoch 29/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2784 - accuracy: 0.8945
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2708 - accuracy: 0.9020
# Epoch 21/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2759 - accuracy: 0.8997
# Epoch 20/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2676 - accuracy: 0.9025
#  31/308 [==>...........................] - ETA: 0s - loss: 0.2648 - accuracy: 0.9042Epoch 26/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2660 - accuracy: 0.9040
# Epoch 29/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2672 - accuracy: 0.9016
# Epoch 30/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2692 - accuracy: 0.9027
# Epoch 27/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2751 - accuracy: 0.8998
# Epoch 21/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2705 - accuracy: 0.9026
# 141/308 [============>.................] - ETA: 0s - loss: 0.2612 - accuracy: 0.9027Epoch 22/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2675 - accuracy: 0.9016
# Epoch 27/30
# 308/308 [==============================] - 1s 3ms/step - loss: 0.2660 - accuracy: 0.9030
# 133/308 [===========>..................] - ETA: 0s - loss: 0.2742 - accuracy: 0.8997Epoch 30/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2668 - accuracy: 0.9045
# Epoch 28/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2672 - accuracy: 0.9010
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2735 - accuracy: 0.9007
# Epoch 22/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2693 - accuracy: 0.9028
# Epoch 23/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2668 - accuracy: 0.9031
# Epoch 28/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2869 - accuracy: 0.8923
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2654 - accuracy: 0.9038
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2668 - accuracy: 0.9037
# Epoch 29/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2729 - accuracy: 0.9003
# 130/308 [===========>..................] - ETA: 0s - loss: 0.2644 - accuracy: 0.9037Epoch 23/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2916 - accuracy: 0.8913
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2698 - accuracy: 0.9028
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2663 - accuracy: 0.9029
# Epoch 24/30
# Epoch 29/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2661 - accuracy: 0.9027
# Epoch 30/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2720 - accuracy: 0.9008
# 169/308 [===============>..............] - ETA: 0s - loss: 0.2637 - accuracy: 0.9038Epoch 24/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2671 - accuracy: 0.9035
# 133/308 [===========>..................] - ETA: 0s - loss: 0.2780 - accuracy: 0.8981Epoch 25/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2655 - accuracy: 0.9034
# Epoch 30/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2648 - accuracy: 0.9039
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2711 - accuracy: 0.9013
# Epoch 25/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2843 - accuracy: 0.8947
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2643 - accuracy: 0.9035
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2678 - accuracy: 0.9036
# Epoch 26/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2700 - accuracy: 0.9015
# Epoch 26/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2950 - accuracy: 0.8934
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2669 - accuracy: 0.9035
# Epoch 27/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2695 - accuracy: 0.9020
# Epoch 27/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2657 - accuracy: 0.9047
# Epoch 28/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2787 - accuracy: 0.8979
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2686 - accuracy: 0.9016
# Epoch 28/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2649 - accuracy: 0.9039
# Epoch 29/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2676 - accuracy: 0.9031
# Epoch 29/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2641 - accuracy: 0.9038
# Epoch 30/30
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2669 - accuracy: 0.9028
# Epoch 30/30
# 308/308 [==============================] - 1s 5ms/step - loss: 0.2626 - accuracy: 0.9058
# 308/308 [==============================] - 1s 4ms/step - loss: 0.2649 - accuracy: 0.9035
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2906 - accuracy: 0.8914
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2823 - accuracy: 0.8946
# Epoch 1/10
# 1845/1845 [==============================] - 9s 4ms/step - loss: 0.2960 - accuracy: 0.8927
# Epoch 2/10
# 1845/1845 [==============================] - 8s 4ms/step - loss: 0.2877 - accuracy: 0.8942
# Epoch 3/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2859 - accuracy: 0.8956
# Epoch 4/10
# 1845/1845 [==============================] - 8s 4ms/step - loss: 0.2844 - accuracy: 0.8958
# Epoch 5/10
# 1845/1845 [==============================] - 8s 4ms/step - loss: 0.2839 - accuracy: 0.8952
# Epoch 6/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2830 - accuracy: 0.8962
# Epoch 7/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2821 - accuracy: 0.8966
# Epoch 8/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2815 - accuracy: 0.8963
# Epoch 9/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2808 - accuracy: 0.8968
# Epoch 10/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2796 - accuracy: 0.8968
# {'batch_size': 16, 'epochs': 10, 'hidden_units': 256}

# %%
best_model_nn = create_model_nn(best_params_nn['hidden_units'])
best_model_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
best_model_nn.fit(X_train, y_train, epochs=best_params_nn['epochs'], batch_size=best_params_nn['batch_size'])
# Out:
# Epoch 1/10
# 1845/1845 [==============================] - 9s 4ms/step - loss: 0.2967 - accuracy: 0.8927
# Epoch 2/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2877 - accuracy: 0.8953
# Epoch 3/10
# 1845/1845 [==============================] - 8s 4ms/step - loss: 0.2856 - accuracy: 0.8952
# Epoch 4/10
# 1845/1845 [==============================] - 8s 4ms/step - loss: 0.2851 - accuracy: 0.8949
# Epoch 5/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2843 - accuracy: 0.8953
# Epoch 6/10
# 1845/1845 [==============================] - 8s 4ms/step - loss: 0.2835 - accuracy: 0.8959
# Epoch 7/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2830 - accuracy: 0.8967
# Epoch 8/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2823 - accuracy: 0.8969
# Epoch 9/10
# 1845/1845 [==============================] - 8s 4ms/step - loss: 0.2812 - accuracy: 0.8961
# Epoch 10/10
# 1845/1845 [==============================] - 7s 4ms/step - loss: 0.2804 - accuracy: 0.8972

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred_prob_nn = best_model_nn.predict(X_test)
y_pred_nn = (y_pred_prob_nn > 0.5).astype(int)

accuracy_nn = accuracy_score(y_test, y_pred_nn)
precision_nn = precision_score(y_test, y_pred_nn)
recall_nn = recall_score(y_test, y_pred_nn)
f1_nn = f1_score(y_test, y_pred_nn)

print('Accuracy: %.2f' % (accuracy_nn*100))
print('Precision: %.2f' % (precision_nn*100))
print('Recall: %.2f' % (recall_nn*100))
print('F1-score: %.2f' % (f1_nn*100))
# Out:
# 308/308 [==============================] - 1s 2ms/step
# Accuracy: 89.34
# Precision: 54.09
# Recall: 21.94
# F1-score: 31.21

# %%
print("Best Parameters: ", best_params_nn)

# Evaluate the model
print(f'Test Accuracy: {accuracy_nn*100:.2f}%')
# Out:
# Best Parameters:  {'batch_size': 16, 'epochs': 10, 'hidden_units': 256}
# Test Accuracy: 89.34%

# %%
y_pred_prob_nn = best_model_nn.predict(X_test)

# Generate ROC curve and calculate AUC
fpr_nn, tpr_nn, thresholds_nn = roc_curve(y_test, y_pred_prob_nn)
auc_nn = roc_auc_score(y_test, y_pred_prob_nn)

# Plot ROC curve
plt.plot(fpr_nn, tpr_nn, label='ROC curve (AUC = {:.2f})'.format(auc_nn))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Apply thresholds
umbral = 0.5
y_pred_discret_nn = np.where(y_pred_prob_nn >= umbral, 1, 0)

# Create confusion matrix
cm_nn = confusion_matrix(y_test, y_pred_discret_nn)

# Visualize confusion matrix
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 308/308 [==============================] - 1s 2ms/step

# %% [markdown]
# ### AdaBoost (Adaptative Boosting):

# %%
# Create the base estimator
base_estimator_ab = DecisionTreeClassifier()

# Create the AdaBoost classifier
ada_boost = AdaBoostClassifier(base_estimator=base_estimator_ab)

# Define the parameter grid for AdaBoost
param_grid_ab = {
    'n_estimators': [50, 100, 200], 
    'learning_rate': [0.1, 0.5, 1.0]  
}


# Perform grid search for AdaBoost
grid_search_ab = GridSearchCV(ada_boost, param_grid_ab, cv=3, n_jobs=-1)
grid_search_ab.fit(X_train, y_train)

# Get the best AdaBoost model and its performance
best_ada_boost = grid_search_ab.best_estimator_
best_params_ab = grid_search_ab.best_params_
best_score_ab = grid_search_ab.best_score_

# Train the best AdaBoost model with all data
best_ada_boost.fit(X_train, y_train)

# Evaluate the best AdaBoost model
test_accuracy_ab = best_ada_boost.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_ab*100:.2f}%')
# Out:
# Test Accuracy: 87.61%

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_ab = best_ada_boost.predict_proba(X_test)[:, 1]
fpr_ab, tpr_ab, thresholds_ab = roc_curve(y_test, y_pred_prob_ab)
auc_ab = roc_auc_score(y_test, y_pred_prob_ab)

# Plot ROC curve
plt.plot(fpr_ab, tpr_ab, label='ROC curve (AUC = {:.2f})'.format(auc_ab))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_ab = best_ada_boost.predict(X_test)
cm_ab = confusion_matrix(y_test, y_pred_ab)

# Visualize confusion matrix
sns.heatmap(cm_ab, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### Gradient Boosting:

# %%
# Create the Gradient Boosting classifier
gradient_boosting = GradientBoostingClassifier()

# Define the parameter grid for Gradient Boosting
param_grid_gb = {
    'n_estimators': [50, 100, 200],        
    'learning_rate': [0.1, 0.5, 1.0],     
    'max_depth': [3, 4, 5]                 
}

# Perform grid search for Gradient Boosting
grid_search_gb = GridSearchCV(gradient_boosting, param_grid_gb, cv=3, n_jobs=-1)
grid_search_gb.fit(X_train, y_train)

# Get the best Gradient Boosting model and its performance
best_gradient_boosting = grid_search_gb.best_estimator_
best_params_gb = grid_search_gb.best_params_
best_score_gb = grid_search_gb.best_score_

# Train the best Gradient Boosting model with all data
best_gradient_boosting.fit(X_train, y_train)

# Evaluate the best Gradient Boosting model
test_accuracy_gb = best_gradient_boosting.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_gb*100:.2f}%')
# Out:
# Test Accuracy: 89.77%

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_gb = best_gradient_boosting.predict_proba(X_test)[:, 1]
fpr_gb, tpr_gb, thresholds_gb = roc_curve(y_test, y_pred_prob_gb)
auc_gb = roc_auc_score(y_test, y_pred_prob_gb)

# Plot ROC curve
plt.plot(fpr_gb, tpr_gb, label='ROC curve (AUC = {:.2f})'.format(auc_gb))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_gb = best_gradient_boosting.predict(X_test)
cm_gb = confusion_matrix(y_test, y_pred_gb)

# Visualize confusion matrix
sns.heatmap(cm_gb, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## Dataset unbalance problem

# %% [markdown]
# By showing the ROC curve, the AUC value and the confusion matrix, we can see that, despite having a high accuracy, there is a problem with our models.
#
# The data we have are unbalanced, since we have much more data from the "No" class than from the "Yes" class. This makes that our models do not learn well due to the unbalance.
#
# To fix it, we have different possible solutions:
#
# - **Penalize the majority class:** Since we learn more with it, by putting a penalty we could make the other class to be taken more into account. However, not all models allow us to make this modification. The logistic regression and the Random Forest implemented does allow us to do it by means of the parameter "class_weight='balanced'". Even so, these models are not the best performing, so it is not an effective measure for the whole analysis.
#
#
#
# - **Try more complex ensemble methods** that work better for these types of unbalanced datasets. One of the possible implementations is to make use of the "StackingClassifier".
#
#
#
# - **Make use of subsampling and oversampling:** That is, if we remove records from the majority class, or synthetically add records from the minority class, we can try to reduce the unbalance and make it more balanced, thus improving the results of our models.
#
#
#
# - **Analyze if there are variables that are not relevant in the dataset for most of our models and eliminate them:** By doing this, we can eliminate variables that always take similar values that are causing this unbalance and that do not contribute information to our models.

# %% [markdown]
# ### OVERSAMPLING APPROACH (and penalizing the majority class if the model allows it)

# %% [markdown]
# Let's start by applying oversampling. For this we make use of the "imblearn" library and the SMOTE (Synthetic Minority Over-sampling Technique) function.

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(k_neighbors = 5, random_state=random_seed)
X_train_os, y_train_os = smote.fit_resample(X_train, y_train)

# %%
print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (29508, 14)
# X_test shape: (9837, 14)
# y_train: (29508,)
# y_test shape: (9837,)

# %%
print("X_train shape:",X_train_os.shape)
print("X_test shape:",X_test.shape)
print("y_train:",y_train_os.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (52510, 14)
# X_test shape: (9837, 14)
# y_train: (52510,)
# y_test shape: (9837,)

# %% [markdown]
# As we can see, more records have been added to the train partitions, from 30882 to 54804 records. It should be noted that it is only applied to the training set and not to the test set to avoid bias in the evaluation of the model.
#
# In this way the model is allowed to more effectively learn the underlying characteristics of the minority classes without compromising the unbiased evaluation of the model on the test set.

# %% [markdown]
# ### We retrain the most successful models with the new train partition.

# %% [markdown]
# #### LOGISTIC REGRESSION (WITH SMOTE):
# #### Linear regression method for binary classification problems
#
# In addition, in this case we use the **penalization to the majority class, as this method allows it**

# %%
model_lr_smote = LogisticRegression(class_weight='balanced')
model_lr_smote.fit( X_train_os, y_train_os)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred_lr_os = model_lr_smote.predict(X_test)

# %%
accuracy_lr_os = accuracy_score(y_test, y_pred_lr_os)
report_lr_os = classification_report(y_test, y_pred_lr_os)
print("Accuracy:", accuracy_lr_os)
print("Classification Report:\n", report_lr_os)
# Out:
# Accuracy: 0.787231879638101
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87      8752
#            1       0.29      0.62      0.39      1085
#
#     accuracy                           0.79      9837
#    macro avg       0.62      0.71      0.63      9837
# weighted avg       0.87      0.79      0.82      9837

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_lr_os = model_lr_smote.predict_proba(X_test)[:, 1]
fpr_lr_os, tpr_lr_os, thresholds_lr_os = roc_curve(y_test, y_pred_prob_lr_os)
auc_lr_os = roc_auc_score(y_test, y_pred_prob_lr_os)

# Plot ROC curve
plt.plot(fpr_lr_os, tpr_lr_os, label='ROC curve (AUC = {:.2f})'.format(auc_lr_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_lr_os = model_lr_smote.predict(X_test)
cm_lr_smote = confusion_matrix(y_test, y_pred_lr_os)

# Visualize confusion matrix
sns.heatmap(cm_lr_smote, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
fig_cm_lr_smote = plt.gcf() 
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO LOGISTIC REGRESSION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Logistic Regression WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_lr_smote, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Logistic Regression WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# As we can see in the figure, by using oversampling and penalization, we obtain a model that classifies the minority class much better. It is true that the majority class is no longer classified as correctly as it was previously. However, we prefer the result to be the latter, since we no longer see the results of the unbalance.

# %% [markdown]
# #### KNN (WITH SMOTE):

# %%
param_grid_knn_os= {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'algorithm': ['ball_tree', 'kd_tree', 'brute']}

knn_os = KNeighborsClassifier()

# refit true, para que entrenemos con todos los datos
grid_search_knn_os = GridSearchCV(knn_os, param_grid_knn_os, cv=3, refit=True, n_jobs=-1)

grid_search_knn_os.fit(X_train_os, y_train_os)

print("Best hyperparameters:", grid_search_knn_os.best_params_)
print("Accuracy score:", grid_search_knn_os.best_score_)

best_model_knn_os = grid_search_knn_os.best_estimator_
y_pred_knn_os = best_model_knn_os.predict(X_test)
# Out:
# Best hyperparameters: {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'distance'}
# Accuracy score: 0.8657216599988796

# %%
accuracy_knn_os = accuracy_score(y_test, y_pred_knn_os)
report_knn_os = classification_report(y_test, y_pred_knn_os)
print("Best Parameters:", grid_search_knn_os.best_params_)
print("Accuracy:", accuracy_knn_os)
print("Classification Report:\n", report_knn_os)
# Out:
# Best Parameters: {'algorithm': 'kd_tree', 'n_neighbors': 3, 'weights': 'distance'}
# Accuracy: 0.8598149842431636
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      8752
#            1       0.36      0.36      0.36      1085
#
#     accuracy                           0.86      9837
#    macro avg       0.64      0.64      0.64      9837
# weighted avg       0.86      0.86      0.86      9837

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_knn_os = best_model_knn_os.predict_proba(X_test)[:, 1]
fpr_knn_os, tpr_knn_os, thresholds_knn_os = roc_curve(y_test, y_pred_prob_knn_os)
auc_knn_os = roc_auc_score(y_test, y_pred_prob_knn_os)

# Plot ROC curve
plt.plot(fpr_knn_os, tpr_knn_os, label='ROC curve (AUC = {:.2f})'.format(auc_knn_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_knn_os = best_model_knn_os.predict(X_test)
cm_knn_os = confusion_matrix(y_test, y_pred_knn_os)

# Visualize confusion matrix
sns.heatmap(cm_knn_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO KNN:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - knn WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_knn_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - knn WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### CLASSIFICATION TREES (WITH SMOTE)

# %%
param_grid_ct_os = {'max_depth': [3, 5, 7, 9, None],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

model_ct_os = DecisionTreeClassifier(random_state=random_seed)
grid_search_ct_os = GridSearchCV(model_ct, param_grid_ct_os, cv=3, n_jobs=-1)
grid_search_ct_os.fit(X_train_os, y_train_os)

best_model_ct_os = grid_search_ct_os.best_estimator_
y_pred_ct_os = best_model_ct_os.predict(X_test)

accuracy_ct_os = accuracy_score(y_test, y_pred_ct_os)
report_ct_os = classification_report(y_test, y_pred_ct_os)
print("Best Parameters:", grid_search_ct_os.best_params_)
print("Accuracy:", accuracy_ct_os)
print("Classification Report:\n", report_ct_os)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.8718105113347565
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      8752
#            1       0.40      0.31      0.35      1085
#
#     accuracy                           0.87      9837
#    macro avg       0.66      0.63      0.64      9837
# weighted avg       0.86      0.87      0.87      9837

# %%
# Generate ROC curve and calculate AUC
y_pred_prob = best_model_ct_os.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
auc = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred = best_model_ct_os.predict(X_test)
cm_ct_os = confusion_matrix(y_test, y_pred_ct_os)

# Visualize confusion matrix
sns.heatmap(cm_ct_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO CT:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_ct, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Classification Trees WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_ct_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix -  Classification Trees WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### RANDOM FOREST (WITH SMOTE):

# %%
param_grid_rf_os = {"n_estimators": [50, 100, 200],
              "max_depth": [None, 5, 10],
              "min_samples_split": [2, 5, 10],
              "min_samples_leaf": [1, 2, 4]}
rfc_os = RandomForestClassifier(random_state=random_seed, class_weight='balanced')
grid_search_rf_os = GridSearchCV(rfc_os, param_grid_rf_os, cv=3, n_jobs=-1)
grid_search_rf_os.fit(X_train_os, y_train_os)

print("Best hyperparameters:", grid_search_rf_os.best_params_)
print("Accuracy score:", grid_search_rf_os.best_score_)

best_model_rf_os = grid_search_rf_os.best_estimator_
y_pred_rf_os = best_model_rf_os.predict(X_test)

accuracy_rf_os = accuracy_score(y_test, y_pred_rf_os)
report_rf_os = classification_report(y_test, y_pred_rf_os)
print("Best Parameters:", grid_search_rf_os.best_params_)
print("Accuracy:", accuracy_rf_os)
print("Classification Report:\n", report_rf_os)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy score: 0.9164931371736987
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy: 0.8774016468435498
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      8752
#            1       0.44      0.38      0.41      1085
#
#     accuracy                           0.88      9837
#    macro avg       0.68      0.66      0.67      9837
# weighted avg       0.87      0.88      0.87      9837

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_rf_os = best_model_rf_os.predict_proba(X_test)[:, 1]
fpr_rf_os, tpr_rf_os, thresholds_rf_os = roc_curve(y_test, y_pred_prob_rf_os)
auc_rf_os = roc_auc_score(y_test, y_pred_prob_rf_os)

# Plot ROC curve
plt.plot(fpr_rf_os, tpr_rf_os, label='ROC curve (AUC = {:.2f})'.format(auc_rf_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_rf_os = best_model_rf_os.predict(X_test)
cm_rf_os = confusion_matrix(y_test, y_pred_rf_os)

# Visualize confusion matrix
sns.heatmap(cm_rf_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO RANDOM FOREST:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Random Forest WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_rf_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Random Forest WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# #### GRADIENT BOOSTING (WITH SMOTE):

# %%
# Create the Gradient Boosting classifier
gradient_boosting_smote = GradientBoostingClassifier()

# Define the parameter grid for Gradient Boosting
param_grid_gb_os = {
    'n_estimators': [50, 100, 200],        
    'learning_rate': [0.1, 0.5, 1.0],     
    'max_depth': [3, 4, 5]                 
}

# Perform grid search for Gradient Boosting
grid_search_gb_os = GridSearchCV(gradient_boosting_smote, param_grid_gb_os, cv=3, n_jobs=-1)
grid_search_gb_os.fit(X_train_os, y_train_os)

# Get the best Gradient Boosting model and its performance
best_gradient_boosting_smote = grid_search_gb_os.best_estimator_
best_params_gb_os = grid_search_gb_os.best_params_
best_score_gb_os = grid_search_gb_os.best_score_

# Train the best Gradient Boosting model with all data
best_gradient_boosting_smote.fit(X_train_os, y_train_os)

# Evaluate the best Gradient Boosting model
test_accuracy_gb_os = best_gradient_boosting_smote.score(X_test, y_test)
print(f'Test Accuracy: {test_accuracy_gb_os*100:.2f}%')
# Out:
# Test Accuracy: 88.67%

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_gb_os = best_gradient_boosting_smote.predict_proba(X_test)[:, 1]
fpr_gb_os, tpr_gb_os, thresholds_gb_os = roc_curve(y_test, y_pred_prob_gb_os)
auc_gb_os = roc_auc_score(y_test, y_pred_prob_gb_os)

# Plot ROC curve
plt.plot(fpr_gb_os, tpr_gb_os, label='ROC curve (AUC = {:.2f})'.format(auc_gb_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_gb_os = best_gradient_boosting_smote.predict(X_test)
cm_gb_smote = confusion_matrix(y_test, y_pred_gb_os)

# Visualize confusion matrix
sns.heatmap(cm_gb_smote, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO GRADIENT BOOSTING:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gráfica 1
sns.heatmap(cm_gb, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Gradient Boosting WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Gráfica 2
sns.heatmap(cm_gb_smote, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Gradient Boosting WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# As we can see in both confusion matrices, the inclusion of oversampling improves the predictions. However, the improvement obtained with Logistic regression is better than with Gradient Boosting. Therefore, although without oversampling we would choose Gradient Boosting as the best model, using oversampling we choose logistic regression as the best model between these two.

# %% [markdown]
# #### NEURAL NETWORK (WITH SMOTE):

# %%
def create_model_nn(hidden_units=128):
    model = Sequential()
    model.add(Dense(hidden_units, input_dim=X_train_os.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Define the parameter gridB
param_grid_nn_os = {
    'hidden_units': [64, 128, 256],
    'epochs': [10, 20, 30],
    'batch_size': [16, 32, 64]
}

# Create the model
model_nn_os = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn=create_model_nn)

# Perform grid search
grid_search_nn_os = GridSearchCV(model_nn_os, param_grid_nn_os, cv=3, n_jobs=-1)
grid_search_nn_os.fit(X_train_os, y_train_os)

# Get the best parameters
best_params_nn_os = grid_search_nn_os.best_params_
best_params_nn_os
# Out:
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/20
# Epoch 1/10
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5103 - accuracy: 0.7191
# 2010/2188 [==========================>...] - ETA: 1s - loss: 0.5105 - accuracy: 0.7191Epoch 2/10
# 2188/2188 [==============================] - 15s 6ms/step - loss: 0.5106 - accuracy: 0.7188
# 2092/2188 [===========================>..] - ETA: 0s - loss: 0.5605 - accuracy: 0.7138Epoch 2/20
# 2188/2188 [==============================] - 15s 6ms/step - loss: 0.5595 - accuracy: 0.7131
# 2033/2188 [==========================>...] - ETA: 0s - loss: 0.5616 - accuracy: 0.7127Epoch 2/20
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.4596 - accuracy: 0.8064
# Epoch 2/20
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.4593 - accuracy: 0.8086
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.4583 - accuracy: 0.8094
# Epoch 2/10
# Epoch 2/20
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.5103 - accuracy: 0.7191
# Epoch 2/10
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.5603 - accuracy: 0.7143
# Epoch 2/10
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4594 - accuracy: 0.8066
#  123/2188 [>.............................] - ETA: 14s - loss: 0.4978 - accuracy: 0.7307Epoch 2/10
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.5616 - accuracy: 0.7132
#   77/2188 [>.............................] - ETA: 18s - loss: 0.4351 - accuracy: 0.8166Epoch 2/20
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.5110 - accuracy: 0.7194
# 1751/2188 [=======================>......] - ETA: 3s - loss: 0.5634 - accuracy: 0.7103Epoch 2/20
# 2188/2188 [==============================] - 17s 7ms/step - loss: 0.5090 - accuracy: 0.7192
# Epoch 2/10
# 2188/2188 [==============================] - 17s 7ms/step - loss: 0.5605 - accuracy: 0.7139
# Epoch 2/10
# 2188/2188 [==============================] - 17s 7ms/step - loss: 0.5106 - accuracy: 0.7199
#  215/2188 [=>............................] - ETA: 15s - loss: 0.4528 - accuracy: 0.8084Epoch 2/20
# 2188/2188 [==============================] - 19s 7ms/step - loss: 0.4591 - accuracy: 0.8094
#  451/2188 [=====>........................] - ETA: 11s - loss: 0.4509 - accuracy: 0.8111Epoch 2/10
# 2188/2188 [==============================] - 20s 7ms/step - loss: 0.5618 - accuracy: 0.7118
#  121/2188 [>.............................] - ETA: 15s - loss: 0.4652 - accuracy: 0.8058Epoch 2/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5009 - accuracy: 0.7279
# 1833/2188 [========================>.....] - ETA: 2s - loss: 0.4489 - accuracy: 0.8143Epoch 3/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5490 - accuracy: 0.7199
# 1974/2188 [==========================>...] - ETA: 1s - loss: 0.4482 - accuracy: 0.8142Epoch 3/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4999 - accuracy: 0.7298
#  159/2188 [=>............................] - ETA: 10s - loss: 0.5501 - accuracy: 0.7193Epoch 3/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4995 - accuracy: 0.7299
#  218/2188 [=>............................] - ETA: 15s - loss: 0.4909 - accuracy: 0.7423Epoch 3/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4492 - accuracy: 0.8125
# Epoch 3/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5492 - accuracy: 0.7189
# 1805/2188 [=======================>......] - ETA: 2s - loss: 0.5011 - accuracy: 0.7276Epoch 3/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4484 - accuracy: 0.8144
# Epoch 3/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4489 - accuracy: 0.8139
# 1915/2188 [=========================>....] - ETA: 1s - loss: 0.5476 - accuracy: 0.7213Epoch 3/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5490 - accuracy: 0.7218
# 1842/2188 [========================>.....] - ETA: 2s - loss: 0.5009 - accuracy: 0.7278Epoch 3/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4486 - accuracy: 0.8141
# 2013/2188 [==========================>...] - ETA: 1s - loss: 0.5004 - accuracy: 0.7285Epoch 3/10
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.5004 - accuracy: 0.7317
# Epoch 3/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.5482 - accuracy: 0.7203
#  541/2188 [======>.......................] - ETA: 9s - loss: 0.5477 - accuracy: 0.7200Epoch 3/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4995 - accuracy: 0.7285
# Epoch 3/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4991 - accuracy: 0.7286
#  424/2188 [====>.........................] - ETA: 9s - loss: 0.4517 - accuracy: 0.8110Epoch 3/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4486 - accuracy: 0.8143
#  948/2188 [===========>..................] - ETA: 8s - loss: 0.4942 - accuracy: 0.7348Epoch 3/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5506 - accuracy: 0.7175
# Epoch 3/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4951 - accuracy: 0.7346
# 1106/2188 [==============>...............] - ETA: 6s - loss: 0.4458 - accuracy: 0.8181Epoch 4/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5414 - accuracy: 0.7243
# 1562/2188 [====================>.........] - ETA: 4s - loss: 0.5392 - accuracy: 0.7264Epoch 4/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4460 - accuracy: 0.8162
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4930 - accuracy: 0.7390
# 2160/2188 [============================>.] - ETA: 0s - loss: 0.5409 - accuracy: 0.7263Epoch 4/20
# 1727/2188 [======================>.......] - ETA: 2s - loss: 0.4918 - accuracy: 0.7394Epoch 4/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4914 - accuracy: 0.7430
# 1996/2188 [==========================>...] - ETA: 1s - loss: 0.4459 - accuracy: 0.8149Epoch 4/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5413 - accuracy: 0.7257
# 1142/2188 [==============>...............] - ETA: 7s - loss: 0.5472 - accuracy: 0.7204Epoch 4/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5411 - accuracy: 0.7259
# Epoch 4/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4463 - accuracy: 0.8142
# 2046/2188 [===========================>..] - ETA: 0s - loss: 0.4457 - accuracy: 0.8151Epoch 4/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4448 - accuracy: 0.8155
#  183/2188 [=>............................] - ETA: 14s - loss: 0.4874 - accuracy: 0.7551Epoch 4/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4458 - accuracy: 0.8159
#  280/2188 [==>...........................] - ETA: 12s - loss: 0.4520 - accuracy: 0.8096Epoch 4/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4942 - accuracy: 0.7362
# 2128/2188 [============================>.] - ETA: 0s - loss: 0.4925 - accuracy: 0.7394Epoch 4/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.5383 - accuracy: 0.7278
#  373/2188 [====>.........................] - ETA: 12s - loss: 0.5407 - accuracy: 0.7296Epoch 4/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4930 - accuracy: 0.7390
# 2173/2188 [============================>.] - ETA: 0s - loss: 0.4933 - accuracy: 0.7375Epoch 4/10
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4932 - accuracy: 0.7375
# Epoch 4/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4453 - accuracy: 0.8160
#  715/2188 [========>.....................] - ETA: 10s - loss: 0.4451 - accuracy: 0.8142Epoch 4/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5445 - accuracy: 0.7233
#  981/2188 [============>.................] - ETA: 8s - loss: 0.4364 - accuracy: 0.8186Epoch 4/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4887 - accuracy: 0.7424
# 1079/2188 [=============>................] - ETA: 6s - loss: 0.4442 - accuracy: 0.8150Epoch 5/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5327 - accuracy: 0.7298
# Epoch 5/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5337 - accuracy: 0.7296
# 1938/2188 [=========================>....] - ETA: 1s - loss: 0.4444 - accuracy: 0.8156Epoch 5/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4840 - accuracy: 0.7492
# 1623/2188 [=====================>........] - ETA: 3s - loss: 0.4837 - accuracy: 0.7476Epoch 5/10
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4831 - accuracy: 0.7520
#  256/2188 [==>...........................] - ETA: 14s - loss: 0.5303 - accuracy: 0.7295Epoch 5/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5332 - accuracy: 0.7310
#  143/2188 [>.............................] - ETA: 12s - loss: 0.5301 - accuracy: 0.7347Epoch 5/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4421 - accuracy: 0.8173
# Epoch 5/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4424 - accuracy: 0.8157
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4430 - accuracy: 0.8162
#   66/2188 [..............................] - ETA: 12s - loss: 0.5162 - accuracy: 0.7424Epoch 5/10
# Epoch 5/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4417 - accuracy: 0.8169
#   60/2188 [..............................] - ETA: 13s - loss: 0.4168 - accuracy: 0.8417Epoch 5/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4846 - accuracy: 0.7470
#  377/2188 [====>.........................] - ETA: 12s - loss: 0.4316 - accuracy: 0.8201Epoch 5/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4837 - accuracy: 0.7498
#  940/2188 [===========>..................] - ETA: 7s - loss: 0.5331 - accuracy: 0.7285Epoch 5/10
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.5284 - accuracy: 0.7333
# Epoch 5/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4422 - accuracy: 0.8172
# Epoch 5/10
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4862 - accuracy: 0.7460
#  765/2188 [=========>....................] - ETA: 7s - loss: 0.4329 - accuracy: 0.8210Epoch 5/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5384 - accuracy: 0.7290
#  456/2188 [=====>........................] - ETA: 10s - loss: 0.4710 - accuracy: 0.7570Epoch 5/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4814 - accuracy: 0.7490
# 1049/2188 [=============>................] - ETA: 7s - loss: 0.4374 - accuracy: 0.8187Epoch 6/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5247 - accuracy: 0.7345
#  961/2188 [============>.................] - ETA: 7s - loss: 0.5370 - accuracy: 0.7298Epoch 6/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4738 - accuracy: 0.7574
#  214/2188 [=>............................] - ETA: 14s - loss: 0.4736 - accuracy: 0.7538Epoch 6/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5250 - accuracy: 0.7355
# 1632/2188 [=====================>........] - ETA: 3s - loss: 0.4762 - accuracy: 0.7535Epoch 6/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4393 - accuracy: 0.8177
# 1321/2188 [=================>............] - ETA: 6s - loss: 0.4784 - accuracy: 0.7549Epoch 6/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5233 - accuracy: 0.7381
# Epoch 6/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4378 - accuracy: 0.8187
# 1469/2188 [===================>..........] - ETA: 4s - loss: 0.4756 - accuracy: 0.7563Epoch 6/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4745 - accuracy: 0.7586
# 1551/2188 [====================>.........] - ETA: 3s - loss: 0.4386 - accuracy: 0.8178Epoch 6/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4374 - accuracy: 0.8199
#  205/2188 [=>............................] - ETA: 11s - loss: 0.5169 - accuracy: 0.7460Epoch 6/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4385 - accuracy: 0.8176
# 1644/2188 [=====================>........] - ETA: 3s - loss: 0.4746 - accuracy: 0.7567Epoch 6/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4757 - accuracy: 0.7542
#  648/2188 [=======>......................] - ETA: 10s - loss: 0.4641 - accuracy: 0.7670Epoch 6/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4383 - accuracy: 0.8181
# Epoch 6/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4732 - accuracy: 0.7578
# 1058/2188 [=============>................] - ETA: 6s - loss: 0.4627 - accuracy: 0.7677Epoch 6/10
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4769 - accuracy: 0.7569
# 2147/2188 [============================>.] - ETA: 0s - loss: 0.5321 - accuracy: 0.7330Epoch 6/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5317 - accuracy: 0.7328
# Epoch 6/10
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.5176 - accuracy: 0.7387
#  903/2188 [===========>..................] - ETA: 8s - loss: 0.4709 - accuracy: 0.7634Epoch 6/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4730 - accuracy: 0.7568
# 1964/2188 [=========================>....] - ETA: 1s - loss: 0.5174 - accuracy: 0.7392Epoch 7/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5172 - accuracy: 0.7393
# Epoch 7/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5144 - accuracy: 0.7425
# 1765/2188 [=======================>......] - ETA: 2s - loss: 0.4356 - accuracy: 0.8191Epoch 7/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4636 - accuracy: 0.7676
# 1786/2188 [=======================>......] - ETA: 2s - loss: 0.4342 - accuracy: 0.8209Epoch 7/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5171 - accuracy: 0.7395
#  137/2188 [>.............................] - ETA: 15s - loss: 0.5117 - accuracy: 0.7491Epoch 7/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4350 - accuracy: 0.8199
# 1300/2188 [================>.............] - ETA: 6s - loss: 0.4668 - accuracy: 0.7647Epoch 7/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4339 - accuracy: 0.8201
# 1487/2188 [===================>..........] - ETA: 4s - loss: 0.4333 - accuracy: 0.8210Epoch 7/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4335 - accuracy: 0.8202
# Epoch 7/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4648 - accuracy: 0.7668
# 1292/2188 [================>.............] - ETA: 6s - loss: 0.5112 - accuracy: 0.7424Epoch 7/20
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4353 - accuracy: 0.8204
# Epoch 7/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4665 - accuracy: 0.7644
#  374/2188 [====>.........................] - ETA: 10s - loss: 0.4280 - accuracy: 0.8275Epoch 7/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4339 - accuracy: 0.8208
# Epoch 7/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5251 - accuracy: 0.7365
#  854/2188 [==========>...................] - ETA: 7s - loss: 0.4317 - accuracy: 0.8248Epoch 7/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4621 - accuracy: 0.7657
#  629/2188 [=======>......................] - ETA: 8s - loss: 0.4590 - accuracy: 0.7710Epoch 7/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5108 - accuracy: 0.7433
# Epoch 7/10
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4675 - accuracy: 0.7641
#   45/2188 [..............................] - ETA: 10s - loss: 0.5132 - accuracy: 0.7250Epoch 7/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5101 - accuracy: 0.7441
#  802/2188 [=========>....................] - ETA: 8s - loss: 0.4532 - accuracy: 0.7759Epoch 8/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4660 - accuracy: 0.7641
# Epoch 8/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5064 - accuracy: 0.7478
# 1821/2188 [=======================>......] - ETA: 2s - loss: 0.4320 - accuracy: 0.8223Epoch 8/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4541 - accuracy: 0.7764
# 1910/2188 [=========================>....] - ETA: 1s - loss: 0.4311 - accuracy: 0.8225Epoch 8/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4305 - accuracy: 0.8227
#  485/2188 [=====>........................] - ETA: 9s - loss: 0.5063 - accuracy: 0.7443 Epoch 8/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5100 - accuracy: 0.7453
# 2146/2188 [============================>.] - ETA: 0s - loss: 0.4323 - accuracy: 0.8208Epoch 8/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4325 - accuracy: 0.8210
# Epoch 8/10
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4300 - accuracy: 0.8229
# 1244/2188 [================>.............] - ETA: 6s - loss: 0.5011 - accuracy: 0.7489Epoch 8/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4557 - accuracy: 0.7726
#  196/2188 [=>............................] - ETA: 14s - loss: 0.4981 - accuracy: 0.7487Epoch 8/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4590 - accuracy: 0.7714
# Epoch 8/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4315 - accuracy: 0.8221
# 1510/2188 [===================>..........] - ETA: 4s - loss: 0.4344 - accuracy: 0.8202Epoch 8/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4315 - accuracy: 0.8212
#  864/2188 [==========>...................] - ETA: 9s - loss: 0.4964 - accuracy: 0.7521Epoch 8/10
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.5173 - accuracy: 0.7406
# 1348/2188 [=================>............] - ETA: 5s - loss: 0.4591 - accuracy: 0.7695Epoch 8/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4495 - accuracy: 0.7778
# 1519/2188 [===================>..........] - ETA: 4s - loss: 0.4593 - accuracy: 0.7697Epoch 8/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5019 - accuracy: 0.7483
# Epoch 8/10
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4583 - accuracy: 0.7743
# 1132/2188 [==============>...............] - ETA: 7s - loss: 0.4219 - accuracy: 0.8267Epoch 8/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5050 - accuracy: 0.7472
#  609/2188 [=======>......................] - ETA: 13s - loss: 0.5045 - accuracy: 0.7503Epoch 9/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4588 - accuracy: 0.7702
#  416/2188 [====>.........................] - ETA: 15s - loss: 0.4937 - accuracy: 0.7539Epoch 9/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4990 - accuracy: 0.7526
#  497/2188 [=====>........................] - ETA: 13s - loss: 0.4607 - accuracy: 0.7763Epoch 9/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4452 - accuracy: 0.7838
# Epoch 9/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4300 - accuracy: 0.8224
# Epoch 9/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4274 - accuracy: 0.8243
# Epoch 9/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5018 - accuracy: 0.7496
# 1186/2188 [===============>..............] - ETA: 7s - loss: 0.4444 - accuracy: 0.7821Epoch 9/10
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4266 - accuracy: 0.8243
# 2165/2188 [============================>.] - ETA: 0s - loss: 0.4471 - accuracy: 0.7821Epoch 9/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4476 - accuracy: 0.7816
#  858/2188 [==========>...................] - ETA: 9s - loss: 0.4534 - accuracy: 0.7777Epoch 9/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4276 - accuracy: 0.8235
# 1507/2188 [===================>..........] - ETA: 4s - loss: 0.4297 - accuracy: 0.8234Epoch 9/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4537 - accuracy: 0.7763
# 1230/2188 [===============>..............] - ETA: 7s - loss: 0.4913 - accuracy: 0.7572Epoch 9/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4284 - accuracy: 0.8241
# 2111/2188 [===========================>..] - ETA: 0s - loss: 0.5087 - accuracy: 0.7452Epoch 9/10
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5093 - accuracy: 0.7442
# 1525/2188 [===================>..........] - ETA: 4s - loss: 0.4488 - accuracy: 0.7797Epoch 9/10
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4414 - accuracy: 0.7840
#  981/2188 [============>.................] - ETA: 8s - loss: 0.4196 - accuracy: 0.8280Epoch 9/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4979 - accuracy: 0.7520
# Epoch 10/20
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4948 - accuracy: 0.7530
# 1159/2188 [==============>...............] - ETA: 7s - loss: 0.4236 - accuracy: 0.8241Epoch 9/10
# 2188/2188 [==============================] - 17s 8ms/step - loss: 0.4484 - accuracy: 0.7803
# Epoch 9/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4527 - accuracy: 0.7758
# 1460/2188 [===================>..........] - ETA: 4s - loss: 0.4272 - accuracy: 0.8222Epoch 10/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4914 - accuracy: 0.7552
# Epoch 10/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4274 - accuracy: 0.8244
#  323/2188 [===>..........................] - ETA: 9s - loss: 0.4435 - accuracy: 0.7841Epoch 10/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4373 - accuracy: 0.7883
# 1835/2188 [========================>.....] - ETA: 2s - loss: 0.4388 - accuracy: 0.7871Epoch 10/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4958 - accuracy: 0.7538
# 1894/2188 [========================>.....] - ETA: 1s - loss: 0.4252 - accuracy: 0.8239Epoch 10/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4252 - accuracy: 0.8242
# Epoch 10/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4387 - accuracy: 0.7869
# Epoch 10/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4234 - accuracy: 0.8251
#  726/2188 [========>.....................] - ETA: 9s - loss: 0.4403 - accuracy: 0.7819Epoch 10/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4253 - accuracy: 0.8240
# Epoch 10/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4477 - accuracy: 0.7795
#  252/2188 [==>...........................] - ETA: 14s - loss: 0.4033 - accuracy: 0.8375Epoch 10/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5026 - accuracy: 0.7494
# 1699/2188 [======================>.......] - ETA: 3s - loss: 0.4847 - accuracy: 0.7604Epoch 10/10
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4250 - accuracy: 0.8257
# 1141/2188 [==============>...............] - ETA: 6s - loss: 0.4185 - accuracy: 0.8285Epoch 10/10
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4930 - accuracy: 0.7546
#  945/2188 [===========>..................] - ETA: 8s - loss: 0.4156 - accuracy: 0.8271Epoch 11/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4325 - accuracy: 0.7926
#  480/2188 [=====>........................] - ETA: 10s - loss: 0.4939 - accuracy: 0.7514Epoch 10/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4861 - accuracy: 0.7601
#  424/2188 [====>.........................] - ETA: 13s - loss: 0.4210 - accuracy: 0.8250Epoch 10/10
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4455 - accuracy: 0.7824
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4831 - accuracy: 0.7601
# 2106/2188 [===========================>..] - ETA: 0s - loss: 0.4387 - accuracy: 0.7880Epoch 11/20
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4386 - accuracy: 0.7886
#  730/2188 [=========>....................] - ETA: 8s - loss: 0.4855 - accuracy: 0.7638Epoch 10/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4251 - accuracy: 0.8258
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4285 - accuracy: 0.7957
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4317 - accuracy: 0.7933
# 2155/2188 [============================>.] - ETA: 0s - loss: 0.4424 - accuracy: 0.7858Epoch 11/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4421 - accuracy: 0.7859
# Epoch 11/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4215 - accuracy: 0.8262
# Epoch 11/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4887 - accuracy: 0.7578
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4211 - accuracy: 0.8262
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4207 - accuracy: 0.8270
# Epoch 11/20
# 1094/1094 [==============================] - 4s 4ms/step - loss: 0.9000 - accuracy: 0.5477
# 1092/2188 [=============>................] - ETA: 5s - loss: 0.4780 - accuracy: 0.7621Epoch 1/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4959 - accuracy: 0.7536
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.7526 - accuracy: 0.5952
# 2118/2188 [============================>.] - ETA: 0s - loss: 0.4230 - accuracy: 0.8257Epoch 1/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4229 - accuracy: 0.8260
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.7624 - accuracy: 0.5790
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4872 - accuracy: 0.7604
#  894/2188 [===========>..................] - ETA: 8s - loss: 0.4165 - accuracy: 0.8292Epoch 12/20
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4924 - accuracy: 0.7736
# 1186/2188 [===============>..............] - ETA: 5s - loss: 0.4346 - accuracy: 0.7911Epoch 1/30
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9886 - accuracy: 0.5377
# 1191/2188 [===============>..............] - ETA: 5s - loss: 0.4195 - accuracy: 0.8275Epoch 1/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4785 - accuracy: 0.7639
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4235 - accuracy: 0.7980
#  997/1094 [==========================>...] - ETA: 0s - loss: 0.5468 - accuracy: 0.7413Epoch 1/30
# 1094/1094 [==============================] - 4s 3ms/step - loss: 0.5355 - accuracy: 0.7438
# 2109/2188 [===========================>..] - ETA: 0s - loss: 0.4766 - accuracy: 0.7635Epoch 1/30
# 2188/2188 [==============================] - 12s 5ms/step - loss: 0.4755 - accuracy: 0.7641
# Epoch 12/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4306 - accuracy: 0.7952
#   73/2188 [>.............................] - ETA: 12s - loss: 0.6010 - accuracy: 0.7029Epoch 11/20
# 2188/2188 [==============================] - 12s 5ms/step - loss: 0.4245 - accuracy: 0.7984
#  298/2188 [===>..........................] - ETA: 10s - loss: 0.5847 - accuracy: 0.7039Epoch 12/20
# 2188/2188 [==============================] - 12s 5ms/step - loss: 0.4357 - accuracy: 0.7905
#  924/1094 [========================>.....] - ETA: 0s - loss: 0.7612 - accuracy: 0.5522Epoch 12/20
# 1094/1094 [==============================] - 5s 4ms/step - loss: 0.7610 - accuracy: 0.5512
# 2188/2188 [==============================] - 11s 5ms/step - loss: 0.4179 - accuracy: 0.8281
# 2134/2188 [============================>.] - ETA: 0s - loss: 0.4198 - accuracy: 0.8266Epoch 12/20
#  242/2188 [==>...........................] - ETA: 10s - loss: 0.4135 - accuracy: 0.8076Epoch 1/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4198 - accuracy: 0.8265
#  469/2188 [=====>........................] - ETA: 9s - loss: 0.4286 - accuracy: 0.7978Epoch 12/20
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.5167 - accuracy: 0.7557
#  772/2188 [=========>....................] - ETA: 7s - loss: 0.5716 - accuracy: 0.7076Epoch 1/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 0.4809 - accuracy: 0.7651
# 1026/2188 [=============>................] - ETA: 6s - loss: 0.4685 - accuracy: 0.8014Epoch 13/20
# 2188/2188 [==============================] - 14s 5ms/step - loss: 0.5609 - accuracy: 0.7139
# 1327/2188 [=================>............] - ETA: 4s - loss: 0.5687 - accuracy: 0.7088Epoch 2/20
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.4597 - accuracy: 0.8068
# 1559/2188 [====================>.........] - ETA: 4s - loss: 0.4259 - accuracy: 0.7993Epoch 2/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4673 - accuracy: 0.7710
# 1714/2188 [======================>.......] - ETA: 3s - loss: 0.4253 - accuracy: 0.7993Epoch 13/20
# 2188/2188 [==============================] - 15s 6ms/step - loss: 0.5099 - accuracy: 0.7170
#  168/2188 [=>............................] - ETA: 16s - loss: 0.4599 - accuracy: 0.8088Epoch 2/30
# 2188/2188 [==============================] - 15s 6ms/step - loss: 0.5616 - accuracy: 0.7129
# 2058/2188 [===========================>..] - ETA: 0s - loss: 0.5103 - accuracy: 0.7188Epoch 2/30
# 2188/2188 [==============================] - 15s 5ms/step - loss: 0.5105 - accuracy: 0.7185
# Epoch 2/30
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.4582 - accuracy: 0.8080
# Epoch 2/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4244 - accuracy: 0.7988
#  124/2188 [>.............................] - ETA: 10s - loss: 0.4679 - accuracy: 0.7979Epoch 12/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4151 - accuracy: 0.8290
# 1511/2188 [===================>..........] - ETA: 4s - loss: 0.4761 - accuracy: 0.7656Epoch 13/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4180 - accuracy: 0.8031
# Epoch 13/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4307 - accuracy: 0.7927
#  705/2188 [========>.....................] - ETA: 8s - loss: 0.4553 - accuracy: 0.7824Epoch 13/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4173 - accuracy: 0.8281
#  201/2188 [=>............................] - ETA: 12s - loss: 0.4107 - accuracy: 0.8066Epoch 13/20
# 2188/2188 [==============================] - 16s 6ms/step - loss: 0.5616 - accuracy: 0.7131
# 1237/2188 [===============>..............] - ETA: 6s - loss: 0.4518 - accuracy: 0.8140Epoch 2/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4758 - accuracy: 0.7663
# Epoch 14/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5496 - accuracy: 0.7202
#  206/2188 [=>............................] - ETA: 11s - loss: 0.4768 - accuracy: 0.7612Epoch 3/20
# 2188/2188 [==============================] - 18s 7ms/step - loss: 0.4586 - accuracy: 0.8073
# 1078/2188 [=============>................] - ETA: 6s - loss: 0.4119 - accuracy: 0.8084Epoch 2/30
# 2188/2188 [==============================] - 12s 5ms/step - loss: 0.5504 - accuracy: 0.7182
#  820/2188 [==========>...................] - ETA: 7s - loss: 0.4706 - accuracy: 0.7649Epoch 3/30
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4502 - accuracy: 0.8149
#   88/2188 [>.............................] - ETA: 13s - loss: 0.5312 - accuracy: 0.7287Epoch 3/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4614 - accuracy: 0.7760
# 2134/2188 [============================>.] - ETA: 0s - loss: 0.5012 - accuracy: 0.7242Epoch 14/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5011 - accuracy: 0.7247
#  999/2188 [============>.................] - ETA: 6s - loss: 0.4711 - accuracy: 0.7638Epoch 3/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4995 - accuracy: 0.7299
# Epoch 3/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4491 - accuracy: 0.8148
#  323/2188 [===>..........................] - ETA: 10s - loss: 0.4519 - accuracy: 0.8139Epoch 3/30
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4149 - accuracy: 0.8040
#  546/2188 [======>.......................] - ETA: 8s - loss: 0.4972 - accuracy: 0.7329Epoch 13/20
# 2188/2188 [==============================] - 12s 6ms/step - loss: 0.4142 - accuracy: 0.8287
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4261 - accuracy: 0.7963
#  553/2188 [======>.......................] - ETA: 8s - loss: 0.4974 - accuracy: 0.7335Epoch 14/20
# Epoch 14/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4106 - accuracy: 0.8083
# Epoch 14/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4136 - accuracy: 0.8304
# 1899/2188 [=========================>....] - ETA: 1s - loss: 0.4680 - accuracy: 0.7683Epoch 14/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4687 - accuracy: 0.7685
#  379/2188 [====>.........................] - ETA: 10s - loss: 0.4098 - accuracy: 0.8318Epoch 15/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5500 - accuracy: 0.7185
# 1308/2188 [================>.............] - ETA: 5s - loss: 0.4432 - accuracy: 0.8183Epoch 3/30
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.5417 - accuracy: 0.7239
# 1660/2188 [=====================>........] - ETA: 3s - loss: 0.4431 - accuracy: 0.8177Epoch 4/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4491 - accuracy: 0.8140
# 1821/2188 [=======================>......] - ETA: 2s - loss: 0.4961 - accuracy: 0.7306Epoch 3/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5416 - accuracy: 0.7231
# Epoch 4/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4452 - accuracy: 0.8156
# 1064/2188 [=============>................] - ETA: 6s - loss: 0.4602 - accuracy: 0.7770Epoch 4/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4546 - accuracy: 0.7806
# Epoch 15/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4956 - accuracy: 0.7312
#  475/2188 [=====>........................] - ETA: 12s - loss: 0.5324 - accuracy: 0.7343Epoch 4/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4937 - accuracy: 0.7361
#  503/2188 [=====>........................] - ETA: 11s - loss: 0.4448 - accuracy: 0.8165Epoch 4/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4454 - accuracy: 0.8166
# Epoch 4/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4214 - accuracy: 0.7985
#  885/2188 [===========>..................] - ETA: 8s - loss: 0.4433 - accuracy: 0.8184Epoch 15/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4128 - accuracy: 0.8297
# Epoch 15/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4068 - accuracy: 0.8097
# 2147/2188 [============================>.] - ETA: 0s - loss: 0.4044 - accuracy: 0.8145Epoch 14/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4101 - accuracy: 0.8307
# Epoch 15/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4045 - accuracy: 0.8143
# 1884/2188 [========================>.....] - ETA: 1s - loss: 0.4629 - accuracy: 0.7755Epoch 15/20
# 2188/2188 [==============================] - 12s 6ms/step - loss: 0.4641 - accuracy: 0.7742
# 1077/2188 [=============>................] - ETA: 6s - loss: 0.4391 - accuracy: 0.8189Epoch 16/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5417 - accuracy: 0.7233
# 1373/2188 [=================>............] - ETA: 4s - loss: 0.5353 - accuracy: 0.7291Epoch 4/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5313 - accuracy: 0.7319
# 1598/2188 [====================>.........] - ETA: 3s - loss: 0.4890 - accuracy: 0.7454Epoch 5/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5323 - accuracy: 0.7304
#  892/2188 [===========>..................] - ETA: 7s - loss: 0.4523 - accuracy: 0.7789Epoch 5/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4456 - accuracy: 0.8161
# 1148/2188 [==============>...............] - ETA: 6s - loss: 0.3963 - accuracy: 0.8187Epoch 4/30
# 2188/2188 [==============================] - 12s 6ms/step - loss: 0.4482 - accuracy: 0.7828
# Epoch 16/20
# 2188/2188 [==============================] - 12s 6ms/step - loss: 0.4891 - accuracy: 0.7393
# Epoch 5/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4418 - accuracy: 0.8175
#  335/2188 [===>..........................] - ETA: 7s - loss: 0.4585 - accuracy: 0.8088Epoch 5/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4876 - accuracy: 0.7458
# Epoch 5/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4424 - accuracy: 0.8175
# Epoch 5/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4174 - accuracy: 0.8039
# 1854/2188 [========================>.....] - ETA: 2s - loss: 0.3989 - accuracy: 0.8165Epoch 16/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4099 - accuracy: 0.8304
# Epoch 16/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4080 - accuracy: 0.8318
# 2034/2188 [==========================>...] - ETA: 1s - loss: 0.3995 - accuracy: 0.8141Epoch 16/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.3990 - accuracy: 0.8141
# Epoch 15/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.3994 - accuracy: 0.8155
# 2070/2188 [===========================>..] - ETA: 0s - loss: 0.4590 - accuracy: 0.7761Epoch 16/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4588 - accuracy: 0.7761
# Epoch 17/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5321 - accuracy: 0.7307
# Epoch 5/30
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9824 - accuracy: 0.5265
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5220 - accuracy: 0.7355
# 1316/2188 [=================>............] - ETA: 5s - loss: 0.4113 - accuracy: 0.8060Epoch 6/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5246 - accuracy: 0.7335
#  860/2188 [==========>...................] - ETA: 7s - loss: 0.4500 - accuracy: 0.7809Epoch 6/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4414 - accuracy: 0.8171
# 1480/2188 [===================>..........] - ETA: 4s - loss: 0.4145 - accuracy: 0.8044Epoch 5/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4829 - accuracy: 0.7483
# 1840/2188 [========================>.....] - ETA: 2s - loss: 0.4805 - accuracy: 0.7543Epoch 6/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4425 - accuracy: 0.7879
#  286/2188 [==>...........................] - ETA: 11s - loss: 0.5238 - accuracy: 0.7343Epoch 17/20
# 1025/2188 [=============>................] - ETA: 7s - loss: 0.5237 - accuracy: 0.7351Epoch 1/30
# 2188/2188 [==============================] - 12s 6ms/step - loss: 0.4782 - accuracy: 0.7564
#  273/2188 [==>...........................] - ETA: 13s - loss: 0.4473 - accuracy: 0.8136Epoch 6/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4383 - accuracy: 0.8193
# Epoch 6/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4124 - accuracy: 0.8064
#  413/2188 [====>.........................] - ETA: 10s - loss: 0.4727 - accuracy: 0.7610Epoch 17/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4396 - accuracy: 0.8183
# Epoch 6/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4059 - accuracy: 0.8331
#  672/2188 [========>.....................] - ETA: 9s - loss: 0.4410 - accuracy: 0.7901Epoch 17/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4091 - accuracy: 0.8313
# Epoch 17/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.3938 - accuracy: 0.8203
# Epoch 17/20
# 2188/2188 [==============================] - 12s 5ms/step - loss: 0.4531 - accuracy: 0.7788
#   30/2188 [..............................] - ETA: 7s - loss: 0.3807 - accuracy: 0.8229Epoch 18/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.3919 - accuracy: 0.8206
# Epoch 16/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5226 - accuracy: 0.7357
# 1536/2188 [====================>.........] - ETA: 3s - loss: 0.5176 - accuracy: 0.7382Epoch 6/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5159 - accuracy: 0.7401
# 1028/2188 [=============>................] - ETA: 6s - loss: 0.4462 - accuracy: 0.7870Epoch 7/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5138 - accuracy: 0.7419
#  710/2188 [========>.....................] - ETA: 10s - loss: 0.3773 - accuracy: 0.8297Epoch 7/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4751 - accuracy: 0.7558
#   82/2188 [>.............................] - ETA: 15s - loss: 0.5026 - accuracy: 0.7439Epoch 7/30
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4368 - accuracy: 0.8198
# 1081/2188 [=============>................] - ETA: 8s - loss: 0.3906 - accuracy: 0.8214Epoch 6/30
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4367 - accuracy: 0.7903
# 1358/2188 [=================>............] - ETA: 5s - loss: 0.4477 - accuracy: 0.7864Epoch 18/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4697 - accuracy: 0.7633
# 1695/2188 [======================>.......] - ETA: 3s - loss: 0.4046 - accuracy: 0.8311Epoch 7/30
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4345 - accuracy: 0.8214
# 1840/2188 [========================>.....] - ETA: 2s - loss: 0.4083 - accuracy: 0.8085Epoch 7/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4358 - accuracy: 0.8191
#  959/2188 [============>.................] - ETA: 7s - loss: 0.5156 - accuracy: 0.7376Epoch 7/30
# 2188/2188 [==============================] - 18s 7ms/step - loss: 0.5096 - accuracy: 0.7173
#   80/2188 [>.............................] - ETA: 13s - loss: 0.4478 - accuracy: 0.8086Epoch 2/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4067 - accuracy: 0.8309
#  782/2188 [=========>....................] - ETA: 8s - loss: 0.4348 - accuracy: 0.8222Epoch 18/20
# 2188/2188 [==============================] - 16s 7ms/step - loss: 0.4072 - accuracy: 0.8089
# Epoch 18/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4477 - accuracy: 0.7862
#  961/2188 [============>.................] - ETA: 8s - loss: 0.5022 - accuracy: 0.7486Epoch 19/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4038 - accuracy: 0.8339
#   28/2188 [..............................] - ETA: 8s - loss: 0.4664 - accuracy: 0.7589Epoch 18/20
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.5138 - accuracy: 0.7436
# 1220/2188 [===============>..............] - ETA: 6s - loss: 0.5056 - accuracy: 0.7465Epoch 7/30
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.3880 - accuracy: 0.8222
#  877/2188 [===========>..................] - ETA: 8s - loss: 0.4646 - accuracy: 0.7690Epoch 18/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.3853 - accuracy: 0.8253
# 1294/2188 [================>.............] - ETA: 5s - loss: 0.4319 - accuracy: 0.8232Epoch 17/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5090 - accuracy: 0.7420
# 1205/2188 [===============>..............] - ETA: 6s - loss: 0.4009 - accuracy: 0.8363Epoch 8/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4674 - accuracy: 0.7628
# 2133/2188 [============================>.] - ETA: 0s - loss: 0.4328 - accuracy: 0.8224Epoch 8/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4325 - accuracy: 0.8223
# 2028/2188 [==========================>...] - ETA: 1s - loss: 0.4312 - accuracy: 0.7954Epoch 7/30
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.5055 - accuracy: 0.7454
# 1474/2188 [===================>..........] - ETA: 4s - loss: 0.4032 - accuracy: 0.8346Epoch 8/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4303 - accuracy: 0.7962
# Epoch 19/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4610 - accuracy: 0.7696
#  305/2188 [===>..........................] - ETA: 13s - loss: 0.4983 - accuracy: 0.7549Epoch 8/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4325 - accuracy: 0.8199
# 1899/2188 [=========================>....] - ETA: 1s - loss: 0.4440 - accuracy: 0.7840Epoch 8/30
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4316 - accuracy: 0.8227
# 1550/2188 [====================>.........] - ETA: 4s - loss: 0.3857 - accuracy: 0.8248Epoch 8/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4428 - accuracy: 0.7848
#  761/2188 [=========>....................] - ETA: 9s - loss: 0.4574 - accuracy: 0.7667Epoch 20/20
# 2188/2188 [==============================] - 14s 7ms/step - loss: 0.4045 - accuracy: 0.8328
# Epoch 19/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4009 - accuracy: 0.8351
#  305/2188 [===>..........................] - ETA: 12s - loss: 0.4227 - accuracy: 0.8227Epoch 19/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4986 - accuracy: 0.7304
#  120/2188 [>.............................] - ETA: 13s - loss: 0.4023 - accuracy: 0.8307Epoch 3/30
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4026 - accuracy: 0.8112
# 2043/2188 [===========================>..] - ETA: 0s - loss: 0.3792 - accuracy: 0.8281Epoch 19/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5065 - accuracy: 0.7465
#  780/2188 [=========>....................] - ETA: 8s - loss: 0.4542 - accuracy: 0.7776Epoch 8/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.3827 - accuracy: 0.8264
# Epoch 19/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.3786 - accuracy: 0.8285
#  899/2188 [===========>..................] - ETA: 7s - loss: 0.4530 - accuracy: 0.7781Epoch 18/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.5022 - accuracy: 0.7465
# 1924/2188 [=========================>....] - ETA: 1s - loss: 0.4254 - accuracy: 0.7981Epoch 9/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4595 - accuracy: 0.7686
# Epoch 9/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4248 - accuracy: 0.7986
# 1852/2188 [========================>.....] - ETA: 2s - loss: 0.4521 - accuracy: 0.7796Epoch 20/20
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4987 - accuracy: 0.7506
# Epoch 9/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4293 - accuracy: 0.8227
#  384/2188 [====>.........................] - ETA: 12s - loss: 0.4984 - accuracy: 0.7477Epoch 8/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4513 - accuracy: 0.7790
# 1588/2188 [====================>.........] - ETA: 3s - loss: 0.4945 - accuracy: 0.7330Epoch 9/30
# 2188/2188 [==============================] - 14s 6ms/step - loss: 0.4299 - accuracy: 0.8208
# 1971/2188 [==========================>...] - ETA: 1s - loss: 0.4290 - accuracy: 0.8237Epoch 9/30
# 2188/2188 [==============================] - 13s 6ms/step - loss: 0.4025 - accuracy: 0.8334
#  592/2188 [=======>......................] - ETA: 9s - loss: 0.4262 - accuracy: 0.8253Epoch 20/20
# 2188/2188 [==============================] - 15s 7ms/step - loss: 0.4284 - accuracy: 0.8237
# 1837/2188 [========================>.....] - ETA: 2s - loss: 0.3980 - accuracy: 0.8159Epoch 9/20
# ...
# Epoch 18/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4008 - accuracy: 0.8325
# 181/547 [========>.....................] - ETA: 1s - loss: 0.4328 - accuracy: 0.7975Epoch 20/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4235 - accuracy: 0.8257
# Epoch 11/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3876 - accuracy: 0.8241
# Epoch 22/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4487 - accuracy: 0.7846
# 400/547 [====================>.........] - ETA: 0s - loss: 0.4323 - accuracy: 0.7966Epoch 24/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4040 - accuracy: 0.8305
# 203/547 [==========>...................] - ETA: 1s - loss: 0.3781 - accuracy: 0.8289Epoch 24/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.4640 - accuracy: 0.7758
# 490/547 [=========================>....] - ETA: 0s - loss: 0.4339 - accuracy: 0.7952Epoch 14/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4341 - accuracy: 0.7955
# 293/547 [===============>..............] - ETA: 1s - loss: 0.4161 - accuracy: 0.8278Epoch 21/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3985 - accuracy: 0.8345
# Epoch 21/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3920 - accuracy: 0.8233
# 375/547 [===================>..........] - ETA: 0s - loss: 0.4394 - accuracy: 0.7917Epoch 19/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3837 - accuracy: 0.8261
# 496/547 [==========================>...] - ETA: 0s - loss: 0.4197 - accuracy: 0.8259Epoch 23/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4199 - accuracy: 0.8260
# Epoch 12/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4451 - accuracy: 0.7892
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4015 - accuracy: 0.8317
# Epoch 25/30
# 157/547 [=======>......................] - ETA: 1s - loss: 0.3822 - accuracy: 0.8249Epoch 25/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4613 - accuracy: 0.7760
# Epoch 15/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4284 - accuracy: 0.7979
# 292/547 [===============>..............] - ETA: 1s - loss: 0.3839 - accuracy: 0.8259Epoch 22/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3961 - accuracy: 0.8353
# Epoch 22/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3810 - accuracy: 0.8290
# Epoch 24/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3880 - accuracy: 0.8249
# 261/547 [=============>................] - ETA: 1s - loss: 0.4253 - accuracy: 0.8024Epoch 20/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4411 - accuracy: 0.7898
# Epoch 26/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4172 - accuracy: 0.8275
# Epoch 13/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4004 - accuracy: 0.8340
# Epoch 26/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4256 - accuracy: 0.8002
# Epoch 23/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4518 - accuracy: 0.7826
# Epoch 16/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3941 - accuracy: 0.8357
# Epoch 23/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4401 - accuracy: 0.7894
# 193/547 [=========>....................] - ETA: 1s - loss: 0.4402 - accuracy: 0.7891Epoch 27/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3983 - accuracy: 0.8347
# Epoch 27/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3773 - accuracy: 0.8300
# Epoch 25/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3832 - accuracy: 0.8289
# Epoch 21/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4139 - accuracy: 0.8288
#  74/547 [===>..........................] - ETA: 2s - loss: 0.3550 - accuracy: 0.8478Epoch 14/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4205 - accuracy: 0.8012
# 233/547 [===========>..................] - ETA: 1s - loss: 0.3762 - accuracy: 0.8328Epoch 24/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3913 - accuracy: 0.8365
# 469/547 [========================>.....] - ETA: 0s - loss: 0.4363 - accuracy: 0.7941Epoch 24/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4473 - accuracy: 0.7845
# Epoch 17/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4372 - accuracy: 0.7934
#  63/547 [==>...........................] - ETA: 1s - loss: 0.3827 - accuracy: 0.8368Epoch 28/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3970 - accuracy: 0.8344
# Epoch 28/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3734 - accuracy: 0.8340
# 461/547 [========================>.....] - ETA: 0s - loss: 0.4088 - accuracy: 0.8328Epoch 26/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3774 - accuracy: 0.8334
# Epoch 22/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4105 - accuracy: 0.8312
# Epoch 15/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4180 - accuracy: 0.8065
# Epoch 25/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3892 - accuracy: 0.8387
# Epoch 25/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4350 - accuracy: 0.7958
# Epoch 29/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4399 - accuracy: 0.7913
# Epoch 18/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3952 - accuracy: 0.8343
#  85/547 [===>..........................] - ETA: 2s - loss: 0.4276 - accuracy: 0.7939Epoch 29/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3685 - accuracy: 0.8380
# Epoch 27/30
# 547/547 [==============================] - 3s 6ms/step - loss: 0.3718 - accuracy: 0.8341
# Epoch 23/30
# 547/547 [==============================] - 3s 6ms/step - loss: 0.4073 - accuracy: 0.8321
# Epoch 16/30
# 547/547 [==============================] - 3s 6ms/step - loss: 0.4128 - accuracy: 0.8070
# Epoch 26/30
# 547/547 [==============================] - 3s 6ms/step - loss: 0.3874 - accuracy: 0.8378
# 249/547 [============>.................] - ETA: 1s - loss: 0.3695 - accuracy: 0.8365Epoch 26/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4304 - accuracy: 0.7980
# Epoch 30/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3927 - accuracy: 0.8358
# Epoch 30/30
# 547/547 [==============================] - 3s 6ms/step - loss: 0.4354 - accuracy: 0.7917
# 168/547 [========>.....................] - ETA: 1s - loss: 0.3804 - accuracy: 0.8406Epoch 19/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3686 - accuracy: 0.8353
# Epoch 28/30
# 547/547 [==============================] - 3s 6ms/step - loss: 0.3686 - accuracy: 0.8367
# Epoch 24/30
# 547/547 [==============================] - 3s 6ms/step - loss: 0.4057 - accuracy: 0.8325
# 256/547 [=============>................] - ETA: 1s - loss: 0.4361 - accuracy: 0.7911Epoch 17/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3852 - accuracy: 0.8388
# Epoch 27/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4272 - accuracy: 0.7995
# 547/547 [==============================] - 3s 6ms/step - loss: 0.4091 - accuracy: 0.8090
# Epoch 27/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3920 - accuracy: 0.8362
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3637 - accuracy: 0.8393
#   1/274 [..............................] - ETA: 1:07 - loss: 0.9848 - accuracy: 0.5312Epoch 29/30
# 547/547 [==============================] - 3s 6ms/step - loss: 0.4294 - accuracy: 0.7949
# Epoch 20/30
# 274/274 [==============================] - 1s 3ms/step - loss: 0.4931 - accuracy: 0.7628
# 274/274 [==============================] - 1s 2ms/step - loss: 0.9851 - accuracy: 0.5233
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3635 - accuracy: 0.8405
# 410/547 [=====================>........] - ETA: 0s - loss: 0.4028 - accuracy: 0.8338Epoch 25/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3837 - accuracy: 0.8398
# Epoch 28/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4039 - accuracy: 0.8135
# Epoch 28/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4035 - accuracy: 0.8335
# Epoch 18/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3614 - accuracy: 0.8400
# Epoch 30/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4241 - accuracy: 0.7995
# Epoch 21/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3624 - accuracy: 0.8389
# Epoch 26/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3824 - accuracy: 0.8412
# Epoch 29/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4021 - accuracy: 0.8140
# Epoch 29/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4002 - accuracy: 0.8352
# Epoch 19/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3579 - accuracy: 0.8414
# 274/274 [==============================] - 1s 3ms/step - loss: 0.7744 - accuracy: 0.5902
# 547/547 [==============================] - 3s 6ms/step - loss: 0.4183 - accuracy: 0.8007
# Epoch 22/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3785 - accuracy: 0.8425
# Epoch 30/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3572 - accuracy: 0.8427
# 534/547 [============================>.] - ETA: 0s - loss: 0.3968 - accuracy: 0.8170Epoch 27/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3972 - accuracy: 0.8165
# Epoch 30/30
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3975 - accuracy: 0.8354
# 226/547 [===========>..................] - ETA: 1s - loss: 0.4146 - accuracy: 0.8076Epoch 20/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3779 - accuracy: 0.8439
# 547/547 [==============================] - 3s 5ms/step - loss: 0.4148 - accuracy: 0.8048
# Epoch 23/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3959 - accuracy: 0.8170
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3517 - accuracy: 0.8457
# Epoch 28/30
# 274/274 [==============================] - 1s 3ms/step - loss: 0.8685 - accuracy: 0.5697
# 547/547 [==============================] - 3s 5ms/step - loss: 0.3959 - accuracy: 0.8364
# Epoch 21/30
# 274/274 [==============================] - 1s 3ms/step - loss: 0.4634 - accuracy: 0.7852
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4087 - accuracy: 0.8087
# Epoch 24/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3475 - accuracy: 0.8481
# Epoch 29/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3910 - accuracy: 0.8378
# Epoch 22/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.4050 - accuracy: 0.8082
# Epoch 25/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3443 - accuracy: 0.8493
# Epoch 30/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3904 - accuracy: 0.8379
# Epoch 23/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3991 - accuracy: 0.8125
# Epoch 26/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3424 - accuracy: 0.8501
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3870 - accuracy: 0.8392
# Epoch 24/30
# 274/274 [==============================] - 1s 3ms/step - loss: 0.7688 - accuracy: 0.6136
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3963 - accuracy: 0.8152
# Epoch 27/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3835 - accuracy: 0.8409
# Epoch 25/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3900 - accuracy: 0.8181
# Epoch 28/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3816 - accuracy: 0.8417
# Epoch 26/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3872 - accuracy: 0.8204
# Epoch 29/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3791 - accuracy: 0.8424
# Epoch 27/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3830 - accuracy: 0.8225
# Epoch 30/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3773 - accuracy: 0.8426
# Epoch 28/30
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3792 - accuracy: 0.8241
# 547/547 [==============================] - 2s 4ms/step - loss: 0.3749 - accuracy: 0.8438
# Epoch 29/30
# 274/274 [==============================] - 1s 3ms/step - loss: 0.4595 - accuracy: 0.7810
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3707 - accuracy: 0.8441
# Epoch 30/30
# 547/547 [==============================] - 2s 5ms/step - loss: 0.3702 - accuracy: 0.8463
# 274/274 [==============================] - 1s 3ms/step - loss: 0.9335 - accuracy: 0.5357
# Epoch 1/30
# 1641/1641 [==============================] - 8s 4ms/step - loss: 0.5606 - accuracy: 0.7220
# Epoch 2/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.5484 - accuracy: 0.7298
# Epoch 3/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.5395 - accuracy: 0.7357
# Epoch 4/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.5284 - accuracy: 0.7434
# Epoch 5/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.5187 - accuracy: 0.7500
# Epoch 6/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.5105 - accuracy: 0.7531
# Epoch 7/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.5020 - accuracy: 0.7575
# Epoch 8/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4949 - accuracy: 0.7621
# Epoch 9/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4857 - accuracy: 0.7666
# Epoch 10/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4778 - accuracy: 0.7686
# Epoch 11/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4699 - accuracy: 0.7752
# Epoch 12/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4626 - accuracy: 0.7785
# Epoch 13/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4557 - accuracy: 0.7816
# Epoch 14/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4478 - accuracy: 0.7859
# Epoch 15/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4406 - accuracy: 0.7912
# Epoch 16/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4340 - accuracy: 0.7949
# Epoch 17/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4284 - accuracy: 0.7964
# Epoch 18/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4222 - accuracy: 0.8014
# Epoch 19/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4175 - accuracy: 0.8030
# Epoch 20/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4114 - accuracy: 0.8072
# Epoch 21/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4065 - accuracy: 0.8088
# Epoch 22/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.4018 - accuracy: 0.8124
# Epoch 23/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.3969 - accuracy: 0.8155
# Epoch 24/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.3949 - accuracy: 0.8172
# Epoch 25/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.3904 - accuracy: 0.8163
# Epoch 26/30
# 1641/1641 [==============================] - 6s 4ms/step - loss: 0.3850 - accuracy: 0.8204
# Epoch 27/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.3817 - accuracy: 0.8221
# Epoch 28/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.3782 - accuracy: 0.8243
# Epoch 29/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.3739 - accuracy: 0.8260
# Epoch 30/30
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.3733 - accuracy: 0.8276
# {'batch_size': 32, 'epochs': 30, 'hidden_units': 128}

# %%
best_model_nn_os = create_model_nn(best_params_nn_os['hidden_units'])
best_model_nn_os.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
best_model_nn_os.fit(X_train, y_train, epochs=best_params_nn_os['epochs'], batch_size=best_params_nn_os['batch_size'])
# Out:
# Epoch 1/30
# 923/923 [==============================] - 5s 4ms/step - loss: 0.2986 - accuracy: 0.8904
# Epoch 2/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2866 - accuracy: 0.8958
# Epoch 3/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2853 - accuracy: 0.8951
# Epoch 4/30
# 191/923 [=====>........................] - ETA: 2s - loss: 0.2854 - accuracy: 0.8958
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2841 - accuracy: 0.8965
# Epoch 5/30
# 540/923 [================>.............] - ETA: 1s - loss: 0.2795 - accuracy: 0.8980
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 872/923 [===========================>..] - ETA: 0s - loss: 0.2810 - accuracy: 0.8973
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2834 - accuracy: 0.8965
# Epoch 6/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2827 - accuracy: 0.8962
# Epoch 7/30
#  17/923 [..............................] - ETA: 2s - loss: 0.3239 - accuracy: 0.8805
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 307/923 [========>.....................] - ETA: 2s - loss: 0.2909 - accuracy: 0.8922
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2822 - accuracy: 0.8962
# Epoch 8/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2817 - accuracy: 0.8963
# Epoch 9/30
# 491/923 [==============>...............] - ETA: 1s - loss: 0.2839 - accuracy: 0.8934
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 3s 4ms/step - loss: 0.2804 - accuracy: 0.8964
# Epoch 10/30
# 211/923 [=====>........................] - ETA: 2s - loss: 0.2787 - accuracy: 0.8983
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 704/923 [=====================>........] - ETA: 0s - loss: 0.2734 - accuracy: 0.8991
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 3s 4ms/step - loss: 0.2795 - accuracy: 0.8963
# Epoch 11/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2785 - accuracy: 0.8974
# Epoch 12/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2776 - accuracy: 0.8984
# Epoch 13/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2768 - accuracy: 0.8969
# Epoch 14/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2762 - accuracy: 0.8976
# Epoch 15/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2753 - accuracy: 0.8988
# Epoch 16/30
# 456/923 [=============>................] - ETA: 1s - loss: 0.2722 - accuracy: 0.8983
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 698/923 [=====================>........] - ETA: 0s - loss: 0.2755 - accuracy: 0.8967
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2743 - accuracy: 0.8985
# Epoch 17/30
# 892/923 [===========================>..] - ETA: 0s - loss: 0.2729 - accuracy: 0.8996
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2735 - accuracy: 0.8993
# Epoch 18/30
# 844/923 [==========================>...] - ETA: 0s - loss: 0.2734 - accuracy: 0.8980
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2734 - accuracy: 0.8978
# Epoch 19/30
# 232/923 [======>.......................] - ETA: 2s - loss: 0.2659 - accuracy: 0.9030
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2730 - accuracy: 0.8988
# Epoch 20/30
# 861/923 [==========================>...] - ETA: 0s - loss: 0.2714 - accuracy: 0.9010
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2724 - accuracy: 0.9005
# Epoch 21/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2716 - accuracy: 0.8996
# Epoch 22/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2717 - accuracy: 0.9003
# Epoch 23/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2713 - accuracy: 0.9001
# Epoch 24/30
#  82/923 [=>............................] - ETA: 3s - loss: 0.2550 - accuracy: 0.9089
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2704 - accuracy: 0.9005
# Epoch 25/30
# 612/923 [==================>...........] - ETA: 1s - loss: 0.2684 - accuracy: 0.9027
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2695 - accuracy: 0.9016
# Epoch 26/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2694 - accuracy: 0.9011
# Epoch 27/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2690 - accuracy: 0.9014
# Epoch 28/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2680 - accuracy: 0.9021
# Epoch 29/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2684 - accuracy: 0.9023
# Epoch 30/30
# 923/923 [==============================] - 4s 4ms/step - loss: 0.2674 - accuracy: 0.9021

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred_prob_nn_os = best_model_nn_os.predict(X_test)
y_pred_nn_os = (y_pred_prob_nn_os > 0.5).astype(int)

accuracy_nn_os = accuracy_score(y_test, y_pred_nn_os)
precision_nn_os = precision_score(y_test, y_pred_nn_os)
recall_nn_os = recall_score(y_test, y_pred_nn_os)
f1_nn_os = f1_score(y_test, y_pred_nn_os)

print('Accuracy: %.2f' % (accuracy_nn_os*100))
print('Precision: %.2f' % (precision_nn_os*100))
print('Recall: %.2f' % (recall_nn_os*100))
print('F1-score: %.2f' % (f1_nn_os*100))
# Out:
# 308/308 [==============================] - 1s 2ms/step
# Accuracy: 89.46
# Precision: 55.97
# Recall: 20.74
# F1-score: 30.26

# %%
print("Best Parameters: ", best_params_nn_os)

# Evaluate the model
print(f'Test Accuracy: {accuracy_nn_os*100:.2f}%')
# Out:
# Best Parameters:  {'batch_size': 32, 'epochs': 30, 'hidden_units': 128}
# Test Accuracy: 89.46%

# %%
y_pred_prob_nn_os = best_model_nn_os.predict(X_test)

fpr_nn_os, tpr_nn_os, thresholds_nn_os = roc_curve(y_test, y_pred_prob_nn_os)
auc_nn_os = roc_auc_score(y_test, y_pred_prob_nn_os)

plt.plot(fpr_nn_os, tpr_nn_os, label='ROC curve (AUC = {:.2f})'.format(auc_nn_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()


umbral = 0.5
y_pred_discret_nn_os = np.where(y_pred_prob_nn_os >= umbral, 1, 0)

cm_nn_os = confusion_matrix(y_test, y_pred_discret_nn_os)

sns.heatmap(cm_nn_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 308/308 [==============================] - 1s 2ms/step

# %% [markdown]
# #### COMPARISON OF THE CONFUSION MATRIX WITH THE 2 APPROACHES TO GRADIENT NEURAL NETWORK:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Graph 1
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - NN WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Graph 2
sns.heatmap(cm_nn_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - NN WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# ### Stacked Generalization Ensemble

# %% [markdown]
# In order to solve the problem of the unbalanced dataset, we can also use different algorithms, as I stated before. One of the ones that behaves better is the Stacked Generalization Ensemble. For this algorithm, we will evaluate it with and without oversampling to analyse the impact of both solutions independently:

# %%
import pandas as pd
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier


# Define base classifiers
rf_classifier = RandomForestClassifier(random_state=random_seed)
lr_classifier = LogisticRegression(random_state=random_seed)
knn_classifier = KNeighborsClassifier()

# Define the StackingClassifier
estimators = [
    ('rf', rf_classifier),
    ('lr', lr_classifier),
    ('knn', knn_classifier)
]

stacking_classifier = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())

# Define params grid
param_grid_sc = {
    'rf__n_estimators': [100, 200, 300],
    'knn__n_neighbors': [3, 5, 7],
    'final_estimator__C': [0.1, 1, 10]
}

# Hiperparms search using GridSearchCV
grid_search_sc = GridSearchCV(stacking_classifier, param_grid_sc, cv=3, n_jobs=-1)
grid_search_sc.fit(X_train, y_train)

# Get the best params
best_params_sc = grid_search_sc.best_params_
print("Mejores parámetros:", best_params_sc)

# Use the best model to predict
best_model_sc = grid_search_sc.best_estimator_
y_pred_sc = best_model_sc.predict(X_test)

# Get the accuracy
accuracy_sc = accuracy_score(y_test, y_pred_sc)
print("Precisión:", accuracy_sc)
# Out:
# Mejores parámetros: {'final_estimator__C': 10, 'knn__n_neighbors': 3, 'rf__n_estimators': 300}
# Precisión: 0.8953949374809393

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_sc = best_model_sc.predict_proba(X_test)[:, 1]
fpr_sc, tpr_sc, thresholds_sc = roc_curve(y_test, y_pred_prob_sc)
auc_sc = roc_auc_score(y_test, y_pred_prob_sc)

# Plot ROC curve
plt.plot(fpr_sc, tpr_sc, label='ROC curve (AUC = {:.2f})'.format(auc_sc))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_sc = best_model_sc.predict(X_test)
cm_sc = confusion_matrix(y_test, y_pred_sc)

# Visualize confusion matrix
sns.heatmap(cm_sc, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### Stacked Generalization Ensemble (with SMOTE)

# %%
import pandas as pd
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

# Define base classifiers
rf_classifier = RandomForestClassifier(random_state=random_seed)
lr_classifier = LogisticRegression(random_state=random_seed)
knn_classifier = KNeighborsClassifier()

# Definir el StackingClassifier
estimators = [
    ('rf', rf_classifier),
    ('lr', lr_classifier),
    ('knn', knn_classifier)
]

stacking_classifier_os = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression(random_state=random_seed))

# Train StackingClassifier with the oversampled dataset
stacking_classifier_os.fit(X_train_os, y_train_os)

# Predict of test
y_pred_sc_os = stacking_classifier_os.predict(X_test)

# Get accuracy
accuracy_sc_os = accuracy_score(y_test, y_pred_sc_os)
print("Precisión:", accuracy_sc_os)
# Out:
# Precisión: 0.8661177188167124

# %%
# Generate ROC curve and calculate AUC
y_pred_prob_sc_os = stacking_classifier_os.predict_proba(X_test)[:, 1]
fpr_sc_os, tpr_sc_os, thresholds_sc_os = roc_curve(y_test, y_pred_prob_sc_os)
auc_sc_os = roc_auc_score(y_test, y_pred_prob_sc_os)

# Plot ROC curve
plt.plot(fpr_sc_os, tpr_sc_os, label='ROC curve (AUC = {:.2f})'.format(auc_sc_os))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Create confusion matrix
y_pred_sc_os = stacking_classifier_os.predict(X_test)
cm_sc_os = confusion_matrix(y_test, y_pred_sc_os)

# Visualize confusion matrix
sns.heatmap(cm_sc_os, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize confusion matrix - Primera vez
fig, axes = plt.subplots(1, 2, figsize=(16, 10))

# Graph 1
sns.heatmap(cm_sc, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix - Stack.Generalization Ensemble WITHOUT Oversampling')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')

# Graph 2
sns.heatmap(cm_sc_os, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Confusion Matrix - Stack.Generalization Ensemble WITH Oversampling')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.show()

# %% [markdown]
# ### ACCURACY AND AUC TABLE SUMMARY

# %%
import pandas as pd

# Define the variables with the models and the desired data
models = ['Logistic Regression', 'k-Nearest Neighbors(k-NN)', 'Support Vector Machines (SVM)', 'Classification Trees', 'Random Forest', 'Ada Boost', 'Gradient Boosting', 'Neural Networks (NN)', 'Stacked Generalization Ensemble']
accuracy = [accuracy_lr, accuracy_knn, accuracy_svm, accuracy_ct, accuracy_rf, test_accuracy_ab, test_accuracy_gb, accuracy_nn, accuracy_sc]
auc = [auc_lr, auc_knn, auc_svm, auc_ct, auc_rf, auc_ab, auc_gb, auc_nn, auc_sc]

# Create a dict
data_summary_no_smote = {
    'Model': models,
    'Accuracy': accuracy,
    'AUC':auc
}

# Create a DataFrame 
df_summary_no_smote = pd.DataFrame(data_summary_no_smote)

print(df_summary_no_smote)
# Out:
#                              Model  Accuracy       AUC
# 0              Logistic Regression  0.892447  0.772308
# 1        k-Nearest Neighbors(k-NN)  0.892244  0.733102
# 2    Support Vector Machines (SVM)  0.893362  0.641034
# 3             Classification Trees  0.894277  0.787629
# 4                    Random Forest  0.896107  0.801033
# 5                        Ada Boost  0.876080  0.620053
# 6                Gradient Boosting  0.897733  0.794340
# 7             Neural Networks (NN)  0.893362  0.789478
# 8  Stacked Generalization Ensemble  0.895395  0.783799

# %%
import pandas as pd

# Define the variables with the models and the desired data
models = ['Logistic Regression', 'k-Nearest Neighbors(k-NN)', 'Random Forest', 'Gradient Boosting', 'Neural Networks (NN)', 'Stacked Generalization Ensemble']
accuracy = [accuracy_lr_os, accuracy_knn_os, accuracy_rf_os, test_accuracy_gb_os, accuracy_nn_os, accuracy_sc_os]
auc = [auc_lr, auc_knn_os, auc_rf_os, auc_gb_os, auc_nn_os, auc_sc_os]

# Create a dict
data_summary_smote = {
    'Model': models,
    'Accuracy': accuracy,
    'AUC':auc
}

# Create a DataFrame 
df_summary_smote = pd.DataFrame(data_summary_smote)

# Mostrar el DataFrame
print(df_summary_smote)
# Out:
#                              Model  Accuracy       AUC
# 0              Logistic Regression  0.787232  0.772308
# 1        k-Nearest Neighbors(k-NN)  0.859815  0.682855
# 2                    Random Forest  0.877402  0.754416
# 3                Gradient Boosting  0.886652  0.755874
# 4             Neural Networks (NN)  0.894582  0.784420
# 5  Stacked Generalization Ensemble  0.866118  0.734844
